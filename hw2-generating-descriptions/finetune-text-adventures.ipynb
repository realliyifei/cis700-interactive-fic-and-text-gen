# %% [markdown]
# ## Data for Learning to Speak and Act in a Fantasy Text Adventure Game
#
#
# Facebook AI Research released a dataset for their paper [Learning to Speak and Act in a Fantasy Text Adventure Game](https://arxiv.org/abs/1903.03094).
#
# Here's paper's abstract:
#
# > We introduce a large-scale crowdsourced text adventure game as a research platform for studying grounded dialogue. In it, agents can perceive, emote, and act while conducting dialogue with other agents. Models and humans can both act as characters within the game. We describe the results of training state-of-the-art generative and retrieval models in this setting. We show that in addition to using past dialogue, these models are able to effectively use the state of the underlying world to condition their predictions. In particular, we show that grounding on the details of the local environment, including location descriptions, and the objects (and their affordances) and characters (and their previous actions) present within it allows better predictions of agent behavior and dialogue. We analyze the ingredients necessary for successful grounding in this setting, and how each of these factors relate to agents that can talk and act successfully.
#
# Their data is called the LIGHT dataset (Learning in Interactive Games with Humans and Text).  It contains 663 locations, 3462 objects and 1755 characters.  I have divided this data into training/dev/test splits.

# %% [markdown]
# ## Load the data
#
# The LIGHT data was released as part of the Facebook's ParlAI system. I extracted the data into several JSON files:
# * ```light_environment_train.json``` contains information about the locations, objects, and characters in the text-adventure games.
# * ```light_dialogue_data.json``` contains sample conversations between pairs of characters.   We'll use this later in the semester.

# %%
# !wget https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class-data/master/light_dialogue/light_environment_train.json
# Out:
# --2022-01-31 21:25:48--  https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class-data/master/light_dialogue/light_environment_train.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3541467 (3.4M) [text/plain]
# Saving to: ‘light_environment_train.json’
#
# light_environment_t 100%[===================>]   3.38M  --.-KB/s    in 0.02s
#
# 2022-01-31 21:25:48 (166 MB/s) - ‘light_environment_train.json’ saved [3541467/3541467]

# %%
import sys
import os
import json

json_filename = 'light_environment_train.json'

f = open(json_filename)
light_environment = json.load(f)

# %% [markdown]
# # LIGHT Environment Data
#
# This section of the Python Notebook will walk you through the LIGHT environment data to show you the different elements of the JSON file.  We will use different pieces of these to fine-tune GPT3 in order to generate new locations and objects for our own text adventure games.

# %% [markdown]
# ### Categories
#
# The locations in LIGHT environment are grouped by categories.
#
# ```
# categories =  light_environment['categories']
#
# categories
#
#  {'11': 'Graveyard',
#  '12': 'Wasteland',
#  '13': 'Abandoned',
#  '14': 'Mountain',
#  '15': 'Cave',
#  '16': 'Tavern',
#  '17': 'Jungle',
#  '18': 'Trail',
#  '19': 'Town',
#  '2': 'Forest',
#  '20': 'Dungeon',
#  '21': 'Inside Cottage',
#  ... }
# ```

# %% [markdown]
# I split the LIGHT environment data into training/dev/test splits based on cateogries.  Here are the categories that ended up in the training partition.

# %%
def get_categories(light_environment):
  return light_environment['categories'].values()

categories = get_categories(light_environment)
print("\n".join(categories))
# Out:
# Forest
# Shore
# Countryside
# Port
# Swamp
# Lake
# Graveyard
# Abandoned
# Cave
# Trail
# Dungeon
# Outside Cottage
# Inside Castle
# Outside Castle
# Inside Church
# Outside Church
# Inside Temple
# Outside Temple
# Inside Tower
# Outside Tower
# Inside Palace
# Outside Palace
# Farm
# city in the clouds
# magical realm
# netherworld
# supernatural
# underwater aquapolis

# %% [markdown]
# ### Rooms
#
# In text-adventure games, locations or settings are often called "rooms".  Rooms have a primary description of the location, a secondary description of the location with its background information, connections to neighboring rooms, and they can contain objects or non-player characters.
#
# Here's what the data structure looks like for a particular room in LIGHT (room number 62, 'An Unfinished Mausoleum', part of the 'Graveyard' category.
#
# ```
# rooms = light_environment['rooms']
# rooms['62']
#
# {'background': "Bright white stone was all the fad for funerary architecture, once upon a time. It's difficult to understand why someone would abandon such a large and expensive undertaking. If they didn't have the money to finish it, they could have sold the stone, surely - or the mausoleum itself. Maybe they just haven't needed it yet? A bit odd, though, given how old it is. Maybe the gravedigger remembers... if he's sober.",
#  'category': 'Graveyard',
#  'description': 'Two-and-a-half walls of the finest, whitest stone stand here, weathered by the passing of countless seasons. There is no roof, nor sign that there ever was one. All indications are that the work was abruptly abandoned. There is no door, nor markings on the walls. Nor is there any indication that any coffin has ever lain here... yet.',
#  'ex_characters': [204, 75, 156, 720],
#  'ex_objects': [1791, 1792, 439],
#  'in_characters': [203, 203],
#  'in_objects': [1790],
#  'neighbors': [108, 109],
#  'room_id': 62,
#  'setting': 'An Unfinished Mausoleum'}
# ```
#
# The **in_objects** and **in_characters** are people and things that are explictly mentioned  listed in the description or the backstory.  The **ex_characters** and **ex_objects** are objects that are possibly present but not mentioned directly. These characters and objects are referenced by a numeric ID which are stored in a seperate part of the LIGHT environment file.

# %% [markdown]
# Here are the rooms that are in the 'Graveyard' category.

# %%
light_environment['rooms']
# Out:
# {'1': {'background': 'The Pine forest is home to many deer and other animals. It is a sanctuary for people escaping the loud city. It is serene and peaceful and many people have found solace here.',
#   'category': 'Forest',
#   'description': 'Very tall and towering pine trees that create a dark canopy of shade. Long skinny trees sway in the sky from the soft breeze. Pine needles scatter the ground like plush carpet.',
#   'ex_characters': [4, 5, 6, 538, 539, 163, 83],
#   'ex_objects': [3, 4, 5, 970, 19, 30],
#   'in_characters': [0, 1, 2, 3, 0, 3],
#   'in_objects': [0, 1, 2, 969],
#   'neighbors': [1, 2],
#   'room_id': 1,
#   'setting': 'Entrance to the Pine trees'},
#  '10': {'background': 'The throne room is the pride and joy of the castle. The king commissioned hundreds of craftsman to construct expensive interior. The king often being important ambassadors to this room to impress with his power',
#   'category': 'Shore',
#   'description': 'ornate and luxurious, the throne room gleams with gold and precious jewels. Priceless painting of past kings line the sides. underneath a vaulted ceiling regal a red carpet connect the throne room entrance to the golden throne itself.',
#   'ex_characters': [31, 32, 33, 34, 35, 36, 570, 120],
#   'ex_objects': [46, 47, 48, 49, 50, 51, 52, 541, 1174],
#   'in_characters': [29, 30, 265, 646],
#   'in_objects': [41, 42, 43, 44, 45, 1172, 1173, 44, 45],
#   'neighbors': [],
#   'room_id': 10,
#   'setting': 'throne room'},
#  '100': {'background': "The Old crypt is located in the middle of the abandoned graveyard.  It's is unkempt and  crumbling around the base with the etched name worn down.  There are old dried vies that are surrounding the crypt showing that it hasn't been entered in quite some time.",
#   'category': 'Graveyard',
#   'description': 'Broken stones and a iron gate closing the entrance with a name placard that the name is worn off.',
#   'ex_characters': [203, 56, 304, 1208, 1209],
#   'ex_objects': [522, 523, 2095, 2096],
#   'in_characters': [],
#   'in_objects': [18, 520, 521, 18, 1114, 2093],
#   'neighbors': [182, 183],
#   'room_id': 100,
#   'setting': 'Old Crypt'},
#  '101': {'background': 'It took many years to build this room.  No other hunter has a room like it, even the king is jealous, those who view this room fear the Duke more than the King. Could there be a conspiracy?  Danger and intrigue live in this room.  You feel it as soon as you enter and view the walls and the ceiling, which compete for your fear and your respect.',
#   'category': 'Inside Castle',
#   'description': "The Show Room Inside the Castle is meant to impress as well as cause fear to whomever enters the room.  The Duke who lives here is a hunter and keeps his captures here.  Some of the thinks preserved and shown on his wall are shocking.  The preserved eyes stare back and let you know the Duke knows no mercy, be careful what you say in this room.  The floor is white like ivory and the walls are also white, but the ceiling is painted and tells a story of the Duke's conquest.",
#   'ex_characters': [306, 307, 228, 1073, 32],
#   'ex_objects': [525, 526, 527, 528, 2099, 2100],
#   'in_characters': [305, 30, 305, 13, 402],
#   'in_objects': [],
#   'neighbors': [184, 185],
#   'room_id': 101,
#   'setting': 'The Show Room Inside the Castle'},
#  '102': {'background': 'The bone pit is rumored to have been originally used by an ancient king to persuade traitors to expose their counterparts.  The king was said to toss the traitors loved ones into the pit, one by one, until he got his answers, eventually tossing the traitor in as well.',
#   'category': 'Outside Temple',
#   'description': 'Grungy and damp, a hole in the ground filled with remains of the fallen. A pungent odor rises from the opening, warding off anyone nearing the area. Ivory spikes with brownish red tips line the outside of the pit.',
#   'ex_characters': [245,
#    227,
#    309,
#    310,
#    296,
#    311,
#    312,
#    125,
#    1131,
#    1211,
#    710,
#    709],
#   'ex_objects': [531, 61, 114, 532, 931, 1573],
#   'in_characters': [308, 30, 604, 308, 1210],
#   'in_objects': [529, 530, 529, 2101],
#   'neighbors': [186, 187],
#   'room_id': 102,
#   'setting': 'bone pit'},
#  '103': {'background': 'The Great Hall is the room in the castle where all can meet and dine. The king sits at a higher dining table than the rest overlooking servants at lower tables. The king meets with all leaders and visitors here.',
#   'category': 'Inside Tower',
#   'description': 'Large room with vast ceilings for meetings and dining. There is a large ornate table at the head of the room for the king and his guest overlooking smaller tables for the servants.',
#   'ex_characters': [315, 316, 32, 509, 1212],
#   'ex_objects': [120, 538, 539, 540, 541, 2104, 2105, 2106],
#   'in_characters': [265, 313, 33, 188, 314, 30, 33, 314, 188],
#   'in_objects': [533, 534, 535, 2102, 534, 2103],
#   'neighbors': [188, 189],
#   'room_id': 103,
#   'setting': 'The Great Hall'},
#  '104': {'background': 'This is a room where scribes and royalty alike come to gain knowledge.  They use this room to study texts containing law and history.',
#   'category': 'Inside Castle',
#   'description': 'A fairly plain looking room compared to the rest of the castle.  In here are many musty shelves of books along with some scientific and writing instruments.',
#   'ex_characters': [319, 320, 396, 1213],
#   'ex_objects': [546, 445, 1722, 2107, 1144],
#   'in_characters': [317, 318, 317, 318],
#   'in_objects': [542, 543, 129, 544, 545, 543, 129],
#   'neighbors': [135, 190],
#   'room_id': 104,
#   'setting': 'Library'},
#  '105': {'background': 'This is where all those who worship come through.  They are greeted by the impressive statues standing outside the temple.',
#   'category': 'Outside Temple',
#   'description': 'There are religious statues standing outside this temple.  The outside of the temple is fairly plain itself and imposing looking.  The floor is made out of stone with a bridge leading to the entrance.',
#   'ex_characters': [120, 322, 723, 430],
#   'ex_objects': [549, 550, 551, 388, 2108],
#   'in_characters': [321],
#   'in_objects': [547, 548, 547],
#   'neighbors': [136, 191],
#   'room_id': 105,
#   'setting': 'Main entrance'},
#  '108': {'background': "This seashore is the pride and joy of the nearest town.  It's kept immaculately clean and the white sand is something that is readily boasted about.",
#   'category': 'Shore',
#   'description': 'The coast seems to stretch on for miles in either direction.  The ocean itself has receded some and the tide has not yet rolled in.  The water laps half-heartedly at the sand and the glistening shades of seashells dot the wet sand.  All around the sand gleams a shade of white.',
#   'ex_characters': [329, 330, 1219, 1220],
#   'ex_objects': [563, 2119, 2120],
#   'in_characters': [],
#   'in_objects': [91, 281, 2118],
#   'neighbors': [197, 198],
#   'room_id': 108,
#   'setting': 'Coast'},
#  '109': {'background': 'The bell is rung daily at high noon. It also tolls when someone has died or married',
#   'category': 'Inside Church',
#   'description': 'The Bell Tower is steep and rises high above the building. The stairs are made of rickety wood and go up thirty stories. The bell is so old that the cracks seem almost perfectly set in the iron.',
#   'ex_characters': [56, 75, 1222, 155, 154, 1223, 156, 304],
#   'ex_objects': [129, 72, 204, 424, 1991, 40, 1442],
#   'in_characters': [1221],
#   'in_objects': [128, 2121, 1138, 755],
#   'neighbors': [199],
#   'room_id': 109,
#   'setting': 'Bell Tower'},
#  '11': {'background': 'The stream was created by rainfall. The water in the sky was becoming raindrops in the clouds and then it fell to the earth. The water accumulates as it flows down from higher elevations. The areas where the water is accumulated is called stream or river.',
#   'category': 'Forest',
#   'description': 'The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.',
#   'ex_characters': [39, 40, 168, 651],
#   'ex_objects': [61, 62, 18, 453],
#   'in_characters': [37, 38, 37, 38],
#   'in_objects': [53, 56, 57, 60, 91],
#   'neighbors': [11, 12],
#   'room_id': 11,
#   'setting': 'The stream'},
#  '110': {'background': "The man that lived in the cottage had built it with his own two hands so long ago that nobody could remember a time he didn't live there. He hosted many dinner parties in the home, although it seemed small it could fit many people.",
#   'category': 'Countryside',
#   'description': 'The small cottage was white with two, shuttered windows. It was in the unique shape of a circle and was built of plaster. Smoke billowed from the chimney.',
#   'ex_characters': [332, 193, 1224, 1225],
#   'ex_objects': [566],
#   'in_characters': [331, 331],
#   'in_objects': [564, 565, 564, 565],
#   'neighbors': [200],
#   'room_id': 110,
#   'setting': 'Cottage'},
#  '111': {'background': 'the bedding room was used as tradition for the royal family to hold meetings there.',
#   'category': 'Inside Palace',
#   'description': 'silks everywhere alongside a huge bed that fit twenty people, the bed was red and yellow silks full of women. There was gold cups everywhere filled with red wine.',
#   'ex_characters': [188, 29, 87, 209, 1226],
#   'ex_objects': [485, 246, 642, 352],
#   'in_characters': [333, 146, 333, 146],
#   'in_objects': [567, 568, 51, 569, 567, 202, 51, 569, 276],
#   'neighbors': [201],
#   'room_id': 111,
#   'setting': 'the bedding room'},
#  '113': {'background': 'A great battle once held here. The battle was not between Soldiers and knights. But by wizards and strange ones. It is said to be haunted for the most part, but tales have been told that men have received great visions of wisdom while walking the meadow.',
#   'category': 'Countryside',
#   'description': 'Large clear outdoor meadow. Flowers of blue and white appearing in bunches here and there. The grass glows with a green light. Not much can be said about its appearance, however there is a mystical allure associated with the place as if a meadow for spirits instead of livestock.',
#   'ex_characters': [335, 336, 337, 1230],
#   'ex_objects': [574, 575, 2129, 2130],
#   'in_characters': [1229],
#   'in_objects': [115, 116, 2128],
#   'neighbors': [203, 204],
#   'room_id': 113,
#   'setting': 'Meadow'},
#  '115': {'background': "This room inside the palace is the Queen's bed chambers. In this very room lived the previous queens of other eras and where the future heir to the throne was born. It's said in these chambers the Queen performs rituals unknown to anyone outside of the palace to keep her young and immortal. Only royalty and royal servants know the secrets of this place.",
#   'category': 'Inside Palace',
#   'description': "This is a beautiful room inside of the palace that is decorated with the finest silk and velvet. The color scheme used represents royalty, royal blue, red, green and purple. The walls are covered in gold and in each corner of the room are golden statues of Greek art. The floors are covered in marble, and despite the patterns, shine so brightly you can even see your own reflection in them! There's also a bed big enough to fit five people on!",
#   'ex_characters': [342, 343, 1237, 253, 509, 87],
#   'ex_objects': [485, 89, 2136, 2137],
#   'in_characters': [340, 341, 340, 1235, 1236],
#   'in_objects': [584, 585, 586, 2134, 585, 2135],
#   'neighbors': [207, 208],
#   'room_id': 115,
#   'setting': "The Queen's Chamber"},
#  '116': {'background': 'This is a room used for storing the belongings of prisoners as well as keeping paper records of those who come through.  Some get their belongings back if they make it out alive.',
#   'category': 'Dungeon',
#   'description': "This is a plain stone room with many trunks piled high.  There's tables with paper records stacked high along with writing instruments.",
#   'ex_characters': [344, 320, 921, 1238],
#   'ex_objects': [590, 591, 668, 1663],
#   'in_characters': [282],
#   'in_objects': [587, 175, 588, 587, 175, 588],
#   'neighbors': [209, 210],
#   'room_id': 116,
#   'setting': 'Storage room'},
#  '117': {'background': 'The alchemist masquerades as a simple noble man, living in the tower with his family and court. Secretly, he is an evil alchemist who is plotting strange things in this hidden tower chamber.',
#   'category': 'Inside Tower',
#   'description': 'The alchemists lab is a hidden, mysterious chamber at the top of the tower. There are all sorts of beakers and potions laid out on wooden tables. Smoke and light emanate from the experiments. A large shelf holds jars of strange ingredients, and in the center of the room there is some sort of huge vat of brewing liquid, bubbling and steaming.',
#   'ex_characters': [347, 348, 349, 1240, 1241],
#   'ex_objects': [600, 2141],
#   'in_characters': [345, 346, 1239],
#   'in_objects': [592, 594, 595, 597, 599, 2138, 2139, 175, 1474, 1500, 2140],
#   'neighbors': [211, 212],
#   'room_id': 117,
#   'setting': 'Alchemists Lab'},
#  '12': {'background': 'The treasure room is the most sacred room inside the castle. This room was created hundreds of years ago to house and protect an ancient magical crystal that was found in the heart of a mystical dragon. Ever since then more and more pieces of treasure have been secured inside the room.',
#   'category': 'Inside Castle',
#   'description': 'It is home to all the most valuable and legendary pieces of fortune that have been collected by the kingdom over hundreds of years. It contains many treasure chests filled to the brim with gold. Necklaces strewn about made from every type of valuable material imaginable. Legendary swords made from the greatest sword makers in all of the lands. Pieces of armor worn by the mightiest warriors that have ever lived are lined up meticulously on one of the walls.',
#   'ex_characters': [41, 42, 13, 210, 656],
#   'ex_objects': [69, 1191, 1192],
#   'in_characters': [653, 654, 655],
#   'in_objects': [63, 64, 65, 67, 1187, 41, 64, 1188, 1189, 1190],
#   'neighbors': [13, 14],
#   'room_id': 12,
#   'setting': 'Treasure Room'},
#  '120': {'background': 'The dungeon was created to keep prisoners and challengers to the thrones for periods of time. The royalty felt it was less expensive to leave them there without eating and meet their fate down there. As time went on, more and more people were lost to the dungeon and it began to be darker and darker.',
#   'category': 'Inside Palace',
#   'description': 'The dungeon is in the very most bottom room of the Palace. Many have gone down to the dungeon through the trap doors inside the palace and have never returned. Walls are covered with spider webs and bones from previous challengers to the throne. The brick dungeon is dark and mysterious.',
#   'ex_characters': [356, 357, 841, 1247, 1248],
#   'ex_objects': [615, 2148],
#   'in_characters': [282, 354, 355, 3, 282, 1246],
#   'in_objects': [611, 612, 613, 132, 132],
#   'neighbors': [217, 218],
#   'room_id': 120,
#   'setting': 'The Dungeon'},
#  '122': {'background': 'This room was designed by a team of the finest decorators in the kingdom, but it has been nicknamed the bloodbath, because the king put to death 3 designers for "not meeting the standard set forth".  The fourth designer, a young upstart, is now the most famous in the land because of his work on this one room.  The king feels most powerful when he is in this room.',
#   'category': 'Inside Palace',
#   'description': "The large four poster bed is adorned with the finest linens that Europe has to offer.  Gold is liberally woven through the fabric of the duvet and the tassels that drape to the floor on each corner of the duvet.  A gauzy purple fabric hanging from the bed posts sets an opaque tone to the room.  One window is shuttered by large wooden planks that can be thrown open to allow the mid day light to illuminate the room.  A large chest of drawers holds a small portion of the King's clothing.",
#   'ex_characters': [302, 362, 32, 1252],
#   'ex_objects': [632, 633, 246],
#   'in_characters': [265, 30],
#   'in_objects': [623,
#    624,
#    625,
#    626,
#    627,
#    628,
#    247,
#    629,
#    630,
#    631,
#    623,
#    624,
#    247,
#    629,
#    630],
#   'neighbors': [220, 221],
#   'room_id': 122,
#   'setting': 'Kings chambers'},
#  '124': {'background': 'The fae inhibit this small cot hidden in the brush of the forest. These small creatures slowly add new brush and decorations to their den as they scavenge the forest for food and supporting their animal friends. The small den lies just a short distance east of the lake with the door facing the lake. One might easily miss it with a quick glance as many bushes and glowing flowers are outside of it.',
#   'category': 'Forest',
#   'description': 'The entryway to the brush den is made of arched bushes and various plants, as is the ceiling and walls. The inside is furnished with seats made of plant roots that have grown together, and a table made of wood adorned with flowers and wooden cups and plates. A small vine dangles with a glowing floor from the middle of the ceiling that lights the room dimly. Three small beds lay in one corner of the room made of interlaced grass and leaves.',
#   'ex_characters': [75, 366, 138, 933],
#   'ex_objects': [2167],
#   'in_characters': [365, 365],
#   'in_objects': [639,
#    640,
#    314,
#    19,
#    641,
#    642,
#    79,
#    639,
#    640,
#    225,
#    186,
#    2163,
#    246,
#    79,
#    2165],
#   'neighbors': [224, 225],
#   'room_id': 124,
#   'setting': 'The Brush Den'},
#  '125': {'background': 'This is gods country. No man could have anything this beautiful. The local government knew it and had this area set away as a protected area years ago.',
#   'category': 'Countryside',
#   'description': 'Green large trees surround the meadow that if filled with beautiful seasonal flowers. A deer is grazing in the far end of the field. A small dirt country road gentle crooks past on the outside of the road.',
#   'ex_characters': [368, 84, 335],
#   'ex_objects': [645, 646, 1649, 867],
#   'in_characters': [367, 0],
#   'in_objects': [2168, 2169, 2170],
#   'neighbors': [226, 227],
#   'room_id': 125,
#   'setting': 'Lush meadow in the country side'},
#  '126': {'background': 'The quicksand pit is relatively unknown by villagers because those that fall victim to the pit never make it out to tell its location. The pit swallows up 100 villagers a year on average. The villagers chalk up this statistic to a monster known as Bigfoot, snatching and eating people up while they sleep.',
#   'category': 'Swamp',
#   'description': 'A large, gurgling pit of quicksand. Many adventurers and poor critters lie at the bottom of the pit. The pit is surrounded by an extensive swampland and is shielded by the many trees and shrubs that surround it.',
#   'ex_characters': [63, 373, 136, 560, 1255, 103],
#   'ex_objects': [168, 203, 40, 454],
#   'in_characters': [370, 371, 171, 372],
#   'in_objects': [20, 647, 20, 647],
#   'neighbors': [228, 229],
#   'room_id': 126,
#   'setting': 'Quicksand Pit'},
#  '127': {'background': 'The sanctuary was built hundreds of years ago, paid for by a rich local family who was known for being very religious.  The sanctuary took 6 months to completely build.',
#   'category': 'Inside Church',
#   'description': 'Enthroned in lavish hues of red and gold, the sanctuary is filled with candles and statues.  Enveloped by a high decorating ceiling, the sanctuary glistens with the sparkling golden adornments.',
#   'ex_characters': [56, 374, 375, 56, 390, 461],
#   'ex_objects': [649, 650, 179, 1060, 541],
#   'in_characters': [],
#   'in_objects': [120, 47, 648, 120, 2173, 225, 2174],
#   'neighbors': [230, 231],
#   'room_id': 127,
#   'setting': 'Sanctuary'},
#  '128': {'background': 'This room is where dark rituals are performed for members of the Cult of the Doomed. The kingdom has yet to know of their dark practices and the cult hopes that stays that way.',
#   'category': 'Inside Temple',
#   'description': 'A room with a solid block stone in the middle with steps leading up to it. Candle stands surround the center with 4 candle holders on each stand. A red carpet leads to the steps to the center of the room.',
#   'ex_characters': [75, 56, 1257, 103],
#   'ex_objects': [653, 72, 1588],
#   'in_characters': [376, 1256],
#   'in_objects': [652, 44, 2176, 44],
#   'neighbors': [232],
#   'room_id': 128,
#   'setting': 'The ritual room'},
#  '13': {'background': 'Not many people go to the stable because they have the stable hand bring the horses to the entrance of the castle. It leaks and is falling into disrepair. For the stable hand it is home. There is a sense of comfort in the drab old building with the gorgeous horses.',
#   'category': 'Outside Castle',
#   'description': 'It is dull to look at. The stable has hay laying everywhere, grey stones making the walls, and large heavy wooden beams hold up the ceiling. So, everything is brown or grey or other shades that bore. There are sections for horses made of wood but looks rickety.',
#   'ex_characters': [43, 44, 663, 365],
#   'ex_objects': [72, 73, 1202, 1203, 1204],
#   'in_characters': [662, 252],
#   'in_objects': [70, 18, 12, 71, 73, 186, 12],
#   'neighbors': [15, 16],
#   'room_id': 13,
#   'setting': 'Horse stables'},
#  '130': {'background': "The temple entrance is the only way to enter the temple of the Gods.  It was constructed a year after the temple was built to keep out the evil that didn't belong.",
#   'category': 'Outside Temple',
#   'description': 'The Temple Entrance is a large arch lined in ancient stones. There is a long walkway flanked by lighted torches. Immediately in front of the interest there is a surface with 5 rocks of different shapes and textures. To enter the temple, one must input the correct "code" by moving the rocks in front of to the correct spots.',
#   'ex_characters': [228, 77, 1260, 1261],
#   'ex_objects': [658, 119],
#   'in_characters': [385],
#   'in_objects': [657, 2182, 2183, 2185],
#   'neighbors': [234, 235],
#   'room_id': 130,
#   'setting': 'Temple Entrance'},
#  '131': {'background': 'The nursery was designed by the queen. All of the children of the castle have spent time being nurtured and raised in the room. Nurses take care of the children here.',
#   'category': 'Inside Palace',
#   'description': 'The nursery is a room dedicated to the care of the young children living in the palace. The ceilings are decorated with a painting of cherubic angel babies playing in clouds. There are luxurious baby bassinets, rocking chairs with cushions, fireplaces to keep the place warm and many toys all over the place. Windows framed in simple drapes offer views of the gardens outside.',
#   'ex_characters': [388, 389, 1262, 1263],
#   'ex_objects': [666, 667, 2190, 2191, 2193],
#   'in_characters': [386, 32, 387, 387],
#   'in_objects': [659, 661, 662, 2085, 2188, 2189, 248],
#   'neighbors': [236, 237],
#   'room_id': 131,
#   'setting': 'Nursery'},
#  '132': {'background': 'The rectory is one of the most important rooms in the church, as it is where the priest and others get ready before they start church, where the put on robes and cassocks and the like. It is vital to the church as a matter of fact. Visibility to the room is blocked off by the altar in front of it, so church goers cannot see it unless they walk behind the altar. It seems to be used as a bit of a storage area for religious artifacts.',
#   'category': 'Inside Church',
#   'description': "This room is quite small and cramped. It's about the size of maybe three wooden carts, which is to say, it's very small. There are boxes all over the place and many candles and other church accessories. There are several big robes hanging next to what looks like a very small closet. Some candles shed an eerie light on the room, flickering softly. There is a small cabinet with several religious tapes and records and a few books. A book case is near and contains many common religious texts.",
#   'ex_characters': [390, 55, 1264, 1265],
#   'ex_objects': [674, 675, 676, 246, 2198, 2199],
#   'in_characters': [56, 56],
#   'in_objects': [668,
#    120,
#    255,
#    120,
#    670,
#    671,
#    129,
#    673,
#    668,
#    120,
#    2194,
#    2196,
#    129,
#    2197,
#    330],
#   'neighbors': [238, 239],
#   'room_id': 132,
#   'setting': 'The rectory'},
#  '134': {'background': "Priests and scribes come here to gain knowledge and translate texts.  The day's sermons are also composed here by candle light.",
#   'category': 'Inside Church',
#   'description': 'A plain room with shelves of religious text are stored.  There are tables and chairs situated around the room available for use.  There are some trunks with books stored.',
#   'ex_characters': [396, 397, 398, 1270, 1271],
#   'ex_objects': [685, 686, 2198, 428],
#   'in_characters': [395, 317, 395, 317],
#   'in_objects': [684, 175, 445, 587, 424, 352, 684, 175, 445, 587, 129, 424],
#   'neighbors': [242, 244],
#   'room_id': 134,
#   'setting': 'Study room'},
#  '136': {'background': "This barn was a landmark of the farm.  Withstanding the elements for almost a century, it has kept it's original construct.  Whenever guests come for fresh eggs or milk, the farmer often boasts about it.",
#   'category': 'Farm',
#   'description': 'The old rustic barn was settled on the outermost edge of the farm.  Standing tall over the fields, this two-story red barn cast a long shadow over the field surrounding it.  Large wooden doors that could be propped open with great effort would lead you directly inside.',
#   'ex_characters': [75, 204, 1272, 1273],
#   'ex_objects': [73, 694, 2213, 2214, 2215, 2216, 2217],
#   'in_characters': [212, 43],
#   'in_objects': [693],
#   'neighbors': [247, 248],
#   'room_id': 136,
#   'setting': 'Barn'},
#  '137': {'background': 'A simple little cottage in the woods where a hunter has made his living. The cottage is but a simple place for a everyday man of the time. His blood hound companion guards the front door from intruders.',
#   'category': 'Outside Cottage',
#   'description': 'Furs hang out on racks to try and get ready for tanning. A dog lays in front of the door into the cottage. A little herb garden is on the opposite side of the cottage to the racks.',
#   'ex_characters': [403, 404, 0, 415],
#   'ex_objects': [698, 784, 2219],
#   'in_characters': [154, 402, 402, 154],
#   'in_objects': [695, 318, 2218, 318],
#   'neighbors': [249, 250],
#   'room_id': 137,
#   'setting': 'Front of the Cottage'},
#  '138': {'background': 'The hunting ground is revered among knights. The greatest knights and archers practice day and night slaying pigs. Some say the grounds are even haunted with the spirits of the deceased organisms.',
#   'category': 'Trail',
#   'description': 'The hunting grounds are spacious and full of wildlife. A variety of hogs and oxen cross the grounds every day. The fields are lush with green and the skies always deep blue.',
#   'ex_characters': [407, 408, 0, 353, 1275],
#   'ex_objects': [20, 116, 22, 732],
#   'in_characters': [405, 406, 798, 405, 406, 228, 104, 734, 1274],
#   'in_objects': [699, 699],
#   'neighbors': [252, 253],
#   'room_id': 138,
#   'setting': 'Hunting grounds'},
#  '14': {'background': 'The forest started out as a small amount of plants and then the plants kept growing and growing until they were vast. After the plants were very grown the animals and all the small livings things decided to make some houses in the plants.',
#   'category': 'Countryside',
#   'description': 'The forest has many trees. It has other plants too. There are animals and many livings things. The forest is very much full of life. When you look at it you might only see plants that are green and different shades of brown but there are many other living things in there too.',
#   'ex_characters': [46, 47, 48, 49, 666, 667],
#   'ex_objects': [75, 76, 77, 364, 1206],
#   'in_characters': [37, 45, 37, 665],
#   'in_objects': [20, 74, 20, 74],
#   'neighbors': [17, 18],
#   'room_id': 14,
#   'setting': 'The forest'},
#  '140': {'background': 'The frogs have made a home in the murky waters of the bog because they are able to hide from predators more easily. The seldom need to be on dry ground and there are a surplus of bugs for them to consume. The reeds are so tall that when birds land on them the frogs can see them and swim quickly away.',
#   'category': 'Swamp',
#   'description': 'Frogs croak in the reeds that surround the bog. The water is very murky and underneath the surface tadpoles dart around. There are minimal places to stand to stay dry.',
#   'ex_characters': [38, 103, 83, 474, 185, 1279],
#   'ex_objects': [20, 20, 531],
#   'in_characters': [412, 413, 414, 48, 84, 186, 413, 414, 48, 84],
#   'in_objects': [705, 705, 2227, 91],
#   'neighbors': [256, 257],
#   'room_id': 140,
#   'setting': 'Bog'},
#  '141': {'background': 'This used to be the room of a wealthy noble.  However, due to his poor business decisions, he was forced to flee and leave his home in disrepair.  Vagrants have come to stay over the years and loot whatever was inside.',
#   'category': 'Abandoned',
#   'description': "A dilapidated wooden structure with a caved in roof and debris everywhere.  Even the trees outside the house are falling apart.  There's waist high grass leading to the house along with a dirt path.",
#   'ex_characters': [137, 415, 103, 1282],
#   'ex_objects': [708, 709, 2228, 2229],
#   'in_characters': [1280, 1281],
#   'in_objects': [707, 707, 20],
#   'neighbors': [258, 259],
#   'room_id': 141,
#   'setting': 'Ruined house'},
#  '142': {'background': 'This is a place that no one dares to go to. It is said to be haunted with many ghosts. Many people who have came here never returned home.',
#   'category': 'Swamp',
#   'description': 'A misty, foggy area with the swamp. It is dirty and smelly.',
#   'ex_characters': [417, 418, 370, 664],
#   'ex_objects': [712, 282, 2230, 2231],
#   'in_characters': [416, 20],
#   'in_objects': [710, 711],
#   'neighbors': [260, 261],
#   'room_id': 142,
#   'setting': 'Haunted Swamp'},
#  '143': {'background': "This barn has been on the farm since the very beginning. It was built by the first generation farmer to live on the land over sixty years ago. It has been repainted numerous times and wasn't originally red. It was actually yellow before switching to red.",
#   'category': 'Farm',
#   'description': "This is an old run down red barn. It's two stories and most farmers wouldn't still be using it. It has chickens and cows inside and harvests eggs and milk for the entire family. The second story has a large pile of hay visible through an old opening in the front.",
#   'ex_characters': [75, 209, 734, 1284],
#   'ex_objects': [72, 717, 367, 1228],
#   'in_characters': [43, 1283],
#   'in_objects': [714, 715, 716, 73, 2232],
#   'neighbors': [262, 263, 264],
#   'room_id': 143,
#   'setting': 'The old red barn'},
#  '144': {'background': 'This graveyard is located outside the notorious town of Brimswood.\nThe many atrocities and constant stress filled throughout the town has earned it a reputation for being haunted by many spirits.',
#   'category': 'Graveyard',
#   'description': 'Dim and low lit. The aura from this cemetery emits sadness and pain perpetually. You can feel and sense the eerie nature of the graveyard crawl up your spine. There seems to be a slight fog slowly making its way across the open parts of the cemetery.',
#   'ex_characters': [419, 420, 1285, 1286, 1287],
#   'ex_objects': [719, 720, 2233, 2234, 2235, 2237],
#   'in_characters': [],
#   'in_objects': [718],
#   'neighbors': [265, 266],
#   'room_id': 144,
#   'setting': 'Cemetery'},
#  '145': {'background': 'This room is where the animal sacrifices are burned to satiate the gods. The fire is kept lit year-round. It is extinguished once per year, on the last day of the year, and relit the next day in honor of the new year.',
#   'category': 'Inside Temple',
#   'description': 'The central location of the temple is the altar room. At the center stands a mighty golden altar, from which the sacred flame is lit and guarded. Only the high priest and his supplicants may enter this room.',
#   'ex_characters': [424, 255, 213, 30],
#   'ex_objects': [388, 119, 404, 129],
#   'in_characters': [421, 422, 423, 421, 1288, 789],
#   'in_objects': [722, 722],
#   'neighbors': [267, 268],
#   'room_id': 145,
#   'setting': 'The altar room'},
#  '146': {'background': 'The confessional is used by the clergyman to collect the confessions of the parishioners. However it has secretly been used to gather sensitive information to blackmail the parishioners.',
#   'category': 'Inside Church',
#   'description': 'The room is a small box, composed of sharply cut stone. The room is uncomfortably small, and filled with a lingering scent of something unfamiliar to the occupants.',
#   'ex_characters': [425, 426, 1290, 111, 30, 32],
#   'ex_objects': [724, 725, 726, 2238, 120],
#   'in_characters': [1289],
#   'in_objects': [],
#   'neighbors': [269, 270],
#   'room_id': 146,
#   'setting': 'Confessional'},
#  '148': {'background': 'This is a secret chamber of the temple that not many people know about. It has a dark history, which no archaeologist has had the misfortune to uncover. Human sacrifices were performed her for many centuries.',
#   'category': 'Inside Temple',
#   'description': 'Bones of the damned riddle the floor and every surface inside the room. Blood stains are rampant on table like surface, surfaces once used for human sacrifices. A foul, but faint, odor pervades even the most hardiest of nostrils.',
#   'ex_characters': [56, 430, 174, 474],
#   'ex_objects': [653, 732, 2242, 406, 204, 684],
#   'in_characters': [],
#   'in_objects': [731, 246, 731, 891],
#   'neighbors': [273, 274],
#   'room_id': 148,
#   'setting': 'Sacrifice Chamber'},
#  '15': {'background': 'After years of renovations to other part of the complex, the rectory remains the oldest piece of the property. A close-knit order of monks had built the rectory hundreds of years ago as a way to house the workers and perhaps any wayward souls. All who work here, including sometimes the head priest, sleep here.',
#   'category': 'Inside Church',
#   'description': 'The rectory is very fragile and rickety due to age and various periods of neglect. Everything is wood-based and scratched up and chipped, including the beds strewn about. The clergymen would call it "cozy" but the space within is almost claustrophobic.',
#   'ex_characters': [55, 56, 57, 58, 59, 60, 692],
#   'ex_objects': [80, 81, 82, 1231, 1232],
#   'in_characters': [50, 51, 52, 53, 54, 688, 689, 690, 54, 691],
#   'in_objects': [78, 79, 1229, 1230],
#   'neighbors': [19, 20],
#   'room_id': 15,
#   'setting': 'Rectory'},
#  '150': {'background': 'The Royal Gardens were conceptualized by the late great Queen. She wanted a beautiful promenade to walk her dogs and converse with her bed maids about court gossip. It was originally commissioned to be 1/2 an acre but has been expanded as time has gone on.',
#   'category': 'Outside Palace',
#   'description': "Lined with rose bushes that look as if they have been watered by the God's, the Royal Gardens is a beauty to behold. An intricate labyrinth made of shrubs is at the center ending with a fountain. There are various benches on the sides of the rose bushes and a small lake in the back drop.",
#   'ex_characters': [434, 435, 13, 247],
#   'ex_objects': [744, 745, 1102, 2247],
#   'in_characters': [210],
#   'in_objects': [739, 740, 650, 741, 742, 739, 647, 650, 741, 742],
#   'neighbors': [277, 278],
#   'room_id': 150,
#   'setting': 'Royal Gardens'},
#  '151': {'background': "the room in the high tower is used for the king's private prison room for traitors.",
#   'category': 'Inside Tower',
#   'description': 'it has old gray brick and it is hard to breathe because it is so high up in the sky, there are old skeletons there from previous prisoners.',
#   'ex_characters': [137, 103, 26, 228, 31],
#   'ex_objects': [202, 747, 961, 1355, 774],
#   'in_characters': [923, 308],
#   'in_objects': [746, 168],
#   'neighbors': [279],
#   'room_id': 151,
#   'setting': 'prison room'},
#  '152': {'background': 'This inside tower is used as a guards hangout. It allows the guards to have a place to call their own. They sleep here between shifts and sometimes eat here.',
#   'category': 'Inside Tower',
#   'description': 'The inside tower is made from a combination of wood and brick. It also has some metal to hold all the doors in place. There are three doors and a staircase that leads up to the guards quarters.',
#   'ex_characters': [436, 437, 33, 228],
#   'ex_objects': [388, 750, 79, 546],
#   'in_characters': [26, 26],
#   'in_objects': [748, 2248],
#   'neighbors': [280, 281],
#   'room_id': 152,
#   'setting': 'Tower'},
#  '154': {'background': 'This tower was made by the lands lord, as a watchtower the first defense and first response. It its considered an honor to be on tower watch, and light the signal fire to warn the nearby town and castle of pending danger!',
#   'category': 'Outside Tower',
#   'description': 'Wide flat landscape. Wonderful view, stretching out for miles. Strong tower made of stone, small hills and mounds throughout the landscape. Large stairs inside the tower leading to the top.',
#   'ex_characters': [75, 43, 439, 275, 228, 30],
#   'ex_objects': [756, 153, 757, 49, 190, 40],
#   'in_characters': [1296],
#   'in_objects': [594, 753, 755, 204, 755, 594, 2251],
#   'neighbors': [284, 285],
#   'room_id': 154,
#   'setting': 'Top side tower overlooking view'},
#  '155': {'background': 'The stables were built when the castle was built. The king was particularly fond of horses and so he requested a very studious stable to fill with the highest quality horses. The horses who live there are all very healthy, strong and skilled.',
#   'category': 'Outside Castle',
#   'description': 'The royal stables hold all of the horses of the noble people living in the castle. They are very well constructed, consisting of expert mason work and fixtures of some sort of heavy, forest-scented wood. Each horse has a large stall, lined with fresh hay replenished by stable hands daily. On the walls of stable, there are tools used to care for and groom the horses, hung on hooks. The stables are lit by lanterns hung throughout the stables.',
#   'ex_characters': [441, 156, 1297, 1298],
#   'ex_objects': [764, 2253, 2254],
#   'in_characters': [252, 440, 30, 252],
#   'in_objects': [759, 760, 73, 72, 761, 762],
#   'neighbors': [286, 287],
#   'room_id': 155,
#   'setting': 'Royal stables'},
#  '157': {'background': 'This area is used by the local wild life to bask in the sun.  Some peasants come here to fish and relax at the end of a long day.',
#   'category': 'Forest',
#   'description': 'A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.',
#   'ex_characters': [76, 204, 38, 168, 84, 1299],
#   'ex_objects': [249, 770, 19, 1392, 705, 1393],
#   'in_characters': [77, 185, 186, 798, 77],
#   'in_objects': [768, 769, 91, 20, 61],
#   'neighbors': [290, 291],
#   'room_id': 157,
#   'setting': 'Pond'},
#  '158': {'background': 'the fountain used to have water and it was well taken care of but the village was abandoned and therefore grass and weeds grew everywhere.',
#   'category': 'Graveyard',
#   'description': "the fountain is the only thing you can hear in the graveyard. It's eerily quiet, not even a bird chirping. The fountain is teen feet high, and it is dry as a desert. It makes the graveyard more eerie than any other one.",
#   'ex_characters': [83, 137, 1300, 1301],
#   'ex_objects': [771, 1982, 439],
#   'in_characters': [],
#   'in_objects': [650, 30, 116, 2258],
#   'neighbors': [292],
#   'room_id': 158,
#   'setting': 'the fountain'},
#  '159': {'background': 'The dungeon was initially created for only the worst enemies of the king, but with the rise of crime and corruption within the kingdom, it is now populated by even the most petty of criminals. Simply looking at a guard the wrong way can land you in the dark abysses of the cruel dungeon. An escape tunnel is believed to exist somewhere within, but the darkness makes it impossible to find, even for the guards.',
#   'category': 'Dungeon',
#   'description': 'The castles dungeon lay buried below the village on the outskirts of the castles garden. Only the guards have access to light, and light is given as a privilege. The interior is stone and smells of mildew and deadly black mold.',
#   'ex_characters': [444, 32, 445, 204, 137, 311],
#   'ex_objects': [773, 154, 774, 1353, 704, 961, 2260],
#   'in_characters': [443, 265, 254, 100, 26, 1302, 100],
#   'in_objects': [2259],
#   'neighbors': [293, 294],
#   'room_id': 159,
#   'setting': 'Dungeon within a castle'},
#  '16': {'background': 'This church has stood for over five hundred years. Many people have knocked on its doors looking for protection or service. It is commanding, yet welcoming.',
#   'category': 'Outside Church',
#   'description': 'The door stands twenty feet tall. It is made of metal with a large knocker at eye level. There is a small sliding window covered with metal so that people inside can slide it and see who is knocking. The door has three large rectangles made of rivets, one high, one in the middle, and one low.',
#   'ex_characters': [61, 62, 174, 700],
#   'ex_objects': [85, 1244],
#   'in_characters': [],
#   'in_objects': [83, 84, 1241, 247, 1242],
#   'neighbors': [21, 22],
#   'room_id': 16,
#   'setting': 'Enormous church entrance door'},
#  '160': {'background': 'This outside tower is used to guard the castle. This is at the front of the castle and always has many guards working there.',
#   'category': 'Outside Tower',
#   'description': 'This outside tower is made from big stones. It is grey with wood trim. There is one glass window that is used as a lookout tower.',
#   'ex_characters': [73, 446, 1015, 1303, 265],
#   'ex_objects': [778, 779, 2263, 2264],
#   'in_characters': [26, 26],
#   'in_objects': [776, 2261, 776, 2262, 336],
#   'neighbors': [295, 296],
#   'room_id': 160,
#   'setting': 'Tower'},
#  '161': {'background': "The gold mine use to be full of glittering gold, shining all around. The miners  were in their by large numbers, picks in their hand, pounding at the walls. It was known for producing gold nuggets the size of a man's palm.",
#   'category': 'Abandoned',
#   'description': 'The entrance is very unstable, with parts falling to the ground. As you enter, the walls have been crudely chipped away to make the path to the old mine. There is trash from the previous miners scattered on the dirt ground. Rocks are all around the area, where one would stumble as they go inside. It used to be a very productive gold mine, now falling to bits. There are broken lanterns, with shattered glass.',
#   'ex_characters': [204, 75, 1304, 1305],
#   'ex_objects': [783, 784, 2266, 887],
#   'in_characters': [447],
#   'in_objects': [216, 781, 2265, 781],
#   'neighbors': [297, 298],
#   'room_id': 161,
#   'setting': 'Gold Mine'},
#  '162': {'background': 'This is a plain building where business matters of the graveyard are conducted.  Peasants and royalty alike come here to make deals to bury their loved ones in the graveyard.',
#   'category': 'Graveyard',
#   'description': 'The building itself is ordinary in appearance and is somewhat foreboding.  It is surrounding by a dense fog and high grass.  Sometimes, one can hear whispers in the wind.',
#   'ex_characters': [448, 449, 1306, 1307],
#   'ex_objects': [20, 790, 2268, 1428],
#   'in_characters': [132, 318],
#   'in_objects': [785, 786, 787, 789, 787, 2267],
#   'neighbors': [299, 300],
#   'room_id': 162,
#   'setting': 'Reception area'},
#  '163': {'background': 'The beach house was built by the king as a means to escape the stress of rule. He goes there every summer and throws raging parties out on the magnificent pier. Few know of this lavish getaway, but those that do are marveled by its opulence.',
#   'category': 'Shore',
#   'description': 'A marvelous beach house that sits upon the fine white sand of the beach. It looks mighty expensive, as the house has solid gold walls. A gigantic and lavish marble pier extends into the ocean out in front of the house.',
#   'ex_characters': [451, 452, 33, 228, 212, 32],
#   'ex_objects': [796, 797, 2272, 845, 2273, 2274],
#   'in_characters': [265, 30],
#   'in_objects': [792, 793, 794, 795, 2270, 281, 186, 2271, 1413],
#   'neighbors': [301, 302],
#   'room_id': 163,
#   'setting': 'Beach House'},
#  '164': {'background': 'The northern shore is a common place for locals to come cool off on warm days. It also serves as a place where women will wash their clothes and any other dirty linens they may have. This is somewhat of a sacred place for a few, mainly those who worship the water gods, as they have erected a small alter to them just off the water.',
#   'category': 'Lake',
#   'description': 'The lake gives way to a slightly sandy and rocky shore. It is dotted with small shrubs and a few trees, but mostly it is a fairly open expanse. It is covered in places by a green short grass. The lake level falls away swiftly from the beach going from a few feet to well over ten feet in a short span.',
#   'ex_characters': [74, 31, 456, 174, 457, 67, 395],
#   'ex_objects': [806, 120, 703],
#   'in_characters': [453, 333, 454, 455, 453, 333],
#   'in_objects': [798, 799, 20, 800, 801, 803, 799, 20, 800, 803],
#   'neighbors': [303, 304],
#   'room_id': 164,
#   'setting': 'Northern Shore'},
#  '165': {'background': "The prisoner's cell includes the zone by which the castle dumps and locks up prisoners. These can be prisoners of war or defectors. There are tales that the cell is haunted and even houses ghosts.",
#   'category': 'Dungeon',
#   'description': "The prisoner's cell is incredibly dreary and dark. The walls are black and made of cobblestone. The atmosphere and smell are damp and repugnant.",
#   'ex_characters': [459, 426, 460, 1308, 103],
#   'ex_objects': [807, 1355, 961],
#   'in_characters': [458, 282, 20],
#   'in_objects': [],
#   'neighbors': [305, 306],
#   'room_id': 165,
#   'setting': "Prisoner's cell"},
#  '166': {'background': 'Made 100 years ago, this chapel has a long history in this town. people have gathered here to worship for 3 generations!',
#   'category': 'Inside Church',
#   'description': 'Quiet and serene, the chapel is lined with oak pews where worshipers can sit',
#   'ex_characters': [235, 236, 235, 809],
#   'ex_objects': [814, 1428, 2276],
#   'in_characters': [461, 3, 461],
#   'in_objects': [810, 811, 812, 811],
#   'neighbors': [307, 308],
#   'room_id': 166,
#   'setting': 'The Chapel'},
#  '167': {'background': 'This small office is where the bishop tends to people who needs help. They come and he offers them guidance. He prays for their souls.',
#   'category': 'Inside Temple',
#   'description': 'It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.',
#   'ex_characters': [167, 56, 807, 87],
#   'ex_objects': [819, 820, 455, 1144],
#   'in_characters': [462, 3, 55, 3],
#   'in_objects': [815, 816, 445, 817, 818, 923, 1501, 445, 2277, 1474],
#   'neighbors': [309, 310],
#   'room_id': 167,
#   'setting': "Clergyman's office"},
#  '168': {'background': 'The great tower in the kingdom has held visage over the royal city for many years. Every guard would give their live to keep the tower standing. If the tower to ever fall the Royal city will surely fall with the tower.',
#   'category': 'Inside Tower',
#   'description': "The near top of the tower 6 feet before the very top. Where the watchers keep their eye out for trouble. It's made of stone and has doors to several places including the outside. there are weapons from all over the world held within the armory.",
#   'ex_characters': [75, 246, 1310, 104],
#   'ex_objects': [732, 821, 1056, 455],
#   'in_characters': [255, 1309],
#   'in_objects': [748, 119, 748, 119],
#   'neighbors': [311, 312],
#   'room_id': 168,
#   'setting': 'The armory'},
#  '169': {'background': 'No one knows what the purpose of this mushroom is. The villagers claim that the witch houses trespassers in here when she turns them into smurfs. Others believe that the witch keeps her mangy mutt inside.',
#   'category': 'Outside Cottage',
# ...
#   'ex_characters': [1602, 1580],
#   'ex_objects': [3797, 3357],
#   'in_characters': [1679],
#   'in_objects': [3667, 3486, 3612, 3445, 2979, 3430, 3708, 3635, 3056, 3712],
#   'neighbors': [1285, 1286],
#   'room_id': 774,
#   'setting': 'The dungeon'},
#  '775': {'background': 'The Geothermal Valley is place where one can come and heal with the minerals and heat that perminates through the body and soul. It is the main attraction in the underwater aquapolis.',
#   'category': 'underwater aquapolis',
#   'description': 'Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.',
#   'ex_characters': [1774, 1737],
#   'ex_objects': [3912, 3303],
#   'in_characters': [],
#   'in_objects': [],
#   'neighbors': [1287, 1288],
#   'room_id': 775,
#   'setting': 'Geothermal Valley'},
#  '78': {'background': 'The Princess was gifted this library for her 16th birthday. She longed to travel and see the world, but will be limited as she is the only heir to the throne. Sensing her longing for more, her kindly father, the King, bestowed upon her the gift of knowledge and escapism.',
#   'category': 'Inside Palace',
#   'description': 'Warm and well lit, this room is equal parts windows and bookshelves. Overflowing with books, maps, parchment, and other odds and ends the shelves sag slightly from the weight. The lush maroon carpet complements the dark oak wood paneled walls, which are lined with rich tapestries.',
#   'ex_characters': [248, 87, 210, 1133],
#   'ex_objects': [1962, 120],
#   'in_characters': [247, 13, 1132, 875],
#   'in_objects': [129, 406, 82, 407, 408, 129, 406, 82, 1961, 407, 408],
#   'neighbors': [142],
#   'room_id': 78,
#   'setting': "Princess' Library"},
#  '80': {'background': 'This staircase was built by the great grandfather of the current king. At the top of the staircase, in the highest tower, lies an vital scroll that holds the secret to protecting the castle.',
#   'category': 'Inside Tower',
#   'description': 'Made of strong granite and oak timbre, it ascends to the highest room in the tower. The granite glitters in the light from the torches that line the walls. The oak is sleek and coated in a glistening protectant.',
#   'ex_characters': [255, 256, 33, 32, 1141],
#   'ex_objects': [153, 119, 1970, 1971],
#   'in_characters': [30, 30],
#   'in_objects': [388, 423, 388, 186],
#   'neighbors': [144, 145],
#   'room_id': 80,
#   'setting': 'A spiral staircase'},
#  '81': {'background': 'This is truly the work horse of the castle. It has seen more action then the throne room or even the war room. Everyone from the king to the kings court visits this room daily. It took years to build and all the workers love having a place to gather.',
#   'category': 'Inside Castle',
#   'description': "It's dark and only lit by a candle stuck in a small candle holder in each wall. For what it is the room is large with plenty of room. It has a small wooden table off to the left. There's a small window behind overlooking the court yard.",
#   'ex_characters': [257, 258, 259, 32, 32, 1017, 899],
#   'ex_objects': [82, 428, 429, 250, 1615],
#   'in_characters': [30, 30],
#   'in_objects': [424, 425, 426, 427, 424, 246],
#   'neighbors': [146, 147],
#   'room_id': 81,
#   'setting': 'Privy room'},
#  '82': {'background': "The King's late older brother was an avid collector and historian of weapons of every kind, and ensured that the castle bought the very best. He had a room commissioned just for the weapons, and was always on the lookout for new ones.",
#   'category': 'Inside Castle',
#   'description': "The Great Armory is a long room filled too to bottom with shelves and racks of weapons of every sort. Swords of every length, weight and style, likes longer than a man is tall, Morning Star maces, longbows, horse bows, crossbows, axes...they're all there.",
#   'ex_characters': [260, 261, 1143, 74],
#   'ex_objects': [436, 1976, 961],
#   'in_characters': [13, 1142],
#   'in_objects': [431, 433, 434, 435, 190, 1975],
#   'neighbors': [148, 149],
#   'room_id': 82,
#   'setting': 'Great Armory'},
#  '83': {'background': 'This cave is only used when the village is being attacked. It is a place to hide from the enemies during war. The cave is good for hiding cause it has no lights and is very hard to find.',
#   'category': 'Cave',
#   'description': 'This cave is big but has no lights. It is made from stone and has a small pool of water in the back. The floor is made from dirt.',
#   'ex_characters': [262, 263, 1167, 1168],
#   'ex_objects': [442, 114, 116],
#   'in_characters': [],
#   'in_objects': [438, 439, 440, 204, 2022, 298, 439],
#   'neighbors': [150, 151],
#   'room_id': 83,
#   'setting': 'Cave'},
#  '84': {'background': 'This banquet hall is where famous leaders come to enjoy a good meal while discussing future goals.',
#   'category': 'Inside Castle',
#   'description': 'Cherry wood walls with paintings of historic kings and queens outlined in gold. A very long cherry wood colored table with chairs on all sides. Candle pieces are on the table about a couple feet apart with five candle sticks on each that are lit.',
#   'ex_characters': [265, 12, 33, 228, 1169, 31],
#   'ex_objects': [448, 89, 449, 1634, 469],
#   'in_characters': [264, 314],
#   'in_objects': [443, 444, 445, 446, 447, 2023, 443, 246, 445, 446],
#   'neighbors': [152, 153],
#   'room_id': 84,
#   'setting': 'Banquet Hall'},
#  '86': {'background': 'The birth of a royal navy ship begins in these shipyards. For 200 years master craftsmen and the royal shipwrights make repairs and create more master pieces for the kingdom.',
#   'category': 'Port',
#   'description': 'A massive shipyard with different Five dry docks. each dry dock has several wooden cranes and rope works. The dry docks are made of stone and the water gate is all harden wood.',
#   'ex_characters': [271, 272, 1183, 964, 1184],
#   'ex_objects': [463, 464, 465, 466, 2043, 2044, 2045],
#   'in_characters': [1181, 1182],
#   'in_objects': [459, 460, 461, 462, 460, 40, 2042],
#   'neighbors': [156, 157],
#   'room_id': 86,
#   'setting': 'Royal Shipyard'},
#  '87': {'background': 'This castle is where the king lives and where other royalty reside. There are fancy dinners here as well as many important meetings.',
#   'category': 'Inside Castle',
#   'description': 'The inside of the castle is made from grey brick. All the floors are made from gold and silver. The castle is lit by lights as well as some candles.',
#   'ex_characters': [273, 32, 14, 252],
#   'ex_objects': [468, 469, 49],
#   'in_characters': [30, 265],
#   'in_objects': [467, 120, 2046, 120, 2047, 2048],
#   'neighbors': [158, 159],
#   'room_id': 87,
#   'setting': 'Castle'},
#  '88': {'background': 'The training fields have been being used for several generations. The inhabitants of the palace used to train somewhere else until flooding destroyed the area, and it was moved here. The fields have been an efficient place and have hosted all of the fighters of the kingdom at some point.',
#   'category': 'Outside Palace',
#   'description': 'The training fields are a large expanse of grass fields, filled with all sorts of training apparatus for the noblemen and soldiers. The grass is not anything fancy, scuffed up and dry in many places, but it gets the job done. There are hay bails arranged all over, training courses, archery targets, weights and more scattered about in stations.',
#   'ex_characters': [228, 277, 252, 1186, 1187, 1188],
#   'ex_objects': [475, 367, 457, 151, 152, 151, 1055, 1056],
#   'in_characters': [274, 275, 276, 180, 274, 275, 1185],
#   'in_objects': [470, 471, 473, 474, 470, 471, 2050, 474],
#   'neighbors': [160, 161],
#   'room_id': 88,
#   'setting': 'Training Fields'},
#  '9': {'background': "This dock is used to offload the high sorceress' supplies.  It is only allowed to be used by her and this port is somewhat mysterious as well.  She receives her goods at night and has guards that hover around her at the port.  No one really knows what kind of supplies she is receiving, but most do not want to know.",
#   'category': 'Port',
#   'description': 'This dock has seen better days.  It is wobbly and broken in areas.  There are holes through to the ocean below if you are not careful.  It is covered with every means of trash.',
#   'ex_characters': [27, 28, 631, 137],
#   'ex_objects': [39, 40, 388],
#   'in_characters': [26, 630, 26],
#   'in_objects': [38],
#   'neighbors': [10],
#   'room_id': 9,
#   'setting': 'Dock at the Port'},
#  '90': {'background': "The debtor's prison is where the King locks people away for not paying their debts. They stay in the tower until someone can repay them. If no one does, then they stay there till they die.",
#   'category': 'Inside Tower',
#   'description': 'A dank and dark prison located in the tower of the castle. There is a single bench made of stone and a bucket for eliminating waste. There are no windows and the prisoners never see the light of day.',
#   'ex_characters': [137, 26, 128, 140],
#   'ex_objects': [32, 479, 2053, 2054],
#   'in_characters': [282, 13, 1190],
#   'in_objects': [477, 478, 477, 478],
#   'neighbors': [164, 165],
#   'room_id': 90,
#   'setting': "Debtor's Prison"},
#  '91': {'background': "The king's quarters served as the king's royal bedroom for centuries.  It used to be the astrologist's laboratory but has since been blessed by various fertility shamans and is physically and spiritually cleansed daily by a powerful wizard.  Daily offerings are made to the paintings of the deities--various fruits, nuts, and sometimes bloodletting into a golden dish is not uncommon.",
#   'category': 'Inside Tower',
#   'description': "Decadent, sensual, and tranquil, the King's Quarters sparkles with the various diamonds and gold-laced furniture comprising the entire room.  Self-portraits of the king himself, his queen, and various demigods line the walls leading up to the bed.  Smooth, bear- and tiger-skin rugs cover the entire floor to protect the bare feet of scantily clad virgins who serve to the beckon and call of the king and his queen.  There is a faint smell of sandalwood wafting to and from each section of the room at all times.",
#   'ex_characters': [154, 209, 285, 213, 1192],
#   'ex_objects': [469, 485, 486, 2058, 2059],
#   'in_characters': [265, 283, 1191, 265, 12],
#   'in_objects': [480, 481, 482, 483, 484, 480, 481, 2056, 2057],
#   'neighbors': [166, 167],
#   'room_id': 91,
#   'setting': "The King's Quarters"},
#  '92': {'background': 'The main hall is the first thing you see walking into the castle. It is both breathtaking and beautiful.',
#   'category': 'Inside Palace',
#   'description': 'Long hallway with high ceilings, long windows, and a very intricate designed ceiling.',
#   'ex_characters': [212, 63, 265, 12, 30, 32, 509, 255],
#   'ex_objects': [89, 443, 2066, 45, 1970],
#   'in_characters': [],
#   'in_objects': [153, 2061, 2062, 2063, 2065, 336],
#   'neighbors': [168],
#   'room_id': 92,
#   'setting': 'The  main hall'},
#  '93': {'background': 'The confessional room is one of the oldest rooms in the church.  Pilgrims come from far away to unload their sins and seek forgiveness from the cardinal.  Tucked away in a small corner of church, the confessional room is modest and secluded.  Although the demand is great, the confessional room is always ready for those who have need of it.',
#   'category': 'Inside Church',
#   'description': 'The confessional room is small and cramped, offering access to only a single person at a time.  Once inside this small, wooden room, A person is alone with nothing but the cardinal and their own sins.  The confessional room has a single wooden bench and small table holding a candle, with a sliding window that allows words to pass through to the other side.  The cardinal waits on the other side, ready to absolve someone of their sins.',
#   'ex_characters': [289, 290, 602, 1195],
#   'ex_objects': [492, 2069],
#   'in_characters': [286, 287, 288, 1194],
#   'in_objects': [456, 1146],
#   'neighbors': [169, 170],
#   'room_id': 93,
#   'setting': 'Confessional Room'},
#  '94': {'background': 'Where there\'s water, there are fish, and where there are fish, there are stories about "the one that got away", and of course fishermen. As they can be unpleasantly salty characters unfit for the company of the more genteel sorts of ladyfolk, enterprising individuals act as middlemen, buying fresh-caught seafood from these disreputable sorts and selling them on. This is one such enterprise, which has clearly both been here a while, and not been entirely prosperous.',
#   'category': 'Port',
#   'description': "A small booth near the edge of the port, it's protected by a piece of old, sun-bleached sailcloth. Baskets of freshly-caught fish, bivalves, and eels sit in the shade in stained wooden troughs of water. A small, aggressive-looking dog is chained to one table, presumably to keep cats away. The stall is redolent with the aroma of fish.",
#   'ex_characters': [293, 294, 411, 184, 137],
#   'ex_objects': [496, 497, 2073, 1194, 2075, 2076],
#   'in_characters': [291, 292, 154, 155, 38, 1196, 1197, 39],
#   'in_objects': [493, 494, 2070, 2072, 246],
#   'neighbors': [171, 172],
#   'room_id': 94,
#   'setting': "Fishmonger's stall"},
#  '96': {'background': 'Unknown cave happened upon, it seems there are no stories, or tales for this place. It seems untouched by human life, as if the world has kept this secret for itself for centuries. We will be able to tell the first tale of this location.',
#   'category': 'Cave',
#   'description': 'Its dark, not much light can be seen in this hollow and empty cave site. Its made of stone that has been here seemingly since time began, the walls are hard as diamond, yet black like darkness itself.',
#   'ex_characters': [297, 298, 1200, 37],
#   'ex_objects': [500, 501, 125],
#   'in_characters': [],
#   'in_objects': [204],
#   'neighbors': [175],
#   'room_id': 96,
#   'setting': 'Dark Cave'},
#  '97': {'background': 'The confessional is as ancient as Catholicism itself. Since the beginning of the Sacrament of Penance, this tiny, benched room has provided countless sinners with respite from their sin.',
#   'category': 'Inside Church',
#   'description': "The red velvet curtains provide privacy and speak to the washing away of sins as the repentant person leaves the booth. The solid oaken bench provides no comfort, and hurries the churchgoer along in their confession. Behind the sheer screen is the waiting priest. Ornate designs are carved into the side of the confessional. Above it is a painting, dulled by age, but still depicting Jesus' death and resurrection with resounding clarity.",
#   'ex_characters': [236, 300, 390, 1203],
#   'ex_objects': [507, 508, 2086, 2087],
#   'in_characters': [56, 299, 1201, 299, 1202],
#   'in_objects': [502, 505, 506, 502, 2083, 2084, 2085],
#   'neighbors': [176, 177],
#   'room_id': 97,
#   'setting': 'Confessional'},
#  '99': {'background': 'After having to deal with the public for the better part of the day, the King comes to relax in his room where he has the chance to go over personal correspondence, eat his meals either with or without the Queen, and engage in some reading for learning or for fun.',
#   'category': 'Inside Palace',
#   'description': 'The more-than-king-sized bed is the dominating feature of this room.  It has four tall posters, draped in the most royal blue canopy that you could imagine.  The inner curtains of the canopy are made of the finest silk his artisans could get their hands on.  Next to the bed is a lavish desk piled high with books.  On the other side of the room is a fireplace and a chair, and yet another pile of books.  [The King is an avid, AVID reader.]',
#   'ex_characters': [265, 302, 303, 32, 1073],
#   'ex_objects': [518, 519, 1474, 2092],
#   'in_characters': [30],
#   'in_objects': [512, 513, 515, 516, 517, 129],
#   'neighbors': [180, 181],
#   'room_id': 99,
#   'setting': "King's Bedroom"}}

# %%
from collections import defaultdict

rooms_by_id = light_environment['rooms']

rooms_by_category = defaultdict(set)
for room_id in rooms_by_id:
  category = light_environment['rooms'][room_id]['category']
  rooms_by_category[category].add(room_id)

def get_room_name(room_id, rooms_by_id=rooms_by_id):
  return rooms_by_id[room_id]['setting']

def print_rooms_for_category(category, rooms_by_category, rooms_by_id):
  rooms = rooms_by_category[category]
  print(category.capitalize())
  for room_id in rooms:
    print('\t', room_id, '-', get_room_name(room_id))

print_rooms_for_category('Graveyard', rooms_by_category, rooms_by_id)
# Out:
# Graveyard
# 	 277 - Graveyard
# 	 386 - Tombstones of the Kings
# 	 100 - Old Crypt
# 	 462 - Dead Tree
# 	 431 - Abandoned workers shed
# 	 62 - An Unfinished Mausoleum
# 	 162 - Reception area
# 	 144 - Cemetery
# 	 158 - the fountain
# 	 340 - A cursed grave
# 	 661 - Main graveyard
# 	 702 - Main street

# %% [markdown]
# ### Neighbors
#
# Rooms are connected to other rooms.  The LIGHT dataset stores the connections in a variable called ```light_environment['neighbors']```.  Here is an example of what is information is stored about these connections.
#
# ```
#  '108': {'connection': 'walking carefully between fallen headstones',
#   'destination': 'Fresh Grave',
#   'direction': 'West',
#   'inverse_id': None,
#   'room_id': 62},
#  '109': {'connection': 'following a dirt trail behind the mausoleum',
#   'destination': 'Dead Tree',
#   'direction': 'South',
#   'inverse_id': None,
#   'room_id': 62},
# ```
#
# These can be thought of as arcs in a directed graph, where the rooms are nodes, and these elements are the arcs that connect a pair of nodes.  The head of the arc (the ***to node***) is specified by the ```destination``` field (a description rather than an ID), and tail of the arc (the ***from node***) is specified by the ```room_id```.

# %%
arcs = light_environment['neighbors']

# Create a dictionary that maps room names ('setting') to IDs
room_names_to_id = {room['setting']:room_id for (room_id,room) in rooms_by_id.items()}


def make_connections(arcs):
#  direction, connected_location, travel_description
  for arc_id, arc in arcs.items():
    try:
      source_id = str(arc['room_id'])
      target_id = str(room_names_to_id[arc['destination']])
      direction = arc['direction']
      travel_description = arc['connection']
      source_name = get_room_name(source_id)
      target_name = get_room_name(target_id)
      # Print out the room connections in the Graveyard
      if source_id in rooms_by_category['Graveyard']:
        print('====')
        print(source_name, '-->', target_name)
        print(direction)
        print(travel_description)
    except:
      pass

make_connections(arcs)
# Out:
# ====
# An Unfinished Mausoleum --> Dead Tree
# South
# following a dirt trail behind the mausoleum
# ====
# Old Crypt --> Abandoned workers shed
# South
# walking down the cobbled path
# ====
# Cemetery --> Main street
# West
# following the cobblestone path
# ====
# Reception area --> Main graveyard
# East
# walking
# ====
# Tombstones of the Kings --> Church
# North
# exiting the graveyard
# ====
# Abandoned workers shed --> Old Crypt
# North
# walking down the cobbled path
# ====
# Main street --> Cemetery
# South
# traveling the road south
# ====
# Main street --> Cemetery
# East
# following the cobblestone path

# %% [markdown]
# ### Characters
#
#
# Characters have a description, a persona (a first person description of who they are and what their motivations might be), a character type (person, creature or object), a location (```in_room_id```) and an an inventory (```carrying_objects```)
#
# The Gravedigger character is listed in the Unfinished Mausoleum's ``in_characters`` variable.  The ``in_characters`` are characters that are explictly mentioned in the location's ``description`` or ``background`` variables.  In this case, the Gravedigger is mentioned in the Unfinished Mausoleum's ``background variahle``.
# ```
# light_environment['characters']['203']
#
# {'base_form': ['gravedigger'],
#  'carrying_objects': [890],
#  'char_type': 'person',
#  'character_id': 203,
#  'corrected_name': 'gravedigger',
#  'desc': 'You might want to talk to the gravedigger, specially if your looking for a friend, he might be odd but you will find a friend in him.',
#  'ex_room_ids': [100, 349],
#  'in_room_ids': [62],
#  'is_plural': 0,
#  'name': 'gravedigger',
#  'orig_room_id': 349,
#  'personas': ["I am low paid labor in this town. I do a job that many people shun because of my contact with death. I am very lonely and wish I had someone to talk to who isn't dead."],
#  'wearing_objects': [],
#  'wielding_objects': []}
#
#  ```
#  Here are the ``ex_characters`` from the Unfinished Mausoleum.  They are not explicitly mentioned in the room's description or background, but the annotators thought that these characters were the kinds of characters that might be found there.
#
# ```
# for id in "204, 75, 156, 720".split(','):
#   print(light_environment['characters'][id.strip()]['corrected_name'])
#
# thief
# peasant
# mouse
# bat
# ```

# %%
for id in "204, 75, 156, 720".split(','):
  print(light_environment['characters'][id.strip()]['corrected_name'])
# Out:
# thief
# peasant
# mouse
# bat

# %% [markdown]
# Here is the Gravedigger character.  Characters have descriptions, name, and personas.  We'll use personas later in the semester when we look at generating dialogue for characters.

# %%
light_environment['characters']['203']
# Out:
# {'base_form': ['gravedigger'],
#  'carrying_objects': [890],
#  'char_type': 'person',
#  'character_id': 203,
#  'corrected_name': 'gravedigger',
#  'desc': 'You might want to talk to the gravedigger, specially if your looking for a friend, he might be odd but you will find a friend in him.',
#  'ex_room_ids': [100, 349],
#  'in_room_ids': [62],
#  'is_plural': 0,
#  'name': 'gravedigger',
#  'orig_room_id': 349,
#  'personas': ["I am low paid labor in this town. I do a job that many people shun because of my contact with death. I am very lonely and wish I had someone to talk to who isn't dead."],
#  'wearing_objects': [],
#  'wielding_objects': []}

# %%
characters_by_id = light_environment['characters']
characters_by_id['203']

from collections import Counter

def count_character_types(characters_by_id):
  character_types = Counter()
  for character_id in characters_by_id:
    character = characters_by_id[character_id]
    char_type = character['char_type']
    character_types[char_type] += 1
  return character_types

character_types = count_character_types(characters_by_id)
print(character_types)
# Out:
# Counter({'person': 1028, 'creature': 304, 'object': 38})

# %% [markdown]
# ### Objects
#
# Objects are inanimate things in the game.  They have descriptions, locations, and a set of properties that could be used to govern how a player interacts with them.  The properties of objects in the light dataset are
# * is_container
# * is_drink
# * is_food
# * is_gettable
# * is_plural
# * is_surface
# * is_weapon
# * is_wearable
#
# These properties have numeric values associated with them.  The values seem to be something like 0.0 = false, 1.0 = true, 0.5 = possibly.
#
# Here is an example object:
# ```
# light_environment['objects']['1188']
#
#  {'base_form': ['sword', 'Sword'],
#  'desc_entries': 2,
#  'descriptions': ['The sword is very old, you would assume it had once belonged to a legendary warrior.',
#   "The sword's legend is known by everyone, it is famous throughout the land."],
#  'ex_room_ids': [],
#  'holding_character_ids': [],
#  'in_room_ids': [12],
#  'is_container': 0.0,
#  'is_drink': 0.0,
#  'is_food': 0.0,
#  'is_gettable': 1.0,
#  'is_plural': 1.0,
#  'is_surface': 0.0,
#  'is_weapon': 1.0,
#  'is_wearable': 0.0,
#  'link_entries': 1,
#  'name': 'Legendary swords',
#  'object_id': 1188}
#  ```

# %%
light_environment['objects']['1188']
# Out:
# {'base_form': ['sword', 'Sword'],
#  'desc_entries': 2,
#  'descriptions': ['The sword is very old, you would assume it had once belonged to a legendary warrior.',
#   "The sword's legend is known by everyone, it is famous throughout the land."],
#  'ex_room_ids': [],
#  'holding_character_ids': [],
#  'in_room_ids': [12],
#  'is_container': 0.0,
#  'is_drink': 0.0,
#  'is_food': 0.0,
#  'is_gettable': 1.0,
#  'is_plural': 1.0,
#  'is_surface': 0.0,
#  'is_weapon': 1.0,
#  'is_wearable': 0.0,
#  'link_entries': 1,
#  'name': 'Legendary swords',
#  'object_id': 1188}

# %%
obj = light_environment['objects']['1188']
print(obj['name'])
print(obj['object_id'])
for label, value in obj.items():
  if label.startswith('is_') and value == 1.0:
    print(label, value)
# Out:
# Legendary swords
# 1188
# is_gettable 1.0
# is_weapon 1.0
# is_plural 1.0

# %%
objects_by_id = light_environment['objects']

def sort_objects_by_property(objects_by_id, thresh=0.5):
  objects_by_property = defaultdict(set)
  for object_id, obj in objects_by_id.items(): 
    name = obj['name']
    for label, value in obj.items():
      if label.startswith('is_') and value >= thresh:
        objects_by_property[label].add(object_id)
  return objects_by_property

objects_by_property = sort_objects_by_property(objects_by_id)

# print 20 objects for each property
for prop in objects_by_property:
  print(prop)
  for counter, object_id in enumerate(objects_by_property[prop]):
    if counter < 20:
      obj_name = objects_by_id[object_id]['name']
      print('\t', obj_name)
# Out:
# is_gettable
# 	 mosses
# 	 practice swords
# 	 hammer
# 	 books
# 	 Robes of Royalty
# 	 parchment
# 	 bows and arrows
# 	 wooden stools
# 	 dragon toe nails
# 	 swamp flower
# 	 robe
# 	 religious tapes and records
# 	 sculptures
# 	 hooks
# 	 Towels
# 	 giant club
# 	 wheelbarrow
# 	 A cross
# 	 Crates
# 	 gold hair
# is_plural
# 	 mosses
# 	 practice swords
# 	 The alters where they kneel in prayer.
# 	 books
# 	 Robes of Royalty
# 	 bows and arrows
# 	 dragon toe nails
# 	 headstones
# 	 religious tapes and records
# 	 sculptures
# 	 hooks
# 	 Towels
# 	 smaller tables
# 	 Crates
# 	 cob webs
# 	 tombstones
# 	 Candle holders
# 	 pianos
# 	 tables, lined with maps and instruments
# 	 grass
# is_weapon
# 	 practice swords
# 	 lighted torches
# 	 hammer
# 	 stones
# 	 books
# 	 metal bucket
# 	 bows and arrows
# 	 hunting rifles
# 	 staff
# 	 bow
# 	 lamps
# 	 stars
# 	 benches made from wood
# 	 a crossbow
# 	 hooks
# 	 giant club
# 	 torture implements
# 	 Pots
# 	 oars
# 	 small metal bucket
# is_surface
# 	 mosses
# 	 The alters where they kneel in prayer.
# 	 parchment
# 	 wooden stools
# 	 alter
# 	 fountaints
# 	 headstones
# 	 couch
# 	 a small pool of water
# 	 wheelbarrow
# 	 smaller tables
# 	 Altar
# 	 Candle holders
# 	 pianos
# 	 tables, lined with maps and instruments
# 	 grass
# 	 tiles
# 	 throne
# 	 hand carved 30 person kings dining table
# 	 food trays
# is_container
# 	 Old cup
# 	 metal bucket
# 	 polished gold
# 	 treasure
# 	 alter
# 	 mystical booth
# 	 wardrobe
# 	 a brook
# 	 water pail
# 	 small metal bucket
# 	 Pots
# 	 jail cells
# 	 store
# 	 wheelbarrow
# 	 news of the kingdom
# 	 Crates
# 	 stored jugs of water
# 	 walls
# 	 kettle
# 	 paintings
# is_wearable
# 	 Robes of Royalty
# 	 mystical necklace with a colorful crystal
# 	 crowns
# 	 Jewels
# 	 the royal coat of arms
# 	 robe
# 	 a rabbit fur coverlet
# 	 A high priest's robe hanging on a hook
# 	 Towels
# 	 jewelry
# 	 Rusty manicals
# 	 A cross
# 	 bones
# 	 gold hair
# 	 Blankets for the stable workers who sleep there
# 	 tassels
# 	 helmet
# 	 dress
# 	 ceremonial hat
# 	 blankets
# is_food
# 	 The plants besides the trees, like bushes and grass.
# 	 Food
# 	 fruit trees
# 	 meat
# 	 moldy bread
# 	 ingredients
# 	 sheep
# 	 lush green vegetation
# 	 fancy dinners
# 	 hay
# 	 leaves
# 	 citrus fruit
# 	 A wide variety of grains, vegetables and fruits
# 	 worms
# 	 mushrooms
# 	 clams
# 	 meals
# 	 honeysuckle has been allowed to climb the garden wall
# 	 alligators
# 	 cows
# is_drink
# 	 Food
# 	 a jug of water
# 	 ingredients
# 	 fancy dinners
# 	 potions
# 	 turquoise color water
# 	 small water spring
# 	 milk
# 	 water wells
# 	 bottle of wine
# 	 baptism pool
# 	 a small pool of water
# 	 red wine
# 	 babbling brook
# 	 algae
# 	 stored jugs of water
# 	 holy water
# 	 small lake
# 	 lake
# 	 bottles of liquor

# %% [markdown]
# # Format Data for Fine-Tuning
#
# Below, I show how to create data to fine-tune OpenAI.  The OpenAI API documentation has a [guide to fine-tuning models](https://beta.openai.com/docs/guides/fine-tuning) that you should read.   The basic format of fine-tuning data is a JSONL file (one JSON object per line) with two key-value pairs: `prompt:` and `completion:`.
#
# ```
# {"prompt": "<prompt text>", "completion": "<ideal generated text>"}
# {"prompt": "<prompt text>", "completion": "<ideal generated text>"}
# {"prompt": "<prompt text>", "completion": "<ideal generated text>"}
# ...
# ```
#
# In the code below, I'll extract a prompt that contains the `Category` and `Setting` variables from a LIGHT Environment room, and I'll have the completion be the room's `Description`.

# %%
def get_room_description(room_id, rooms_by_id, light_environment):
  """
  This generates a prompt and a completion which can be used to fine-tune OpenAI.
  This version just gnnerates 
  """
  prompt = ""
  completion = ""
  prompt += "Category: {category}\n".format(category=rooms_by_id[room_id]['category'].capitalize())
  prompt += "Setting: {setting}\n".format(setting=rooms_by_id[room_id]['setting'].capitalize())
  completion += "Description: {description}\n".format(description=rooms_by_id[room_id]['description'])
  completion += "###\n"

  return prompt, completion


def create_location_finetuning_data(filename='fine_tuning_location_descriptions.jsonl'):
  fine_tuning_data = []
  for category in categories:
    rooms = rooms_by_category[category]
    for room_id in rooms:
      data = {}
      prompt, completion = get_room_description(room_id, rooms_by_id, light_environment)
      data['prompt'] = prompt
      data['completion'] = completion
      print(prompt, end="")
      print(completion)
      fine_tuning_data.append(data)

  with open(filename, 'w') as out:
    for data in fine_tuning_data:
        out.write(json.dumps(data))
        out.write('\n')

create_location_finetuning_data()
# Out:
# Category: Forest
# Setting: Along the banks of a river in the forest
# Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.
# ###
#
# Category: Forest
# Setting: The stream
# Description: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.
# ###
#
# Category: Forest
# Setting: Forbidden forest
# Description: The forbidden forest is a dark and very scary place. The trees are covered in spider web nets and huge spiders. The forest echoes sounds of witches' laughs and creepy crawly animals.  There is a brisk breeze that runs through the trees that will put chills down your spine.
# ###
#
# Category: Forest
# Setting: Woods
# Description: The woods are vast. Everywhere you turn it all looks the same. There are scratches on the trees from lost travelers marking their path. There are sounds coming from everywhere and yet no where. There are faint yellow circles up in the trees and bushes, possibly eyes starting at you.
# ###
#
# Category: Forest
# Setting: Ant hill
# Description: The ant hill is very large, over 5 feet high, and is wrapped around the base of a pine tree. The ants are huge compared to normal ants, and jut in and out of large holes in the ant hill. Bones of animals and even people can be seen sticking out of the red dirt ant hill.
# ###
#
# Category: Forest
# Setting: Mysterious forest outskirts
# Description: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.
# ###
#
# Category: Forest
# Setting: Pine tree graveyard
# Description: Once known as a forest of solitude, the entrance to the pine trees is now a bleak and dreary graveyard.  Dead grass and moss fill the ground along with crawling critters that mark fear in the mind among the he who venture here.  Tombstones so old many of the names are no longer eligible.  Dense fog surrounds the area, thick tree tops blotting out the sunlight, and an eerie silence fills the air.  Cold it feels, the air, but the ground is soft and warm.  Sound can not enter, no escape this dwelling.
# ###
#
# Category: Forest
# Setting: Fairy forest
# Description: The fairy forest is full of brightly colored flowers that grow up to 30 feet tall.  There are also ornate birds that live here.  When you whistle, a fairy will come to you and tweak your nose.  They don't like a lot of nose so it irritates them enough for them to come out of their homes made from watermelon skins.
# ###
#
# Category: Forest
# Setting: Entrance to the pine trees
# Description: Very tall and towering pine trees that create a dark canopy of shade. Long skinny trees sway in the sky from the soft breeze. Pine needles scatter the ground like plush carpet.
# ###
#
# Category: Forest
# Setting: Unsettling forest area
# Description: The forest is actually very creepy even during the day. The trees are so tall that they block the sunlight. There is always fog in the forest which makes it very hard to see. There are a lot of mushrooms near the trees and none of them are edible
# ###
#
# Category: Forest
# Setting: Firewood forest
# Description: The forest has many trees. The majority of the trees are green however a few are orange and red. The forest is huge and seems to never end.
# ###
#
# Category: Forest
# Setting: The clearing
# Description: the clearing is surrounded by old pine trees where knights used to practice swinging their swords. There are haystacks where they take wenches and pay them a sickle.
# ###
#
# Category: Forest
# Setting: Forest entrance
# Description: The path quickly narrows and darkens upon entering the forest.  Dense branches overhead block all but a few stray rays of sunshine.  Fallen leaves just beginning to rot blanket the forest floor, and every footstep kicks up a rich, loamy scent as fresh ground is unearthed.
# ###
#
# Category: Forest
# Setting: North forest
# Description: Filled with huge trees, the forest is home to many types of animals. Huge predators such as tigers and bears roam the grounds as do small animals like squirrels. Colorful birds fly among the trees. Wildflowers grow on the ground. Dappled sunlight streams through the huge canopy of trees.
# ###
#
# Category: Forest
# Setting: Riverbed
# Description: With clear air and the sound of gurgling water near it, the river bed is silty and muddy. The river rushes by the land as more and more dirt separates from the land. The land of the riverbed slick with mud and filled with bugs and worms/
# ###
#
# Category: Forest
# Setting: Pond
# Description: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.
# ###
#
# Category: Forest
# Setting: Flower garden
# Description: This clearing is in reveal a wide circle of trees. Proud oaks stand close enough that only the smallest of fauna can squeeze through, protecting the garden within from curious deer and hungry rabbits. Flowers of every hue and shade crowd the soft lawn of grass, soaking up what light they can through the shadows cast by the branches above. Purple, yellow, red, blue - even green blossoms bob in the breeze, their scents mixing to create a heady perfume. Vines and creepers climb up the tree trunks, dripping with grapes and berries.
# ###
#
# Category: Forest
# Setting: A wooded magical village
# Description: The village lay hidden in a secret grotto that is set in a sort of valley between trees. The village is populated by child-like peoples who wear clothes made of various plant matter such as large leaves and vines. The homes are made of wood, and seemingly blend into the green dense backdrop.
# ###
#
# Category: Forest
# Setting: Picnic area
# Description: In this picnic area, there is a wide clearing with some cut down tree stumps made for people to sit and enjoy their lunch.  There's also a small pond nearby where people can feed fish and watch turtles sunbathe.
# ###
#
# Category: Forest
# Setting: South forest
# Description: The forest is lined with tall trees but has a long walkway for travelers. I the middle of the forest is a long river surrounded by tall grass with clear blue waters and lots of colorful fish.
# ###
#
# Category: Forest
# Setting: A room hidden in the dense canopy
# Description: Its a large room with types of beings you have never seen before. There is a counter and a person who greets people suprise when you arrive because you are not one of them. The room has an unfamiliar feel to it. with doors leading to walkways, other buildings, an entire city
# ###
#
# Category: Forest
# Setting: Woodlands
# Description: The lush hunting grounds cover acres of land, tall trees and thickets of bushes sprawling across the land. Fields of open land are under the deep blue sky, showing the depth of the landscape. The grounds forest is thick but full of light, letting the multitude of wildlife be seen by the naked eye. The abundance of greenery makes it a prime location for hogs and oxen as they explore the land.
# ###
#
# Category: Forest
# Setting: The brush den
# Description: The entryway to the brush den is made of arched bushes and various plants, as is the ceiling and walls. The inside is furnished with seats made of plant roots that have grown together, and a table made of wood adorned with flowers and wooden cups and plates. A small vine dangles with a glowing floor from the middle of the ceiling that lights the room dimly. Three small beds lay in one corner of the room made of interlaced grass and leaves.
# ###
#
# Category: Shore
# Setting: Lighthouse
# Description: The lighthouse is an off-white color, towering fifty feet over the shore. The light from the building extends out for miles past the shoreline.
# ###
#
# Category: Shore
# Setting: Beach house
# Description: A marvelous beach house that sits upon the fine white sand of the beach. It looks mighty expensive, as the house has solid gold walls. A gigantic and lavish marble pier extends into the ocean out in front of the house.
# ###
#
# Category: Shore
# Setting: King's quarters
# Description: The room is large. The largest of all the throne rooms. The carvings on the wall are ornate and historical. The room is clearly built for royalty. The bed is covered in designed covers. It is truly a sight to see.
# ###
#
# Category: Shore
# Setting: Large cliffs
# Description: Towering cliffs of gray granite line the coast. A few meters of sand lie between the ocean and the base of the cliffs.
# ###
#
# Category: Shore
# Setting: Fishing pier
# Description: A spindly, long fishing pier that sits right outside the village. Barnacles cover its pilings in vast numbers. Many villagers can be seen fishing atop of it. Birds and pelicans squawk and fly above it.
# ###
#
# Category: Shore
# Setting: The beach
# Description: Sand that is white as snow. the water is as clear as a crystal. down the shore is some cliffs
# ###
#
# Category: Shore
# Setting: Coast
# Description: The coast seems to stretch on for miles in either direction.  The ocean itself has receded some and the tide has not yet rolled in.  The water laps half-heartedly at the sand and the glistening shades of seashells dot the wet sand.  All around the sand gleams a shade of white.
# ###
#
# Category: Shore
# Setting: Old docks
# Description: The shore near the docks. There is fog except on rare occasions. More dangerous than most people would like. You never know what dangers luck from creatures leaving and entering the waters.
# ###
#
# Category: Shore
# Setting: A battleship
# Description: It is a glamorous wooden ship.  It glistens like there are diamonds encrusted on the hull.  There are ornate railings on the stairs as it is a massive boat.  There is even a sea monster on the bow, complete with jeweled eyes and gold hair.
# ###
#
# Category: Shore
# Setting: Enchanted light house
# Description: Slightly rusted and corroded from the crashing waves, elegant and tall. each window and opening is lined with a bronze trim.  Some gears can be seen turning along the side, rotating a middle section of the light house.
# ###
#
# Category: Shore
# Setting: Throne room
# Description: ornate and luxurious, the throne room gleams with gold and precious jewels. Priceless painting of past kings line the sides. underneath a vaulted ceiling regal a red carpet connect the throne room entrance to the golden throne itself.
# ###
#
# Category: Shore
# Setting: Pier walkway
# Description: On the seashore facing the pier, seagulls squawk as they swirl overhead. The smell of salt fills the air, and the gentle, dull roar of the waves lapping the beach is omnipresent. A gentle breeze blows, and the chatter of the villagers fishing drifts down to the shoreline from the pier.
# ###
#
# Category: Shore
# Setting: Beach house
# Description: the beach house is falling apart due to the storms, it's door is hanging and it's humid inside. There is no floor, just sand, and a hole to serve as the outhouse.
# ###
#
# Category: Shore
# Setting: Turquoise shore
# Description: A beautiful turquoise color water by the shore. It is filled with many gems and gold.
# ###
#
# Category: Countryside
# Setting: Meadow
# Description: Large clear outdoor meadow. Flowers of blue and white appearing in bunches here and there. The grass glows with a green light. Not much can be said about its appearance, however there is a mystical allure associated with the place as if a meadow for spirits instead of livestock.
# ###
#
# Category: Countryside
# Setting: The small dirt road
# Description: This small dirt road is flanked by a lush green forest on each side with birds chirping and the occasional deer running about.  Sometimes, you can find broken down wooden wagons left behind from ambushes carried out by bandits.
# ###
#
# Category: Countryside
# Setting: Countryside
# Description: The countryside is quite nice, it's not filled with a lot of people but with travelers here and there. Some in small groups some on their own. They are hosting a campfire where everyone has some to sit and is telling stories about their adventures. Someone is showing local children how to wield some weapons. Another is offering lodge, and stable for travelers and their animals.
# ###
#
# Category: Countryside
# Setting: Main gate
# Description: The main gate is tall and strong enough to protect the mansion from invaders, and has large wooden doors reinforced by planks and steel sheets. There are two towers on either side of the gate for the town's watchmen to use as their post.
# ###
#
# Category: Countryside
# Setting: Chicken pen
# Description: The chicken pen has wire cages situated on three different levels, with hay at the bottom for the chicken's to sit in. There lie small holes in the cages for the eggs to fall through and be easily harvested by the farmers. The old wooden walls of the chicken pen are beginning to deteriorate and show signs of age.
# ###
#
# Category: Countryside
# Setting: Lush meadow in the country side
# Description: Green large trees surround the meadow that if filled with beautiful seasonal flowers. A deer is grazing in the far end of the field. A small dirt country road gentle crooks past on the outside of the road.
# ###
#
# Category: Countryside
# Setting: Path to the manor
# Description: The outside of the manor is rather imposing with a large stone building and two immense guardian sculptures on the outside depicting mythical beasts. There are also small gardens to the left and right.  The main path itself is a cobbled one that only beckons visitors if they are worthy enough.
# ###
#
# Category: Countryside
# Setting: Maidens cottage
# Description: Free standing in the vast countryside, with gentle rolling hills and lush green grass and vegetation sits the cottage. There are a couple of Oak trees close to the cottage as the only tall trees around for miles. Colorful Dandelions, perennials, and daisies grow wildly and freely along the hills.
# ###
#
# Category: Countryside
# Setting: A cabin
# Description: Plain, pretty basic wooden cabin.  In a field of wildflowers, there is also a pen for the chickens, a clothes line.
# ###
#
# Category: Countryside
# Setting: Meadow
# Description: This meadow is composed of green, luscious, rolling hills. Flowers dot the expanse. In the evening, one may stand from the hills of this meadow and see the sun set beneath the horizon off in the distance.
# ###
#
# Category: Countryside
# Setting: The forest
# Description: The forest has many trees. It has other plants too. There are animals and many livings things. The forest is very much full of life. When you look at it you might only see plants that are green and different shades of brown but there are many other living things in there too.
# ###
#
# Category: Countryside
# Setting: Valley of doom
# Description: The Valley of Doom is overrun by dead trees and grasses.  Eerie looking animals peer at you through the brushes.  It is a dark and wicked place.
# ###
#
# Category: Countryside
# Setting: Horse field
# Description: The horse field includes a huge plains for horses to ride. The fields are yellow and green. The place smells of musk and horse.
# ###
#
# Category: Countryside
# Setting: Flower field
# Description: The flower field contains acres of wild growing flowers that are a bright pink when they are in bloom. There are woods surrounding it, but no trees in the field, only flowers. There are paths that work their way through the field.
# ###
#
# Category: Countryside
# Setting: Pig pen
# Description: A filthy pen where tons of squalling pigs rut and throw a ruckus, Their snorts and farts can be heard from any passerby miles before getting to the pen. The pig pen is a few feet from Farmer Bob's cottage. The pigs never sleep and are always eating and playing in the mud.
# ###
#
# Category: Countryside
# Setting: Hillside manor
# Description: A quaint manor that sits in the rolling hills. It is surrounded by a small stone fence and looks quite inviting to passersby. It looks like any other home that a well off business man would own.
# ###
#
# Category: Countryside
# Setting: Cottage
# Description: The small cottage was white with two, shuttered windows. It was in the unique shape of a circle and was built of plaster. Smoke billowed from the chimney.
# ###
#
# Category: Countryside
# Setting: Nearby road
# Description: The road cuts through the countryside. It is a dirt road, with a fence lining the eastern side and a grassy meadow to the west.
# ###
#
# Category: Countryside
# Setting: Hillside mansion
# Description: I sweeping villa that rests on the grand hills. Everyone can see how grand it is when they approach from the country road. A tall, wrought-iron fence surround its grounds, which extends for miles.
# ###
#
# Category: Countryside
# Setting: Peasant's cottage
# Description: The peasant's cottage is a fairly simple wood building with a straw thatched roof.  Inside, you have a fireplace and large pot for cooking, a long wooden dinner table, and some hay filled beds lying on the floor.  There are two chests lying inside with personal belongings such as clothes and family heirlooms.
# ###
#
# Category: Port
# Setting: Fish market
# Description: The port is filled with many different small shops that sell fishes caught throughout the day. It is incredibly loud and busy with many customers and fisherman walking around and haggling for a good price on the fishes. There are tons of boxes sitting on the floors everywhere filled with ice, fish, and the fishermen's belongings.
# ###
#
# Category: Port
# Setting: Dock
# Description: There are creaky wooden walkways with empty sections where boats can rest.  There are a few buildings surrounding this area that sell supplies to sailors.
# ###
#
# Category: Port
# Setting: Crew berthing
# Description: The main quarters for the crew of the vessel. Its dirty, smelly and not a place where anyone but a pirate would want to stay. There are bunks stacked on bunks the place is cramped and no one goes there for any reason besides sleeping.
# ###
#
# Category: Port
# Setting: Captain's cabin
# Description: The captain's cabin is a complete mess. There are multiple maps on the wall, pinned over one another, each with messy writing scrawled over it and multiple X marks in random places. Papers overflow off the desk and across the floor in waves, impeding the captain as he paces, muttering angrily. The bed is messy and unmade, giving the impression that the captain has spent the night tossing and turning. Random objects have been thrown about the room.
# ###
#
# Category: Port
# Setting: Warehouses
# Description: The warehouses are the largest structures in the port, rising well above the adjoining buildings. Constructed from virgin timber, the beams overhead support lofts that are filled to capacity with boxes, crates, and barrels full of goods from all over the world. Carefully checking each parcel that crosses the doorway, the warehouse manager knows exactly where everything belongs inside.
# ###
#
# Category: Port
# Setting: Port tavern
# Description: The port tavern is the shadiest of all the shady bars in the city. Every night, on its grimy stools at the wooden bar, you can find some of the slimiest sailors in the world. The walls are of peeling blue paint and are always dripping with condensation. Women of ill-repute line one wall, old men on the verge of passing out line another. The floor is littered with trash, barnacles, and bodily fluids. Tending the bar is a small, round man with a bushy mustache.
# ###
#
# Category: Port
# Setting: Dock at the port
# Description: This dock has seen better days.  It is wobbly and broken in areas.  There are holes through to the ocean below if you are not careful.  It is covered with every means of trash.
# ###
#
# Category: Port
# Setting: Ferry terminal
# Description: A huge terminal with a lot of traffic. The Ferry Terminal has a warm and positive vibe that welcomes all travelers across the land. It has an open space with a lot of illumination during the night.
# ###
#
# Category: Port
# Setting: Fishmonger's stall
# Description: A small booth near the edge of the port, it's protected by a piece of old, sun-bleached sailcloth. Baskets of freshly-caught fish, bivalves, and eels sit in the shade in stained wooden troughs of water. A small, aggressive-looking dog is chained to one table, presumably to keep cats away. The stall is redolent with the aroma of fish.
# ###
#
# Category: Port
# Setting: Quay
# Description: During the day, the quay is bustling with typical activity of a port: burly longshoremen carry crates and roll barrels away from ships for storage and sailors who still have their sea-legs saunter past on their way to drink and more adventures. By night, the quay is teeming with unsavory characters: men who are hardly men any more after losing their way through drink and gambling hunker amongst coils of rope stiffened by the salt water while rats scramble from box to box gnawing their way into the goods contained inside.
# ###
#
# Category: Port
# Setting: Supply store
# Description: With so many ships docked at the port, sailor from all the ships crowd the bazaar. The supply store is filled with buyers today. The inside is plain and unadorned. Sturdy shelves hold common supplies. Along the walls are the larger items for sale.
# ###
#
# Category: Port
# Setting: Pirate ship
# Description: A majestic, shimmering, black pirate ship sits upon the water. Its numerous cannons give it a menacing look. Tons of pirates hop upon its decks in a furious jig. The lone captain plods around in his cabin, plotting on where to seize his treasure next.
# ###
#
# Category: Port
# Setting: Port skyline
# Description: The local port sits an a majestic inlet of the ocean. The countless docks are constantly bustling with new arrivals and departures. People of all kinds come here for business or leisure. On the shore sits a skyline of many buildings packed with residents going about their day. The smell of salt and seafood fills the air.
# ###
#
# Category: Port
# Setting: Boat house
# Description: A small house type establishment that serves as a hang out for people about to board the boats.  There is nautical themed decor everywhere.  Life Buoys, mounted fish, replica boats.  It's all wood inside with a bar as well.  A lot of creaky looking wood too, probably weathered a good bit as the house is old itself.
# ###
#
# Category: Port
# Setting: The docks
# Description: The docks are a rough place with a lot of rough group of individuals who hang out there.  It is where the ships port and deport, only few know what really goes on there.
# ###
#
# Category: Port
# Setting: Marketplace
# Description: Merchants call out their wares and try desperately to get the attention of the wealthier passerby. People from all over the world hustle to and fro, some keenly eyeing the many tapestries, spices, tools and foods, others openly staring in wonder. Still others hurry along, heads down and avoiding eye contact. Colors, smells and sounds assault the senses. The cries of the gulls can hardly be deciphered from the chatter of the crowds, the ringing of the blacksmith's hammer, the bells of the nearby shipyard, and the hollers of the merchants.
# ###
#
# Category: Port
# Setting: Royal shipyard
# Description: A massive shipyard with different Five dry docks. each dry dock has several wooden cranes and rope works. The dry docks are made of stone and the water gate is all harden wood.
# ###
#
# Category: Port
# Setting: Fishing store
# Description: This store is a small one room stone building with wares laid about on tables.  One can see fishing poles, wooden buckets with dirt and bait inside, along with some mounted trophies.
# ###
#
# Category: Port
# Setting: Wharf
# Description: The waves lash gently against the wooden posts, the water here has always been calm and passive, it seems to represent the people of this small town. The fishermen here are not boisterous, they are quiet, at least when it comes to sound. They'll talk your ear off if you let them, they have lots of stories to tell. The pier here is long, it extends at least forty feet into the ocean, many ships are anchored to it, many people traverse down it buying and selling their local catches.
# ###
#
# Category: Port
# Setting: Large galleon
# Description: The deck of this rather large ship is strong and freshly swapped with tar. Its mast reaches far into the sky like gleaming pillar of hope and freedom. Its sturdy ship made for long voyages with thick planks and strong rails.
# ###
#
# Category: Port
# Setting: Loading dock
# Description: The loading dock is filled with life and movement. Many trucks back up into the
# ###
#
# Category: Port
# Setting: The village of tamerak
# Description: A thriving sea port filled with merchants, foods, women, and gold.  Hundreds of boats fill the shores, fisherman pushing out to sea and pulling into dock.  Seagulls hover silently above the merchants selling fish.  Pirates can be seen causing trouble with the locals.  Brothels and bars are in abundance, as well as the smell of fish.
# ###
#
# Category: Swamp
# Setting: Bog
# Description: Frogs croak in the reeds that surround the bog. The water is very murky and underneath the surface tadpoles dart around. There are minimal places to stand to stay dry.
# ###
#
# Category: Swamp
# Setting: A military outpost at the heart of the swamp
# Description: Moist, and murky the bog remained. As you reach the outpost that description doesn't change seeing the bog gobbers swimming through the thick water, and fermenting goblins perched atop the outpost's walls.
# ###
#
# Category: Swamp
# Setting: Soldiers camp
# Description: The camp is hidden away in a light forest of trees and brush that might be hard to find if there had not been a symbol on the trees leading up to it. You can feel the anxiety of the soldiers here, as this camp is not well fortified by any conventional means, but instead is supposed to be hidden and camouflaged to throw off anyone that might pursue. The camp is nothing more than a fire and some barracks. Nothing fancy to see.
# ###
#
# Category: Swamp
# Setting: Haunted swamp
# Description: A misty, foggy area with the swamp. It is dirty and smelly.
# ###
#
# Category: Swamp
# Setting: Witch's house
# Description: Old and worn by the time that has passed and the environment where it was built, the wood rotted and worn by the swamp. It should have sunk years ago into the swamp but somehow it remains standing despite the ever sinking earth around it.
# ###
#
# Category: Swamp
# Setting: Bank
# Description: This is a grassy area that surrounds much of the swamp.  It's a plain field with some trees nearby along with some rocks.
# ###
#
# Category: Swamp
# Setting: Troll's bridge
# Description: Muddy and murky waters lie under a bridge that seems to go nowhere. It is made of cobblestone and just as long as it is wide. Beneath it live a hideous troll that makes people pay to cross.
# ###
#
# Category: Swamp
# Setting: Boathouse
# Description: The boathouse is a very small building with peeling paint. It is made out of wood, with one half planted in the water on stilts. Inside, there are boats floating in the water. There are hinged doors which can be opened to allow boats to come in and out. There are some ropes and other tools a boater may need stored in the boathouse.
# ###
#
# Category: Swamp
# Setting: Darkest part of the swamp
# Description: The light doesn't pierce the heavy overhanging trees in this near pitch black area of the swamp.  The water is extremely murky and there are occasional fins poking up from the water belonging to some kind of creature.  The air is thick and heavy and insects constantly buzz about.
# ###
#
# Category: Swamp
# Setting: Quicksand pit
# Description: A large, gurgling pit of quicksand. Many adventurers and poor critters lie at the bottom of the pit. The pit is surrounded by an extensive swampland and is shielded by the many trees and shrubs that surround it.
# ###
#
# Category: Swamp
# Setting: Murky water
# Description: The water is murky and dark. There are unknown dangers lurking in it, such as alligators and poisonous snakes. Plants and trees hide more dangerous animals. It is cold.
# ###
#
# Category: Lake
# Setting: The swimming hole
# Description: The swimming hole is calm and clear.  The sun sparkles off the ripples that form on the surface of the water.  Fish occasionally jump from the water and splash back in.
# ###
#
# Category: Lake
# Setting: Fishing dock
# Description: Folks call the area a Lake, but it's more like a pond.  Small and unimportant looking, yet peaceful.  The dock is no prize winner either.  Narrow in width, boards broken with several down right missing all together!  No tree nearby, no canopy, nothing to shade oneself on a hot day while fishing.  The watering hole may look small in size, but it deceives the eyes.  The water is as deep as the heavens.  No man knows what lurks beyond the light in this Lake.
# ###
#
# Category: Lake
# Setting: Northern shore
# Description: The lake gives way to a slightly sandy and rocky shore. It is dotted with small shrubs and a few trees, but mostly it is a fairly open expanse. It is covered in places by a green short grass. The lake level falls away swiftly from the beach going from a few feet to well over ten feet in a short span.
# ###
#
# Category: Lake
# Setting: Drinking water lake
# Description: Surrounded by skittering chipmunks and chirping crickets, the drinking lake teems with life. Flora and fauna both thrive near the pristine waters. Tall thick plant life surrounds the lake, with strong roots and stems protruding from the nutrient rich soil. The lake water shimmers in the sun, so clear and clean that one can see the rock lake floor many feet below.
# ###
#
# Category: Lake
# Setting: Fishing shack
# Description: The fishing shack is a small wooden structure that is crudely built and is surrounded by boats. The wood flooring around the shack is well weathered and often used.
# ###
#
# Category: Lake
# Setting: Dock
# Description: The wood used to make the dock is of highest quality, commissioned from trees that stand towering in the local forests. Despite time having passed it has been taken care of to the point where even a hint of warping from the water beneath will have a plank torn and replaced within a night.
# ###
#
# Category: Lake
# Setting: The lagoon
# Description: The Lagoon is a dark and mysterious place during the night hours.  A lot of moss and lily pads surround the shore.  The water is very murky.
# ###
#
# Category: Lake
# Setting: Lakeside house
# Description: Its white and vibrant, certainly a location for some lord, It has 3 floors, and fine gardening surround the house. Its open and breezy this place is calm and peaceful.
# ###
#
# Category: Lake
# Setting: Brim canal
# Description: Slow flowing branching from the large lake, is the brim canal where dozens and dozens of brim fish call it home. The edges are lined with irregular rocks and lush green vegetation. Tall pine trees overlook the canal and lake making it a peaceful place to just go sick and watch the brim swim by.
# ###
#
# Category: Lake
# Setting: Launching point
# Description: The Launching point features a number of large wooden planks sitting at a downward slope going straight into the water.  On each side of the launching point there sits a large, ornate bronze figure of a light house that is used to tether the ships to the dock and keep them from casting away while the sailors prepare to board the ship. The launching point is very narrow, with large stone braces on either side of the dock.
# ###
#
# Category: Lake
# Setting: Clean water lake
# Description: The lake is crystal clear, lined with trees, to the far back of the lake there's a small formation of rocks almost like a small waterfall allowing water to flow into the lake. It's quite beautiful, the sun bathing the surrounding area in a warmth so comforting you could easily fall asleep on the shore. There's an old wooden bath, for its age it seems to look like almost new, and rarely used. There are no animals nearby except for birds softly chirping in the trees.
# ###
#
# Category: Lake
# Setting: Lake
# Description: The beautiful lake glistens in the sun as water can be seen in all directions. you can see several feet beneath the water because it is so clear.
# ###
#
# Category: Lake
# Setting: Island
# Description: This island is located in the center of a lake. It is smaller than a ship and covered in moss.
# ###
#
# Category: Graveyard
# Setting: A cursed grave
# Description: The sun never seems to shine on this grave.  The letters on the tombstone have long since faded, and many stories are told about whose bones lay buried in the dirt.  Until recently, it was overgrown with grass and weeds.  Someone had come and cleared the weeds, and the dirt looked as if it had been turned over.
# ###
#
# Category: Graveyard
# Setting: Main street
# Description: main street is bleak and outdated. it wears the atmosphere of the cemetery based on association. it is dark even in sunlight and has a unique odor
# ###
#
# Category: Graveyard
# Setting: Dead tree
# Description: The dead tree is many, many decades old. It lies on its side, and is rotted through and through. It is blackened on its top. It is humongous. It would have been very, very tall once upon a time. It smells dank. It cannot be moved.
# ###
#
# Category: Graveyard
# Setting: Main graveyard
# Description: This is an ominous place that a thick fog envelops.  There are rows of primitive gravestones and crosses along with some angelic statues for the more wealthy.  You can hear sobs in the distance as a funeral ceremony is underway.
# ###
#
# Category: Graveyard
# Setting: Cemetery
# Description: Dim and low lit. The aura from this cemetery emits sadness and pain perpetually. You can feel and sense the eerie nature of the graveyard crawl up your spine. There seems to be a slight fog slowly making its way across the open parts of the cemetery.
# ###
#
# Category: Graveyard
# Setting: The fountain
# Description: the fountain is the only thing you can hear in the graveyard. It's eerily quiet, not even a bird chirping. The fountain is teen feet high, and it is dry as a desert. It makes the graveyard more eerie than any other one.
# ###
#
# Category: Graveyard
# Setting: Reception area
# Description: The building itself is ordinary in appearance and is somewhat foreboding.  It is surrounding by a dense fog and high grass.  Sometimes, one can hear whispers in the wind.
# ###
#
# Category: Graveyard
# Setting: Abandoned workers shed
# Description: Moss now grows across what was once a red painted wooden shed, standing in the area just outside the graveyard. The wood shed is splintering, and there is evidence that termites have eaten away at the walls as holes poke through the shed. Inside the shed there lies leaves and plants that have been dragged in their by the wild animals that at one point called the abandoned shed their home.
# ###
#
# Category: Graveyard
# Setting: Tombstones of the kings
# Description: The tombstones of the kings are the most notable part of the graveyard. These tombstones are erected from fine marble and have piles of gold and riches lying next to them. A small metal fence surrounds this section of the graveyard, and cuts it off from the common folk.
# ###
#
# Category: Graveyard
# Setting: Old crypt
# Description: Broken stones and a iron gate closing the entrance with a name placard that the name is worn off.
# ###
#
# Category: Graveyard
# Setting: An unfinished mausoleum
# Description: Two-and-a-half walls of the finest, whitest stone stand here, weathered by the passing of countless seasons. There is no roof, nor sign that there ever was one. All indications are that the work was abruptly abandoned. There is no door, nor markings on the walls. Nor is there any indication that any coffin has ever lain here... yet.
# ###
#
# Category: Graveyard
# Setting: Graveyard
# Description: The dark and gloomy graveyard has fog all the time and has a large amount of graves everywhere you step. There are whispers and shadows that appear from the darkness and there is always a light drizzle that seems to moisten the place.
# ###
#
# Category: Abandoned
# Setting: Collapsed west wing
# Description: The rocks have all but fallen into the ocean.  There is moss and other plant life climbing the remaining rocks, making it a very moist and gloomy environment.  There are some small left-behind pieces of what appear to have been some furniture, and possibly a cradle.
# ###
#
# Category: Abandoned
# Setting: The forsaken castle
# Description: Old and creepy, the castle has been abandoned for centuries now. It is broken and destroyed.
# ###
#
# Category: Abandoned
# Setting: Weathered shack
# Description: A weathered shack with a roof made of old broken tiles sits in the middle of the forest. The wood is starting to split and the shack appears as if it will crumble at any moment.
# ###
#
# Category: Abandoned
# Setting: Abandoned mine
# Description: It's dark, cold, and musty. There is old machinery lying around, rusting, and discarded tools lie on the ground. Cobwebs are everywhere. The rock walls are damp, and a trickle of water can be heard coming from somewhere off in the dark.
# ###
#
# Category: Abandoned
# Setting: Land beyond the wasteland
# Description: Not a man in sight nor an animal to hear. This land is completely barren and hot, unfit for any agricultural activity. It has been left abandoned so much so that the King has not even had time give it a name, so people simply refer to is as "Abandoned"
# ###
#
# Category: Abandoned
# Setting: An abandoned castle on an ocean cliff side
# Description: The castle is located at the top of an erosive cliff face of a vast ocean. An entire wing of the castle appear to have collapsed into the ocean due to the erosion of the cliff face, perhaps the reason why the castle now lay abandoned.
# ###
#
# Category: Abandoned
# Setting: A lonely island
# Description: the island only has one coconut tree and waves crashing and appearing missing wooden boat parts. The pirates are nowhere to be seen.
# ###
#
# Category: Abandoned
# Setting: Abandoned mine entrance
# Description: The abandoned mine is located in a field with a few trees. It is unable to be seen from far away. The closer you get the more you  notice the ground caving in around the hole. When you peer down into the mine, you see crumbling walls and concrete and a hole so deep you can't see where it ends.
# ###
#
# Category: Abandoned
# Setting: Ruined house
# Description: A dilapidated wooden structure with a caved in roof and debris everywhere.  Even the trees outside the house are falling apart.  There's waist high grass leading to the house along with a dirt path.
# ###
#
# Category: Abandoned
# Setting: Gold mine
# Description: The entrance is very unstable, with parts falling to the ground. As you enter, the walls have been crudely chipped away to make the path to the old mine. There is trash from the previous miners scattered on the dirt ground. Rocks are all around the area, where one would stumble as they go inside. It used to be a very productive gold mine, now falling to bits. There are broken lanterns, with shattered glass.
# ###
#
# Category: Cave
# Setting: Underwater cave
# Description: The underwater cave is dark and rocky. Inside the cave fish and tadpoles have taken over. The water is cold, no light gets in. Once inside, a rocky outcrop allows swimmers to come up for air.
# ###
#
# Category: Cave
# Setting: Bat room
# Description: It is cold, dark and filled with bats. it is humid and there are some paddles on the ground.
# ###
#
# Category: Cave
# Setting: The troll's lair
# Description: Covered with rotting meat from nearby wildlife, the Troll's lair reeks of death.  If the stench alone wasn't enough to scare off an unfortunate travelers who stumbled upon it, the bones of unlucky spelunkers would be.  The Troll places his spoils near the numerous stalagmites on the damp cave wall, his red eyes patiently scanning the dark cave interior for anything that may disturb his isolation.
# ###
#
# Category: Cave
# Setting: Cave
# Description: Cold and dark, the moist cool walls enclose all who proceed. With just torches to light the way the large opening gets smaller and smaller.
# ###
#
# Category: Cave
# Setting: Underground cavern
# Description: The underground cavern is covered in precious metals and gems. In the wall, rubies, emeralds and sapphires sparkle. There is gold and silver, shining brightly. It is cool in the underground cavern.
# ###
#
# Category: Cave
# Setting: Cave
# Description: This cave is big but has no lights. It is made from stone and has a small pool of water in the back. The floor is made from dirt.
# ###
#
# Category: Cave
# Setting: Gallery
# Description: The cave is pitch black and smells of dank and mold. It's quiet except for a faint dripping noise from water overhead and the occasionally scurrying of an unseen rodent through the darkness. Barely discernable by the light of a torch is a small pile of bones in one corner. From what type of animal they are from is unclear.
# ###
#
# Category: Cave
# Setting: The underground river
# Description: The river is small and winding and hard to see because there are no lights within its' location. The river has many colorful rocks and gems.
# ###
#
# Category: Cave
# Setting: Entrance
# Description: The entrance to his cave is covered in hanging moss with shrubs on either side of the entrance.  The path to this cave is a small dirt one with low grass on the floor.
# ###
#
# Category: Cave
# Setting: Cave exit
# Description: The large cave is covered along the walls with bright torches.  A large hole has been carved in the ceiling of the cave, right above the ladder that descends into the underground cave.  On good bright days, sunlight directly surround the hole with the gold ornate ladder descending into the underground part of the cave.  On the walls of the cave the torches illuminate many ornate drawings and paintings mainly dealing with the history of Kings of the realm.
# ###
#
# Category: Cave
# Setting: Underground chamber
# Description: This location is very gloomy, damp and magical. Has a lot of geodes and various types of crystals.
# ###
#
# Category: Cave
# Setting: Bandit lair
# Description: The outside of the cave looks normal. Inside goes for about 10 feet til' you reach the front of the Bandit lair. Inside is a barracks and dining hall with beds and a big table with chairs around it.
# ###
#
# Category: Cave
# Setting: Primary cave
# Description: Dark and with a lot of space in it. The primary cave has a scary look that scares people away. Underneath, in the floor, many precious minerals that no one dares to get out.
# ###
#
# Category: Cave
# Setting: Dark cave
# Description: Its dark, not much light can be seen in this hollow and empty cave site. Its made of stone that has been here seemingly since time began, the walls are hard as diamond, yet black like darkness itself.
# ###
#
# Category: Cave
# Setting: Orc cave
# Description: It is a dark cave that is cold and damp inside. The floor is rocks covered it bat poop. It is damp from the ceiling dripping of water. The cave just goes on what seems to be endlessly into the dark abyss. The only lite you can see is from the distance entrance of the cave.
# ###
#
# Category: Cave
# Setting: Secret tunnel
# Description: Your senses are met with the dank moisture of a secret tunnel. The stony walls are full of lichen and cave moss. Stalactites and stalagmites pepper the small channel, which bleeds in a pinpoint light from a far off point. The chill air of the King's forest whistles through the tunnel interior.
# ###
#
# Category: Trail
# Setting: Grassy plains
# Description: Flowers are blooming all around and the sun is shining. Small animals are roaming the area looking for food and relaxing. The trail is located in the center of the grassy plain and is made of stone.
# ###
#
# Category: Trail
# Setting: Trailhead
# Description: the trailhead is a worn down area leading in many directions, it has shown the wear of constant horse travel and other methods of transportation. it is till well used but in need of a makeover
# ###
#
# Category: Trail
# Setting: Path in forest
# Description: The trail path is a well designed path in the middle of a deep, dark forest. It is made purely from the bones of the innocent that were sacrificed to the ogre. There are eyes looking in the dark at you as you walk on the trail.
# ###
#
# Category: Trail
# Setting: Knight's hunting ground
# Description: The knight's hunting ground is lush and full of animals and other organisms. This area features trees, a long dirt path, and a variety of colorful wildlife.
# ###
#
# Category: Trail
# Setting: Tree of spirits
# Description: The Tree of Spirits is a large oak tree that is over 500 years old. It exceeds 100 feet tall and 10 feet wide. It's branches spread out several feet and it is home to several animals.
# ###
#
# Category: Trail
# Setting: Across the king's garden
# Description: Heavily forested with dense undergrowth that stretches for miles. A cool mist enshrouds the trees and shrubs. The sounds of birds chirping fills the air and in the distance, the rumbling of a waterfall can be heard.
# ###
#
# Category: Trail
# Setting: Hunting grounds
# Description: The hunting grounds are spacious and full of wildlife. A variety of hogs and oxen cross the grounds every day. The fields are lush with green and the skies always deep blue.
# ###
#
# Category: Trail
# Setting: Scenic overlook
# Description: This lovely clearing overlooks the great mountain range. It is covered in wildflowers of all different colors. There are stone benches where one can sit.
# ###
#
# Category: Trail
# Setting: The ghost trail
# Description: The Ghost Trail is dark, with no torches or writing.  The stars shine over head, the glow of the moon seems to beam in lulls. The trail seems to go on east or west as far as the eye can see.
# ###
#
# Category: Trail
# Setting: Trail exit
# Description: The woodland area creates a gentle, peaceful feel as one walks along past the leafy fronds and gently shifting foliage.  The path is firm and wide, having been traversed by many feet, but not so wide as to allow a merchant's cart to pass through.  A bird's cry sounds in the distance, followed by a ruffle of feathers, and then silence.  The beauty of the forest hides the struggle of nature that lies within...
# ###
#
# Category: Trail
# Setting: The opening to the drawbridge of the castle
# Description: The trailhead to the forest is a dirt trail, dusty as it has not rained in a while. The overhang of the trees is luscious and green with only patches of sunlight beaming through the dense canopy. There are many large trees, some with arrows still stuck in their trunks. The trail is treacherous as it leads through the densest part of the forest, through a stream and to a well-hidden castle. Once inside the forest, the shade and canopy has provided plenty of opportunities for foliage to grow making it harder to follow.
# ###
#
# Category: Dungeon
# Setting: A wet dungeon
# Description: It is dark and eerie, especially because there is only one candle. The candle is low on wax, it will be out soon. The brick walls surrounding the dungeon are scratched with fingernails, moss is growing.
# ###
#
# Category: Dungeon
# Setting: Torture equipment storage room
# Description: The torture storage room is a well organized room of equipment, there are lashes and cat-o-nine tails hanging from the wall, several malicious devices covered by tarp. There is a iron maiden on a dolly, some clubs for plainly breaking thigh bones in one corner, along with jars of thumbscrews, boxes or pins and a big table with ropes and a crank that stretches people until they are really uncomfortable
# ###
#
# Category: Dungeon
# Setting: Prisoner's cell
# Description: The prisoner's cell is incredibly dreary and dark. The walls are black and made of cobblestone. The atmosphere and smell are damp and repugnant.
# ###
#
# Category: Dungeon
# Setting: Torture room
# Description: The room is sparse and cold. A variety of torture implements are housed in the room, and a bloodied prisoner can often be found hanging in shackles on the wall of the room.
# ###
#
# Category: Dungeon
# Setting: Storage room
# Description: This is a plain stone room with many trunks piled high.  There's tables with paper records stacked high along with writing instruments.
# ###
#
# ...
# ###
#
# Category: Magical realm
# Setting: The cabin of an ogre
# Description: The wooden walls of the cabin are crudely adorned with a green, suspicious ooze. A dusty rug lays on the cold wooden floor of the cabin, dimly lit with a lantern situated in a corner in front of a large cobweb.
# ###
#
# Category: Magical realm
# Setting: Inside of a troll cave
# Description: A damp and vile smelling cave that only is lit by the sun that goes through the entrance. Skeletons from small animals can be seen sprawled across the floor. A little pile of leaves sit in a corner next to a campfire.
# ###
#
# Category: Magical realm
# Setting: Echo hall
# Description: A gigantic dome-like building with a round table in the center of it. There is magelight above it and encircles the dome. Traces of wizards' histories appear on the walls and disappear from time to time.
# ###
#
# Category: Magical realm
# Setting: Swamp
# Description: The swamp is glowing with wonder and color.  There are parts that range from dark red to bright yellow.  People often visit here to speak with the gods and claim it can be both harmful to those it dislikes and healing to those who it deems worthy.
# ###
#
# Category: Magical realm
# Setting: Elf's room
# Description: A tiny room in a red mushroom. Tiny frames with photos of an elf family decorate the walls of a well-lit room. A miniscule lantern lit with a single morsel shines on a table made of oak bark.
# ###
#
# Category: Magical realm
# Setting: Secret magician's workshop
# Description: This is the hidden workshop of the most powerful wizard in the land.  There are ornate tapestries on the walls depicting wizards using their powers and potions in battle.
# ###
#
# Category: Magical realm
# Setting: The fountain of youth
# Description: The water here bubbles softly, cascading down the golden framework of the fountain.  The water is clear as crystal, and shimmers softly with a faint glow that doesn't seem to quite reflect the light around it.  The fountain itself is made of elaborately filigrees of gold and silver that twist and curve to show the sparkle of the water best, and it breathtaking to behold. While the fountain's beauty is what first draws the eye, a careful glace down at the earth around it reveals a frightening sight.  Skeletons, some clad in ancient armor from kingdoms long turned to dust, others worn down so that even what clothing they had has long since disintegrated, litter the earth.  Beautiful flowers grow up from them, partially obscuring whatever carnage caused these people to perish.
# ###
#
# Category: Magical realm
# Setting: The royal tent
# Description: The walls of this tent shimmer with a soft glow at every passing breeze.  Though they seem thin and almost weblike, no trace of a draft comes from them.  A bed made of cloth that is both soft and warm hangs in the corner of the tent.  It seems to perfectly fit there, as though it was grown from the tent walls instead of skillfully placed.  The floor is carpeted with impossibly vibrant rugs, the likes of which no mortal eye has seen, and the walls of the tent rise up so high that the ceiling cannot be seen.  A brazier glows softly, and above it hangs a golden teapot.  Vapors rising from its spout waft into the space, smelling of cinnamon and spices. There is a soft glowing stone by one side of the tent wall that looks like a flagstone crafted from an impossibly large pearl. The tent is warm and inviting, and a little unnervingly beautiful.  Truly, this is a place worthy of the Royal Family of the Alabaster Elves.
# ###
#
# Category: Magical realm
# Setting: Wizard's lair
# Description: The wizard's lair is a mystical room. The walls are painted to resemble the night sky and pots of overgrown plants line the walls. Cages that once held creatures sit on top of an oak table in the center of the lair.
# ###
#
# Category: Netherworld
# Setting: The thrones of death
# Description: The main part of this room room would be the throne.  It is a shiny black with some gold ornate decorations on it. It sits on a black and gold pedestal. There is  a smaller throne in the room decorated in purple and gold.   It does not sit on a pedestal.  The room is decorated in tones of purple and blue with black accents.  This signifies death.  There are paintings of dolphin on the all.  Also to signify death.  The dolphins are typically gray.
# ###
#
# Category: Netherworld
# Setting: The pit of despair
# Description: A sinking hole in the ground, roughly 15 feet in diameter, covered by the grabbing appendages of sinners who once walked in the land of the living. A cacophony of moans, screams and scratching bellows from the depths of the cavern. There is a pool of blood, tears and excrement at the bottom of the hole where limbs can be faintly seen trying to reach the surface but never able to.
# ###
#
# Category: Netherworld
# Setting: Lava lake
# Description: A vast lake of molten magma. The temperature is well above that which would kill most mortal beings. It is surrounded by black rock formed by cooled magma. The bubbling pit seems entirely devoid of life.
# ###
#
# Category: Netherworld
# Setting: Dungeon
# Description: Dark and dreary, the dungeon hosts a portal for evil to access the netherworld. The moist dank smell casts doubt of goodness as you see the drab construct of jail cells lining the perimeter of the room.
# ###
#
# Category: Netherworld
# Setting: Viewing room
# Description: The viewing room is where those who have passed on come to watch their family members in the living world one day per year. The room resembles an opera theater. There are seats throughout the room and boxes for those who were wealthy in life to sit in. There is a stage with a large magical dome on it for viewing.
# ###
#
# Category: Netherworld
# Setting: Withered gardens
# Description: Dead trees and plants cluster in this garden, their branches thin and bone-like.  As they sway in the ghostly breeze, they look almost like skeletal hands, grasping for any living presence nearby to drain the life out of them.  There is a a dried up fountain made of cracked marble, and a bench that is made of rotting wood.  It looks as though it might turn into dust at the slightest touch.
# ###
#
# Category: Netherworld
# Setting: Whipping chamber
# Description: a stone wall with straps for tying up men and women to be punished for their immortal sins
# ###
#
# Category: Netherworld
# Setting: Reaper's lair
# Description: A room that gets very little light except for a dim candle on a pole. The walls are made of blackened stones. A wooden door with a heavy lock stands tall.
# ###
#
# Category: Netherworld
# Setting: Cavern
# Description: a lonely and isolated place, a cavernous hole in the side of a craggy mountain that leads to a network of underground tunnels.
# ###
#
# Category: Netherworld
# Setting: Torture chanber
# Description: This room is very grim and evil. There are many torturing devices strewn about. There is also blood all over the walls. The smell is putrid and relentless.
# ###
#
# Category: Netherworld
# Setting: Devil's den
# Description: The Devil's Den is dark and fiery; no one dares to look at the blood covered walls. Skulls on stakes line the walls, with piles of bones scattered on the floor.
# ###
#
# Category: Netherworld
# Setting: Lower dungeon
# Description: The lower dungeon is set below the mail hall. It is dark, lit by only a few dim torches. Water is constantly dripping down the walls, giving it a dank and musty smell. There are manacles and cages set along the walls. In the middle of the room sits a table with manacles on all corners which are attached to a large rotating lever.
# ###
#
# Category: Netherworld
# Setting: The devils castle
# Description: It is a castle that has burning flames that burn for eternity all around it. It is the tallest structure in all of the netherworld. It is dark and pitch black in some areas. It can be seen from miles away.
# ###
#
# Category: Netherworld
# Setting: The dark kings throne room
# Description: Filled with skeletons and zombies and dead bodies, the throne room of the Dark King has literally no light.
# ###
#
# Category: Netherworld
# Setting: Lord's castle
# Description: This is the location in the netherworld where the Lord and controller lives.  It is in the center of the netherworld and is difficult to reach as it is built on high rocky cliffs.
# ###
#
# Category: Supernatural
# Setting: Haunted basement
# Description: The basement is cold, damp, and dark. What little light coming in from the window is blotted out and dimmed by the spider webs sprawled across its surface. The shadows in the corners of the room appear nearly pitch black, and it almost feels as if something is looking back at you from within them.
# ###
#
# Category: Supernatural
# Setting: Magic room
# Description: A room that once entered, cannot be escaped. The walls are all mirrors, and you can never again find the door.
# ###
#
# Category: Supernatural
# Setting: Ghost monk quarters
# Description: a simple room for an undead monk. There is an uncomfortable bed, no windows, a small table with a candle, some illustrations in a book, and not much else. There is a stool
# ###
#
# Category: Supernatural
# Setting: Stonehenge
# Description: Technical and advanced, the enormous stones stand looking as if they are placed on top of each other by divine design. The green grass is a stark contrast to the gray stones hovering in the distance.
# ###
#
# Category: Supernatural
# Setting: Fighting arena inside tourney grounds
# Description: Filled with embroidered banners and filled with a crowd aching for entertainment, the fighting arena offers glory to all who enter. The arena itself is covered in orange dirt and surround by emblems and crests of all the knights who participate. There are weapon racks sprinkled alongside the edge of the arena.
# ###
#
# Category: Supernatural
# Setting: Goddess hollow
# Description: The Goddess Hollow is a place created to worship woodland spirits. It is a small, closet-like room in a hollowed out tree that has existed for hundreds of years. Within the hollow there are piles of sticks, flowers, and home-made items presented to the woodland spirits.
# ###
#
# Category: Supernatural
# Setting: Astral plane
# Description: An area between worlds where the physics known to man become irrelevant. It is a space beyond time that is home to being spectral and inconceivable to those without the eyes to see them.
# ###
#
# Category: Supernatural
# Setting: The glade of mysteries
# Description: The leaves of the trees surrounding this glade glow unnaturally, as though lit from within.  There seems to be almost a presence to this place, a waiting watchful force.  Bits of music sound occasionally, tunes that seem familiar and yet quite alien, as though played by someone who had only heard the melody described to them, instead of hearing it themselves.  And yet all this pales in comparison to the pool found in the center.  The water gleams silver, seemingly absorbing and reflecting back the light of the trees around it tenfold.  Though there is a soft breeze that blows through the glade, there is not a ripple to be seen on the water's perfectly mirrored surface.
# ###
#
# Category: Supernatural
# Setting: Bridge in the forest
# Description: You are at a bridge. It is old and used very rarely. It is dim and foggy. The brigde is large and there is a small stream below it.
# ###
#
# Category: Underwater aquapolis
# Setting: Geothermal valley
# Description: Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.
# ###
#
# Category: Underwater aquapolis
# Setting: Dry dock room
# Description: The room is located on the border wall of the aquapolis. There is one on the far north and far south side.
# ###
#
# Category: Underwater aquapolis
# Setting: Farmhouse
# Description: a small house on a seaweed plantation, small and rustic, really only the single room with a closet, maybe, a table and some chairs
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater marketplace
# Description: The marketplace is the main hub for the residents of the aquapolis. With high ceilings and bright, colorful flags at each market stand, the place seems to stretch on forever. Near the entrance, there is a young boy attempting to sell the latest news of the kingdom.
# ###
#
# Category: Underwater aquapolis
# Setting: Underwater aquapolis
# Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# ###
#
# Category: Underwater aquapolis
# Setting: The dungeon
# Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# ###
#
# Category: Underwater aquapolis
# Setting: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# ###
#
# Category: Underwater aquapolis
# Setting: The lords treasury
# Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# ###
#
# Category: Underwater aquapolis
# Setting: Research lab
# Description: The research lab is the main science hub of the aquapolis. Dozens of scientists are working on a myriad of different projects.
# ###
#
# Category: Underwater aquapolis
# Setting: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# ###
#
# Category: Underwater aquapolis
# Setting: The marketplace
# Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# ###
#
# Category: Underwater aquapolis
# Setting: Toad hollow
# Description: Toad Hollow is a filthy room within the Underwater Aquapolis. When you enter, you are greeted by the reek of scummy pond water. You enter Toad Hollow through a drainage pipe that you have to crawl through. Once inside Toad Hollow, you can stand up, but you still don't feel comfortable with your surroundings. As far as the eye can see there is muddy water in a circular basin with lily pads floating in it. On the pads, giant toads jump back and forth making gurgling, croaking sounds. As you wade deeper into Toad Hollow, the water comes up to your waist and you see the flash of a fin. There is legend that a creature lives in the center of Toad Hollow that is half human, half monster. Not even the strongest knight has been brave enough to examine it. The fin disappears back underwater but there is a red glint suggesting eyes are watching you. When you reach the other side of the basin, you crawl into another drainage pipe and feel relieved that you're out of this place.
# ###

# %% [markdown]
# # Fine-tune GPT3 with the OpenAI API
#
# Next, we'll perform fine-tuning with this data using OpenAI.

# %%
# %%capture
# !pip install --upgrade openai
# !pip install jsonlines

# %% [markdown]
# Once you've got access to the OpenAI API, you can find your OpenAI API key [here](https://beta.openai.com/account/api-keys).

# %%
import os
import openai

print('Enter OpenAI API key:')
openai.api_key = input()

os.environ['OPENAI_API_KEY']=openai.api_key
# Out:
# Enter OpenAI API key:
# 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

# %%
# !head fine_tuning_location_descriptions.jsonl
# Out:
# {"prompt": "Category: Forest\nSetting: Riverbed\n", "completion": "Description: With clear air and the sound of gurgling water near it, the river bed is silty and muddy. The river rushes by the land as more and more dirt separates from the land. The land of the riverbed slick with mud and filled with bugs and worms/\n###\n"}
# {"prompt": "Category: Forest\nSetting: Firewood forest\n", "completion": "Description: The forest has many trees. The majority of the trees are green however a few are orange and red. The forest is huge and seems to never end.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Along the banks of a river in the forest\n", "completion": "Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Flower garden\n", "completion": "Description: This clearing is in reveal a wide circle of trees. Proud oaks stand close enough that only the smallest of fauna can squeeze through, protecting the garden within from curious deer and hungry rabbits. Flowers of every hue and shade crowd the soft lawn of grass, soaking up what light they can through the shadows cast by the branches above. Purple, yellow, red, blue - even green blossoms bob in the breeze, their scents mixing to create a heady perfume. Vines and creepers climb up the tree trunks, dripping with grapes and berries.\n###\n"}
# {"prompt": "Category: Forest\nSetting: The clearing\n", "completion": "Description: the clearing is surrounded by old pine trees where knights used to practice swinging their swords. There are haystacks where they take wenches and pay them a sickle.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Fairy forest\n", "completion": "Description: The fairy forest is full of brightly colored flowers that grow up to 30 feet tall.  There are also ornate birds that live here.  When you whistle, a fairy will come to you and tweak your nose.  They don't like a lot of nose so it irritates them enough for them to come out of their homes made from watermelon skins.\n###\n"}
# {"prompt": "Category: Forest\nSetting: Woodlands\n", "completion": "Description: The lush hunting grounds cover acres of land, tall trees and thickets of bushes sprawling across the land. Fields of open land are under the deep blue sky, showing the depth of the landscape. The grounds forest is thick but full of light, letting the multitude of wildlife be seen by the naked eye. The abundance of greenery makes it a prime location for hogs and oxen as they explore the land.\n###\n"}
# {"prompt": "Category: Forest\nSetting: The stream\n", "completion": "Description: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.\n###\n"}
# {"prompt": "Category: Forest\nSetting: North forest\n", "completion": "Description: Filled with huge trees, the forest is home to many types of animals. Huge predators such as tigers and bears roam the grounds as do small animals like squirrels. Colorful birds fly among the trees. Wildflowers grow on the ground. Dappled sunlight streams through the huge canopy of trees.\n###\n"}
# {"prompt": "Category: Forest\nSetting: A room hidden in the dense canopy\n", "completion": "Description: Its a large room with types of beings you have never seen before. There is a counter and a person who greets people suprise when you arrive because you are not one of them. The room has an unfamiliar feel to it. with doors leading to walkways, other buildings, an entire city\n###\n"}

# %% [markdown]
# Next, we'll make the fine tuning API call via the command line.  Here the -m argument gives the model.  There are 4 sizes of GPT3 models.  They go in alphabetical order from smallest to largest.
# * Ada
# * Babbage
# * Currie
# * Davinci
#
# The models as the model sizes increase, so does their quality and their cost.  Davinci is the highest quality and highest cost model.  I recommend starting by fine-tuning smaller models to debug your code first so that you don't rack up costs.
#
# Fine-tuning curie costs about $0.50 for this data.

# %%
# model name: ada:ft-cis-700-48-2022-01-26-03-55-04
# model name: babbage:ft-cis-700-48-2022-01-29-03-34-26
# !openai api fine_tunes.create -t fine_tuning_location_descriptions.jsonl -m babbage
# Out:
# Found potentially duplicated files with name 'fine_tuning_location_descriptions.jsonl', purpose 'fine-tune' and size 196498 bytes
# file-08LSXxBNLVXCGZDbFdD1sZR6
# file-dxtSWLthysPSNJsaJFji9C5k
# Enter file ID to reuse an already uploaded file, or an empty string to upload this file anyway:
# Upload progress: 100% 196k/196k [00:00<00:00, 341Mit/s]
# Uploaded file from fine_tuning_location_descriptions.jsonl: file-eVIqoQ7ZJlMiPt6Upth4qfox
# Created fine-tune: ft-nuz5zcUtSWMGcS4bhQCaYwR7
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2022-01-29 03:22:18] Created fine-tune: ft-nuz5zcUtSWMGcS4bhQCaYwR7
# [2022-01-29 03:22:27] Fine-tune costs $0.09
# [2022-01-29 03:22:27] Fine-tune enqueued. Queue number: 0
# [2022-01-29 03:22:30] Fine-tune started
# [2022-01-29 03:25:36] Completed epoch 1/4
# [2022-01-29 03:28:18] Completed epoch 2/4
# [2022-01-29 03:31:00] Completed epoch 3/4
# [2022-01-29 03:33:42] Completed epoch 4/4
# [2022-01-29 03:34:28] Uploaded model: babbage:ft-cis-700-48-2022-01-29-03-34-26
# [2022-01-29 03:34:31] Uploaded result file: file-Vwmw34XHCHYcj10GZMIhdFX0
# [2022-01-29 03:34:32] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m babbage:ft-cis-700-48-2022-01-29-03-34-26 -p <YOUR_PROMPT>

# %% [markdown]
# You should copy down the fine-tune numbers which look like this:
#
# ```
# Created fine-tune: ft-VzQpTwfnWAzDXNKgPTFtiZg2
#
# [2022-01-21 23:22:47] Uploaded model: curie:ft-ccb-lab-members-2022-01-21-23-22-46
# ```
#
# If you forget to write it down, you can list your fine-tuned runs and models this way. These model names aren't mneumonic, so it is probably a good idea to make a note on what your model's inputs and outputs are.

# %%
# !openai api fine_tunes.list
# Out:
# {
#   "data": [
#     {
#       "created_at": 1643169166,
#       "fine_tuned_model": "ada:ft-cis-700-48-2022-01-26-03-55-04",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-ulusZ12hCWtHYpU2M6qv1Gkk",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-bf3sK1yipoxt2SvO8joBKAaU",
#       "result_files": [
#         {
#           "bytes": 16136,
#           "created_at": 1643169307,
#           "filename": "compiled_results.csv",
#           "id": "file-rXMSi9w5Aqr11a27tpmKCR7E",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 5827,
#           "created_at": 1643169165,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-OdkS56cB9vd1UASvdmSuvQW3",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643169309,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643169794,
#       "fine_tuned_model": "davinci:ft-cis-700-48-2022-01-26-04-14-03",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-OBNdhdyVXNQ5SgrxEDs77UFa",
#       "model": "davinci",
#       "object": "fine-tune",
#       "organization_id": "org-bf3sK1yipoxt2SvO8joBKAaU",
#       "result_files": [
#         {
#           "bytes": 16075,
#           "created_at": 1643170446,
#           "filename": "compiled_results.csv",
#           "id": "file-BUYhI11ELC0ac50XrYCme3FH",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 5827,
#           "created_at": 1643169793,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-F8t6zpR7Qe8GunCW0jNRA5x2",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643170449,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643171926,
#       "fine_tuned_model": "ada:ft-cis-700-48-2022-01-26-04-53-48",
#       "hyperparams": {
#         "batch_size": 2,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-c5DZQtG7ums9k9o7T7BMtiz5",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-bf3sK1yipoxt2SvO8joBKAaU",
#       "result_files": [
#         {
#           "bytes": 87084,
#           "created_at": 1643172830,
#           "filename": "compiled_results.csv",
#           "id": "file-5jtXioUR2Z3YhpFRSqgcblgJ",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 57828,
#           "created_at": 1643171925,
#           "filename": "fine_tuning_intent_determination-1.jsonl",
#           "id": "file-WQNQn4UkT9uhgTyb6o6dORNW",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643172834,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643425556,
#       "fine_tuned_model": "ada:ft-cis-700-48-2022-01-29-03-14-36",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-GVRRlJUnYo2n278c71HtxLyD",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-bf3sK1yipoxt2SvO8joBKAaU",
#       "result_files": [
#         {
#           "bytes": 117691,
#           "created_at": 1643426078,
#           "filename": "compiled_results.csv",
#           "id": "file-eEG5JTdJF5ZFcm9lJsAo9XIF",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 196498,
#           "created_at": 1643425554,
#           "filename": "fine_tuning_location_descriptions.jsonl",
#           "id": "file-dxtSWLthysPSNJsaJFji9C5k",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643426081,
#       "validation_files": []
#     },
#     {
#       "created_at": 1643426538,
#       "fine_tuned_model": "babbage:ft-cis-700-48-2022-01-29-03-34-26",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.05,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.1
#       },
#       "id": "ft-nuz5zcUtSWMGcS4bhQCaYwR7",
#       "model": "babbage",
#       "object": "fine-tune",
#       "organization_id": "org-bf3sK1yipoxt2SvO8joBKAaU",
#       "result_files": [
#         {
#           "bytes": 117825,
#           "created_at": 1643427269,
#           "filename": "compiled_results.csv",
#           "id": "file-Vwmw34XHCHYcj10GZMIhdFX0",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 196498,
#           "created_at": 1643426537,
#           "filename": "fine_tuning_location_descriptions.jsonl",
#           "id": "file-eVIqoQ7ZJlMiPt6Upth4qfox",
#           "object": "file",
#           "purpose": "fine-tune",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "updated_at": 1643427272,
#       "validation_files": []
#     }
#   ],
#   "object": "list"
# }

# %% [markdown]
# You can run your fine tuned model in the OpenAI Playground.  After the model is finished finetuning you'll find it in the Engine dropdown menu.
#
# You'll need to give the inputs that we used as the "prompt" in our training data.  In this case we gave it a `Category:` and a `Location:` name.  You can also add the `Description:` part of the completion if you want. You should also set the stop sequence to be `###`. For example, we could type this input into the playground:
#
# ```
# Category: Dark Forest
# Location: Winter's Glade
# Description:
# ```
# If you press the "Generate" then your fine tuned model will output something like:
#
# > The forest at night is not a place one would willingly set foot in. It is cold and dark and seems to go on forever. Trees loom over you, blocking out the light of the moon and stars. The only sound is the occasional howl of a wolf and the occasional splashing of water.
#
# If you don't like the description, you can press the "Regerate" button to get other outputs like:
#
# > The winter's glade is a dark and eerie place. It is home to many animals, but little else. The trees are barren and the ground is covered in snow.
#
# Or
#
# > The dark forest is a place where not even a ray of light can pierce the tangled web of branches overhead. Needles from vast numbers of trees protrude at awkward angles, their branches thin and frail, more like twigs than the strong trunks they resemble. Between the branches, a darkness deeper than night reigns. It is from this darkness that the trees themselves appear as ghosts, for the branches do not embrace the earth so much as merely touch it. The tips of the branches move slightly with every breath taken by the trees, and the dark forest seems to breathe along with them.
#
# Or
#
# > The forest has now turned white.  The trees are barren and dead, their branches thin and broken.  There's a light dusting of snow on the ground, and it looks as if the forest is trying to erase all traces of life from the earth.

# %% [markdown]
# You can press the "Code" button to get a snippet of code that you can adapt into your own Python programs.
#
# ```
# import os
# import openai
#
# openai.api_key = os.getenv("OPENAI_API_KEY")
#
# response = openai.Completion.create(
#   model="curie:ft-ccb-lab-members-2022-01-21-23-22-46",
#   prompt="Category: Dark Forest\nLocation: Winter's Glade\nDescription:",
#   temperature=0.7,
#   max_tokens=64,
#   top_p=1,
#   frequency_penalty=0,
#   presence_penalty=0,
#   stop=["###"]
# )
# ```
#
# Here's an example of how to write a function using the code that the OpenAI API provides.

# %%
def get_location_description(category, location_name, finetuned_model):
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Category: {category}\nSetting: {location}\nDescription:".format(
    #   prompt="Category: {category}\nLocation: {location}\nDescription:".format(
          category=category.capitalize(),
          location=location_name.capitalize()
      ),
      temperature=0.7,
      max_tokens=64,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0,
      stop=["###"]
      )
  return response['choices'][0]['text']

# Replace with your model's name
finetuned_model = "babbage:ft-cis-700-48-2022-01-29-03-34-26"
# finetuned_model = "ada:ft-cis-700-48-2022-01-26-03-55-04" # bad performance 
# finetuned_model = "curie:ft-ccb-lab-members-2022-01-21-23-22-46"
category = "Dark Forest"
location_name = "Winter's Glade"

descripton = get_location_description(category, location_name, finetuned_model)
print(descripton)
# Out:
#  The glade is dark and cold. A few feet away, a white bear is sleeping in the sun. The bear is brown with a white topknot. The glade has a faint odor of pine.

# %% [markdown]
# # TODO: Fine-Tune Additional Models for Text Adventure Games
#
# In this assignment, we'll ask you to fine-tune models to perform the following tasks:
# 1. Describe a location (I've given you this code.  You can adapt it for other models)
# - inputs: category, location name
# - output: location description
# 2. List the items that are at a location
# - inputs: category, location name, location description, number of items
# - output: list of item names
# 3. Describe an item
# - inputs: category, location name, location description, item name
# - output: item description
# 4. List connections from the current location
# - inputs: category, location name, location description, and optionally a partial list of existing connections (direction, location name) tuples
# - output: a list of (direction, location name) tuples
# 5. Get an item's properties
# - inputs: item name, item description, property (e.g. gettable)
# - output: True or False if the item has that property

# %% [markdown]
# ## 1. Describe a location

# %%
# 1. Describe a location (already trained above as a tutorial example)
# - inputs: category, location name
# - output: location description 
def get_location_description(category, location_name, finetuned_model):
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Category: {category}\nLocation: {location}\nDescription:".format(
          category=category.capitalize(),
          location=location_name.capitalize()
      ),
      temperature=0.7,
      max_tokens=64,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0,
      stop=["###"]
      )
  return response['choices'][0]['text']

# %% [markdown]
# ## 2. List the items that are at a location

# %%
# 2. List the items that are at a location
# - inputs: category, location name, location description, number of items
# - output: list of item names
def get_items_at_location_prompt(room_id, rooms_by_id, light_environment):
  """
  This generates a prompt and a completion which can be used to fine-tune OpenAI.
  This version just gnnerates 
  """
  objects = rooms_by_id[room_id]['in_objects']
  prompt = ""
  completion = ""
  prompt += "Category: {category}\n".format(category=rooms_by_id[room_id]['category'].capitalize())
  prompt += "Location: {setting}\n".format(setting=rooms_by_id[room_id]['setting'].capitalize())
  prompt += "Description: {description}\n".format(description=rooms_by_id[room_id]['description'])
  prompt += "Number of items: {number_of_items}\n".format(number_of_items=len(objects))
  items = [light_environment['objects'][str(object_id)]['name'] for object_id in objects]
  items_str = ', '.join(items)
  completion += "Items: {items}\n".format(items=items_str)
  completion += "###\n"

  return prompt, completion


def create_items_at_location_finetuning_data(filename='fine_tuning_items_at_location.jsonl'):
  fine_tuning_data = []
  for category in categories:
    rooms = rooms_by_category[category]
    for room_id in rooms:
      data = {}
      prompt, completion = get_items_at_location_prompt(room_id, rooms_by_id, light_environment)
      data['prompt'] = prompt
      data['completion'] = completion
      print(prompt, end="")
      print(completion)
      fine_tuning_data.append(data)

  with open(filename, 'w') as out:
    for data in fine_tuning_data:
        out.write(json.dumps(data))
        out.write('\n')

create_items_at_location_finetuning_data()
# Out:
# Category: Forest
# Location: A room hidden in the dense canopy
# Description: Its a large room with types of beings you have never seen before. There is a counter and a person who greets people suprise when you arrive because you are not one of them. The room has an unfamiliar feel to it. with doors leading to walkways, other buildings, an entire city
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: Entrance to the pine trees
# Description: Very tall and towering pine trees that create a dark canopy of shade. Long skinny trees sway in the sky from the soft breeze. Pine needles scatter the ground like plush carpet.
# Number of items: 4
# Items: towering pine trees, Long skinny trees, Pine needles, needles
# ###
#
# Category: Forest
# Location: South forest
# Description: The forest is lined with tall trees but has a long walkway for travelers. I the middle of the forest is a long river surrounded by tall grass with clear blue waters and lots of colorful fish.
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: Mysterious forest outskirts
# Description: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.
# Number of items: 2
# Items: trees, food
# ###
#
# Category: Forest
# Location: Fairy forest
# Description: The fairy forest is full of brightly colored flowers that grow up to 30 feet tall.  There are also ornate birds that live here.  When you whistle, a fairy will come to you and tweak your nose.  They don't like a lot of nose so it irritates them enough for them to come out of their homes made from watermelon skins.
# Number of items: 2
# Items: brightly colored flowers that grow up to 30 feet tall, homes made from watermelon skins
# ###
#
# Category: Forest
# Location: Ant hill
# Description: The ant hill is very large, over 5 feet high, and is wrapped around the base of a pine tree. The ants are huge compared to normal ants, and jut in and out of large holes in the ant hill. Bones of animals and even people can be seen sticking out of the red dirt ant hill.
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: Unsettling forest area
# Description: The forest is actually very creepy even during the day. The trees are so tall that they block the sunlight. There is always fog in the forest which makes it very hard to see. There are a lot of mushrooms near the trees and none of them are edible
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: North forest
# Description: Filled with huge trees, the forest is home to many types of animals. Huge predators such as tigers and bears roam the grounds as do small animals like squirrels. Colorful birds fly among the trees. Wildflowers grow on the ground. Dappled sunlight streams through the huge canopy of trees.
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: Riverbed
# Description: With clear air and the sound of gurgling water near it, the river bed is silty and muddy. The river rushes by the land as more and more dirt separates from the land. The land of the riverbed slick with mud and filled with bugs and worms/
# Number of items: 12
# Items: clear air, gurgling water, river, the land, dirt, mud, water, dirt, river, mud, worms, fish
# ###
#
# Category: Forest
# Location: Pine tree graveyard
# Description: Once known as a forest of solitude, the entrance to the pine trees is now a bleak and dreary graveyard.  Dead grass and moss fill the ground along with crawling critters that mark fear in the mind among the he who venture here.  Tombstones so old many of the names are no longer eligible.  Dense fog surrounds the area, thick tree tops blotting out the sunlight, and an eerie silence fills the air.  Cold it feels, the air, but the ground is soft and warm.  Sound can not enter, no escape this dwelling.
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: The stream
# Description: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.
# Number of items: 5
# Items: The water, rainfall, The water in the sky, higher elevations, water
# ###
#
# Category: Forest
# Location: A wooded magical village
# Description: The village lay hidden in a secret grotto that is set in a sort of valley between trees. The village is populated by child-like peoples who wear clothes made of various plant matter such as large leaves and vines. The homes are made of wood, and seemingly blend into the green dense backdrop.
# Number of items: 6
# Items: clothes, plant matter, large leaves, vines, homes, clothes made of various plant matter such as large leaves and vines
# ###
#
# Category: Forest
# Location: Woods
# Description: The woods are vast. Everywhere you turn it all looks the same. There are scratches on the trees from lost travelers marking their path. There are sounds coming from everywhere and yet no where. There are faint yellow circles up in the trees and bushes, possibly eyes starting at you.
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: The brush den
# Description: The entryway to the brush den is made of arched bushes and various plants, as is the ceiling and walls. The inside is furnished with seats made of plant roots that have grown together, and a table made of wood adorned with flowers and wooden cups and plates. A small vine dangles with a glowing floor from the middle of the ceiling that lights the room dimly. Three small beds lay in one corner of the room made of interlaced grass and leaves.
# Number of items: 15
# Items: arched bushes, various plants, seats, flowers, wooden cups, plates, beds, arched bushes, various plants, ceiling, walls, seats made of plant roots, table, beds, small vine
# ###
#
# Category: Forest
# Location: Along the banks of a river in the forest
# Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.
# Number of items: 6
# Items: river, fish, insects, grass, river, riverbank
# ###
#
# Category: Forest
# Location: Woodlands
# Description: The lush hunting grounds cover acres of land, tall trees and thickets of bushes sprawling across the land. Fields of open land are under the deep blue sky, showing the depth of the landscape. The grounds forest is thick but full of light, letting the multitude of wildlife be seen by the naked eye. The abundance of greenery makes it a prime location for hogs and oxen as they explore the land.
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: Forbidden forest
# Description: The forbidden forest is a dark and very scary place. The trees are covered in spider web nets and huge spiders. The forest echoes sounds of witches' laughs and creepy crawly animals.  There is a brisk breeze that runs through the trees that will put chills down your spine.
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: Picnic area
# Description: In this picnic area, there is a wide clearing with some cut down tree stumps made for people to sit and enjoy their lunch.  There's also a small pond nearby where people can feed fish and watch turtles sunbathe.
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: The clearing
# Description: the clearing is surrounded by old pine trees where knights used to practice swinging their swords. There are haystacks where they take wenches and pay them a sickle.
# Number of items: 7
# Items: the clearing, old pine trees, swords, haystacks, sickle, river, trees
# ###
#
# Category: Forest
# Location: Firewood forest
# Description: The forest has many trees. The majority of the trees are green however a few are orange and red. The forest is huge and seems to never end.
# Number of items: 3
# Items: The forest has many trees., wood is gathered to make fire, new trees are built once a year
# ###
#
# Category: Forest
# Location: Flower garden
# Description: This clearing is in reveal a wide circle of trees. Proud oaks stand close enough that only the smallest of fauna can squeeze through, protecting the garden within from curious deer and hungry rabbits. Flowers of every hue and shade crowd the soft lawn of grass, soaking up what light they can through the shadows cast by the branches above. Purple, yellow, red, blue - even green blossoms bob in the breeze, their scents mixing to create a heady perfume. Vines and creepers climb up the tree trunks, dripping with grapes and berries.
# Number of items: 0
# Items:
# ###
#
# Category: Forest
# Location: Pond
# Description: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.
# Number of items: 5
# Items: frogs, wildlife, water, trees, rocks
# ###
#
# Category: Forest
# Location: Forest entrance
# Description: The path quickly narrows and darkens upon entering the forest.  Dense branches overhead block all but a few stray rays of sunshine.  Fallen leaves just beginning to rot blanket the forest floor, and every footstep kicks up a rich, loamy scent as fresh ground is unearthed.
# Number of items: 0
# Items:
# ###
#
# Category: Shore
# Location: Enchanted light house
# Description: Slightly rusted and corroded from the crashing waves, elegant and tall. each window and opening is lined with a bronze trim.  Some gears can be seen turning along the side, rotating a middle section of the light house.
# Number of items: 2
# Items: window, gears
# ###
#
# Category: Shore
# Location: Coast
# Description: The coast seems to stretch on for miles in either direction.  The ocean itself has receded some and the tide has not yet rolled in.  The water laps half-heartedly at the sand and the glistening shades of seashells dot the wet sand.  All around the sand gleams a shade of white.
# Number of items: 3
# Items: water, sand, glistening shades of seashells
# ###
#
# Category: Shore
# Location: Beach house
# Description: the beach house is falling apart due to the storms, it's door is hanging and it's humid inside. There is no floor, just sand, and a hole to serve as the outhouse.
# Number of items: 6
# Items: beach house, door, the beach house, it's door, sand, a hole
# ###
#
# Category: Shore
# Location: The beach
# Description: Sand that is white as snow. the water is as clear as a crystal. down the shore is some cliffs
# Number of items: 2
# Items: Sand that is white as snow, water is as clear as a crystal
# ###
#
# Category: Shore
# Location: Turquoise shore
# Description: A beautiful turquoise color water by the shore. It is filled with many gems and gold.
# Number of items: 7
# Items: turquoise color water, gold, mermaids, shiny things, many gems, gold, water
# ###
#
# Category: Shore
# Location: Fishing pier
# Description: A spindly, long fishing pier that sits right outside the village. Barnacles cover its pilings in vast numbers. Many villagers can be seen fishing atop of it. Birds and pelicans squawk and fly above it.
# Number of items: 4
# Items: Barnacles, pilings, peasants, pelicans
# ###
#
# Category: Shore
# Location: Old docks
# Description: The shore near the docks. There is fog except on rare occasions. More dangerous than most people would like. You never know what dangers luck from creatures leaving and entering the waters.
# Number of items: 0
# Items:
# ###
#
# Category: Shore
# Location: Beach house
# Description: A marvelous beach house that sits upon the fine white sand of the beach. It looks mighty expensive, as the house has solid gold walls. A gigantic and lavish marble pier extends into the ocean out in front of the house.
# Number of items: 9
# Items: A gigantic and lavish marble pier, the ocean, fine white sand, the beach, beach, sand, walls, pier, ocean
# ###
#
# Category: Shore
# Location: Throne room
# Description: ornate and luxurious, the throne room gleams with gold and precious jewels. Priceless painting of past kings line the sides. underneath a vaulted ceiling regal a red carpet connect the throne room entrance to the golden throne itself.
# Number of items: 9
# Items: gold, precious jewels, priceless painting, red carpet, golden throne, priceless painting of past kings, vaulted ceiling, red carpet, golden throne
# ###
#
# Category: Shore
# Location: King's quarters
# Description: The room is large. The largest of all the throne rooms. The carvings on the wall are ornate and historical. The room is clearly built for royalty. The bed is covered in designed covers. It is truly a sight to see.
# Number of items: 3
# Items: carvings, bed, designed covers.
# ###
#
# Category: Shore
# Location: Lighthouse
# Description: The lighthouse is an off-white color, towering fifty feet over the shore. The light from the building extends out for miles past the shoreline.
# Number of items: 2
# Items: lighthouse, ships
# ###
#
# Category: Shore
# Location: Pier walkway
# Description: On the seashore facing the pier, seagulls squawk as they swirl overhead. The smell of salt fills the air, and the gentle, dull roar of the waves lapping the beach is omnipresent. A gentle breeze blows, and the chatter of the villagers fishing drifts down to the shoreline from the pier.
# Number of items: 0
# Items:
# ###
#
# Category: Shore
# Location: Large cliffs
# Description: Towering cliffs of gray granite line the coast. A few meters of sand lie between the ocean and the base of the cliffs.
# Number of items: 0
# Items:
# ###
#
# Category: Shore
# Location: A battleship
# Description: It is a glamorous wooden ship.  It glistens like there are diamonds encrusted on the hull.  There are ornate railings on the stairs as it is a massive boat.  There is even a sea monster on the bow, complete with jeweled eyes and gold hair.
# Number of items: 8
# Items: ornate railings on the stairs, sea monster on the bow, hull, ornate railings, stairs, sea monster, jeweled eyes, gold hair
# ###
#
# Category: Countryside
# Location: Countryside
# Description: The countryside is quite nice, it's not filled with a lot of people but with travelers here and there. Some in small groups some on their own. They are hosting a campfire where everyone has some to sit and is telling stories about their adventures. Someone is showing local children how to wield some weapons. Another is offering lodge, and stable for travelers and their animals.
# Number of items: 0
# Items:
# ###
#
# Category: Countryside
# Location: Hillside mansion
# Description: I sweeping villa that rests on the grand hills. Everyone can see how grand it is when they approach from the country road. A tall, wrought-iron fence surround its grounds, which extends for miles.
# Number of items: 1
# Items: fence
# ###
#
# Category: Countryside
# Location: Pig pen
# Description: A filthy pen where tons of squalling pigs rut and throw a ruckus, Their snorts and farts can be heard from any passerby miles before getting to the pen. The pig pen is a few feet from Farmer Bob's cottage. The pigs never sleep and are always eating and playing in the mud.
# Number of items: 1
# Items: mud
# ###
#
# Category: Countryside
# Location: Chicken pen
# Description: The chicken pen has wire cages situated on three different levels, with hay at the bottom for the chicken's to sit in. There lie small holes in the cages for the eggs to fall through and be easily harvested by the farmers. The old wooden walls of the chicken pen are beginning to deteriorate and show signs of age.
# Number of items: 0
# Items:
# ###
#
# Category: Countryside
# Location: Hillside manor
# Description: A quaint manor that sits in the rolling hills. It is surrounded by a small stone fence and looks quite inviting to passersby. It looks like any other home that a well off business man would own.
# Number of items: 5
# Items: quaint manor, rolling hills, small stone fence, home, bookshop
# ###
#
# Category: Countryside
# Location: Meadow
# Description: Large clear outdoor meadow. Flowers of blue and white appearing in bunches here and there. The grass glows with a green light. Not much can be said about its appearance, however there is a mystical allure associated with the place as if a meadow for spirits instead of livestock.
# Number of items: 3
# Items: Flowers, grass, meadow
# ###
#
# Category: Countryside
# Location: Nearby road
# Description: The road cuts through the countryside. It is a dirt road, with a fence lining the eastern side and a grassy meadow to the west.
# Number of items: 0
# Items:
# ###
#
# Category: Countryside
# Location: Flower field
# Description: The flower field contains acres of wild growing flowers that are a bright pink when they are in bloom. There are woods surrounding it, but no trees in the field, only flowers. There are paths that work their way through the field.
# Number of items: 0
# Items:
# ###
#
# Category: Countryside
# Location: Maidens cottage
# Description: Free standing in the vast countryside, with gentle rolling hills and lush green grass and vegetation sits the cottage. There are a couple of Oak trees close to the cottage as the only tall trees around for miles. Colorful Dandelions, perennials, and daisies grow wildly and freely along the hills.
# Number of items: 5
# Items: gentle rolling hills, couple of Oak trees, Colorful Dandelions, herd some sheep, grasslands around the cottage
# ###
#
# Category: Countryside
# Location: Peasant's cottage
# Description: The peasant's cottage is a fairly simple wood building with a straw thatched roof.  Inside, you have a fireplace and large pot for cooking, a long wooden dinner table, and some hay filled beds lying on the floor.  There are two chests lying inside with personal belongings such as clothes and family heirlooms.
# Number of items: 0
# Items:
# ###
#
# Category: Countryside
# Location: Main gate
# Description: The main gate is tall and strong enough to protect the mansion from invaders, and has large wooden doors reinforced by planks and steel sheets. There are two towers on either side of the gate for the town's watchmen to use as their post.
# Number of items: 0
# Items:
# ###
#
# Category: Countryside
# Location: Horse field
# Description: The horse field includes a huge plains for horses to ride. The fields are yellow and green. The place smells of musk and horse.
# Number of items: 1
# Items: horses
# ###
#
# Category: Countryside
# Location: Path to the manor
# Description: The outside of the manor is rather imposing with a large stone building and two immense guardian sculptures on the outside depicting mythical beasts. There are also small gardens to the left and right.  The main path itself is a cobbled one that only beckons visitors if they are worthy enough.
# Number of items: 0
# Items:
# ###
#
# Category: Countryside
# Location: The forest
# Description: The forest has many trees. It has other plants too. There are animals and many livings things. The forest is very much full of life. When you look at it you might only see plants that are green and different shades of brown but there are many other living things in there too.
# Number of items: 4
# Items: trees, plants, trees, plants
# ###
#
# Category: Countryside
# Location: A cabin
# Description: Plain, pretty basic wooden cabin.  In a field of wildflowers, there is also a pen for the chickens, a clothes line.
# Number of items: 7
# Items: Plain, pretty basic wooden cabin, wildflowers, a pen for the chickens, a clothes line, wildflowers, pen, clothes line
# ###
#
# Category: Countryside
# Location: Lush meadow in the country side
# Description: Green large trees surround the meadow that if filled with beautiful seasonal flowers. A deer is grazing in the far end of the field. A small dirt country road gentle crooks past on the outside of the road.
# Number of items: 3
# Items: Green large trees, beautiful seasonal flowers, small dirt country road
# ###
#
# Category: Countryside
# Location: The small dirt road
# Description: This small dirt road is flanked by a lush green forest on each side with birds chirping and the occasional deer running about.  Sometimes, you can find broken down wooden wagons left behind from ambushes carried out by bandits.
# Number of items: 0
# Items:
# ###
#
# Category: Countryside
# Location: Cottage
# Description: The small cottage was white with two, shuttered windows. It was in the unique shape of a circle and was built of plaster. Smoke billowed from the chimney.
# Number of items: 4
# Items: shuttered windows, chimney, shuttered windows, chimney
# ###
#
# Category: Countryside
# Location: Meadow
# Description: This meadow is composed of green, luscious, rolling hills. Flowers dot the expanse. In the evening, one may stand from the hills of this meadow and see the sun set beneath the horizon off in the distance.
# Number of items: 3
# Items: Flowers, green, luscious, rolling hills, Flowers
# ###
#
# Category: Countryside
# Location: Valley of doom
# Description: The Valley of Doom is overrun by dead trees and grasses.  Eerie looking animals peer at you through the brushes.  It is a dark and wicked place.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Marketplace
# Description: Merchants call out their wares and try desperately to get the attention of the wealthier passerby. People from all over the world hustle to and fro, some keenly eyeing the many tapestries, spices, tools and foods, others openly staring in wonder. Still others hurry along, heads down and avoiding eye contact. Colors, smells and sounds assault the senses. The cries of the gulls can hardly be deciphered from the chatter of the crowds, the ringing of the blacksmith's hammer, the bells of the nearby shipyard, and the hollers of the merchants.
# Number of items: 5
# Items: tapestries, spices, tools, food, blacksmith's hammer
# ###
#
# Category: Port
# Location: Boat house
# Description: A small house type establishment that serves as a hang out for people about to board the boats.  There is nautical themed decor everywhere.  Life Buoys, mounted fish, replica boats.  It's all wood inside with a bar as well.  A lot of creaky looking wood too, probably weathered a good bit as the house is old itself.
# Number of items: 5
# Items: nautical themed decor, Life Buoys, mounted fish, replica boats, a bar
# ###
#
# Category: Port
# Location: Quay
# Description: During the day, the quay is bustling with typical activity of a port: burly longshoremen carry crates and roll barrels away from ships for storage and sailors who still have their sea-legs saunter past on their way to drink and more adventures. By night, the quay is teeming with unsavory characters: men who are hardly men any more after losing their way through drink and gambling hunker amongst coils of rope stiffened by the salt water while rats scramble from box to box gnawing their way into the goods contained inside.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Warehouses
# Description: The warehouses are the largest structures in the port, rising well above the adjoining buildings. Constructed from virgin timber, the beams overhead support lofts that are filled to capacity with boxes, crates, and barrels full of goods from all over the world. Carefully checking each parcel that crosses the doorway, the warehouse manager knows exactly where everything belongs inside.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Fishing store
# Description: This store is a small one room stone building with wares laid about on tables.  One can see fishing poles, wooden buckets with dirt and bait inside, along with some mounted trophies.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Ferry terminal
# Description: A huge terminal with a lot of traffic. The Ferry Terminal has a warm and positive vibe that welcomes all travelers across the land. It has an open space with a lot of illumination during the night.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Fishmonger's stall
# Description: A small booth near the edge of the port, it's protected by a piece of old, sun-bleached sailcloth. Baskets of freshly-caught fish, bivalves, and eels sit in the shade in stained wooden troughs of water. A small, aggressive-looking dog is chained to one table, presumably to keep cats away. The stall is redolent with the aroma of fish.
# Number of items: 5
# Items: Baskets of freshly-caught fish, a piece of old, sun-bleached sailcloth, old, sun-bleached sailcloth, stained wooden troughs, table
# ###
#
# Category: Port
# Location: Large galleon
# Description: The deck of this rather large ship is strong and freshly swapped with tar. Its mast reaches far into the sky like gleaming pillar of hope and freedom. Its sturdy ship made for long voyages with thick planks and strong rails.
# Number of items: 4
# Items: deck, mast, mast, tar
# ###
#
# Category: Port
# Location: Loading dock
# Description: The loading dock is filled with life and movement. Many trucks back up into the
# Number of items: 2
# Items: pirates, cargo
# ###
#
# Category: Port
# Location: The docks
# Description: The docks are a rough place with a lot of rough group of individuals who hang out there.  It is where the ships port and deport, only few know what really goes on there.
# Number of items: 3
# Items: ships, ships, product
# ###
#
# Category: Port
# Location: Wharf
# Description: The waves lash gently against the wooden posts, the water here has always been calm and passive, it seems to represent the people of this small town. The fishermen here are not boisterous, they are quiet, at least when it comes to sound. They'll talk your ear off if you let them, they have lots of stories to tell. The pier here is long, it extends at least forty feet into the ocean, many ships are anchored to it, many people traverse down it buying and selling their local catches.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Port tavern
# Description: The port tavern is the shadiest of all the shady bars in the city. Every night, on its grimy stools at the wooden bar, you can find some of the slimiest sailors in the world. The walls are of peeling blue paint and are always dripping with condensation. Women of ill-repute line one wall, old men on the verge of passing out line another. The floor is littered with trash, barnacles, and bodily fluids. Tending the bar is a small, round man with a bushy mustache.
# Number of items: 5
# Items: grimy stools, wooden bar, barnacles, bodily fluids, grimy stools at the wooden bar
# ###
#
# Category: Port
# Location: Port skyline
# Description: The local port sits an a majestic inlet of the ocean. The countless docks are constantly bustling with new arrivals and departures. People of all kinds come here for business or leisure. On the shore sits a skyline of many buildings packed with residents going about their day. The smell of salt and seafood fills the air.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Fish market
# Description: The port is filled with many different small shops that sell fishes caught throughout the day. It is incredibly loud and busy with many customers and fisherman walking around and haggling for a good price on the fishes. There are tons of boxes sitting on the floors everywhere filled with ice, fish, and the fishermen's belongings.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Dock at the port
# Description: This dock has seen better days.  It is wobbly and broken in areas.  There are holes through to the ocean below if you are not careful.  It is covered with every means of trash.
# Number of items: 1
# Items: dock
# ###
#
# Category: Port
# Location: Royal shipyard
# Description: A massive shipyard with different Five dry docks. each dry dock has several wooden cranes and rope works. The dry docks are made of stone and the water gate is all harden wood.
# Number of items: 7
# Items: dry docks are made of stone, wooden cranes, rope works, water gate is all harden wood, wooden cranes, rope, water gate
# ###
#
# Category: Port
# Location: The village of tamerak
# Description: A thriving sea port filled with merchants, foods, women, and gold.  Hundreds of boats fill the shores, fisherman pushing out to sea and pulling into dock.  Seagulls hover silently above the merchants selling fish.  Pirates can be seen causing trouble with the locals.  Brothels and bars are in abundance, as well as the smell of fish.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Crew berthing
# Description: The main quarters for the crew of the vessel. Its dirty, smelly and not a place where anyone but a pirate would want to stay. There are bunks stacked on bunks the place is cramped and no one goes there for any reason besides sleeping.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Captain's cabin
# Description: The captain's cabin is a complete mess. There are multiple maps on the wall, pinned over one another, each with messy writing scrawled over it and multiple X marks in random places. Papers overflow off the desk and across the floor in waves, impeding the captain as he paces, muttering angrily. The bed is messy and unmade, giving the impression that the captain has spent the night tossing and turning. Random objects have been thrown about the room.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Dock
# Description: There are creaky wooden walkways with empty sections where boats can rest.  There are a few buildings surrounding this area that sell supplies to sailors.
# Number of items: 2
# Items: wooden walkways, boats
# ###
#
# Category: Port
# Location: Supply store
# Description: With so many ships docked at the port, sailor from all the ships crowd the bazaar. The supply store is filled with buyers today. The inside is plain and unadorned. Sturdy shelves hold common supplies. Along the walls are the larger items for sale.
# Number of items: 0
# Items:
# ###
#
# Category: Port
# Location: Pirate ship
# Description: A majestic, shimmering, black pirate ship sits upon the water. Its numerous cannons give it a menacing look. Tons of pirates hop upon its decks in a furious jig. The lone captain plods around in his cabin, plotting on where to seize his treasure next.
# Number of items: 2
# Items: cabin, cannons
# ###
#
# Category: Swamp
# Location: Murky water
# Description: The water is murky and dark. There are unknown dangers lurking in it, such as alligators and poisonous snakes. Plants and trees hide more dangerous animals. It is cold.
# Number of items: 4
# Items: water, plants, alligators, poisonous snakes
# ###
#
# Category: Swamp
# Location: Quicksand pit
# Description: A large, gurgling pit of quicksand. Many adventurers and poor critters lie at the bottom of the pit. The pit is surrounded by an extensive swampland and is shielded by the many trees and shrubs that surround it.
# Number of items: 4
# Items: trees, shrubs, trees, shrubs
# ###
#
# Category: Swamp
# Location: Darkest part of the swamp
# Description: The light doesn't pierce the heavy overhanging trees in this near pitch black area of the swamp.  The water is extremely murky and there are occasional fins poking up from the water belonging to some kind of creature.  The air is thick and heavy and insects constantly buzz about.
# Number of items: 0
# Items:
# ###
#
# Category: Swamp
# Location: Soldiers camp
# Description: The camp is hidden away in a light forest of trees and brush that might be hard to find if there had not been a symbol on the trees leading up to it. You can feel the anxiety of the soldiers here, as this camp is not well fortified by any conventional means, but instead is supposed to be hidden and camouflaged to throw off anyone that might pursue. The camp is nothing more than a fire and some barracks. Nothing fancy to see.
# Number of items: 0
# Items:
# ###
#
# Category: Swamp
# Location: Witch's house
# Description: Old and worn by the time that has passed and the environment where it was built, the wood rotted and worn by the swamp. It should have sunk years ago into the swamp but somehow it remains standing despite the ever sinking earth around it.
# Number of items: 4
# Items: building, swamp, wood, earth
# ###
#
# Category: Swamp
# Location: Bog
# Description: Frogs croak in the reeds that surround the bog. The water is very murky and underneath the surface tadpoles dart around. There are minimal places to stand to stay dry.
# Number of items: 4
# Items: reeds, reeds, bog, water
# ###
#
# Category: Swamp
# Location: Troll's bridge
# Description: Muddy and murky waters lie under a bridge that seems to go nowhere. It is made of cobblestone and just as long as it is wide. Beneath it live a hideous troll that makes people pay to cross.
# Number of items: 1
# Items: waters
# ###
#
# Category: Swamp
# Location: Bank
# Description: This is a grassy area that surrounds much of the swamp.  It's a plain field with some trees nearby along with some rocks.
# Number of items: 6
# Items: trees, rocks, swamp, field, trees, rocks
# ###
#
# Category: Swamp
# Location: A military outpost at the heart of the swamp
# Description: Moist, and murky the bog remained. As you reach the outpost that description doesn't change seeing the bog gobbers swimming through the thick water, and fermenting goblins perched atop the outpost's walls.
# Number of items: 2
# Items: walls, thick water
# ###
#
# Category: Swamp
# Location: Boathouse
# Description: The boathouse is a very small building with peeling paint. It is made out of wood, with one half planted in the water on stilts. Inside, there are boats floating in the water. There are hinged doors which can be opened to allow boats to come in and out. There are some ropes and other tools a boater may need stored in the boathouse.
# Number of items: 2
# Items: boats floating, ropes and other tools
# ###
#
# Category: Swamp
# Location: Haunted swamp
# Description: A misty, foggy area with the swamp. It is dirty and smelly.
# Number of items: 2
# Items: many ghosts, swamp
# ###
#
# Category: Lake
# Location: Launching point
# Description: The Launching point features a number of large wooden planks sitting at a downward slope going straight into the water.  On each side of the launching point there sits a large, ornate bronze figure of a light house that is used to tether the ships to the dock and keep them from casting away while the sailors prepare to board the ship. The launching point is very narrow, with large stone braces on either side of the dock.
# Number of items: 0
# Items:
# ###
#
# Category: Lake
# Location: Drinking water lake
# Description: Surrounded by skittering chipmunks and chirping crickets, the drinking lake teems with life. Flora and fauna both thrive near the pristine waters. Tall thick plant life surrounds the lake, with strong roots and stems protruding from the nutrient rich soil. The lake water shimmers in the sun, so clear and clean that one can see the rock lake floor many feet below.
# Number of items: 0
# Items:
# ###
#
# Category: Lake
# Location: Lake
# Description: The beautiful lake glistens in the sun as water can be seen in all directions. you can see several feet beneath the water because it is so clear.
# Number of items: 1
# Items: water
# ###
#
# Category: Lake
# Location: Island
# Description: This island is located in the center of a lake. It is smaller than a ship and covered in moss.
# Number of items: 1
# Items: moss
# ###
#
# Category: Lake
# Location: Fishing shack
# Description: The fishing shack is a small wooden structure that is crudely built and is surrounded by boats. The wood flooring around the shack is well weathered and often used.
# Number of items: 3
# Items: small wooden structure, boats, wood flooring
# ###
#
# Category: Lake
# Location: Northern shore
# Description: The lake gives way to a slightly sandy and rocky shore. It is dotted with small shrubs and a few trees, but mostly it is a fairly open expanse. It is covered in places by a green short grass. The lake level falls away swiftly from the beach going from a few feet to well over ten feet in a short span.
# Number of items: 10
# Items: lake, small shrubs, trees, green short grass, clothes, small alter, small shrubs, trees, green short grass, small alter
# ###
#
# Category: Lake
# Location: Clean water lake
# Description: The lake is crystal clear, lined with trees, to the far back of the lake there's a small formation of rocks almost like a small waterfall allowing water to flow into the lake. It's quite beautiful, the sun bathing the surrounding area in a warmth so comforting you could easily fall asleep on the shore. There's an old wooden bath, for its age it seems to look like almost new, and rarely used. There are no animals nearby except for birds softly chirping in the trees.
# Number of items: 0
# Items:
# ###
#
# Category: Lake
# Location: Fishing dock
# Description: Folks call the area a Lake, but it's more like a pond.  Small and unimportant looking, yet peaceful.  The dock is no prize winner either.  Narrow in width, boards broken with several down right missing all together!  No tree nearby, no canopy, nothing to shade oneself on a hot day while fishing.  The watering hole may look small in size, but it deceives the eyes.  The water is as deep as the heavens.  No man knows what lurks beyond the light in this Lake.
# Number of items: 0
# Items:
# ###
#
# Category: Lake
# Location: Dock
# Description: The wood used to make the dock is of highest quality, commissioned from trees that stand towering in the local forests. Despite time having passed it has been taken care of to the point where even a hint of warping from the water beneath will have a plank torn and replaced within a night.
# Number of items: 0
# Items:
# ###
#
# Category: Lake
# Location: Lakeside house
# Description: Its white and vibrant, certainly a location for some lord, It has 3 floors, and fine gardening surround the house. Its open and breezy this place is calm and peaceful.
# Number of items: 1
# Items: floors
# ###
#
# Category: Lake
# Location: The swimming hole
# Description: The swimming hole is calm and clear.  The sun sparkles off the ripples that form on the surface of the water.  Fish occasionally jump from the water and splash back in.
# Number of items: 0
# Items:
# ###
#
# Category: Lake
# Location: Brim canal
# Description: Slow flowing branching from the large lake, is the brim canal where dozens and dozens of brim fish call it home. The edges are lined with irregular rocks and lush green vegetation. Tall pine trees overlook the canal and lake making it a peaceful place to just go sick and watch the brim swim by.
# Number of items: 5
# Items: dozens and dozens of brim fish, irregular rocks, lush green vegetation, Tall pine trees, some clothes
# ###
#
# Category: Lake
# Location: The lagoon
# Description: The Lagoon is a dark and mysterious place during the night hours.  A lot of moss and lily pads surround the shore.  The water is very murky.
# Number of items: 3
# Items: Lagoon, moss, lily pads
# ###
#
# Category: Graveyard
# Location: Graveyard
# Description: The dark and gloomy graveyard has fog all the time and has a large amount of graves everywhere you step. There are whispers and shadows that appear from the darkness and there is always a light drizzle that seems to moisten the place.
# Number of items: 1
# Items: graves
# ###
#
# Category: Graveyard
# Location: Tombstones of the kings
# Description: The tombstones of the kings are the most notable part of the graveyard. These tombstones are erected from fine marble and have piles of gold and riches lying next to them. A small metal fence surrounds this section of the graveyard, and cuts it off from the common folk.
# Number of items: 3
# Items: tombstones, piles of gold and riches, A small metal fence
# ###
#
# Category: Graveyard
# Location: Old crypt
# Description: Broken stones and a iron gate closing the entrance with a name placard that the name is worn off.
# Number of items: 6
# Items: stones, gate, placard, stones, iron gate, name placard
# ###
#
# Category: Graveyard
# Location: Dead tree
# Description: The dead tree is many, many decades old. It lies on its side, and is rotted through and through. It is blackened on its top. It is humongous. It would have been very, very tall once upon a time. It smells dank. It cannot be moved.
# Number of items: 0
# Items:
# ###
#
# Category: Graveyard
# Location: Abandoned workers shed
# Description: Moss now grows across what was once a red painted wooden shed, standing in the area just outside the graveyard. The wood shed is splintering, and there is evidence that termites have eaten away at the walls as holes poke through the shed. Inside the shed there lies leaves and plants that have been dragged in their by the wild animals that at one point called the abandoned shed their home.
# Number of items: 0
# Items:
# ###
#
# Category: Graveyard
# Location: An unfinished mausoleum
# Description: Two-and-a-half walls of the finest, whitest stone stand here, weathered by the passing of countless seasons. There is no roof, nor sign that there ever was one. All indications are that the work was abruptly abandoned. There is no door, nor markings on the walls. Nor is there any indication that any coffin has ever lain here... yet.
# Number of items: 1
# Items: walls of the finest, whitest stone
# ###
#
# Category: Graveyard
# Location: Reception area
# Description: The building itself is ordinary in appearance and is somewhat foreboding.  It is surrounding by a dense fog and high grass.  Sometimes, one can hear whispers in the wind.
# Number of items: 6
# Items: The building, dense fog, high grass, the wind, high grass, graveyard
# ###
#
# Category: Graveyard
# Location: Cemetery
# Description: Dim and low lit. The aura from this cemetery emits sadness and pain perpetually. You can feel and sense the eerie nature of the graveyard crawl up your spine. There seems to be a slight fog slowly making its way across the open parts of the cemetery.
# Number of items: 1
# Items: a slight fog
# ###
#
# Category: Graveyard
# Location: The fountain
# Description: the fountain is the only thing you can hear in the graveyard. It's eerily quiet, not even a bird chirping. The fountain is teen feet high, and it is dry as a desert. It makes the graveyard more eerie than any other one.
# Number of items: 4
# Items: fountain, weeds, grass, The fountain
# ###
#
# Category: Graveyard
# Location: A cursed grave
# Description: The sun never seems to shine on this grave.  The letters on the tombstone have long since faded, and many stories are told about whose bones lay buried in the dirt.  Until recently, it was overgrown with grass and weeds.  Someone had come and cleared the weeds, and the dirt looked as if it had been turned over.
# Number of items: 2
# Items: dirt, bones
# ###
#
# Category: Graveyard
# Location: Main graveyard
# Description: This is an ominous place that a thick fog envelops.  There are rows of primitive gravestones and crosses along with some angelic statues for the more wealthy.  You can hear sobs in the distance as a funeral ceremony is underway.
# Number of items: 0
# Items:
# ###
#
# Category: Graveyard
# Location: Main street
# Description: main street is bleak and outdated. it wears the atmosphere of the cemetery based on association. it is dark even in sunlight and has a unique odor
# Number of items: 0
# Items:
# ###
#
# Category: Abandoned
# Location: An abandoned castle on an ocean cliff side
# Description: The castle is located at the top of an erosive cliff face of a vast ocean. An entire wing of the castle appear to have collapsed into the ocean due to the erosion of the cliff face, perhaps the reason why the castle now lay abandoned.
# Number of items: 3
# Items: castle, cliff, ocean
# ###
#
# Category: Abandoned
# Location: A lonely island
# Description: the island only has one coconut tree and waves crashing and appearing missing wooden boat parts. The pirates are nowhere to be seen.
# Number of items: 5
# Items: a coconut tree, skeletons, coconut tree, wooden boat parts, skeletons
# ###
#
# Category: Abandoned
# Location: The forsaken castle
# Description: Old and creepy, the castle has been abandoned for centuries now. It is broken and destroyed.
# Number of items: 0
# Items:
# ###
#
# Category: Abandoned
# Location: Collapsed west wing
# Description: The rocks have all but fallen into the ocean.  There is moss and other plant life climbing the remaining rocks, making it a very moist and gloomy environment.  There are some small left-behind pieces of what appear to have been some furniture, and possibly a cradle.
# Number of items: 0
# Items:
# ###
#
# Category: Abandoned
# Location: Gold mine
# Description: The entrance is very unstable, with parts falling to the ground. As you enter, the walls have been crudely chipped away to make the path to the old mine. There is trash from the previous miners scattered on the dirt ground. Rocks are all around the area, where one would stumble as they go inside. It used to be a very productive gold mine, now falling to bits. There are broken lanterns, with shattered glass.
# Number of items: 4
# Items: Rocks, broken lanterns, path to the old mine, broken lanterns
# ###
#
# Category: Abandoned
# Location: Ruined house
# Description: A dilapidated wooden structure with a caved in roof and debris everywhere.  Even the trees outside the house are falling apart.  There's waist high grass leading to the house along with a dirt path.
# Number of items: 3
# Items: debris, debris, trees
# ###
#
# Category: Abandoned
# Location: Abandoned mine entrance
# Description: The abandoned mine is located in a field with a few trees. It is unable to be seen from far away. The closer you get the more you  notice the ground caving in around the hole. When you peer down into the mine, you see crumbling walls and concrete and a hole so deep you can't see where it ends.
# Number of items: 0
# Items:
# ###
#
# Category: Abandoned
# Location: Abandoned mine
# Description: It's dark, cold, and musty. There is old machinery lying around, rusting, and discarded tools lie on the ground. Cobwebs are everywhere. The rock walls are damp, and a trickle of water can be heard coming from somewhere off in the dark.
# Number of items: 5
# Items: old machinery, Cobwebs, rock walls, old machinery lying around, rusting, Cobwebs are everywhere
# ###
#
# Category: Abandoned
# Location: Weathered shack
# Description: A weathered shack with a roof made of old broken tiles sits in the middle of the forest. The wood is starting to split and the shack appears as if it will crumble at any moment.
# Number of items: 3
# Items: old broken tiles, wood, shack
# ###
#
# Category: Abandoned
# Location: Land beyond the wasteland
# Description: Not a man in sight nor an animal to hear. This land is completely barren and hot, unfit for any agricultural activity. It has been left abandoned so much so that the King has not even had time give it a name, so people simply refer to is as "Abandoned"
# Number of items: 0
# Items:
# ###
#
# Category: Cave
# Location: Orc cave
# Description: It is a dark cave that is cold and damp inside. The floor is rocks covered it bat poop. It is damp from the ceiling dripping of water. The cave just goes on what seems to be endlessly into the dark abyss. The only lite you can see is from the distance entrance of the cave.
# Number of items: 2
# Items: floor, ceiling
# ###
#
# Category: Cave
# Location: Primary cave
# Description: Dark and with a lot of space in it. The primary cave has a scary look that scares people away. Underneath, in the floor, many precious minerals that no one dares to get out.
# Number of items: 0
# Items:
# ###
#
# Category: Cave
# Location: Gallery
# Description: The cave is pitch black and smells of dank and mold. It's quiet except for a faint dripping noise from water overhead and the occasionally scurrying of an unseen rodent through the darkness. Barely discernable by the light of a torch is a small pile of bones in one corner. From what type of animal they are from is unclear.
# Number of items: 0
# Items:
# ###
#
# Category: Cave
# Location: Entrance
# Description: The entrance to his cave is covered in hanging moss with shrubs on either side of the entrance.  The path to this cave is a small dirt one with low grass on the floor.
# Number of items: 4
# Items: moss, shrubs, dirt, grass
# ###
#
# Category: Cave
# Location: Bandit lair
# Description: The outside of the cave looks normal. Inside goes for about 10 feet til' you reach the front of the Bandit lair. Inside is a barracks and dining hall with beds and a big table with chairs around it.
# Number of items: 3
# Items: beds, big table, chairs
# ###
#
# Category: Cave
# Location: Underground chamber
# Description: This location is very gloomy, damp and magical. Has a lot of geodes and various types of crystals.
# Number of items: 2
# Items: crystals, mystical lions
# ...
# Number of items: 7
# Items: tent, bed, floor, rug, brazier, teapot, stone
# ###
#
# Category: Magical realm
# Location: Faeries den
# Description: Stunning with silver walls and gold decorations, Magical items can be found on the shelves, including crystals, faery wands, and a crown.
# Number of items: 5
# Items: gold decorations, magical items, crystals, faery wands, crown
# ###
#
# Category: Magical realm
# Location: The fountain of youth
# Description: The water here bubbles softly, cascading down the golden framework of the fountain.  The water is clear as crystal, and shimmers softly with a faint glow that doesn't seem to quite reflect the light around it.  The fountain itself is made of elaborately filigrees of gold and silver that twist and curve to show the sparkle of the water best, and it breathtaking to behold. While the fountain's beauty is what first draws the eye, a careful glace down at the earth around it reveals a frightening sight.  Skeletons, some clad in ancient armor from kingdoms long turned to dust, others worn down so that even what clothing they had has long since disintegrated, litter the earth.  Beautiful flowers grow up from them, partially obscuring whatever carnage caused these people to perish.
# Number of items: 5
# Items: water, fountain, water, flower, ancient armor
# ###
#
# Category: Magical realm
# Location: Echo hall
# Description: A gigantic dome-like building with a round table in the center of it. There is magelight above it and encircles the dome. Traces of wizards' histories appear on the walls and disappear from time to time.
# Number of items: 3
# Items: round table, magelight, wizards' histories
# ###
#
# Category: Netherworld
# Location: The dark kings throne room
# Description: Filled with skeletons and zombies and dead bodies, the throne room of the Dark King has literally no light.
# Number of items: 3
# Items: skeleton, zombies, dead bodies
# ###
#
# Category: Netherworld
# Location: Dungeon
# Description: Dark and dreary, the dungeon hosts a portal for evil to access the netherworld. The moist dank smell casts doubt of goodness as you see the drab construct of jail cells lining the perimeter of the room.
# Number of items: 3
# Items: portal for evil to access, jail cells, secrets of evil
# ###
#
# Category: Netherworld
# Location: Torture chanber
# Description: This room is very grim and evil. There are many torturing devices strewn about. There is also blood all over the walls. The smell is putrid and relentless.
# Number of items: 3
# Items: room, devices, walls
# ###
#
# Category: Netherworld
# Location: Reaper's lair
# Description: A room that gets very little light except for a dim candle on a pole. The walls are made of blackened stones. A wooden door with a heavy lock stands tall.
# Number of items: 2
# Items: wooden door, heavy lock
# ###
#
# Category: Netherworld
# Location: The pit of despair
# Description: A sinking hole in the ground, roughly 15 feet in diameter, covered by the grabbing appendages of sinners who once walked in the land of the living. A cacophony of moans, screams and scratching bellows from the depths of the cavern. There is a pool of blood, tears and excrement at the bottom of the hole where limbs can be faintly seen trying to reach the surface but never able to.
# Number of items: 0
# Items:
# ###
#
# Category: Netherworld
# Location: The thrones of death
# Description: The main part of this room room would be the throne.  It is a shiny black with some gold ornate decorations on it. It sits on a black and gold pedestal. There is  a smaller throne in the room decorated in purple and gold.   It does not sit on a pedestal.  The room is decorated in tones of purple and blue with black accents.  This signifies death.  There are paintings of dolphin on the all.  Also to signify death.  The dolphins are typically gray.
# Number of items: 3
# Items: throne, pedestal, paintings
# ###
#
# Category: Netherworld
# Location: Lord's castle
# Description: This is the location in the netherworld where the Lord and controller lives.  It is in the center of the netherworld and is difficult to reach as it is built on high rocky cliffs.
# Number of items: 1
# Items: rocky cliffs
# ###
#
# Category: Netherworld
# Location: Viewing room
# Description: The viewing room is where those who have passed on come to watch their family members in the living world one day per year. The room resembles an opera theater. There are seats throughout the room and boxes for those who were wealthy in life to sit in. There is a stage with a large magical dome on it for viewing.
# Number of items: 6
# Items: room, seats, boxes, stage, dome, ball
# ###
#
# Category: Netherworld
# Location: Devil's den
# Description: The Devil's Den is dark and fiery; no one dares to look at the blood covered walls. Skulls on stakes line the walls, with piles of bones scattered on the floor.
# Number of items: 3
# Items: skulls on stakes, piles of bones, souls
# ###
#
# Category: Netherworld
# Location: Cavern
# Description: a lonely and isolated place, a cavernous hole in the side of a craggy mountain that leads to a network of underground tunnels.
# Number of items: 3
# Items: hole, underground tunnels, souls
# ###
#
# Category: Netherworld
# Location: The devils castle
# Description: It is a castle that has burning flames that burn for eternity all around it. It is the tallest structure in all of the netherworld. It is dark and pitch black in some areas. It can be seen from miles away.
# Number of items: 4
# Items: castle, flame, structure, ground
# ###
#
# Category: Netherworld
# Location: Whipping chamber
# Description: a stone wall with straps for tying up men and women to be punished for their immortal sins
# Number of items: 2
# Items: stone, straps
# ###
#
# Category: Netherworld
# Location: Lower dungeon
# Description: The lower dungeon is set below the mail hall. It is dark, lit by only a few dim torches. Water is constantly dripping down the walls, giving it a dank and musty smell. There are manacles and cages set along the walls. In the middle of the room sits a table with manacles on all corners which are attached to a large rotating lever.
# Number of items: 6
# Items: torches, manacles, cages, walls, table, lever
# ###
#
# Category: Netherworld
# Location: Withered gardens
# Description: Dead trees and plants cluster in this garden, their branches thin and bone-like.  As they sway in the ghostly breeze, they look almost like skeletal hands, grasping for any living presence nearby to drain the life out of them.  There is a a dried up fountain made of cracked marble, and a bench that is made of rotting wood.  It looks as though it might turn into dust at the slightest touch.
# Number of items: 7
# Items: trees, plants, garden, branches, fountain, marble, bench
# ###
#
# Category: Netherworld
# Location: Lava lake
# Description: A vast lake of molten magma. The temperature is well above that which would kill most mortal beings. It is surrounded by black rock formed by cooled magma. The bubbling pit seems entirely devoid of life.
# Number of items: 2
# Items: molten magma, black rock
# ###
#
# Category: Supernatural
# Location: Magic room
# Description: A room that once entered, cannot be escaped. The walls are all mirrors, and you can never again find the door.
# Number of items: 2
# Items: walls, door
# ###
#
# Category: Supernatural
# Location: Stonehenge
# Description: Technical and advanced, the enormous stones stand looking as if they are placed on top of each other by divine design. The green grass is a stark contrast to the gray stones hovering in the distance.
# Number of items: 2
# Items: green grass, gray stones
# ###
#
# Category: Supernatural
# Location: Astral plane
# Description: An area between worlds where the physics known to man become irrelevant. It is a space beyond time that is home to being spectral and inconceivable to those without the eyes to see them.
# Number of items: 2
# Items: astral plane, abode
# ###
#
# Category: Supernatural
# Location: Fighting arena inside tourney grounds
# Description: Filled with embroidered banners and filled with a crowd aching for entertainment, the fighting arena offers glory to all who enter. The arena itself is covered in orange dirt and surround by emblems and crests of all the knights who participate. There are weapon racks sprinkled alongside the edge of the arena.
# Number of items: 6
# Items: banners, arena, dirt, emblems, crests, weapon racks
# ###
#
# Category: Supernatural
# Location: The glade of mysteries
# Description: The leaves of the trees surrounding this glade glow unnaturally, as though lit from within.  There seems to be almost a presence to this place, a waiting watchful force.  Bits of music sound occasionally, tunes that seem familiar and yet quite alien, as though played by someone who had only heard the melody described to them, instead of hearing it themselves.  And yet all this pales in comparison to the pool found in the center.  The water gleams silver, seemingly absorbing and reflecting back the light of the trees around it tenfold.  Though there is a soft breeze that blows through the glade, there is not a ripple to be seen on the water's perfectly mirrored surface.
# Number of items: 4
# Items: leaves, trees, glade, pool
# ###
#
# Category: Supernatural
# Location: Bridge in the forest
# Description: You are at a bridge. It is old and used very rarely. It is dim and foggy. The brigde is large and there is a small stream below it.
# Number of items: 4
# Items: bridge, stream, road, forest
# ###
#
# Category: Supernatural
# Location: Haunted basement
# Description: The basement is cold, damp, and dark. What little light coming in from the window is blotted out and dimmed by the spider webs sprawled across its surface. The shadows in the corners of the room appear nearly pitch black, and it almost feels as if something is looking back at you from within them.
# Number of items: 6
# Items: window, web, concrete, documents, journal, house
# ###
#
# Category: Supernatural
# Location: Goddess hollow
# Description: The Goddess Hollow is a place created to worship woodland spirits. It is a small, closet-like room in a hollowed out tree that has existed for hundreds of years. Within the hollow there are piles of sticks, flowers, and home-made items presented to the woodland spirits.
# Number of items: 3
# Items: hollowed out tree, piles of sticks, flowers, and home-made items, gifts
# ###
#
# Category: Supernatural
# Location: Ghost monk quarters
# Description: a simple room for an undead monk. There is an uncomfortable bed, no windows, a small table with a candle, some illustrations in a book, and not much else. There is a stool
# Number of items: 4
# Items: uncomfortable bed, small table with a candle, some illustrations in a book, stool
# ###
#
# Category: Underwater aquapolis
# Location: Research lab
# Description: The research lab is the main science hub of the aquapolis. Dozens of scientists are working on a myriad of different projects.
# Number of items: 0
# Items:
# ###
#
# Category: Underwater aquapolis
# Location: The lords treasury
# Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# Number of items: 1
# Items: riches from the very infancy of the empire
# ###
#
# Category: Underwater aquapolis
# Location: Dry dock room
# Description: The room is located on the border wall of the aquapolis. There is one on the far north and far south side.
# Number of items: 2
# Items: dry dock, door
# ###
#
# Category: Underwater aquapolis
# Location: Underwater marketplace
# Description: The marketplace is the main hub for the residents of the aquapolis. With high ceilings and bright, colorful flags at each market stand, the place seems to stretch on forever. Near the entrance, there is a young boy attempting to sell the latest news of the kingdom.
# Number of items: 3
# Items: news of the kingdom, colorful flags, market stand
# ###
#
# Category: Underwater aquapolis
# Location: The marketplace
# Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Number of items: 4
# Items: wares, stalls, colorful dyes, water
# ###
#
# Category: Underwater aquapolis
# Location: Toad hollow
# Description: Toad Hollow is a filthy room within the Underwater Aquapolis. When you enter, you are greeted by the reek of scummy pond water. You enter Toad Hollow through a drainage pipe that you have to crawl through. Once inside Toad Hollow, you can stand up, but you still don't feel comfortable with your surroundings. As far as the eye can see there is muddy water in a circular basin with lily pads floating in it. On the pads, giant toads jump back and forth making gurgling, croaking sounds. As you wade deeper into Toad Hollow, the water comes up to your waist and you see the flash of a fin. There is legend that a creature lives in the center of Toad Hollow that is half human, half monster. Not even the strongest knight has been brave enough to examine it. The fin disappears back underwater but there is a red glint suggesting eyes are watching you. When you reach the other side of the basin, you crawl into another drainage pipe and feel relieved that you're out of this place.
# Number of items: 2
# Items: pads, drainage pipe
# ###
#
# Category: Underwater aquapolis
# Location: Farmhouse
# Description: a small house on a seaweed plantation, small and rustic, really only the single room with a closet, maybe, a table and some chairs
# Number of items: 2
# Items: table, chair
# ###
#
# Category: Underwater aquapolis
# Location: Geothermal valley
# Description: Deep and warm the geothermal valley boasts a reviving epicenter for all to migrate to. The warm bursts of heat send bubble around the perimeter of the valley reflecting colors of green and blue.
# Number of items: 0
# Items:
# ###
#
# Category: Underwater aquapolis
# Location: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Number of items: 4
# Items: painted walls as blue as the sea itself, tables constructed of beautiful coral, decorative shells, ceiling
# ###
#
# Category: Underwater aquapolis
# Location: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Number of items: 7
# Items: shed, tools, hooks, hoe, shovel, seaweed, shack
# ###
#
# Category: Underwater aquapolis
# Location: Underwater aquapolis
# Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# Number of items: 3
# Items: coral, pearl, and seashells, florescent rocks and shells, beautiful and priceless items
# ###
#
# Category: Underwater aquapolis
# Location: The dungeon
# Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Number of items: 10
# Items: flame, walls, rot, gangrene, death, decay, moldy, iron maiden, spike, dried blood
# ###

# %%
# !head fine_tuning_items_at_location.jsonl
# Out:
# {"prompt": "Category: Forest\nLocation: Along the banks of a river in the forest\nDescription: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\nNumber of items: 6\n", "completion": "Items: river, fish, insects, grass, river, riverbank\n###\n"}
# {"prompt": "Category: Forest\nLocation: The stream\nDescription: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.\nNumber of items: 5\n", "completion": "Items: The water, rainfall, The water in the sky, higher elevations, water\n###\n"}
# {"prompt": "Category: Forest\nLocation: Forbidden forest\nDescription: The forbidden forest is a dark and very scary place. The trees are covered in spider web nets and huge spiders. The forest echoes sounds of witches' laughs and creepy crawly animals.  There is a brisk breeze that runs through the trees that will put chills down your spine.\nNumber of items: 0\n", "completion": "Items: \n###\n"}
# {"prompt": "Category: Forest\nLocation: Woods\nDescription: The woods are vast. Everywhere you turn it all looks the same. There are scratches on the trees from lost travelers marking their path. There are sounds coming from everywhere and yet no where. There are faint yellow circles up in the trees and bushes, possibly eyes starting at you.\nNumber of items: 0\n", "completion": "Items: \n###\n"}
# {"prompt": "Category: Forest\nLocation: Ant hill\nDescription: The ant hill is very large, over 5 feet high, and is wrapped around the base of a pine tree. The ants are huge compared to normal ants, and jut in and out of large holes in the ant hill. Bones of animals and even people can be seen sticking out of the red dirt ant hill.\nNumber of items: 0\n", "completion": "Items: \n###\n"}
# {"prompt": "Category: Forest\nLocation: Mysterious forest outskirts\nDescription: The forest is a dark and mysterious place, where few but the bravest hunters dare wander. The trees loom over you, obscuring any sort of sunlight. Despite this, it is a valuable food and lumber resource for the nearby castle's inhabitants, for the trees are tall and thick and a plentiful amount of deer wander about within.\nNumber of items: 2\n", "completion": "Items: trees, food\n###\n"}
# {"prompt": "Category: Forest\nLocation: Pine tree graveyard\nDescription: Once known as a forest of solitude, the entrance to the pine trees is now a bleak and dreary graveyard.  Dead grass and moss fill the ground along with crawling critters that mark fear in the mind among the he who venture here.  Tombstones so old many of the names are no longer eligible.  Dense fog surrounds the area, thick tree tops blotting out the sunlight, and an eerie silence fills the air.  Cold it feels, the air, but the ground is soft and warm.  Sound can not enter, no escape this dwelling.\nNumber of items: 0\n", "completion": "Items: \n###\n"}
# {"prompt": "Category: Forest\nLocation: Fairy forest\nDescription: The fairy forest is full of brightly colored flowers that grow up to 30 feet tall.  There are also ornate birds that live here.  When you whistle, a fairy will come to you and tweak your nose.  They don't like a lot of nose so it irritates them enough for them to come out of their homes made from watermelon skins.\nNumber of items: 2\n", "completion": "Items: brightly colored flowers that grow up to 30 feet tall, homes made from watermelon skins\n###\n"}
# {"prompt": "Category: Forest\nLocation: Entrance to the pine trees\nDescription: Very tall and towering pine trees that create a dark canopy of shade. Long skinny trees sway in the sky from the soft breeze. Pine needles scatter the ground like plush carpet.\nNumber of items: 4\n", "completion": "Items: towering pine trees, Long skinny trees, Pine needles, needles\n###\n"}
# {"prompt": "Category: Forest\nLocation: Unsettling forest area\nDescription: The forest is actually very creepy even during the day. The trees are so tall that they block the sunlight. There is always fog in the forest which makes it very hard to see. There are a lot of mushrooms near the trees and none of them are edible\nNumber of items: 0\n", "completion": "Items: \n###\n"}

# %%
# model name: babbage:ft-cis-700-48-2022-01-31-01-29-36
# model fine-tune: ft-hAVWhIDKP8BJYSNwfbIcwvSx
# !openai api fine_tunes.create -t fine_tuning_items_at_location.jsonl -m babbage
# Out:
# Upload progress: 100% 231k/231k [00:00<00:00, 331Mit/s]
# Uploaded file from fine_tuning_items_at_location.jsonl: file-vFWnIOhiH2QOZwld9nGOPFcZ
# Created fine-tune: ft-hAVWhIDKP8BJYSNwfbIcwvSx
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2022-01-31 01:17:27] Created fine-tune: ft-hAVWhIDKP8BJYSNwfbIcwvSx
# [2022-01-31 01:17:37] Fine-tune costs $0.12
# [2022-01-31 01:17:38] Fine-tune enqueued. Queue number: 0
# [2022-01-31 01:17:40] Fine-tune started
# [2022-01-31 01:20:48] Completed epoch 1/4
# [2022-01-31 01:23:30] Completed epoch 2/4
# [2022-01-31 01:26:13] Completed epoch 3/4
# [2022-01-31 01:28:55] Completed epoch 4/4
# [2022-01-31 01:29:38] Uploaded model: babbage:ft-cis-700-48-2022-01-31-01-29-36
# [2022-01-31 01:29:41] Uploaded result file: file-XhbjF22WOZbHvxOBuvvBfr2E
# [2022-01-31 01:29:41] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m babbage:ft-cis-700-48-2022-01-31-01-29-36 -p <YOUR_PROMPT>

# %%
def get_items_at_location(category, location_name, location_description, number_of_items, finetuned_model):
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Category: {category}\nLocation: {location}\nDescription: {location_description}\nNumber of items: {number_of_items}\nItems:".format(
          category=category.capitalize(),
          location=location_name.capitalize(),
          location_description=location_description,
          number_of_items=number_of_items
      ),
      temperature=0.5,
      max_tokens=64,
      top_p=1,
      frequency_penalty=1,
      presence_penalty=0,
      stop=["###"]
      )
  return response['choices'][0]['text']


finetuned_model = "babbage:ft-cis-700-48-2022-01-31-01-29-36"
category = "Dark Forest"
location_name = "Winter's Glade"
location_description = "This is a hidden glade in a dark forest of giant trees.  The forest is full of dangerous creatures that live in the trees.  There are also many mushrooms near the trees that are edible but poisonous if consumed."
number_of_items = 7

descripton = get_items_at_location(category, location_name, location_description, number_of_items, finetuned_model)
print(descripton)
# Out:
#  giant trees, dangerous creatures, trees, mushrooms, glade, giant trees

# %% [markdown]
# ## 3. Describe an item

# %%
# 3. Describe an item
# - inputs: category, location name, location description, item name
# - output: item description 
def get_item_description_prompt(item_id, room_id, rooms_by_id, light_environment):
  """
  This generates a prompt and a completion which can be used to fine-tune OpenAI.
  This version just gnnerates 
  """
  prompt = ""
  completion = ""
  prompt += "Category: {category}\n".format(category=rooms_by_id[room_id]['category'].capitalize())
  prompt += "Location Name: {setting}\n".format(setting=rooms_by_id[room_id]['setting'].capitalize())
  prompt += "Location Description: {description}\n".format(description=rooms_by_id[room_id]['description'])
  prompt += "Item Name: {item_name}\n".format(item_name=light_environment['objects'][str(item_id)]['name'])
  completion += "Item Description: {item_description}\n".format(item_description=' '.join(light_environment['objects'][str(item_id)]['descriptions']))
  completion += "###\n"

  return prompt, completion


def create_item_finetuning_data(filename='fine_tuning_item_descriptions.jsonl'):
  fine_tuning_data = []
  for category in categories:
    rooms = rooms_by_category[category]
    for room_id in rooms:
      objects = rooms_by_id[room_id]['in_objects']
      for item_id in objects:
        data = {}
        prompt, completion = get_item_description_prompt(item_id, room_id, rooms_by_id, light_environment)
        data['prompt'] = prompt
        data['completion'] = completion
        print(prompt, end="")
        print(completion)
        fine_tuning_data.append(data)

  with open(filename, 'w') as out:
    for data in fine_tuning_data:
        out.write(json.dumps(data))
        out.write('\n')

create_item_finetuning_data()
# Out:
# Streaming output truncated to the last 5000 lines.
# ###
#
# Category: Inside temple
# Location Name: Within the king's mansion
# Location Description: A divine location filled with the smells of religious scents. Red carpet is laid son the floor, red worship ornaments lace the walls and fire torches hover upon pedestals. The Statue of Omamoko rests upon the crescendo at the end of the walking aisle, its eye gleaming with Imperial Stone.
# Item Name: scents
# Item Description: The scent fills the air.  It is a musty, nasty smell.
# ###
#
# Category: Inside temple
# Location Name: Within the king's mansion
# Location Description: A divine location filled with the smells of religious scents. Red carpet is laid son the floor, red worship ornaments lace the walls and fire torches hover upon pedestals. The Statue of Omamoko rests upon the crescendo at the end of the walking aisle, its eye gleaming with Imperial Stone.
# Item Name: Red carpet
# Item Description: A dark red carpet, soft, lush, thoughtfully laid out and relatively clean.
# ###
#
# Category: Inside temple
# Location Name: Within the king's mansion
# Location Description: A divine location filled with the smells of religious scents. Red carpet is laid son the floor, red worship ornaments lace the walls and fire torches hover upon pedestals. The Statue of Omamoko rests upon the crescendo at the end of the walking aisle, its eye gleaming with Imperial Stone.
# Item Name: fire torches
# Item Description: the torch has a worn out handle but the fire is still strong and fiery with a long red flame.
# ###
#
# Category: Inside temple
# Location Name: The ritual room
# Location Description: A room with a solid block stone in the middle with steps leading up to it. Candle stands surround the center with 4 candle holders on each stand. A red carpet leads to the steps to the center of the room.
# Item Name: Candle
# Item Description: The candle smells of enchanting vanilla and wax drips down it's side. It has been used a few times but not overused
# ###
#
# Category: Inside temple
# Location Name: The ritual room
# Location Description: A room with a solid block stone in the middle with steps leading up to it. Candle stands surround the center with 4 candle holders on each stand. A red carpet leads to the steps to the center of the room.
# Item Name: red carpet
# Item Description: luxurious carpet could be used in the castles to give entrance to the members of royalty the red carpet is clean and beautifful
# ###
#
# Category: Inside temple
# Location Name: The ritual room
# Location Description: A room with a solid block stone in the middle with steps leading up to it. Candle stands surround the center with 4 candle holders on each stand. A red carpet leads to the steps to the center of the room.
# Item Name: candle holders
# Item Description: The holder is so old it couldn't even hold a candle anymore. It's rusted out.
# ###
#
# Category: Inside temple
# Location Name: The ritual room
# Location Description: A room with a solid block stone in the middle with steps leading up to it. Candle stands surround the center with 4 candle holders on each stand. A red carpet leads to the steps to the center of the room.
# Item Name: red carpet
# Item Description: luxurious carpet could be used in the castles to give entrance to the members of royalty the red carpet is clean and beautifful
# ###
#
# Category: Inside temple
# Location Name: Inside the temple
# Location Description: The stained glass glistens in the sun. The pews are lines perfectly.
# Item Name: stained glass
# Item Description: The stained glass towers above, and it presents vibrant colors of biblical stories when the sunlight shows through it.
# ###
#
# Category: Inside temple
# Location Name: Inside the temple
# Location Description: The stained glass glistens in the sun. The pews are lines perfectly.
# Item Name: pews
# Item Description: The pew is made of wood and is very long.
# ###
#
# Category: Inside temple
# Location Name: Inside the temple
# Location Description: The stained glass glistens in the sun. The pews are lines perfectly.
# Item Name: stained glass
# Item Description: The stained glass towers above, and it presents vibrant colors of biblical stories when the sunlight shows through it.
# ###
#
# Category: Inside temple
# Location Name: Inside the temple
# Location Description: The stained glass glistens in the sun. The pews are lines perfectly.
# Item Name: pews
# Item Description: The pew is made of wood and is very long.
# ###
#
# Category: Inside temple
# Location Name: Inside temple crypt
# Location Description: Bones and coffins are as far as the eye can see. Rats scurry too and fro as they nibble on the desiccated remains. The coffins that are still intact are all open from grave robbers that visited long ago. A smell of mothballs pervades the air.
# Item Name: Bones
# Item Description: The bone is gnarled and cracked at its most vulnerable points.
# ###
#
# Category: Inside temple
# Location Name: Inside temple crypt
# Location Description: Bones and coffins are as far as the eye can see. Rats scurry too and fro as they nibble on the desiccated remains. The coffins that are still intact are all open from grave robbers that visited long ago. A smell of mothballs pervades the air.
# Item Name: coffins
# Item Description: The coffin is clearly very old and covered in a layers of dust.
# ###
#
# Category: Inside temple
# Location Name: Dungeon
# Location Description: A dirty stone room with tables and torture instruments abound.  There's pieces of equipment in various corners of the room.
# Item Name: torture instruments
# Item Description: The torture instruments thick with rust no longer able to harm
# ###
#
# Category: Inside temple
# Location Name: Dungeon
# Location Description: A dirty stone room with tables and torture instruments abound.  There's pieces of equipment in various corners of the room.
# Item Name: tables
# Item Description: On further inspection of the table you notice it was worn and had numerous dagger strikes into it. The table is rough metal, its chips and divots are filled with blood. The table is made of one large plank of wood, and appears to be highly polished. The table is small and made of wood.
# ###
#
# Category: Inside temple
# Location Name: Dungeon
# Location Description: A dirty stone room with tables and torture instruments abound.  There's pieces of equipment in various corners of the room.
# Item Name: table
# Item Description: The table was large and heavy. Its surface is piled with goblets and platters. Dented, chipped, and leaning slightly to the side, this table is a witness to many brawls. The table is round and made of roughly-chopped wood planks. The large, oval-shaped table is covered in scratches and dents from years of use.
# ###
#
# Category: Inside temple
# Location Name: Dungeon
# Location Description: A dirty stone room with tables and torture instruments abound.  There's pieces of equipment in various corners of the room.
# Item Name: torture instrument
# Item Description: The spike gleam wickedly and are flecked with dried blood on this torture implement.  You're not quite sure how it is used, but it looks painful.
# ###
#
# Category: Inside temple
# Location Name: The prayer room
# Location Description: It is serene and quiet. Some old gods and goddess statues are on the altar. They are made out of pure gold with some jewel for the ornaments. The red carpet welcomed the visitor and soon as you walk in, you can see the bright gold pillars surrounding the room.
# Item Name: goddess
# Item Description: The goddess is plump and unadorned and her skin is as smooth as polished bronze.
# ###
#
# Category: Inside temple
# Location Name: The prayer room
# Location Description: It is serene and quiet. Some old gods and goddess statues are on the altar. They are made out of pure gold with some jewel for the ornaments. The red carpet welcomed the visitor and soon as you walk in, you can see the bright gold pillars surrounding the room.
# Item Name: ornaments
# Item Description: The oranment is made of brass and contains many delicate carvings.
# ###
#
# Category: Inside temple
# Location Name: Hidden passageway
# Location Description: This is a narrow underground path that is surrounded by stone walls and a dirty and grimy floor.  Many insects and rodents dwell here underneath the temple.
# Item Name: stone walls
# Item Description: Layers and layers of strategically placed stones, bonded together with a paste made of lime powder. The stone walls have seen great history in the past.
# ###
#
# Category: Inside temple
# Location Name: Hidden passageway
# Location Description: This is a narrow underground path that is surrounded by stone walls and a dirty and grimy floor.  Many insects and rodents dwell here underneath the temple.
# Item Name: a dirty and grimy floor
# Item Description: The dirty and grimy floor has drinks spilled on it. The floor is dirty and in need of a good sweeping.
# ###
#
# Category: Inside temple
# Location Name: Inside temple
# Location Description: It is solemn. There are candles lit everywhere and the although the temple is full, no one is speaking and all you can hear are muted scuffling feet.  There is an eerie shadow cast on the walls that look like there are ghosts moving from this realm to the next.
# Item Name: There are candles lit everywhere
# Item Description: The candle is tall and white, and smells strongly of tallow.
# ###
#
# Category: Inside temple
# Location Name: Inside temple
# Location Description: It is solemn. There are candles lit everywhere and the although the temple is full, no one is speaking and all you can hear are muted scuffling feet.  There is an eerie shadow cast on the walls that look like there are ghosts moving from this realm to the next.
# Item Name: candles
# Item Description: Trails of wax running down the candle's sides seem to hint that it's used quite often. The candle is burning, with its wax running down the side. The candles light dwindles as the wick continues to shorten, you doubt the light from it would last much longer. The candles have an overwhelming scent. The beeswax candle cast a soft halo of light around the flame. The candle burns brightly and gives off a sweet scent.
# ###
#
# Category: Inside temple
# Location Name: Inside temple
# Location Description: It is solemn. There are candles lit everywhere and the although the temple is full, no one is speaking and all you can hear are muted scuffling feet.  There is an eerie shadow cast on the walls that look like there are ghosts moving from this realm to the next.
# Item Name: temple
# Item Description: This temple rises to a great height, so much so that you must crane your neck back to see its tallest peak.  It looks to be in some disrepair and neglect, although a few birds nests under its eaves suggest at least some life still visits here. The temple is white with a golden dome with tall ivory columns reaching into the sky.
# ###
#
# Category: Inside temple
# Location Name: Inside temple
# Location Description: It is solemn. There are candles lit everywhere and the although the temple is full, no one is speaking and all you can hear are muted scuffling feet.  There is an eerie shadow cast on the walls that look like there are ghosts moving from this realm to the next.
# Item Name: walls
# Item Description: The wall goes up very high. It is painted beige with some paint chips missing. The wall is made of hewn marble that is polished to a glowing sheen, so much so that you can see your reflection upon it. The wall looks new, not a single scratch to be seen.
# ###
#
# Category: Inside temple
# Location Name: Sacrificial altar
# Location Description: A room with a stone floor and a massive statue of a god the peasants worship.  This area gives off chilling vibes.  There's pieces of armor and weapons stored in the room used for various ceremonies.
# Item Name: statue of a god
# Item Description: The statue of the god is intimidatingly large, and the feet of the statue are shiny from so many people touching them over centuries.
# ###
#
# Category: Inside temple
# Location Name: Sacrificial altar
# Location Description: A room with a stone floor and a massive statue of a god the peasants worship.  This area gives off chilling vibes.  There's pieces of armor and weapons stored in the room used for various ceremonies.
# Item Name: pieces of armor
# Item Description: This piece of armor is made from forged metal, and seems rather heavy.  You think it would be helpful at stopping a blow from something sharp.
# ###
#
# Category: Inside temple
# Location Name: Sacrificial altar
# Location Description: A room with a stone floor and a massive statue of a god the peasants worship.  This area gives off chilling vibes.  There's pieces of armor and weapons stored in the room used for various ceremonies.
# Item Name: weapons
# Item Description: On closer inspection, the weapons looked rusted and chipped it appears they have seen many battles for the freedom of the King and its people. The weapon is sharp and you are frightened by its very look. The weapons are used by knights to fend off invaders.
# ###
#
# Category: Inside temple
# Location Name: Sacrificial altar
# Location Description: A room with a stone floor and a massive statue of a god the peasants worship.  This area gives off chilling vibes.  There's pieces of armor and weapons stored in the room used for various ceremonies.
# Item Name: armor
# Item Description: The armor is well worn, not old, but seemingly used a great deal. the armor is worn to protect in the sword fights The armor is sturdy and strong it has a bright silver color and a rough texture. The armor has a plain design, but it looks very strong. The exterior has some dents in it, as if it has been worn before in a battle.
# ###
#
# Category: Inside temple
# Location Name: Sacrificial altar
# Location Description: A room with a stone floor and a massive statue of a god the peasants worship.  This area gives off chilling vibes.  There's pieces of armor and weapons stored in the room used for various ceremonies.
# Item Name: weapons
# Item Description: On closer inspection, the weapons looked rusted and chipped it appears they have seen many battles for the freedom of the King and its people. The weapon is sharp and you are frightened by its very look. The weapons are used by knights to fend off invaders.
# ###
#
# Category: Inside temple
# Location Name: Temple foyer
# Location Description: The temple foyer is a grand entrance with a soaring ceiling painted with the richest cobalt blue and ruby red paints in the entire land. Gold statues welcome the weary traveler with gods depicted in various states of repose. There are windows near the soaring ceilings that let in afternoon light from the east and the west and the floor is inlaid with the finest marble in all the land. A calm water fountain trickles peacefully in the center of the foyer.
# Item Name: a soaring ceiling painted with the richest cobalt blue and ruby red paints
# Item Description: The ceiling has the color red to represent the blood of the enemies and rich cobalt blue to represent the blue skies ahead.
# ###
#
# Category: Inside temple
# Location Name: Temple foyer
# Location Description: The temple foyer is a grand entrance with a soaring ceiling painted with the richest cobalt blue and ruby red paints in the entire land. Gold statues welcome the weary traveler with gods depicted in various states of repose. There are windows near the soaring ceilings that let in afternoon light from the east and the west and the floor is inlaid with the finest marble in all the land. A calm water fountain trickles peacefully in the center of the foyer.
# Item Name: Gold statues
# Item Description: This is a gold statue of a Siberian husky.
# ###
#
# Category: Inside temple
# Location Name: Temple foyer
# Location Description: The temple foyer is a grand entrance with a soaring ceiling painted with the richest cobalt blue and ruby red paints in the entire land. Gold statues welcome the weary traveler with gods depicted in various states of repose. There are windows near the soaring ceilings that let in afternoon light from the east and the west and the floor is inlaid with the finest marble in all the land. A calm water fountain trickles peacefully in the center of the foyer.
# Item Name: A calm water fountain
# Item Description: The fountain is large and round. It has carvings of fish on it.
# ###
#
# Category: Inside temple
# Location Name: Priest's chambers
# Location Description: The priest's chambers is archaic and mysterious. Religious idols and symbols line the walls of the chambers. White cloth and drapes hang from the ceilings.
# Item Name: Religious idols and symbols
# Item Description: The idol is full with dust and crakced, you can barely notice it is an idol.
# ###
#
# Category: Inside temple
# Location Name: Priest's chambers
# Location Description: The priest's chambers is archaic and mysterious. Religious idols and symbols line the walls of the chambers. White cloth and drapes hang from the ceilings.
# Item Name: White cloth and drapes
# Item Description: White cloth and drapes can be used to illustrate a story at church.
# ###
#
# Category: Inside temple
# Location Name: The front altar
# Location Description: The altar is lush with its red silk prayer bench. Many red and white candles provide a somber ambiance.
# Item Name: red silk prayer bench
# Item Description: The bench is used for prayer and is covered with a lovely red silk fabric.
# ###
#
# Category: Inside temple
# Location Name: The front altar
# Location Description: The altar is lush with its red silk prayer bench. Many red and white candles provide a somber ambiance.
# Item Name: red and white candles
# Item Description: the candle has very bright light The candle's wax is almost melted all the way but still serves as a good source for light.
# ###
#
# Category: Inside temple
# Location Name: The front altar
# Location Description: The altar is lush with its red silk prayer bench. Many red and white candles provide a somber ambiance.
# Item Name: alter
# Item Description: The alter is littered with offerings, and bares an inscription in a strange, mysterious language.
# ###
#
# Category: Inside temple
# Location Name: The front altar
# Location Description: The altar is lush with its red silk prayer bench. Many red and white candles provide a somber ambiance.
# Item Name: temple
# Item Description: This temple rises to a great height, so much so that you must crane your neck back to see its tallest peak.  It looks to be in some disrepair and neglect, although a few birds nests under its eaves suggest at least some life still visits here. The temple is white with a golden dome with tall ivory columns reaching into the sky.
# ###
#
# Category: Inside temple
# Location Name: Treasure cavern
# Location Description: Glittering as far as the eye can see the Treasure Cavern is filled with gold, silver, precious gems, and other priceless items. The stacks and stacks of gold plates, goblets, and coins tip precariously from side to side and threaten to fall and cause a landslide of treasures.
# Item Name: gold
# Item Description: Shining in the sun light, the valuable gold presents its self in a small piece no bigger than a pebble. The gold shines in the sunlight, it's been carefully crafted into a perfectly rectangular bar.
# ###
#
# Category: Inside temple
# Location Name: Treasure cavern
# Location Description: Glittering as far as the eye can see the Treasure Cavern is filled with gold, silver, precious gems, and other priceless items. The stacks and stacks of gold plates, goblets, and coins tip precariously from side to side and threaten to fall and cause a landslide of treasures.
# Item Name: silver
# Item Description: The shiny silver looks valuable to you, either as currency or as a raw material.
# ###
#
# Category: Inside temple
# Location Name: Treasure cavern
# Location Description: Glittering as far as the eye can see the Treasure Cavern is filled with gold, silver, precious gems, and other priceless items. The stacks and stacks of gold plates, goblets, and coins tip precariously from side to side and threaten to fall and cause a landslide of treasures.
# Item Name: precious gems
# Item Description: The gem is shiny and bright. The last owner took good care of it. These beautiful precious gems were worn by Queen Martha. They are purple and shiny
# ###
#
# Category: Inside temple
# Location Name: Treasure cavern
# Location Description: Glittering as far as the eye can see the Treasure Cavern is filled with gold, silver, precious gems, and other priceless items. The stacks and stacks of gold plates, goblets, and coins tip precariously from side to side and threaten to fall and cause a landslide of treasures.
# Item Name: stacks of gold plates
# Item Description: The plate is made of glass and is white with a gold rim around it.
# ###
#
# Category: Inside temple
# Location Name: Treasure cavern
# Location Description: Glittering as far as the eye can see the Treasure Cavern is filled with gold, silver, precious gems, and other priceless items. The stacks and stacks of gold plates, goblets, and coins tip precariously from side to side and threaten to fall and cause a landslide of treasures.
# Item Name: goblets
# Item Description: Who would drink out of this golden goblet? It has a whole in it and it's so dirty
# ###
#
# Category: Inside temple
# Location Name: Treasure cavern
# Location Description: Glittering as far as the eye can see the Treasure Cavern is filled with gold, silver, precious gems, and other priceless items. The stacks and stacks of gold plates, goblets, and coins tip precariously from side to side and threaten to fall and cause a landslide of treasures.
# Item Name: coins
# Item Description: The coin seemed old, rusted, and worthless. However, after closer inspection, you reveal the underlying intricate design of the priceless coin.
# ###
#
# Category: Inside temple
# Location Name: The hall of the goddess
# Location Description: An 80-foot tall bronze statue of a 8 legged Goddess is the centerpiece for this Hall.  On four certain Holy Days in the Calendar, people from across the Continent come to worship at her feet and lay money, flowers, and wishes written on paper at her altar.
# Item Name: 80-foot tall bronze statue of a 8 legged Goddess
# Item Description: The deity seems to stare into the distance, the mere mortals bellow her not worthy of her gaze. The statue is of an 8 legged goddess and seems to be built entirely of bronze. It towers over you even from a distance.
# ###
#
# Category: Inside temple
# Location Name: The hall of the goddess
# Location Description: An 80-foot tall bronze statue of a 8 legged Goddess is the centerpiece for this Hall.  On four certain Holy Days in the Calendar, people from across the Continent come to worship at her feet and lay money, flowers, and wishes written on paper at her altar.
# Item Name: money
# Item Description: The small, tarnished coin is imprinted with a seal you don't recognize. The coins are heavy as they should be and well worn.  Bite marks from previous handling could be seen around the sides.
# ###
#
# Category: Inside temple
# Location Name: The hall of the goddess
# Location Description: An 80-foot tall bronze statue of a 8 legged Goddess is the centerpiece for this Hall.  On four certain Holy Days in the Calendar, people from across the Continent come to worship at her feet and lay money, flowers, and wishes written on paper at her altar.
# Item Name: flowers
# Item Description: These flowers grow tall behind the castle. They are medicinal and used in teas for the Kind and Queen. The flower smells like fresh lavender and has beautiful colors. The flower is majestic, a royal blue with a bright green stem. The flower is delicate and the petals are brightly colored. the flower is dry and withered. The flower is fresh and fragrant.  It has several vibrant petals.
# ###
#
# Category: Inside temple
# Location Name: Shrine of sretniy
# Location Description: The Shrine of Sretniy, the mischievous weasel god and patron of explorers, detectives, thieves and jokesters, contains a steel statue of the cheerful mustelids deity. It is unusually cute for a serious religious idol. The room is densely filled with offerings of both precious jewelry and shiny but non-expensive objects.
# Item Name: steel statue
# Item Description: The steel statue looks like it has seen better days. It's all dirty and has marks all over it.
# ###
#
# Category: Inside temple
# Location Name: Sacrifice chamber
# Location Description: Bones of the damned riddle the floor and every surface inside the room. Blood stains are rampant on table like surface, surfaces once used for human sacrifices. A foul, but faint, odor pervades even the most hardiest of nostrils.
# Item Name: Bones
# Item Description: The bone is gnarled and cracked at its most vulnerable points.
# ###
#
# Category: Inside temple
# Location Name: Sacrifice chamber
# Location Description: Bones of the damned riddle the floor and every surface inside the room. Blood stains are rampant on table like surface, surfaces once used for human sacrifices. A foul, but faint, odor pervades even the most hardiest of nostrils.
# Item Name: table
# Item Description: The table was large and heavy. Its surface is piled with goblets and platters. Dented, chipped, and leaning slightly to the side, this table is a witness to many brawls. The table is round and made of roughly-chopped wood planks. The large, oval-shaped table is covered in scratches and dents from years of use.
# ###
#
# Category: Inside temple
# Location Name: Sacrifice chamber
# Location Description: Bones of the damned riddle the floor and every surface inside the room. Blood stains are rampant on table like surface, surfaces once used for human sacrifices. A foul, but faint, odor pervades even the most hardiest of nostrils.
# Item Name: Bones
# Item Description: The bone is gnarled and cracked at its most vulnerable points.
# ###
#
# Category: Inside temple
# Location Name: Sacrifice chamber
# Location Description: Bones of the damned riddle the floor and every surface inside the room. Blood stains are rampant on table like surface, surfaces once used for human sacrifices. A foul, but faint, odor pervades even the most hardiest of nostrils.
# Item Name: temple
# Item Description: This temple rises to a great height, so much so that you must crane your neck back to see its tallest peak.  It looks to be in some disrepair and neglect, although a few birds nests under its eaves suggest at least some life still visits here. The temple is white with a golden dome with tall ivory columns reaching into the sky.
# ###
#
# Category: Inside temple
# Location Name: Royal tomb
# Location Description: This is a large room in the center of the Temple with really high ceilings and there are tombs for every empress and emperor of which are decorated with jewels and treasures and precious stones.
# Item Name: tombs
# Item Description: The tomb is falling apart, and the remains inside have been disturbed.
# ###
#
# Category: Inside temple
# Location Name: Royal tomb
# Location Description: This is a large room in the center of the Temple with really high ceilings and there are tombs for every empress and emperor of which are decorated with jewels and treasures and precious stones.
# Item Name: jewels
# Item Description: The jewels are magnificent, they seem to have a deep history inside of their splendor.
# ###
#
# Category: Inside temple
# Location Name: Royal tomb
# Location Description: This is a large room in the center of the Temple with really high ceilings and there are tombs for every empress and emperor of which are decorated with jewels and treasures and precious stones.
# Item Name: treasures
# Item Description: The treasure itself is no more than a simple golden diadem, it is the purest gold you have ever seen.
# ###
#
# Category: Inside temple
# Location Name: Royal tomb
# Location Description: This is a large room in the center of the Temple with really high ceilings and there are tombs for every empress and emperor of which are decorated with jewels and treasures and precious stones.
# Item Name: precious stones
# Item Description: The precious stone holds a glimmer of its own. When you hold the stone to the light, it glows from within.
# ###
#
# Category: Inside temple
# Location Name: Royal tomb
# Location Description: This is a large room in the center of the Temple with really high ceilings and there are tombs for every empress and emperor of which are decorated with jewels and treasures and precious stones.
# Item Name: tombs for every empress and emperor
# Item Description: The tomb is decorated with many fine riches. You wonder who might deserve such a place.
# ###
#
# Category: Inside temple
# Location Name: Royal tomb
# Location Description: This is a large room in the center of the Temple with really high ceilings and there are tombs for every empress and emperor of which are decorated with jewels and treasures and precious stones.
# Item Name: jewels
# Item Description: The jewels are magnificent, they seem to have a deep history inside of their splendor.
# ###
#
# Category: Inside temple
# Location Name: Royal tomb
# Location Description: This is a large room in the center of the Temple with really high ceilings and there are tombs for every empress and emperor of which are decorated with jewels and treasures and precious stones.
# Item Name: treasures
# Item Description: The treasure itself is no more than a simple golden diadem, it is the purest gold you have ever seen.
# ###
#
# Category: Inside temple
# Location Name: Royal tomb
# Location Description: This is a large room in the center of the Temple with really high ceilings and there are tombs for every empress and emperor of which are decorated with jewels and treasures and precious stones.
# Item Name: precious stones
# Item Description: The precious stone holds a glimmer of its own. When you hold the stone to the light, it glows from within.
# ###
#
# Category: Inside temple
# Location Name: Royal tomb
# Location Description: This is a large room in the center of the Temple with really high ceilings and there are tombs for every empress and emperor of which are decorated with jewels and treasures and precious stones.
# Item Name: personalized tomb
# Item Description: The tomb is preserved and well kept.
# ###
#
# Category: Inside temple
# Location Name: Inside the fairy temple
# Location Description: The fairy temple is very small.  No human has ever been in there, but there was a fairy interpreter that described it as covered in green leaves and grass.  He said they told him that there is a giant frog in the middle that eats all of the pesky flies.
# Item Name: green leaves
# Item Description: The leaf is green and appears fresh, as if it has fallen off of a tree recently.
# ###
#
# Category: Inside temple
# Location Name: Inside the fairy temple
# Location Description: The fairy temple is very small.  No human has ever been in there, but there was a fairy interpreter that described it as covered in green leaves and grass.  He said they told him that there is a giant frog in the middle that eats all of the pesky flies.
# Item Name: grass
# Item Description: The grass is green and smells sweet as if it were Springtime. The grass is green and magnificent, it has a lot of life. Upon inspecting, The grass you see large animal shaped paw prints tracking North. the grass is lush and green. The grass is stained with the blood of battles past. the grass is burned and dead. it has been killed by wildfires and is a tan and brown color A green plant that is often used for ground cover for parks and peoples homes.
# ###
#
# Category: Inside temple
# Location Name: Inside the fairy temple
# Location Description: The fairy temple is very small.  No human has ever been in there, but there was a fairy interpreter that described it as covered in green leaves and grass.  He said they told him that there is a giant frog in the middle that eats all of the pesky flies.
# Item Name: scarab beetle
# Item Description: It is crawling around by the door, where it must have come from.
# ###
#
# Category: Inside temple
# Location Name: Clergyman's office
# Location Description: It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.
# Item Name: simple wooden table
# Item Description: The table is light in color and made from a common wood. It seems relatively new.
# ###
#
# Category: Inside temple
# Location Name: Clergyman's office
# Location Description: It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.
# Item Name: a cross
# Item Description: The cross has jewels embedded and a rosary attached.
# ###
#
# Category: Inside temple
# Location Name: Clergyman's office
# Location Description: It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.
# Item Name: chairs
# Item Description: The chair is made out of sturdy wood. It is plain but well-built. The wooden chair is beginning to crack and come apart. The chair is worn with age, its seat and back rounded smooth from use.  It creaks as if it carries rheumatism in its glued points of contact. The castle chairs were large and ornate, perfect for a king. The chair is simple, with a straight back and solid seat.
# ###
#
# Category: Inside temple
# Location Name: Clergyman's office
# Location Description: It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.
# Item Name: old prayer books
# Item Description: the old prayer book is tattered and worn. it has markings all over it from a previous owner
# ###
#
# Category: Inside temple
# Location Name: Clergyman's office
# Location Description: It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.
# Item Name: single shelf
# Item Description: The shelf is sturdy and made of wood.  A few items sit on the dusty shelf.
# ###
#
# Category: Inside temple
# Location Name: Clergyman's office
# Location Description: It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.
# Item Name: wooden table
# Item Description: The wooden table is small, but it is well made.
# ###
#
# Category: Inside temple
# Location Name: Clergyman's office
# Location Description: It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.
# Item Name: cross
# Item Description: the cross is large in size, but made of a lightweight wood. it has nails on the left and right sides, indicating it is religious in nature
# ###
#
# Category: Inside temple
# Location Name: Clergyman's office
# Location Description: It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.
# Item Name: chairs
# Item Description: The chair is made out of sturdy wood. It is plain but well-built. The wooden chair is beginning to crack and come apart. The chair is worn with age, its seat and back rounded smooth from use.  It creaks as if it carries rheumatism in its glued points of contact. The castle chairs were large and ornate, perfect for a king. The chair is simple, with a straight back and solid seat.
# ###
#
# Category: Inside temple
# Location Name: Clergyman's office
# Location Description: It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.
# Item Name: prayer books
# Item Description: One book can change the world
# ###
#
# Category: Inside temple
# Location Name: Clergyman's office
# Location Description: It is a very small and sparse office with little decoration. It has a simple wooden table, and a cross on the wall. There are two chairs. There are many old prayer books on a single shelf.
# Item Name: shelf
# Item Description: The shelf is sturdy and held in place with rusty iron brackets.  It held a collection of vials and potions.  The bottles are dusty and looked like they've been there for years.
# ###
#
# Category: Inside temple
# Location Name: The altar room
# Location Description: The central location of the temple is the altar room. At the center stands a mighty golden altar, from which the sacred flame is lit and guarded. Only the high priest and his supplicants may enter this room.
# Item Name: sacred flame
# Item Description: It was once said that if a sword was thrown into the sacred flame , it can be made indestructible .
# ###
#
# Category: Inside temple
# Location Name: The altar room
# Location Description: The central location of the temple is the altar room. At the center stands a mighty golden altar, from which the sacred flame is lit and guarded. Only the high priest and his supplicants may enter this room.
# Item Name: sacred flame
# Item Description: It was once said that if a sword was thrown into the sacred flame , it can be made indestructible .
# ###
#
# Category: Inside temple
# Location Name: {}
# Location Description: Dark and spooky at first sight for those who don't understand, but majestic after taking a closer look. The walls of the hallways and tomb rooms are made of a dark precious, priceless metal.  Ornaments of gold and silver sculptures are covering the tombs that contain the corps of those who have past away while there voices still sing the grime anthem of death in the lightless corridors.
# Item Name: gold and silver sculptures
# Item Description: The sculpture shines brightly. A gleaming testament to the material it embodies.
# ###
#
# Category: Inside temple
# Location Name: {}
# Location Description: Dark and spooky at first sight for those who don't understand, but majestic after taking a closer look. The walls of the hallways and tomb rooms are made of a dark precious, priceless metal.  Ornaments of gold and silver sculptures are covering the tombs that contain the corps of those who have past away while there voices still sing the grime anthem of death in the lightless corridors.
# Item Name: tomb
# Item Description: The tomb is filled with cobwebs. It has a dank, musty smell, and water dripped from the walls.
# ###
#
# Category: Inside temple
# Location Name: Meditation room
# Location Description: The floor and walls are wooden and polished to a shine. Golden meditating statues line the walls, the air is cool and many monks sit still with their eyes closed on mats on the ground. In the far center of the room there is a giant golden Buddha towering over everyone in its pedestal.
# Item Name: Golden meditating statues
# Item Description: This statue gleams from being well polished, and looks like a lady with long hair, closed eyes and a serene expression.  She seems almost wistful as you look upon her.
# ###
#
# Category: Inside temple
# Location Name: Meditation room
# Location Description: The floor and walls are wooden and polished to a shine. Golden meditating statues line the walls, the air is cool and many monks sit still with their eyes closed on mats on the ground. In the far center of the room there is a giant golden Buddha towering over everyone in its pedestal.
# Item Name: giant golden Buddha
# Item Description: The giant golden Buddha has a peaceful smile and shines bright like the sun.
# ###
#
# Category: Inside temple
# Location Name: Meditation room
# Location Description: The floor and walls are wooden and polished to a shine. Golden meditating statues line the walls, the air is cool and many monks sit still with their eyes closed on mats on the ground. In the far center of the room there is a giant golden Buddha towering over everyone in its pedestal.
# Item Name: Golden meditating statues
# Item Description: This statue gleams from being well polished, and looks like a lady with long hair, closed eyes and a serene expression.  She seems almost wistful as you look upon her.
# ###
#
# Category: Inside temple
# Location Name: Meditation room
# Location Description: The floor and walls are wooden and polished to a shine. Golden meditating statues line the walls, the air is cool and many monks sit still with their eyes closed on mats on the ground. In the far center of the room there is a giant golden Buddha towering over everyone in its pedestal.
# Item Name: mats on the ground
# Item Description: the mat has an interesting pattern, it is dusty and old but the pattern and the colors remain.
# ###
#
# Category: Inside temple
# Location Name: Meditation room
# Location Description: The floor and walls are wooden and polished to a shine. Golden meditating statues line the walls, the air is cool and many monks sit still with their eyes closed on mats on the ground. In the far center of the room there is a giant golden Buddha towering over everyone in its pedestal.
# Item Name: giant golden Buddha
# Item Description: The giant golden Buddha has a peaceful smile and shines bright like the sun.
# ###
#
# Category: Inside temple
# Location Name: Hall of echoes
# Location Description: the hall of echos is grand, and has one throne seat for the high priestess. Light shows through the hundreds of windows.
# Item Name: throne
# Item Description: That throne is where kings and queens would sit during their reign The throne has very intricate carvings on the sides, and large clawed feet at the base of each leg.
# ###
#
# Category: Outside temple
# Location Name: Temple entrance
# Location Description: The Temple Entrance is a large arch lined in ancient stones. There is a long walkway flanked by lighted torches. Immediately in front of the interest there is a surface with 5 rocks of different shapes and textures. To enter the temple, one must input the correct "code" by moving the rocks in front of to the correct spots.
# Item Name: The Temple Entrance
# Item Description: The entrance is made of stone and has strange language engraved all across it
# ###
#
# Category: Outside temple
# Location Name: Temple entrance
# Location Description: The Temple Entrance is a large arch lined in ancient stones. There is a long walkway flanked by lighted torches. Immediately in front of the interest there is a surface with 5 rocks of different shapes and textures. To enter the temple, one must input the correct "code" by moving the rocks in front of to the correct spots.
# Item Name: lighted torches
# Item Description: The lit torch gives off a huge amount of smoke, and appears to be crafted hastily.
# ###
#
# Category: Outside temple
# Location Name: Temple entrance
# Location Description: The Temple Entrance is a large arch lined in ancient stones. There is a long walkway flanked by lighted torches. Immediately in front of the interest there is a surface with 5 rocks of different shapes and textures. To enter the temple, one must input the correct "code" by moving the rocks in front of to the correct spots.
# Item Name: 5 rocks
# Item Description: A plain old rock that one might find laying on the ground.
# ###
#
# Category: Outside temple
# Location Name: Temple entrance
# Location Description: The Temple Entrance is a large arch lined in ancient stones. There is a long walkway flanked by lighted torches. Immediately in front of the interest there is a surface with 5 rocks of different shapes and textures. To enter the temple, one must input the correct "code" by moving the rocks in front of to the correct spots.
# Item Name: temple of the Gods
# Item Description: The temple is filled with candles and incense. It was built from polished black stones long ago.
# ###
#
# Category: Outside temple
# Location Name: Hilltop temple grounds
# Location Description: A tall white building with stained glass windows and surrounded lush green grass.  It sits on top of a hill with many steps to climb.  Each room has a different setting and painted walls to set the mood.
# Item Name: windows
# Item Description: An egress to the outside of a building. Mostly used for looking through or letting fresh air in. Examining the window closer, it has different shards each one of a different color and texture. The window is divided into four panes with little strips of wood, and there are handprints smudged on the glass.
# ###
#
# Category: Outside temple
# Location Name: Hilltop temple grounds
# Location Description: A tall white building with stained glass windows and surrounded lush green grass.  It sits on top of a hill with many steps to climb.  Each room has a different setting and painted walls to set the mood.
# Item Name: grass
# Item Description: The grass is green and smells sweet as if it were Springtime. The grass is green and magnificent, it has a lot of life. Upon inspecting, The grass you see large animal shaped paw prints tracking North. the grass is lush and green. The grass is stained with the blood of battles past. the grass is burned and dead. it has been killed by wildfires and is a tan and brown color A green plant that is often used for ground cover for parks and peoples homes.
# ###
#
# Category: Outside temple
# Location Name: Hilltop temple grounds
# Location Description: A tall white building with stained glass windows and surrounded lush green grass.  It sits on top of a hill with many steps to climb.  Each room has a different setting and painted walls to set the mood.
# Item Name: walls
# Item Description: The wall goes up very high. It is painted beige with some paint chips missing. The wall is made of hewn marble that is polished to a glowing sheen, so much so that you can see your reflection upon it. The wall looks new, not a single scratch to be seen.
# ###
#
# Category: Outside temple
# Location Name: Hilltop temple grounds
# Location Description: A tall white building with stained glass windows and surrounded lush green grass.  It sits on top of a hill with many steps to climb.  Each room has a different setting and painted walls to set the mood.
# Item Name: fountaints
# Item Description: The fountain flows red with the blood of soldiers.  The stone is stained red, and no water emerges from the spout.
# ###
#
# Category: Outside temple
# Location Name: Hilltop temple grounds
# Location Description: A tall white building with stained glass windows and surrounded lush green grass.  It sits on top of a hill with many steps to climb.  Each room has a different setting and painted walls to set the mood.
# Item Name: plants
# Item Description: The plant is wilted, trampled by marching soldiers. The plant is small and very green. It has tiny holes in the leaves. The plant has a green stalk , large yellow petals with a white center, and droops over under the flowers weight.
# ###
#
# Category: Outside temple
# Location Name: Hilltop temple grounds
# Location Description: A tall white building with stained glass windows and surrounded lush green grass.  It sits on top of a hill with many steps to climb.  Each room has a different setting and painted walls to set the mood.
# Item Name: stained glass windows
# Item Description: The glass window is old and dusty with small pieces of glass falling out
# ###
#
# Category: Outside temple
# Location Name: Hilltop temple grounds
# Location Description: A tall white building with stained glass windows and surrounded lush green grass.  It sits on top of a hill with many steps to climb.  Each room has a different setting and painted walls to set the mood.
# Item Name: grass
# Item Description: The grass is green and smells sweet as if it were Springtime. The grass is green and magnificent, it has a lot of life. Upon inspecting, The grass you see large animal shaped paw prints tracking North. the grass is lush and green. The grass is stained with the blood of battles past. the grass is burned and dead. it has been killed by wildfires and is a tan and brown color A green plant that is often used for ground cover for parks and peoples homes.
# ###
#
# Category: Outside temple
# Location Name: Hilltop temple grounds
# Location Description: A tall white building with stained glass windows and surrounded lush green grass.  It sits on top of a hill with many steps to climb.  Each room has a different setting and painted walls to set the mood.
# Item Name: hill
# ...
# ###
#
# Category: Underwater aquapolis
# Location Name: Underwater aquapolis
# Location Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# Item Name: florescent rocks and shells
# Item Description: The shell was very bright florescent and shiney, it was very eye catching to say the least.
# ###
#
# Category: Underwater aquapolis
# Location Name: Underwater aquapolis
# Location Description: The underwater aquapolis is a massive and ornate city at the bottom of the ocean. The walls of the buildings are made or coral, pearl, and seashells. Schools of fish swim in and out of the circular holes in the walls that act as windows. The aquapolis is illuminated by florescent rocks and shells that line every building.
# Item Name: beautiful and priceless items
# Item Description: The item seems shiny and made of expensive materials
# ###
#
# Category: Underwater aquapolis
# Location Name: The dungeon
# Location Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item Name: flame
# Item Description: The flame glistens a vibrant red.
# ###
#
# Category: Underwater aquapolis
# Location Name: The dungeon
# Location Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item Name: walls
# Item Description: The wall was painted blue. The wallpaper appears to have been painted over.
# ###
#
# Category: Underwater aquapolis
# Location Name: The dungeon
# Location Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item Name: rot
# Item Description: The rot is putrid and puss is oozing from it at a disturbing pace.
# ###
#
# Category: Underwater aquapolis
# Location Name: The dungeon
# Location Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item Name: gangrene
# Item Description: The gangrene is lushly green and festers.
# ###
#
# Category: Underwater aquapolis
# Location Name: The dungeon
# Location Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item Name: death
# Item Description: Death is a scary but inevitable thing.
# ###
#
# Category: Underwater aquapolis
# Location Name: The dungeon
# Location Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item Name: decay
# Item Description: The stench is horrendous, with maggots seen writhing just beneath the surface of the decay.
# ###
#
# Category: Underwater aquapolis
# Location Name: The dungeon
# Location Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item Name: moldy
# Item Description: The mold is covering the surface of the food in green and red patches.
# ###
#
# Category: Underwater aquapolis
# Location Name: The dungeon
# Location Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item Name: iron maiden
# Item Description: The iron maiden smelled of fresh pine and hadn't been touched by a person yet.
# ###
#
# Category: Underwater aquapolis
# Location Name: The dungeon
# Location Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item Name: spike
# Item Description: Hence the renewed concern that the current spike could knock recovery off key.
# ###
#
# Category: Underwater aquapolis
# Location Name: The dungeon
# Location Description: Dark only lit by the flickering flame licking the walls. smell of rot and gangrene. death and decay the walls moist and moldy. the sounds of screams fill the air along with dispear and fate. in the center a iron maiden recently used and open. the spikes a reddish brown from dried blood.
# Item Name: dried blood
# Item Description: The blood is dried and crusty with a smell of iron.
# ###
#
# Category: Underwater aquapolis
# Location Name: Tool shed
# Location Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Item Name: shed
# Item Description: A shed is like a llitle house or a garage where you can keep your things, the sheds are usually in the back yards of the houses
# ###
#
# Category: Underwater aquapolis
# Location Name: Tool shed
# Location Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Item Name: tools
# Item Description: The tool has a wooden handle with leather wrapped around the handle, and a long wooden rod protrudes from the handle.
# ###
#
# Category: Underwater aquapolis
# Location Name: Tool shed
# Location Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Item Name: hooks
# Item Description: The hooks are tiny, dull, and tangled, and are of no use to anyone in this condition.
# ###
#
# Category: Underwater aquapolis
# Location Name: Tool shed
# Location Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Item Name: hoe
# Item Description: The hole has a splintered handle, and the head is caked with crumbling, drying mud.
# ###
#
# Category: Underwater aquapolis
# Location Name: Tool shed
# Location Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Item Name: shovel
# Item Description: The shovel is dirt-encrusted and grimy.
# ###
#
# Category: Underwater aquapolis
# Location Name: Tool shed
# Location Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Item Name: seaweed
# Item Description: The beach is destroyed from the storm, there is seaweed every where.
# ###
#
# Category: Underwater aquapolis
# Location Name: Tool shed
# Location Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# Item Name: shack
# Item Description: In the middle of this deserted forest a shack sits, with a mossy roof and stained glass windows.
# ###
#
# Category: Underwater aquapolis
# Location Name: The lords treasury
# Location Description: Deep inside the volcanic cave that is the foundation of the aquapolis lies the treasury.  Some believe its existence is a myth, but others claim they have been there.  Those that claim they have seen it say you must dive out of the aquapolis' basement while holding your breath, through the cold deep water that is filled with deadly volcanic gas.  The treasury room itself is a dry cave filled with riches from the very infancy of the empire
# Item Name: riches from the very infancy of the empire
# Item Description: The rich from the very infancy of the empire is golden and sparkles in the sun.
# ###
#
# Category: Underwater aquapolis
# Location Name: Neptune's throne room
# Location Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Item Name: painted walls as blue as the sea itself
# Item Description: The wall seems to be dirty and covered in graffiti
# ###
#
# Category: Underwater aquapolis
# Location Name: Neptune's throne room
# Location Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Item Name: tables constructed of beautiful coral
# Item Description: the table has a history of it's own, full of color and scratches with each telling a tale
# ###
#
# Category: Underwater aquapolis
# Location Name: Neptune's throne room
# Location Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Item Name: decorative shells
# Item Description: The shell looks clean and delicate.  It looks like it has been washed.
# ###
#
# Category: Underwater aquapolis
# Location Name: Neptune's throne room
# Location Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# Item Name: ceiling
# Item Description: The ceiling is cracked, wet and stained.
# ###
#
# Category: Underwater aquapolis
# Location Name: The marketplace
# Location Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Item Name: wares
# Item Description: The ware is old and cracked, but the inscriptions upon its' faces speak to the care taken during its' creation.
# ###
#
# Category: Underwater aquapolis
# Location Name: The marketplace
# Location Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Item Name: stalls
# Item Description: He grabbed his horse from it's stall and proceeded to ride into the battle to reclaim his honor.
# ###
#
# Category: Underwater aquapolis
# Location Name: The marketplace
# Location Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Item Name: colorful dyes
# Item Description: There are many leftover colorful dyes. These look like they would be good for coloring clothing.
# ###
#
# Category: Underwater aquapolis
# Location Name: The marketplace
# Location Description: The marketplace is unlike any surface dwellers' paltry trading area, for beneath the waves there is no need for gravity to limit where and how the wares can be displayed.  Indeed, the market is quite crowded, with merchants as likely setting up stalls upside down on the ceiling as on the floor.  Colorful dyes are used around some of the more exotic booths, the color clouding the water and drawing the eye to it.  High shrills pierce the waters as various merchants call out their wares to the merpeoples passing by.
# Item Name: water
# Item Description: The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven.
# ###
#
# Category: Underwater aquapolis
# Location Name: Toad hollow
# Location Description: Toad Hollow is a filthy room within the Underwater Aquapolis. When you enter, you are greeted by the reek of scummy pond water. You enter Toad Hollow through a drainage pipe that you have to crawl through. Once inside Toad Hollow, you can stand up, but you still don't feel comfortable with your surroundings. As far as the eye can see there is muddy water in a circular basin with lily pads floating in it. On the pads, giant toads jump back and forth making gurgling, croaking sounds. As you wade deeper into Toad Hollow, the water comes up to your waist and you see the flash of a fin. There is legend that a creature lives in the center of Toad Hollow that is half human, half monster. Not even the strongest knight has been brave enough to examine it. The fin disappears back underwater but there is a red glint suggesting eyes are watching you. When you reach the other side of the basin, you crawl into another drainage pipe and feel relieved that you're out of this place.
# Item Name: pads
# Item Description: these pads are new, extra comfortable and easy to install in the leggings of armor
# ###
#
# Category: Underwater aquapolis
# Location Name: Toad hollow
# Location Description: Toad Hollow is a filthy room within the Underwater Aquapolis. When you enter, you are greeted by the reek of scummy pond water. You enter Toad Hollow through a drainage pipe that you have to crawl through. Once inside Toad Hollow, you can stand up, but you still don't feel comfortable with your surroundings. As far as the eye can see there is muddy water in a circular basin with lily pads floating in it. On the pads, giant toads jump back and forth making gurgling, croaking sounds. As you wade deeper into Toad Hollow, the water comes up to your waist and you see the flash of a fin. There is legend that a creature lives in the center of Toad Hollow that is half human, half monster. Not even the strongest knight has been brave enough to examine it. The fin disappears back underwater but there is a red glint suggesting eyes are watching you. When you reach the other side of the basin, you crawl into another drainage pipe and feel relieved that you're out of this place.
# Item Name: drainage pipe
# Item Description: A drainage pipe which may or may not be filled with unsanitary contents.
# ###

# %%
# !head fine_tuning_item_descriptions.jsonl
# Out:
# {"prompt": "Category: Forest\nLocation Name: Along the banks of a river in the forest\nLocation Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\nItem Name: river\n", "completion": "Item Description: This river is strong, mighty, and full of fish that feed the nearby village. The river is wide and fast moving.\n###\n"}
# {"prompt": "Category: Forest\nLocation Name: Along the banks of a river in the forest\nLocation Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\nItem Name: fish\n", "completion": "Item Description: The fish is partially eaten, its thin bones poking out. It has been charred beyond recognition and smells a little bad. the fish is large\n###\n"}
# {"prompt": "Category: Forest\nLocation Name: Along the banks of a river in the forest\nLocation Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\nItem Name: insects\n", "completion": "Item Description: The insect moves slowly, as if it has been injured. You are afraid that itmight bit or sting.\n###\n"}
# {"prompt": "Category: Forest\nLocation Name: Along the banks of a river in the forest\nLocation Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\nItem Name: grass\n", "completion": "Item Description: The grass is green and smells sweet as if it were Springtime. The grass is green and magnificent, it has a lot of life. Upon inspecting, The grass you see large animal shaped paw prints tracking North. the grass is lush and green. The grass is stained with the blood of battles past. the grass is burned and dead. it has been killed by wildfires and is a tan and brown color A green plant that is often used for ground cover for parks and peoples homes.\n###\n"}
# {"prompt": "Category: Forest\nLocation Name: Along the banks of a river in the forest\nLocation Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\nItem Name: river\n", "completion": "Item Description: This river is strong, mighty, and full of fish that feed the nearby village. The river is wide and fast moving.\n###\n"}
# {"prompt": "Category: Forest\nLocation Name: Along the banks of a river in the forest\nLocation Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\nItem Name: riverbank\n", "completion": "Item Description: The riverbank looks steep and hard to cross. The riverbank has rocks along its edge and there seems to be some turtles laying about sunbathing.\n###\n"}
# {"prompt": "Category: Forest\nLocation Name: The stream\nLocation Description: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.\nItem Name: The water\n", "completion": "Item Description: The water is dark and murky and has small ripples passing through.\n###\n"}
# {"prompt": "Category: Forest\nLocation Name: The stream\nLocation Description: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.\nItem Name: rainfall\n", "completion": "Item Description: the raifall is sufficient for planting season.\n###\n"}
# {"prompt": "Category: Forest\nLocation Name: The stream\nLocation Description: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.\nItem Name: The water in the sky\n", "completion": "Item Description: Only Water in the sky can help the prosperity of the kingdom, because the drought has affected the harvests of farmers.\n###\n"}
# {"prompt": "Category: Forest\nLocation Name: The stream\nLocation Description: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.\nItem Name: higher elevations\n", "completion": "Item Description: The mountain elevation gives the landscape a beautiful vista.\n###\n"}

# %%
# model name: babbage:ft-cis-700-48-2022-01-31-02-09-12
# model fine-tune: ft-bDPhMVthLQSOs5O3jnNwbkxS
# !openai api fine_tunes.create -t fine_tuning_item_descriptions.jsonl -m babbage
# Out:
# [2022-01-31 01:41:31] Created fine-tune: ft-bDPhMVthLQSOs5O3jnNwbkxS
# [2022-01-31 01:41:46] Fine-tune costs $0.40
# [2022-01-31 01:41:47] Fine-tune enqueued. Queue number: 0
# [2022-01-31 01:41:50] Fine-tune started
# [2022-01-31 01:48:47] Completed epoch 1/4
# [2022-01-31 01:55:20] Completed epoch 2/4
# [2022-01-31 02:01:53] Completed epoch 3/4
# [2022-01-31 02:08:26] Completed epoch 4/4
# [2022-01-31 02:09:14] Uploaded model: babbage:ft-cis-700-48-2022-01-31-02-09-12
# [2022-01-31 02:09:16] Uploaded result file: file-obXlrIIFwnePguVLhfce4H3G
# [2022-01-31 02:09:17] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m babbage:ft-cis-700-48-2022-01-31-02-09-12 -p <YOUR_PROMPT>

# %%
def get_item_description(category, item_name, finetuned_model, location_name="", location_description="", ):
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Category: {category}\nLocation Name: {location}\nLocation Description: {location_description}\nItem Name: {item_name}\nItem Description:".format(
          category=category.capitalize(),
          location=location_name.capitalize(),
          location_description=location_description,
          item_name=item_name
      ),
      temperature=0.7,
      max_tokens=64,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0,
      stop=["###"]
      )
  return response['choices'][0]['text']

finetuned_model = "babbage:ft-cis-700-48-2022-01-31-02-09-12"
category = "Dark Forest"
item_name = "giant trees"
location_name = "Winter's Glade"
location_description = "This is a hidden glade in a dark forest of giant trees.  The forest is full of dangerous creatures that live in the trees.  There are also many mushrooms near the trees that are edible but poisonous if consumed."

descripton = get_item_description(category, item_name, finetuned_model, location_name=location_name, location_description=location_description, )
print(descripton)
# Out:
#  The giant tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it.

# %% [markdown]
# ## 4. List connections from the current location

# %%
# from thefuzz import fuzz

# 4. List connections from the current location
# - inputs: category, location name, location description, and optionally a partial list of existing connections (direction, location name) tuples 
# - output: a list of (direction, location name) tuples

def get_room_connection_finetuning(room_id, rooms_by_id, connection_ids_depth, light_environment):
  """
  This generates a prompt and a completion which can be used to fine-tune OpenAI.
  This version just gnnerates 
  """
  arcs = light_environment['neighbors']
  connection_list = [f"{arcs[str(id)]['direction']};{arcs[str(id)]['destination']}" for id in rooms_by_id[room_id]['neighbors'] if arcs[str(id)]['destination'] in room_names_to_id]
  prompt = ""
  completion = ""
  prompt += "Category: {category}\n".format(category=rooms_by_id[room_id]['category'].capitalize())
  prompt += "Location: {location_name}\n".format(location_name=rooms_by_id[room_id]['setting'].capitalize())
  prompt += "Description: {location_description}\n".format(location_description=rooms_by_id[room_id]['description'])
  prompt += "All Locations: {all_locations}\n".format(all_locations=', '.join([rooms_by_id[connect_room_id]['setting'] for connect_room_id in connection_ids_depth]))
  completion += "Tuples: {connections}\n".format(connections='|'.join(connection_list))
  completion += "###\n"

  return prompt, completion

def bfs(room_id, depth):
  connection_ids_all = []
  connection_ids_prev = [room_id]
  for d in range(depth):
    connection_ids_curr = []
    #   print("connection_ids", connection_ids)
    for room_id_curr in connection_ids_prev:
        connection_ids_curr.extend([room_names_to_id[arcs[str(id)]['destination']] for id in rooms_by_id[str(room_id_curr)]['neighbors'] if arcs[str(id)]['destination'] in room_names_to_id])
    connection_ids_curr = list(set(connection_ids_curr))
    connection_ids_prev = connection_ids_curr
    connection_ids_all.extend(connection_ids_curr)
  connection_ids_all = list(set(connection_ids_all))
  return connection_ids_all

def create_connection_finetuning_data(filename='fine_tuning_connections.jsonl'):
  fine_tuning_data = []
  arcs = light_environment['neighbors']
  print("room_names_to_id", room_names_to_id.keys())
  room_descriptions_to_id = {room['description']:room_id for (room_id, room) in rooms_by_id.items()}
  for category in categories:
    rooms = rooms_by_category[category]
    
    for room_id in rooms:
      connection_ids_depth = bfs(room_id, 10)
      if len(connection_ids_depth) == 0:
          continue
      data = {}
      prompt, completion = get_room_connection_finetuning(room_id, rooms_by_id, connection_ids_depth, light_environment)
      print(prompt + completion)
      data['prompt'] = prompt
      data['completion'] = completion
      fine_tuning_data.append(data)

  print("len(fine_tuning_data)", len(fine_tuning_data))

  with open(filename, 'w') as out:
    for data in fine_tuning_data:
        out.write(json.dumps(data))
        out.write('\n')

create_connection_finetuning_data()
# Out:
# room_names_to_id dict_keys(['The rectory', 'Orc cave', 'Church Entryway', 'Large Farm', 'Firewood Forest', 'Temple gardens', 'Church field', 'Southernmost Tower Entryway', 'Meadow', 'mysterious forest outskirts', 'Castle farm', 'The Lower Dungeon Guard Room', 'In Front of a Stone Tower', 'A small church', 'A wet dungeon', 'Enormous church entrance door', 'Hilltop temple grounds', "Castle Maids' Room", 'Privy room', 'The Inside Temple', 'Haunted Swamp', 'Turquoise Shore', 'The Forsaken Castle', 'The Great Hall', 'An Unfinished Mausoleum', "Fishmonger's stall", 'The beach', 'abandoned mine', 'The Dungeon', 'path in forest', 'The prayer room', 'Barn', 'Cemetery', "Queen's Bedchamber", 'The altar room', 'Confessional', 'Torture Room', 'Island', 'Lighthouse', 'Watchtower', 'Port Tavern', 'Prison room', 'Dungeon', 'Master Bedroom', 'Outside Temple', 'Graveyard', 'Outside Castle', 'The opening to the drawbridge of the castle', 'Bell Tower', "Troll's bridge", 'Dungeon within a castle', 'A wooded magical village', 'An abandoned castle on an ocean cliff side', 'Inside a desolate cave', 'Knights Quarters', 'Underground Chamber', 'outside the church of monks', 'Temple courtyard', 'Inside the Unicorn palace', 'Inside Temple', 'The witches cottage', 'Inside the fairy temple', 'Fairy Forest', 'Inside the fairies church', "Inside the king's palace", 'Dining Hall', 'Confessional Room', "Wizard's Quarters", 'Castle', 'Cave', 'Tower', 'Royal Gardens', 'The Docks', 'The Sacred Temple', 'The Lagoon', 'Inside the temple', 'Outside tower', 'Lake', 'Outside Church', 'Riverbed', 'A military outpost at the heart of the swamp', 'Royal Kitchen', 'Inside Tower', "Princess' Library", 'Treasure Cavern', 'Bathroom', 'The  main hall', 'The living quarters', 'Kings chambers', 'Entrance to the Pine trees', 'Courtyard', 'Large Galleon', 'Dark Cave', 'Top side tower overlooking view', 'Lakeside House', 'Armory', 'Torture Chamber', 'Treasure Room', 'throne room', 'Coast', 'Bat room', 'The Choir room', 'Jail room', 'Underground Cavern', 'Castle Kitchen', 'Moat', "Clergyman's office", 'Grand Dancing Hall', 'Murky water', 'scenic overlook', 'Tombstones of the Kings', 'Sanctuary', 'Rectory', 'Meditation room', 'Loading Dock', 'The tower base', "The King's Quarters", 'A spiral staircase', 'Marketplace', 'Beyond the Wall', 'Land beyond the Wasteland', 'Adjacent to the Guest Castle', "Inside the King's Castle", "Across the King's Garden", "Within the King's Mansion", 'The Chapel', 'A battleship', 'Banquet Hall', 'Entrance to castle', 'A cabin', 'Pew', 'Entrance to church', 'Dock at the Port', 'Dock', "Witch's House", 'Within the walls of the city', "The Queen's Chamber", 'Cottage', 'Bog', 'Nave', "King's Quarters", 'Weapon Closet', "Princess' Chamber", 'Inside Church', 'Training Fields', 'Alchemists Lab', 'Nursery', 'Royal stables', 'Boathouse', 'Tool Shed', 'Library', "The Troll's Lair", 'The Barracks', 'Throne Room', 'The Brush Den', 'Next to an Altar', 'The Ball Room', 'Along the banks of a river in the forest', "King's Bedroom", 'The Winter Gardens', "Servant's Quarters", 'A cursed grave', 'Foyer', 'Guard Shack', 'The Hall of the Goddess', 'the throne', 'The old red barn', 'Fishing Pier', 'High Priest Chamber', 'Beside church pews', 'Quicksand Pit', 'Sacrifice Chamber', 'Beach House', 'Mushroom Hut', 'Pirate Ship', 'beside tower entrance', 'Palace Throne', 'Palace Kitchen', 'Hillside Manor', 'Pig Pen', 'Beside temple entrance', 'Tower Dungeon', 'Beside church entrance', 'Castle Armory', 'Hillside Mansion', 'palace ballroom', 'Church Altar', 'Tower Sewers', 'inside temple crypt', 'Gold Mine', 'stable', 'The room at the top of the tower', 'a lonely island', 'the whipping station', 'the bedding room', 'prison room', 'the fountain', 'beach house', 'stained glass room', 'the farmer hill', 'the clearing', 'Hall of echoes', 'bathing room', 'The Show Room Inside the Castle', 'Inside Church Back Row', 'bone pit', 'Enchanted light house', 'Sacrificial altar', 'Murder hole', 'G ...
# Category: Forest
# Location: Along the banks of a river in the forest
# Description: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.
# All Locations: South Forest, Along the banks of a river in the forest, North Forest
# Tuples: North;North Forest|South;South Forest
# ###
#
# Category: Forest
# Location: The stream
# Description: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.
# All Locations: The swimming hole, The stream
# Tuples: South;The swimming hole
# ###
#
# Category: Forest
# Location: Woods
# Description: The woods are vast. Everywhere you turn it all looks the same. There are scratches on the trees from lost travelers marking their path. There are sounds coming from everywhere and yet no where. There are faint yellow circles up in the trees and bushes, possibly eyes starting at you.
# All Locations: Dark Cave, Woods
# Tuples: Inside;Dark Cave
# ###
#
# Category: Forest
# Location: Ant hill
# Description: The ant hill is very large, over 5 feet high, and is wrapped around the base of a pine tree. The ants are huge compared to normal ants, and jut in and out of large holes in the ant hill. Bones of animals and even people can be seen sticking out of the red dirt ant hill.
# All Locations: Riverbed, Ant hill
# Tuples: South;Riverbed|South;Riverbed
# ###
#
# Category: Forest
# Location: Entrance to the pine trees
# Description: Very tall and towering pine trees that create a dark canopy of shade. Long skinny trees sway in the sky from the soft breeze. Pine needles scatter the ground like plush carpet.
# All Locations: Entrance to the Pine trees, picnic area
# Tuples: North;picnic area
# ###
#
# Category: Forest
# Location: Unsettling forest area
# Description: The forest is actually very creepy even during the day. The trees are so tall that they block the sunlight. There is always fog in the forest which makes it very hard to see. There are a lot of mushrooms near the trees and none of them are edible
# All Locations: mysterious forest outskirts
# Tuples: Outside;mysterious forest outskirts
# ###
#
# Category: Forest
# Location: Forest entrance
# Description: The path quickly narrows and darkens upon entering the forest.  Dense branches overhead block all but a few stray rays of sunshine.  Fallen leaves just beginning to rot blanket the forest floor, and every footstep kicks up a rich, loamy scent as fresh ground is unearthed.
# All Locations: Forest entrance, Northern Shore
# Tuples: East;Northern Shore
# ###
#
# Category: Forest
# Location: Riverbed
# Description: With clear air and the sound of gurgling water near it, the river bed is silty and muddy. The river rushes by the land as more and more dirt separates from the land. The land of the riverbed slick with mud and filled with bugs and worms/
# All Locations: Riverbed, Ant hill
# Tuples: North;Ant hill
# ###
#
# Category: Forest
# Location: Pond
# Description: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.
# All Locations: Valley of doom, Cave
# Tuples: East;Cave
# ###
#
# Category: Forest
# Location: Flower garden
# Description: This clearing is in reveal a wide circle of trees. Proud oaks stand close enough that only the smallest of fauna can squeeze through, protecting the garden within from curious deer and hungry rabbits. Flowers of every hue and shade crowd the soft lawn of grass, soaking up what light they can through the shadows cast by the branches above. Purple, yellow, red, blue - even green blossoms bob in the breeze, their scents mixing to create a heady perfume. Vines and creepers climb up the tree trunks, dripping with grapes and berries.
# All Locations: The Brush Den, Lake, flower garden
# Tuples: North;The Brush Den
# ###
#
# Category: Forest
# Location: Picnic area
# Description: In this picnic area, there is a wide clearing with some cut down tree stumps made for people to sit and enjoy their lunch.  There's also a small pond nearby where people can feed fish and watch turtles sunbathe.
# All Locations: Entrance to the Pine trees, picnic area
# Tuples: East;Entrance to the Pine trees|South;Entrance to the Pine trees
# ###
#
# Category: Forest
# Location: South forest
# Description: The forest is lined with tall trees but has a long walkway for travelers. I the middle of the forest is a long river surrounded by tall grass with clear blue waters and lots of colorful fish.
# All Locations: South Forest, Along the banks of a river in the forest, North Forest
# Tuples: South;Along the banks of a river in the forest|North;Along the banks of a river in the forest
# ###
#
# Category: Forest
# Location: A room hidden in the dense canopy
# Description: Its a large room with types of beings you have never seen before. There is a counter and a person who greets people suprise when you arrive because you are not one of them. The room has an unfamiliar feel to it. with doors leading to walkways, other buildings, an entire city
# All Locations: Firewood Forest
# Tuples: South;Firewood Forest
# ###
#
# Category: Forest
# Location: Woodlands
# Description: The lush hunting grounds cover acres of land, tall trees and thickets of bushes sprawling across the land. Fields of open land are under the deep blue sky, showing the depth of the landscape. The grounds forest is thick but full of light, letting the multitude of wildlife be seen by the naked eye. The abundance of greenery makes it a prime location for hogs and oxen as they explore the land.
# All Locations: woodlands, Hunting grounds
# Tuples: South;Hunting grounds
# ###
#
# Category: Forest
# Location: The brush den
# Description: The entryway to the brush den is made of arched bushes and various plants, as is the ceiling and walls. The inside is furnished with seats made of plant roots that have grown together, and a table made of wood adorned with flowers and wooden cups and plates. A small vine dangles with a glowing floor from the middle of the ceiling that lights the room dimly. Three small beds lay in one corner of the room made of interlaced grass and leaves.
# All Locations: The Brush Den, Lake, flower garden
# Tuples: West;Lake|South;flower garden
# ###
#
# Category: Shore
# Location: Lighthouse
# Description: The lighthouse is an off-white color, towering fifty feet over the shore. The light from the building extends out for miles past the shoreline.
# All Locations: Dock, Castle
# Tuples: West;Dock
# ###
#
# Category: Shore
# Location: King's quarters
# Description: The room is large. The largest of all the throne rooms. The carvings on the wall are ornate and historical. The room is clearly built for royalty. The bed is covered in designed covers. It is truly a sight to see.
# All Locations: washroom, King's Quarters
# Tuples: East;washroom
# ###
#
# Category: Shore
# Location: Large cliffs
# Description: Towering cliffs of gray granite line the coast. A few meters of sand lie between the ocean and the base of the cliffs.
# All Locations: Large cliffs, The beach
# Tuples: South;The beach
# ###
#
# Category: Shore
# Location: Fishing pier
# Description: A spindly, long fishing pier that sits right outside the village. Barnacles cover its pilings in vast numbers. Many villagers can be seen fishing atop of it. Birds and pelicans squawk and fly above it.
# All Locations: Fishing Pier, pier walkway
# Tuples: North;pier walkway
# ###
#
# Category: Shore
# Location: The beach
# Description: Sand that is white as snow. the water is as clear as a crystal. down the shore is some cliffs
# All Locations: Large cliffs, The beach
# Tuples: North;Large cliffs
# ###
#
# Category: Shore
# Location: Old docks
# Description: The shore near the docks. There is fog except on rare occasions. More dangerous than most people would like. You never know what dangers luck from creatures leaving and entering the waters.
# All Locations: Enchanted light house, old docks
# Tuples: West;Enchanted light house
# ###
#
# Category: Shore
# Location: Enchanted light house
# Description: Slightly rusted and corroded from the crashing waves, elegant and tall. each window and opening is lined with a bronze trim.  Some gears can be seen turning along the side, rotating a middle section of the light house.
# All Locations: Enchanted light house, old docks
# Tuples: East;old docks
# ###
#
# Category: Shore
# Location: Pier walkway
# Description: On the seashore facing the pier, seagulls squawk as they swirl overhead. The smell of salt fills the air, and the gentle, dull roar of the waves lapping the beach is omnipresent. A gentle breeze blows, and the chatter of the villagers fishing drifts down to the shoreline from the pier.
# All Locations: Fishing Pier, pier walkway
# Tuples: South;Fishing Pier
# ###
#
# Category: Countryside
# Location: Meadow
# Description: Large clear outdoor meadow. Flowers of blue and white appearing in bunches here and there. The grass glows with a green light. Not much can be said about its appearance, however there is a mystical allure associated with the place as if a meadow for spirits instead of livestock.
# All Locations: Meadow, nearby road
# Tuples: West;nearby road
# ###
#
# Category: Countryside
# Location: The small dirt road
# Description: This small dirt road is flanked by a lush green forest on each side with birds chirping and the occasional deer running about.  Sometimes, you can find broken down wooden wagons left behind from ambushes carried out by bandits.
# All Locations: The small dirt road, Lush meadow in the country side
# Tuples: Inside;Lush meadow in the country side
# ###
#
# Category: Countryside
# Location: Chicken pen
# Description: The chicken pen has wire cages situated on three different levels, with hay at the bottom for the chicken's to sit in. There lie small holes in the cages for the eggs to fall through and be easily harvested by the farmers. The old wooden walls of the chicken pen are beginning to deteriorate and show signs of age.
# All Locations: A cabin, Chicken Pen
# Tuples: South;A cabin
# ###
#
# Category: Countryside
# Location: Lush meadow in the country side
# Description: Green large trees surround the meadow that if filled with beautiful seasonal flowers. A deer is grazing in the far end of the field. A small dirt country road gentle crooks past on the outside of the road.
# All Locations: The small dirt road, Lush meadow in the country side
# Tuples: Outside;The small dirt road
# ###
#
# Category: Countryside
# Location: A cabin
# Description: Plain, pretty basic wooden cabin.  In a field of wildflowers, there is also a pen for the chickens, a clothes line.
# All Locations: A cabin, Chicken Pen
# Tuples: North;Chicken Pen
# ###
#
# Category: Countryside
# Location: Valley of doom
# Description: The Valley of Doom is overrun by dead trees and grasses.  Eerie looking animals peer at you through the brushes.  It is a dark and wicked place.
# All Locations: Valley of doom, Cave
# Tuples: East;Cave
# ###
#
# Category: Countryside
# Location: Horse field
# Description: The horse field includes a huge plains for horses to ride. The fields are yellow and green. The place smells of musk and horse.
# All Locations: peasant's cottage
# Tuples: North;peasant's cottage
# ###
#
# Category: Countryside
# Location: Cottage
# Description: The small cottage was white with two, shuttered windows. It was in the unique shape of a circle and was built of plaster. Smoke billowed from the chimney.
# All Locations: Throne room, Royal Kitchen, Garden
# Tuples: Outside;Garden
# ###
#
# Category: Countryside
# Location: Nearby road
# Description: The road cuts through the countryside. It is a dirt road, with a fence lining the eastern side and a grassy meadow to the west.
# All Locations: Meadow
# Tuples: East;Meadow
# ###
#
# Category: Countryside
# Location: Hillside mansion
# Description: I sweeping villa that rests on the grand hills. Everyone can see how grand it is when they approach from the country road. A tall, wrought-iron fence surround its grounds, which extends for miles.
# All Locations: main gate
# Tuples: North;main gate
# ###
#
# Category: Port
# Location: Dock
# Description: There are creaky wooden walkways with empty sections where boats can rest.  There are a few buildings surrounding this area that sell supplies to sailors.
# All Locations: Castle
# Tuples: North;Castle
# ###
#
# Category: Port
# Location: Captain's cabin
# Description: The captain's cabin is a complete mess. There are multiple maps on the wall, pinned over one another, each with messy writing scrawled over it and multiple X marks in random places. Papers overflow off the desk and across the floor in waves, impeding the captain as he paces, muttering angrily. The bed is messy and unmade, giving the impression that the captain has spent the night tossing and turning. Random objects have been thrown about the room.
# All Locations: Pirate Ship, crew berthing, captain's cabin
# Tuples: Up;Pirate Ship|Outside;Pirate Ship
# ###
#
# Category: Port
# Location: Warehouses
# Description: The warehouses are the largest structures in the port, rising well above the adjoining buildings. Constructed from virgin timber, the beams overhead support lofts that are filled to capacity with boxes, crates, and barrels full of goods from all over the world. Carefully checking each parcel that crosses the doorway, the warehouse manager knows exactly where everything belongs inside.
# All Locations: Warehouses, Port Tavern
# Tuples: North;Port Tavern
# ###
#
# Category: Port
# Location: Port tavern
# Description: The port tavern is the shadiest of all the shady bars in the city. Every night, on its grimy stools at the wooden bar, you can find some of the slimiest sailors in the world. The walls are of peeling blue paint and are always dripping with condensation. Women of ill-repute line one wall, old men on the verge of passing out line another. The floor is littered with trash, barnacles, and bodily fluids. Tending the bar is a small, round man with a bushy mustache.
# All Locations: Warehouses, Port Tavern
# Tuples: South;Warehouses
# ###
#
# Category: Port
# Location: Fishmonger's stall
# Description: A small booth near the edge of the port, it's protected by a piece of old, sun-bleached sailcloth. Baskets of freshly-caught fish, bivalves, and eels sit in the shade in stained wooden troughs of water. A small, aggressive-looking dog is chained to one table, presumably to keep cats away. The stall is redolent with the aroma of fish.
# All Locations: Wharf, Fishmonger's stall, Quay
# Tuples: North;Wharf|East;Quay
# ###
#
# Category: Port
# Location: Quay
# Description: During the day, the quay is bustling with typical activity of a port: burly longshoremen carry crates and roll barrels away from ships for storage and sailors who still have their sea-legs saunter past on their way to drink and more adventures. By night, the quay is teeming with unsavory characters: men who are hardly men any more after losing their way through drink and gambling hunker amongst coils of rope stiffened by the salt water while rats scramble from box to box gnawing their way into the goods contained inside.
# All Locations: Wharf, Fishmonger's stall, Quay
# Tuples: South;Fishmonger's stall|West;Fishmonger's stall
# ###
#
# Category: Port
# Location: Supply store
# Description: With so many ships docked at the port, sailor from all the ships crowd the bazaar. The supply store is filled with buyers today. The inside is plain and unadorned. Sturdy shelves hold common supplies. Along the walls are the larger items for sale.
# All Locations: Supply store, Boat House
# Tuples: Inside;Boat House|Outside;Boat House
# ###
#
# Category: Port
# Location: Pirate ship
# Description: A majestic, shimmering, black pirate ship sits upon the water. Its numerous cannons give it a menacing look. Tons of pirates hop upon its decks in a furious jig. The lone captain plods around in his cabin, plotting on where to seize his treasure next.
# All Locations: Pirate Ship, crew berthing, captain's cabin
# Tuples: Inside;captain's cabin|Down;crew berthing
# ###
#
# Category: Port
# Location: Port skyline
# Description: The local port sits an a majestic inlet of the ocean. The countless docks are constantly bustling with new arrivals and departures. People of all kinds come here for business or leisure. On the shore sits a skyline of many buildings packed with residents going about their day. The smell of salt and seafood fills the air.
# All Locations: Port Skyline, Large Galleon
# Tuples: West;Large Galleon
# ###
#
# Category: Port
# Location: Boat house
# Description: A small house type establishment that serves as a hang out for people about to board the boats.  There is nautical themed decor everywhere.  Life Buoys, mounted fish, replica boats.  It's all wood inside with a bar as well.  A lot of creaky looking wood too, probably weathered a good bit as the house is old itself.
# All Locations: Supply store, Boat House
# Tuples: Down;Supply store
# ###
#
# Category: Port
# Location: The docks
# Description: The docks are a rough place with a lot of rough group of individuals who hang out there.  It is where the ships port and deport, only few know what really goes on there.
# All Locations: Fishing Store, Fish Market, The Docks
# Tuples: South;Fish Market|East;Fishing Store
# ###
#
# Category: Port
# Location: Fishing store
# Description: This store is a small one room stone building with wares laid about on tables.  One can see fishing poles, wooden buckets with dirt and bait inside, along with some mounted trophies.
# All Locations: Fishing Store, Fish Market, The Docks
# Tuples: North;The Docks|West;The Docks
# ###
#
# Category: Port
# Location: Large galleon
# Description: The deck of this rather large ship is strong and freshly swapped with tar. Its mast reaches far into the sky like gleaming pillar of hope and freedom. Its sturdy ship made for long voyages with thick planks and strong rails.
# All Locations: Port Skyline, Large Galleon
# Tuples: East;Port Skyline
# ###
#
# Category: Port
# Location: The village of tamerak
# Description: A thriving sea port filled with merchants, foods, women, and gold.  Hundreds of boats fill the shores, fisherman pushing out to sea and pulling into dock.  Seagulls hover silently above the merchants selling fish.  Pirates can be seen causing trouble with the locals.  Brothels and bars are in abundance, as well as the smell of fish.
# All Locations: Dungeon, King's Quarters, washroom, Library, Church, Tombstones of the Kings, Main entrance, Throne Room, Graveyard
# Tuples: West;Tombstones of the Kings
# ###
#
# Category: Swamp
# Location: Bog
# Description: Frogs croak in the reeds that surround the bog. The water is very murky and underneath the surface tadpoles dart around. There are minimal places to stand to stay dry.
# All Locations: Bog, Underwater Cave, Flower Field
# Tuples: Inside;Underwater Cave|North;Flower Field
# ###
#
# Category: Swamp
# Location: Soldiers camp
# Description: The camp is hidden away in a light forest of trees and brush that might be hard to find if there had not been a symbol on the trees leading up to it. You can feel the anxiety of the soldiers here, as this camp is not well fortified by any conventional means, but instead is supposed to be hidden and camouflaged to throw off anyone that might pursue. The camp is nothing more than a fire and some barracks. Nothing fancy to see.
# All Locations: soldiers camp, Boathouse
# Tuples: East;Boathouse
# ###
#
# Category: Swamp
# Location: Troll's bridge
# Description: Muddy and murky waters lie under a bridge that seems to go nowhere. It is made of cobblestone and just as long as it is wide. Beneath it live a hideous troll that makes people pay to cross.
# All Locations: Troll's bridge, Darkest part of the swamp
# Tuples: South;Darkest part of the swamp
# ###
#
# Category: Swamp
# Location: Boathouse
# Description: The boathouse is a very small building with peeling paint. It is made out of wood, with one half planted in the water on stilts. Inside, there are boats floating in the water. There are hinged doors which can be opened to allow boats to come in and out. There are some ropes and other tools a boater may need stored in the boathouse.
# All Locations: soldiers camp, Boathouse
# Tuples: West;soldiers camp
# ###
#
# Category: Swamp
# Location: Darkest part of the swamp
# Description: The light doesn't pierce the heavy overhanging trees in this near pitch black area of the swamp.  The water is extremely murky and there are occasional fins poking up from the water belonging to some kind of creature.  The air is thick and heavy and insects constantly buzz about.
# All Locations: Troll's bridge, Darkest part of the swamp
# Tuples: North;Troll's bridge
# ###
#
# Category: Lake
# Location: The swimming hole
# Description: The swimming hole is calm and clear.  The sun sparkles off the ripples that form on the surface of the water.  Fish occasionally jump from the water and splash back in.
# All Locations: The stream, The swimming hole
# Tuples: North;The stream
# ###
#
# Category: Lake
# Location: Fishing dock
# Description: Folks call the area a Lake, but it's more like a pond.  Small and unimportant looking, yet peaceful.  The dock is no prize winner either.  Narrow in width, boards broken with several down right missing all together!  No tree nearby, no canopy, nothing to shade oneself on a hot day while fishing.  The watering hole may look small in size, but it deceives the eyes.  The water is as deep as the heavens.  No man knows what lurks beyond the light in this Lake.
# All Locations: Fishing shack, Fishing Dock
# Tuples: West;Fishing shack
# ###
#
# Category: Lake
# Location: Northern shore
# Description: The lake gives way to a slightly sandy and rocky shore. It is dotted with small shrubs and a few trees, but mostly it is a fairly open expanse. It is covered in places by a green short grass. The lake level falls away swiftly from the beach going from a few feet to well over ten feet in a short span.
# All Locations: Northern Shore, Forest entrance
# Tuples: West;Forest entrance
# ###
#
# Category: Lake
# Location: Drinking water lake
# Description: Surrounded by skittering chipmunks and chirping crickets, the drinking lake teems with life. Flora and fauna both thrive near the pristine waters. Tall thick plant life surrounds the lake, with strong roots and stems protruding from the nutrient rich soil. The lake water shimmers in the sun, so clear and clean that one can see the rock lake floor many feet below.
# All Locations: drinking water lake, Tree of Spirits
# Tuples: East;Tree of Spirits
# ###
#
# Category: Lake
# Location: Fishing shack
# Description: The fishing shack is a small wooden structure that is crudely built and is surrounded by boats. The wood flooring around the shack is well weathered and often used.
# All Locations: Fishing shack, Fishing Dock
# Tuples: East;Fishing Dock
# ###
#
# Category: Lake
# Location: Dock
# Description: The wood used to make the dock is of highest quality, commissioned from trees that stand towering in the local forests. Despite time having passed it has been taken care of to the point where even a hint of warping from the water beneath will have a plank torn and replaced within a night.
# All Locations: Supply store, Boat House, Dock, Launching point, Castle
# Tuples: North;Launching point|Inside;Boat House
# ###
#
# Category: Lake
# Location: The lagoon
# Description: The Lagoon is a dark and mysterious place during the night hours.  A lot of moss and lily pads surround the shore.  The water is very murky.
# All Locations: Forbidden Forest
# Tuples: North;Forbidden Forest
# ###
#
# Category: Lake
# Location: Lakeside house
# Description: Its white and vibrant, certainly a location for some lord, It has 3 floors, and fine gardening surround the house. Its open and breezy this place is calm and peaceful.
# All Locations: Lake
# Tuples: North;Lake
# ###
#
# Category: Lake
# Location: Launching point
# Description: The Launching point features a number of large wooden planks sitting at a downward slope going straight into the water.  On each side of the launching point there sits a large, ornate bronze figure of a light house that is used to tether the ships to the dock and keep them from casting away while the sailors prepare to board the ship. The launching point is very narrow, with large stone braces on either side of the dock.
# All Locations: Dock, Castle
# Tuples: South;Dock
# ###
#
# Category: Lake
# Location: Clean water lake
# Description: The lake is crystal clear, lined with trees, to the far back of the lake there's a small formation of rocks almost like a small waterfall allowing water to flow into the lake. It's quite beautiful, the sun bathing the surrounding area in a warmth so comforting you could easily fall asleep on the shore. There's an old wooden bath, for its age it seems to look like almost new, and rarely used. There are no animals nearby except for birds softly chirping in the trees.
# All Locations: clean water lake, weathered shack
# Tuples: Down;weathered shack|West;weathered shack
# ###
#
# Category: Graveyard
# Location: Main street
# Description: main street is bleak and outdated. it wears the atmosphere of the cemetery based on association. it is dark even in sunlight and has a unique odor
# All Locations: Cemetery, Main street
# Tuples: South;Cemetery|East;Cemetery
# ###
#
# Category: Graveyard
# Location: Cemetery
# Description: Dim and low lit. The aura from this cemetery emits sadness and pain perpetually. You can feel and sense the eerie nature of the graveyard crawl up your spine. There seems to be a slight fog slowly making its way across the open parts of the cemetery.
# All Locations: Cemetery, Main street
# Tuples: West;Main street
# ###
#
# Category: Graveyard
# Location: Reception area
# Description: The building itself is ordinary in appearance and is somewhat foreboding.  It is surrounding by a dense fog and high grass.  Sometimes, one can hear whispers in the wind.
# All Locations: Main graveyard
# Tuples: East;Main graveyard
# ###
#
# Category: Graveyard
# Location: Abandoned workers shed
# Description: Moss now grows across what was once a red painted wooden shed, standing in the area just outside the graveyard. The wood shed is splintering, and there is evidence that termites have eaten away at the walls as holes poke through the shed. Inside the shed there lies leaves and plants that have been dragged in their by the wild animals that at one point called the abandoned shed their home.
# All Locations: Old Crypt, Abandoned workers shed
# Tuples: North;Old Crypt
# ###
#
# Category: Graveyard
# Location: Tombstones of the kings
# Description: The tombstones of the kings are the most notable part of the graveyard. These tombstones are erected from fine marble and have piles of gold and riches lying next to them. A small metal fence surrounds this section of the graveyard, and cuts it off from the common folk.
# All Locations: Dungeon, King's Quarters, washroom, Library, Church, Main entrance, Throne Room, Graveyard
# Tuples: North;Church
# ###
#
# Category: Graveyard
# Location: Old crypt
# Description: Broken stones and a iron gate closing the entrance with a name placard that the name is worn off.
# All Locations: Old Crypt, Abandoned workers shed
# Tuples: South;Abandoned workers shed
# ###
#
# Category: Graveyard
# Location: An unfinished mausoleum
# Description: Two-and-a-half walls of the finest, whitest stone stand here, weathered by the passing of countless seasons. There is no roof, nor sign that there ever was one. All indications are that the work was abruptly abandoned. There is no door, nor markings on the walls. Nor is there any indication that any coffin has ever lain here... yet.
# All Locations: Dead Tree
# Tuples: South;Dead Tree
# ###
#
# Category: Abandoned
# Location: Collapsed west wing
# Description: The rocks have all but fallen into the ocean.  There is moss and other plant life climbing the remaining rocks, making it a very moist and gloomy environment.  There are some small left-behind pieces of what appear to have been some furniture, and possibly a cradle.
# All Locations: Collapsed West Wing, King's Quarters, washroom, An abandoned castle on an ocean cliff side, Throne Room
# Tuples: South;An abandoned castle on an ocean cliff side|East;An abandoned castle on an ocean cliff side
# ###
#
# Category: Abandoned
# Location: Weathered shack
# Description: A weathered shack with a roof made of old broken tiles sits in the middle of the forest. The wood is starting to split and the shack appears as if it will crumble at any moment.
# All Locations: clean water lake, weathered shack
# Tuples: East;clean water lake
# ###
#
# Category: Abandoned
# Location: An abandoned castle on an ocean cliff side
# Description: The castle is located at the top of an erosive cliff face of a vast ocean. An entire wing of the castle appear to have collapsed into the ocean due to the erosion of the cliff face, perhaps the reason why the castle now lay abandoned.
# All Locations: Collapsed West Wing, King's Quarters, washroom, An abandoned castle on an ocean cliff side, Throne Room
# Tuples: West;Collapsed West Wing|Inside;Throne Room
# ###
#
# Category: Abandoned
# Location: Ruined house
# Description: A dilapidated wooden structure with a caved in roof and debris everywhere.  Even the trees outside the house are falling apart.  There's waist high grass leading to the house along with a dirt path.
# All Locations: Dungeon, King's Quarters, washroom, Library, Main entrance, Throne Room, Graveyard
# Tuples: North;Graveyard
# ###
#
# Category: Cave
# Location: Underwater cave
# Description: The underwater cave is dark and rocky. Inside the cave fish and tadpoles have taken over. The water is cold, no light gets in. Once inside, a rocky outcrop allows swimmers to come up for air.
# All Locations: Bog, Underwater Cave, Flower Field
# Tuples: South;Bog|Outside;Bog
# ###
#
# Category: Cave
# Location: Cave
# Description: Cold and dark, the moist cool walls enclose all who proceed. With just torches to light the way the large opening gets smaller and smaller.
# All Locations: Valley of doom, Cave
# Tuples: West;Valley of doom
# ###
#
# Category: Cave
# Location: Underground cavern
# Description: The underground cavern is covered in precious metals and gems. In the wall, rubies, emeralds and sapphires sparkle. There is gold and silver, shining brightly. It is cool in the underground cavern.
# All Locations: Underground Cavern, cave exit, the underground river
# Tuples: Down;the underground river|Up;cave exit
# ###
#
# Category: Cave
# Location: Gallery
# Description: The cave is pitch black and smells of dank and mold. It's quiet except for a faint dripping noise from water overhead and the occasionally scurrying of an unseen rodent through the darkness. Barely discernable by the light of a torch is a small pile of bones in one corner. From what type of animal they are from is unclear.
# All Locations: Gallery, Primary Cave
# Tuples: West;Primary Cave
# ###
#
# Category: Cave
# Location: Entrance
# Description: The entrance to his cave is covered in hanging moss with shrubs on either side of the entrance.  The path to this cave is a small dirt one with low grass on the floor.
# All Locations: Valley of doom, Pond, Cave
# Tuples: West;Pond
# ###
#
# Category: Cave
# Location: Cave exit
# Description: The large cave is covered along the walls with bright torches.  A large hole has been carved in the ceiling of the cave, right above the ladder that descends into the underground cave.  On good bright days, sunlight directly surround the hole with the gold ornate ladder descending into the underground part of the cave.  On the walls of the cave the torches illuminate many ornate drawings and paintings mainly dealing with the history of Kings of the realm.
# All Locations: Underground Cavern, cave exit, the underground river
# Tuples: Up;Underground Cavern|Down;Underground Cavern
# ###
#
# Category: Cave
# Location: Primary cave
# Description: Dark and with a lot of space in it. The primary cave has a scary look that scares people away. Underneath, in the floor, many precious minerals that no one dares to get out.
# All Locations: Gallery, Primary Cave
# Tuples: East;Gallery
# ###
#
# Category: Cave
# Location: Dark cave
# Description: Its dark, not much light can be seen in this hollow and empty cave site. Its made of stone that has been here seemingly since time began, the walls are hard as diamond, yet black like darkness itself.
# All Locations: Dark Cave, Woods
# Tuples: Outside;Woods
# ###
#
# Category: Cave
# Location: Secret tunnel
# Description: Your senses are met with the dank moisture of a secret tunnel. The stony walls are full of lichen and cave moss. Stalactites and stalagmites pepper the small channel, which bleeds in a pinpoint light from a far off point. The chill air of the King's forest whistles through the tunnel interior.
# All Locations: Storage room
# Tuples: East;Storage room
# ###
#
# Category: Trail
# Location: Trailhead
# Description: the trailhead is a worn down area leading in many directions, it has shown the wear of constant horse travel and other methods of transportation. it is till well used but in need of a makeover
# All Locations: The opening to the drawbridge of the castle, Trailhead
# Tuples: Inside;The opening to the drawbridge of the castle
# ###
#
# Category: Trail
# Location: Path in forest
# Description: The trail path is a well designed path in the middle of a deep, dark forest. It is made purely from the bones of the innocent that were sacrificed to the ogre. There are eyes looking in the dark at you as you walk on the trail.
# All Locations: path in forest, Trail Exit
# Tuples: South;Trail Exit
# ###
#
# Category: Trail
# Location: Tree of spirits
# Description: The Tree of Spirits is a large oak tree that is over 500 years old. It exceeds 100 feet tall and 10 feet wide. It's branches spread out several feet and it is home to several animals.
# All Locations: drinking water lake, Tree of Spirits
# Tuples: West;drinking water lake
# ###
#
# Category: Trail
# Location: Hunting grounds
# Description: The hunting grounds are spacious and full of wildlife. A variety of hogs and oxen cross the grounds every day. The fields are lush with green and the skies always deep blue.
# All Locations: woodlands, Hunting grounds
# Tuples: North;woodlands
# ###
#
# Category: Trail
# Location: Trail exit
# Description: The woodland area creates a gentle, peaceful feel as one walks along past the leafy fronds and gently shifting foliage.  The path is firm and wide, having been traversed by many feet, but not so wide as to allow a merchant's cart to pass through.  A bird's cry sounds in the distance, followed by a ruffle of feathers, and then silence.  The beauty of the forest hides the struggle of nature that lies within...
# All Locations: path in forest, Trail Exit
# Tuples: North;path in forest
# ###
#
# Category: Trail
# Location: The opening to the drawbridge of the castle
# Description: The trailhead to the forest is a dirt trail, dusty as it has not rained in a while. The overhang of the trees is luscious and green with only patches of sunlight beaming through the dense canopy. There are many large trees, some with arrows still stuck in their trunks. The trail is treacherous as it leads through the densest part of the forest, through a stream and to a well-hidden castle. Once inside the forest, the shade and canopy has provided plenty of opportunities for foliage to grow making it harder to follow.
# All Locations: The opening to the drawbridge of the castle, Trailhead
# Tuples: Outside;Trailhead
# ###
#
# Category: Dungeon
# Location: Torture room
# Description: The room is sparse and cold. A variety of torture implements are housed in the room, and a bloodied prisoner can often be found hanging in shackles on the wall of the room.
# All Locations: Torture Room, Torture equipment storage room, Pet chamber
# Tuples: North;Pet chamber|South;Torture equipment storage room
# ###
#
# Category: Dungeon
# Location: Dungeon within a castle
# Description: The castles dungeon lay buried below the village on the outskirts of the castles garden. Only the guards have access to light, and light is given as a privilege. The interior is stone and smells of mildew and deadly black mold.
# All Locations: Entrance, Valley of doom, Pond, Cave
# Tuples: Inside;Entrance
# ###
#
# Category: Dungeon
# Location: Inside a desolate cave
# Description: The dungeon exists inside a dark cave. Enchanted torches light the cave up and lead the way to this ancient dungeon. Creatures can be seen populating the dungeon, but it is unknown if they are malevolent or benign.
# All Locations: Prisoners Cells
# Tuples: North;Prisoners Cells
# ###
#
# Category: Dungeon
# Location: Torture room
# Description: An absolutely filthy and disgusting place.  Blood from the recently tortured covers the floors and walls, and the place is generally filthy and grimy.  There are various pieces of torture equipment lying around the room as well as instruments, tables, and chairs.
# All Locations: Disposal area, Torture room
# Tuples: Down;Disposal area
# ###
#
# Category: Outside cottage
# Location: Small graveyard
# Description: This is a small grassy area located under a large oak tree.  There are two home made wooden crosses set up along with mounds where the bodies are buried.
# All Locations: Dungeon, Garden, Cottage, Royal Kitchen, King's Quarters, washroom, Stable, Main entrance, Throne room, Throne Room, Peasant living quarters
# Tuples: North;Cottage|West;Stable
# ###
#
# Category: Outside cottage
# Location: Front of the cottage
# Description: Furs hang out on racks to try and get ready for tanning. A dog lays in front of the door into the cottage. A little herb garden is on the opposite side of the cottage to the racks.
# All Locations: Throne room, Royal Kitchen, Garden, Cottage
# Tuples: Inside;Cottage
# ###
#
# Category: Outside cottage
# Location: Backyard
# Description: Fresh Dark green grass covering the hill over the wet soil is the daily routine for a farmer. Beneath the grass are the freshly grow carrots. Addition to these beautiful living-hood are the two healthy black cows to gaze over the grass avoiding the carrot farm.
# All Locations: the farmer hill, backyard
# Tuples: Inside;the farmer hill
# ###
#
# Category: Outside cottage
# Location: The farmer hill
# Description: the hill is a large patch of farming cattle and carrots growing in the grass. The grass is dark green and the hill's soil is moist. There are two black as night cows grazing, carefully avoiding the carrots.
# All Locations: the farmer hill, backyard
# Tuples: Outside;backyard
# ###
#
# Category: Outside cottage
# Location: Garden
# Description: A wooden fenced in area with different sections depending on the type of vegetable or plant grown.  Surrounding this garden are some oak trees with low grass covering the floor.
# All Locations: Garden, Cave, Cottage, Royal Kitchen, Valley of doom, Throne room, Pond
# Tuples: North;Cottage|South;Pond
# ###
#
# Category: Inside castle
# Location: Kings bedroom
# Description: There is a large bed against the wall with wooden headboard and posts holding up a fancy roof over the bed.  There is a large tapestry  across from the bed depicting a map of the kingdom.  On the floor is a large bear rug.  The walls are decorated with gold and jewels.  There are 2 large wooden doors.  One leads to a hallway, the other leads to a bathroom.  There is a large wardrobe that is painted red and gold.
# All Locations: Royal Bathroom, Castle Royal tower, Kings bedroom
# Tuples: Up;Castle Royal tower|West;Royal Bathroom
# ###
#
# Category: Inside castle
# Location: Lavoratory
# Description: The lavatory contains a long trough for which the knights can use for urination. Crude toilets are also included for defecation. The design is all stone walls with candles, and no privacy walls.
# All Locations: Knights Quarters, Lavoratory
# Tuples: Outside;Knights Quarters|North;Knights Quarters
# ###
#
# Category: Inside castle
# Location: The kitchens
# Description: The kitchens are a busy, hot place. They are filled with kitchen staff rushing around to prepare the main meals for the king's family and residing nobles. Tonight they are preparing two deer the king and his nobles caught while hunting, as well as some rabbit from a few days ago and seasoned vegetables. There are multiple fires around the kitchen to cook the animals and boil the vegetables, and combined with the heat of all the people the room is stifling. While the main kitchen workers are middle aged women who stay at one station, there are also younger children running around taking ingredients from one place to another. People are shouting instructions and gossip to one another constantly, so it is very hard to hear anything, but the atmosphere is very cheerful.
# All Locations: kitchens, Dining Hall
# Tuples: Inside;Dining Hall|East;Dining Hall
# ###
#
# Category: Inside castle
# Location: Castle basement
# Description: Inside of the murky basement, along the walls lay many hidden treasures of the castle. Long hidden wooden chests containing gold and other valuables, away from the eyes of the greedy, each chest is secured with a chain and a lock. There is many rats running around as well. In the air there is an unpleasant smell of dampness and the floors are dusty. There is a table  in the center on the room on which are piled many rat traps and rat poison. There are also some broken chairs set up near the wall, some missing a leg or two.
# All Locations: washroom, Throne Room, Dungeon, King's Quarters
# Tuples: Up;Dungeon
# ###
#
# Category: Inside castle
# Location: Castle maids' room
# Description: Inside the maids room is dark and grey.  It is much different from the rest of the Castle which has grand walls and floors and paintings from famous painters around the wall.  The maid holds many secrets in this room.  One which is a secret door that holds paintings she should not have.
# All Locations: Castle Maids' Room, Basement
# Tuples: Down;Basement
# ###
#
# Category: Inside castle
# Location: Castle
# Description: This castle is made from red brick. The walls are all painted purple and have gold trim. There is a big chandelier that lights up the main room of the castle.
# All Locations: Barn, Chicken coop
# Tuples: East;Barn
# ###
#
# Category: Inside castle
# Location: Guard barracks
# Description: This is a long, wide hall, filled with bunk beds, foot lockers, side tables and various possessions, stuffed in corners, or under furniture. The high ceiling it pointed and a dizzying array of beams criss-cross their way down the length of the room. Neat, uncluttered and relatively free of dirt. Swords, axes, maces and bows lean against walls or hang from pegs. A large center pathway, twenty feet wide, separates the long rows of beds. Two large tables near the back of the room are each surrounded by twelve old, but serviceable chairs.
# All Locations: Guard Barracks, Great Armory
# Tuples: North;Great Armory|South;Great Armory
# ###
#
# Category: Inside castle
# Location: Dining hall
# Description: The dining room holds a gleaming, gilded wooden table that can seat 100! There are gilded mirrors on the walls, and hundreds of candles, which are lit every night. There is a large handmade rug on the floor and tapestries lining the walls depicting past royalty.
# All Locations: kitchens, castle exit, Dining Hall
# Tuples: South;castle exit
# ###
#
# Category: Inside castle
# Location: Pet chamber
# Description: You see dozens of tiny luxurious cages where the menagerie is kept.  Instead of metal bars, the cages have bars of clearest crystal, and within are every sort of animal that walks, crawls, flaps or slithers.
# All Locations: Torture Room, Torture equipment storage room, Pet chamber
# Tuples: North;Torture Room|South;Torture Room
# ###
#
# Category: Inside castle
# Location: Chapel of the eight
# Description: Made entirely out of gold and with precious jewels all around. Sculptures and many symbols with a red carpet goes from the entrance up until the end of the chapel.
# All Locations: throne room
# Tuples: North;throne room
# ###
#
# Category: Inside castle
# Location: Grand ballroom
# Description: There is a large marbled floor with ornate inlay-ed floor decorations.  The ceiling is tall and also ornately decorated with beautiful plaster decorations that touches by gold lining.  The space is high and well lit with many windows but has a dark musky smell.
# All Locations: Dining hall, Grand Ballroom
# Tuples: Up;Dining hall
# ###
#
# Category: Inside castle
# Location: Dungeon
# ...
# All Locations: Top floor of palace, Dungeon, King's Quarters, washroom, Master Bedroom, Library, Main entrance, Throne Room
# Tuples: Up;Top floor of palace
# ###
#
# Category: Inside palace
# Location: Queen's quarters
# Description: This room is luxurious. It is lined with the finest golds and silks. The colors are purple and pink and a variety of drapes cover the walls.
# All Locations: Queen's quarters, hidden revolutionaries' headquarters, Castle front, King's chambers
# Tuples: North;King's chambers|Down;hidden revolutionaries' headquarters
# ###
#
# Category: Inside palace
# Location: Palace entrance
# Description: The palace entrance is majestic and well built. There are beautiful decorations from all over the world from the greatest artists. It is mostly gold and pretty colors.
# All Locations: the throne, Palace Entrance
# Tuples: North;the throne
# ###
#
# Category: Outside palace
# Location: Palace garden
# Description: The Palace garden is a lavish and lush garden filled with delicate roses and towering trees. In the center of the garden stand's a statue of the nation's founding leader. The statue is surrounded by a moat. There are stone walk ways throughout the gardens for visitors to walk through.
# All Locations: kitchens, Dining Hall
# Tuples: Inside;Dining Hall
# ###
#
# Category: Outside palace
# Location: Main castle doors
# Description: The main castle doors are ornate. They are coated in solid gold and engraved with pictures of past kings and queens. They have huge gilded handles. They are heavy and have a faint metallic odor. They gleam in the sunlight.
# All Locations: Cemetery, Main street
# Tuples: North;Cemetery
# ###
#
# Category: Outside palace
# Location: Garden
# Description: The bright green shoots of new vegetables and herbs are seen in rows of dark brown earth. The stone wall that surrounds the garden is low enough to let in the warm sun. A basket has been left near the wall for gathering items for meals.
# All Locations: Throne room, Royal Kitchen, Garden
# Tuples: Inside;Royal Kitchen
# ###
#
# Category: Outside palace
# Location: Hidden garden
# Description: There are plenty of roses, wilted, but still red.  A large statue of a beautiful woman stands in the middle, ivy growing around her.  She seems very kind in her expression.  It seems as though she may be buried underneath.  There is an overgrown mess of plants that form an archway that she is staring at.
# All Locations: The Ball Room
# Tuples: Inside;The Ball Room
# ###
#
# Category: Outside palace
# Location: Stable
# Description: A plain wooden building with some hanging tapestries.  There are some handsome looking horses that reside here along with some farm equipment stored inside.
# All Locations: Dungeon, King's Quarters, washroom, Stable, Main entrance, Throne Room, Peasant living quarters
# Tuples: North;Main entrance|West;Peasant living quarters
# ###
#
# Category: Outside palace
# Location: Courtyard exterior
# Description: Paths as well as vines, fountains, and sitting areas are decoratively placed through out the courtyard. It's a place where people are welcome and arrive to enter the castle of the court.
# All Locations: Dungeon, King's Quarters, washroom, Main entrance, Throne Room, Courtyard
# Tuples: East;Courtyard
# ###
#
# Category: Outside palace
# Location: Laundry lines
# Description: The laundry lines extend for meters. 6 rows of lines go from north to south. The area is filled with people putting their clothes to dry. All the lines are in an opening of trees that the sun hits perfectly to help dry. To the right you can see a stream through the tree where people go to wash their clothes before they hang them to dry.
# All Locations: Dungeon, King's Quarters, washroom, Main entrance, Throne Room, Courtyard
# Tuples: North;Courtyard
# ###
#
# Category: Outside palace
# Location: Garden
# Description: Many beautiful types of flowers and plants grow here.  There's a small shed used for store gardening equipment.
# All Locations: Dungeon, King's Quarters, washroom, Main entrance, Throne Room
# Tuples: Down;Dungeon|North;Main entrance
# ###
#
# Category: Outside palace
# Location: Courtyard
# Description: An area with a beautiful garden in center surrounded by stone walls with entrances to different parts of the palace.  There's statues of mythological figures in different corners of the courtyard.
# All Locations: Dungeon, King's Quarters, washroom, Main entrance, Throne Room
# Tuples: North;Main entrance|Down;Dungeon
# ###
#
# Category: Outside palace
# Location: Courtyard
# Description: Hand carved stone surround the courtyard made by the most skilled masons with their impervious designs. Its large and quiet with hanging moss, and several beds of flowers.
# All Locations: Dungeon, King's Quarters, washroom, Courtyard exterior, Main entrance, Throne Room, Courtyard
# Tuples: West;Courtyard exterior|West;Courtyard
# ###
#
# Category: Outside palace
# Location: Peasant living quarters
# Description: The peasant living quarters are generally very bare, dirty, and primitive for the most part.  It's essentially a large straw hut with hay-filled sleeping mats on the floor, and piles of clothes.  There are several plain white sacks containing potatoes, apples, and other basic foods for the residents here.
# All Locations: Dungeon, King's Quarters, washroom, Stable, Main entrance, Throne Room, Peasant living quarters
# Tuples: East;Stable
# ###
#
# Category: Outside palace
# Location: Courtyard
# Description: The courtyard is a huge pavilion of stone patio outside of the palace. It is in the shape of a large rectangle and boarders the west end of the palace. It is bordered in luscious hedges dotted with colorful flowers, particularly roses. Throughout the courtyard there are potted flowers, stone benches, statues and bird baths and fenced garden plots, and also a central atrium, that all evoke the feeling on an Arcadian garden.
# All Locations: Dungeon, King's Quarters, washroom, Main entrance, Laundry Lines, Royal stables, Courtyard, Throne Room, stable hand's quarters
# Tuples: North;Royal stables|South;Laundry Lines
# ###
#
# Category: Farm
# Location: Sheriff office
# Description: The sheriff's office is a small building on the southern edge of the farm. There is a desk with decrees from the king and other papers strewn about. Hanging on the wall are swords and other weapons. The room is small and cluttered, with various books and other things strewn about.
# All Locations: Large Farm, Sheriff Office
# Tuples: North;Large Farm
# ###
#
# Category: Farm
# Location: Adjacent to the guest castle
# Description: Green, fertile, and blessed with crops of all kind. This well-kept farm grows corn, rice, and wheat for the King's Family and closest aides. Animals such as horses, goats, and the bleating of sheep keeps this Farm bustling with activity.
# All Locations: Horse Tent, Adjacent to the Guest Castle
# Tuples: Down;Horse Tent
# ###
#
# Category: Farm
# Location: Chicken coop
# Description: The yard outside the barn is on a small, but well-maintained farm plot. There are enclosures for animals, and a short path leading up to a handsome, cozy farmhouse surrounded by large trees. The sun is warm, and the smell of grass and animal odors hangs in the air.
# All Locations: Barn, Chicken coop
# Tuples: Inside;Barn
# ###
#
# Category: Farm
# Location: Stilt home
# Description: This stilt home has large wooden vertical beams propping it up to avoid the annual flooding that comes about during the year.  The dark wooden home itself is rather plain on the inside and outside with a thatch roof.  There's a small garden to the rear of the stilt home.
# All Locations: Pig Pen, Stilt Home, Lake, The old red barn
# Tuples: South;The old red barn
# ###
#
# Category: Farm
# Location: Barn
# Description: A large shed like building aside any farmers house. Usually made out of wood with a large gate for moving animals. Used to store animals or farm equipment.
# All Locations: Lake
# Tuples: East;Lake
# ###
#
# Category: Farm
# Location: Large farm
# Description: The farm is huge, over 1000 acres. There are a ton of horses that live on the farm and a wooden fence is around all roads of the farm. There is a red barn in the center of the farm.
# All Locations: Large Farm, Sheriff Office
# Tuples: South;Sheriff Office
# ###
#
# Category: Farm
# Location: Farmer's house
# Description: a single room cottage with a dirt floor, minimally decorated with only a table, a pallet and a wood burning stove there is but a single window and a single door at this place
# All Locations: Barn, Chicken coop
# Tuples: Inside;Barn|South;Barn
# ###
#
# Category: Farm
# Location: Stable
# Description: It's a plain wooden building that has survived many harsh seasons.  The floor of the stable is covered in hay and there's food and pieces of farm equipment stored inside.
# All Locations: Dungeon, Royal Kitchen, Garden, King's Quarters, washroom, Stable, Main entrance, Throne room, Main house, Throne Room, Peasant living quarters
# Tuples: North;Main house|South;Garden
# ###
#
# Category: Farm
# Location: The old red barn
# Description: This is an old run down red barn. It's two stories and most farmers wouldn't still be using it. It has chickens and cows inside and harvests eggs and milk for the entire family. The second story has a large pile of hay visible through an old opening in the front.
# All Locations: Pig Pen, Stilt Home, Lake, The old red barn
# Tuples: East;Pig Pen|South;Lake|North;Stilt Home
# ###
#
# Category: Farm
# Location: Barn
# Description: The barn is old and rustic on the inside, with fresh red paint on the outside. Inside there is a ladder leading up to a loft. There is hay everywhere.
# All Locations: Barn, Chicken coop
# Tuples: Outside;Chicken coop
# ###
#
# Category: Farm
# Location: The living quarters
# Description: Small barn like building, with old wooden doors and not many windows. It has different rooms as well as a decent sized kitchen.
# All Locations: Barn, Chicken coop
# Tuples: South;Chicken coop
# ###
#
# Category: Farm
# Location: Barn
# Description: The old rustic barn was settled on the outermost edge of the farm.  Standing tall over the fields, this two-story red barn cast a long shadow over the field surrounding it.  Large wooden doors that could be propped open with great effort would lead you directly inside.
# All Locations: Farmer's house, Corn field, Chicken coop, Barn
# Tuples: North;Farmer's house|Outside;Corn field
# ###
#
# Category: Farm
# Location: Castle farm
# Description: The farm is a large patch of land located directly outside of the castle walls. A wide variety of grains, vegetables and fruits are grown here to feed the castle's people. A few lone barns are scattered across the farmland, housing a wide array of farm animals that are slaughtered for their delicious meats.
# All Locations: Watchtower
# Tuples: East;Watchtower
# ###
#
# Category: Farm
# Location: Horse tent
# Description: Held erect by large bronze poles planted firmly in the ground, the purple and gold Horse tent offers a canvas over a number of stalls, each with it's own accommodations including fresh hay and a trough that is refilled daily. The tent's entrance is kept open during the day to allow sunlight to shine into the tent illuminating those inside, while the other end of the tent has a door leading directly into the guest castle.
# All Locations: Horse Tent, Adjacent to the Guest Castle
# Tuples: North;Adjacent to the Guest Castle
# ###
#
# Category: Farm
# Location: Main house
# Description: A fairly plain wooden building, the fireplace in the center of the back wall provides warmth during the winter seasons. There are paintings on the wall showing the farmer's forefathers and the previous owners. The floor is adorned with animal pelt rugs, and wood crafted furniture for the farmers to sit in.
# All Locations: Dungeon, King's Quarters, washroom, Stable, Main entrance, Throne Room, Peasant living quarters
# Tuples: South;Stable
# ###
#
# Category: Farm
# Location: An open field
# Description: An old run down farm, long abandoned by the inhabitants due to a ghost in the well directly in front of the farmhouse. It has seen better days, the wood is old and warped, scorched from fire set by brigands. Old tools litter the yard and bits of armor. It is obvious many have used this as a temporary camp since it's days as a working farm.
# All Locations: An Open Field, In Front of a Stone Tower
# Tuples: North;In Front of a Stone Tower
# ###
#
# Category: City in the clouds
# Location: Harp store
# Description: it's a cloudy store selling harps for angel men
# All Locations: cloud tavern
# Tuples: outside;cloud tavern
# ###
#
# Category: Magical realm
# Location: The cabin of an ogre
# Description: The wooden walls of the cabin are crudely adorned with a green, suspicious ooze. A dusty rug lays on the cold wooden floor of the cabin, dimly lit with a lantern situated in a corner in front of a large cobweb.
# All Locations: Throne room, Royal Kitchen, Garden
# Tuples: outside;Garden
# ###
#
# Category: Magical realm
# Location: Elf's room
# Description: A tiny room in a red mushroom. Tiny frames with photos of an elf family decorate the walls of a well-lit room. A miniscule lantern lit with a single morsel shines on a table made of oak bark.
# All Locations: kitchen
# Tuples: west;kitchen
# ###
#
# Category: Magical realm
# Location: Secret magician's workshop
# Description: This is the hidden workshop of the most powerful wizard in the land.  There are ornate tapestries on the walls depicting wizards using their powers and potions in battle.
# All Locations: Storage room
# Tuples: north;Storage room
# ###
#
# Category: Magical realm
# Location: Wizard's lair
# Description: The wizard's lair is a mystical room. The walls are painted to resemble the night sky and pots of overgrown plants line the walls. Cages that once held creatures sit on top of an oak table in the center of the lair.
# All Locations: kitchen
# Tuples: north;kitchen
# ###
#
# Category: Netherworld
# Location: Dungeon
# Description: Dark and dreary, the dungeon hosts a portal for evil to access the netherworld. The moist dank smell casts doubt of goodness as you see the drab construct of jail cells lining the perimeter of the room.
# All Locations: washroom, Throne Room, King's Quarters
# Tuples: inside;Throne Room
# ###
#
# Category: Netherworld
# Location: Torture chanber
# Description: This room is very grim and evil. There are many torturing devices strewn about. There is also blood all over the walls. The smell is putrid and relentless.
# All Locations: Dungeon, King's Quarters, washroom, Library, Main entrance, Throne Room, Graveyard
# Tuples: outside;Graveyard
# ###
#
# Category: Netherworld
# Location: The devils castle
# Description: It is a castle that has burning flames that burn for eternity all around it. It is the tallest structure in all of the netherworld. It is dark and pitch black in some areas. It can be seen from miles away.
# All Locations: Dungeon, King's Quarters, washroom, Library, Main entrance, Throne Room, Graveyard
# Tuples: down;Graveyard
# ###
#
# Category: Supernatural
# Location: Magic room
# Description: A room that once entered, cannot be escaped. The walls are all mirrors, and you can never again find the door.
# All Locations: Throne room, Tub, Bathroom
# Tuples: down;Throne room|outside;Bathroom
# ###
#
# Category: Supernatural
# Location: Bridge in the forest
# Description: You are at a bridge. It is old and used very rarely. It is dim and foggy. The brigde is large and there is a small stream below it.
# All Locations: Valley of doom, Cave
# Tuples: east;Cave
# ###
#
# Category: Underwater aquapolis
# Location: Tool shed
# Description: a shed with tools hanging from hooks. there are various hoes and shovels. it's for seaweed harvest
# All Locations: farmhouse
# Tuples: east;farmhouse
# ###
#
# Category: Underwater aquapolis
# Location: Neptune's throne room
# Description: A small room in the castle, Neptune's throne room is adorned with painted walls as blue as the sea itself. Tables constructed of beautiful coral lean against all four walls with decorative shells serving as a border for them. The ceiling is painted to resemble waves.
# All Locations: Dungeon, King's Quarters, washroom, Main entrance, Throne Room, Courtyard
# Tuples: outside;Courtyard
# ###
#
# len(fine_tuning_data) 314

# %%
# !head fine_tuning_connections.jsonl
# Out:
# {"prompt": "Category: Forest\nLocation: Along the banks of a river in the forest\nDescription: The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself.\nAll Locations: South Forest, Along the banks of a river in the forest, North Forest\n", "completion": "Tuples: North;North Forest|South;South Forest\n###\n"}
# {"prompt": "Category: Forest\nLocation: The stream\nDescription: The stream is always going. The water moves quickly in some places and slowly in other places. There is a dry spot on each side of the water. In some areas you will see animals drinking the water. There are also fish swimming around in the deeper parts of the stream.\nAll Locations: The swimming hole, The stream\n", "completion": "Tuples: South;The swimming hole\n###\n"}
# {"prompt": "Category: Forest\nLocation: Woods\nDescription: The woods are vast. Everywhere you turn it all looks the same. There are scratches on the trees from lost travelers marking their path. There are sounds coming from everywhere and yet no where. There are faint yellow circles up in the trees and bushes, possibly eyes starting at you.\nAll Locations: Dark Cave, Woods\n", "completion": "Tuples: Inside;Dark Cave\n###\n"}
# {"prompt": "Category: Forest\nLocation: Ant hill\nDescription: The ant hill is very large, over 5 feet high, and is wrapped around the base of a pine tree. The ants are huge compared to normal ants, and jut in and out of large holes in the ant hill. Bones of animals and even people can be seen sticking out of the red dirt ant hill.\nAll Locations: Riverbed, Ant hill\n", "completion": "Tuples: South;Riverbed|South;Riverbed\n###\n"}
# {"prompt": "Category: Forest\nLocation: Entrance to the pine trees\nDescription: Very tall and towering pine trees that create a dark canopy of shade. Long skinny trees sway in the sky from the soft breeze. Pine needles scatter the ground like plush carpet.\nAll Locations: Entrance to the Pine trees, picnic area\n", "completion": "Tuples: North;picnic area\n###\n"}
# {"prompt": "Category: Forest\nLocation: Unsettling forest area\nDescription: The forest is actually very creepy even during the day. The trees are so tall that they block the sunlight. There is always fog in the forest which makes it very hard to see. There are a lot of mushrooms near the trees and none of them are edible\nAll Locations: mysterious forest outskirts\n", "completion": "Tuples: Outside;mysterious forest outskirts\n###\n"}
# {"prompt": "Category: Forest\nLocation: Forest entrance\nDescription: The path quickly narrows and darkens upon entering the forest.  Dense branches overhead block all but a few stray rays of sunshine.  Fallen leaves just beginning to rot blanket the forest floor, and every footstep kicks up a rich, loamy scent as fresh ground is unearthed.\nAll Locations: Forest entrance, Northern Shore\n", "completion": "Tuples: East;Northern Shore\n###\n"}
# {"prompt": "Category: Forest\nLocation: Riverbed\nDescription: With clear air and the sound of gurgling water near it, the river bed is silty and muddy. The river rushes by the land as more and more dirt separates from the land. The land of the riverbed slick with mud and filled with bugs and worms/\nAll Locations: Riverbed, Ant hill\n", "completion": "Tuples: North;Ant hill\n###\n"}
# {"prompt": "Category: Forest\nLocation: Pond\nDescription: A small area with a body of water in the center along with turtles, frogs, and other wildlife that live here.  Surrounding this pone are a dense set of trees along with some rocks here and there.\nAll Locations: Valley of doom, Cave\n", "completion": "Tuples: East;Cave\n###\n"}
# {"prompt": "Category: Forest\nLocation: Flower garden\nDescription: This clearing is in reveal a wide circle of trees. Proud oaks stand close enough that only the smallest of fauna can squeeze through, protecting the garden within from curious deer and hungry rabbits. Flowers of every hue and shade crowd the soft lawn of grass, soaking up what light they can through the shadows cast by the branches above. Purple, yellow, red, blue - even green blossoms bob in the breeze, their scents mixing to create a heady perfume. Vines and creepers climb up the tree trunks, dripping with grapes and berries.\nAll Locations: The Brush Den, Lake, flower garden\n", "completion": "Tuples: North;The Brush Den\n###\n"}

# %%
# Out:
# Upload progress: 100% 144k/144k [00:00<00:00, 136Mit/s]
# Uploaded file from fine_tuning_connections.jsonl: file-Y7vhdoGc5FYwn0EuwHHEG72K
# Created fine-tune: ft-dDpsrwnij5Ny19bcrKMZZNHg
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2022-01-31 05:48:36] Created fine-tune: ft-dDpsrwnij5Ny19bcrKMZZNHg
# [2022-01-31 05:48:42] Fine-tune costs $0.07
# [2022-01-31 05:48:43] Fine-tune enqueued. Queue number: 0
# [2022-01-31 05:48:47] Fine-tune started
#
# Stream interrupted. Job is still running.
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-dDpsrwnij5Ny19bcrKMZZNHg
#
# To cancel your job, run:
#
#   openai api fine_tunes.cancel -i ft-dDpsrwnij5Ny19bcrKMZZNHg

# %%
# model name: babbage:ft-cis-700-48-2022-01-31-05-56-21
# model fine-tune: ft-dDpsrwnij5Ny19bcrKMZZNHg
# !openai api fine_tunes.create -t fine_tuning_connections.jsonl -m babbage
# Out:
# [2022-01-31 05:48:36] Created fine-tune: ft-dDpsrwnij5Ny19bcrKMZZNHg
# [2022-01-31 05:48:42] Fine-tune costs $0.07
# [2022-01-31 05:48:43] Fine-tune enqueued. Queue number: 0
# [2022-01-31 05:48:47] Fine-tune started
# [2022-01-31 05:50:47] Completed epoch 1/4
# [2022-01-31 05:52:23] Completed epoch 2/4
# [2022-01-31 05:54:00] Completed epoch 3/4
# [2022-01-31 05:55:36] Completed epoch 4/4
# [2022-01-31 05:56:22] Uploaded model: babbage:ft-cis-700-48-2022-01-31-05-56-21
# [2022-01-31 05:56:25] Uploaded result file: file-jdKUnXOgwGDSBZstOb7cUGbV
# [2022-01-31 05:56:26] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m babbage:ft-cis-700-48-2022-01-31-05-56-21 -p <YOUR_PROMPT>

# %%
def get_connections(category, location_name, location_description, finetuned_model, all_locations): # current_connections=[]):
#   current_connections = [item.capitalize() for item in current_connections]
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Category: {category}\nLocation: {location_name}\nDescription: {location_description}\nAll Locations: {all_locations}\nTuples:".format(
          category=category.capitalize(),
          location_name=location_name.capitalize(),
          location_description=location_description,
          all_locations=', '.join(all_locations) if all_locations else ''
      ),
      temperature=0.7,
      max_tokens=64,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0,
      stop=["###"]
      )
  return response['choices'][0]['text']

finetuned_model = "babbage:ft-cis-700-48-2022-01-31-05-56-21"
category = "Forest"
location_name = "Along the banks of a river in the forest"
location_description = "The river that runs through this part of the forest is clear and cold and crystal blue.  Small fish dart about, and a few lazy insects flit back and forth above the riverbank.  Lush grass slopes up from the river itself."
all_locations = ['South Forest', 'Along the banks of a river in the forest', 'North Forest']

connections = get_connections(category, location_name, location_description, finetuned_model, all_locations)
print(connections)
# Out:
#  North;North Forest|South;South Forest

# %% [markdown]
# ## 5. Get an item's properties

# %%
# 5. Get an item's properties
# - inputs: item name, item description, property (e.g. gettable)
# - output: True or False if the item has that property

def get_item_finetuning(item_id, property_name, room_id, rooms_by_id, light_environment):
  """
  This generates a prompt and a completion which can be used to fine-tune OpenAI.
  This version just gnnerates 
  """
  obj = light_environment['objects'][str(item_id)]
  prompt = ""
  completion = "" 
  prompt += "Item: {item_name}\n".format(item_name=obj['name'].capitalize())
  prompt += "Description: {item_description}\n".format(item_description=' '.join(obj['descriptions']).capitalize())
  prompt += "Property: {property_name}\n".format(property_name=property_name)
  completion += "Boolean: {boolean}\n".format(boolean= (obj[str(property_name)] >= 0.5)) # set >=0.5 as True and < 0.5 is False
  completion += "###\n"

  return prompt, completion


def create_item_finetuning_data(filename='fine_tuning_item_property.jsonl'):
  fine_tuning_data = []
  property_names  = ["is_gettable", "is_weapon", "is_surface", "is_container", "is_wearable", "is_drink", "is_food"]
  for category in categories:
    rooms = rooms_by_category[category]
    for room_id in rooms:
      objects = rooms_by_id[room_id]['in_objects']
      for item_id in objects:
        for property_name in property_names:
          data = {}
          prompt, completion = get_item_finetuning(item_id, property_name, room_id, rooms_by_id, light_environment)
          print(prompt + completion)
          data['prompt'] = prompt
          data['completion'] = completion
          fine_tuning_data.append(data)

  with open(filename, 'w') as out:
    for data in fine_tuning_data:
        out.write(json.dumps(data))
        out.write('\n')

create_item_finetuning_data()
# Out:
# Streaming output truncated to the last 5000 lines.
# ###
#
# Item: Throne
# Description: The throne is opulent, and richly upholstered.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Throne
# Description: The throne is opulent, and richly upholstered.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Throne
# Description: The throne is opulent, and richly upholstered.
# Property: is_surface
# Boolean: True
# ###
#
# Item: Throne
# Description: The throne is opulent, and richly upholstered.
# Property: is_container
# Boolean: False
# ###
#
# Item: Throne
# Description: The throne is opulent, and richly upholstered.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Throne
# Description: The throne is opulent, and richly upholstered.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Throne
# Description: The throne is opulent, and richly upholstered.
# Property: is_food
# Boolean: False
# ###
#
# Item: Pedestal
# Description: The wooden pedestal, although large, is very poorly made with what seems to be unfinished elm wood.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Pedestal
# Description: The wooden pedestal, although large, is very poorly made with what seems to be unfinished elm wood.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Pedestal
# Description: The wooden pedestal, although large, is very poorly made with what seems to be unfinished elm wood.
# Property: is_surface
# Boolean: True
# ###
#
# Item: Pedestal
# Description: The wooden pedestal, although large, is very poorly made with what seems to be unfinished elm wood.
# Property: is_container
# Boolean: True
# ###
#
# Item: Pedestal
# Description: The wooden pedestal, although large, is very poorly made with what seems to be unfinished elm wood.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Pedestal
# Description: The wooden pedestal, although large, is very poorly made with what seems to be unfinished elm wood.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Pedestal
# Description: The wooden pedestal, although large, is very poorly made with what seems to be unfinished elm wood.
# Property: is_food
# Boolean: False
# ###
#
# Item: Paintings
# Description: Bring on the prehistoric cave painting
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Paintings
# Description: Bring on the prehistoric cave painting
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Paintings
# Description: Bring on the prehistoric cave painting
# Property: is_surface
# Boolean: False
# ###
#
# Item: Paintings
# Description: Bring on the prehistoric cave painting
# Property: is_container
# Boolean: True
# ###
#
# Item: Paintings
# Description: Bring on the prehistoric cave painting
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Paintings
# Description: Bring on the prehistoric cave painting
# Property: is_drink
# Boolean: False
# ###
#
# Item: Paintings
# Description: Bring on the prehistoric cave painting
# Property: is_food
# Boolean: False
# ###
#
# Item: Molten magma
# Description: The magma flows in the strangest way, but the heat it puts off reminds you that it is still quite dangerous.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Molten magma
# Description: The magma flows in the strangest way, but the heat it puts off reminds you that it is still quite dangerous.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Molten magma
# Description: The magma flows in the strangest way, but the heat it puts off reminds you that it is still quite dangerous.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Molten magma
# Description: The magma flows in the strangest way, but the heat it puts off reminds you that it is still quite dangerous.
# Property: is_container
# Boolean: False
# ###
#
# Item: Molten magma
# Description: The magma flows in the strangest way, but the heat it puts off reminds you that it is still quite dangerous.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Molten magma
# Description: The magma flows in the strangest way, but the heat it puts off reminds you that it is still quite dangerous.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Molten magma
# Description: The magma flows in the strangest way, but the heat it puts off reminds you that it is still quite dangerous.
# Property: is_food
# Boolean: False
# ###
#
# Item: Black rock
# Description: Upon further examinations this is no ordinary rock, but a black rock with a foreign inscription that appears to glow in the firelight.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Black rock
# Description: Upon further examinations this is no ordinary rock, but a black rock with a foreign inscription that appears to glow in the firelight.
# Property: is_weapon
# Boolean: True
# ###
#
# Item: Black rock
# Description: Upon further examinations this is no ordinary rock, but a black rock with a foreign inscription that appears to glow in the firelight.
# Property: is_surface
# Boolean: True
# ###
#
# Item: Black rock
# Description: Upon further examinations this is no ordinary rock, but a black rock with a foreign inscription that appears to glow in the firelight.
# Property: is_container
# Boolean: False
# ###
#
# Item: Black rock
# Description: Upon further examinations this is no ordinary rock, but a black rock with a foreign inscription that appears to glow in the firelight.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Black rock
# Description: Upon further examinations this is no ordinary rock, but a black rock with a foreign inscription that appears to glow in the firelight.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Black rock
# Description: Upon further examinations this is no ordinary rock, but a black rock with a foreign inscription that appears to glow in the firelight.
# Property: is_food
# Boolean: False
# ###
#
# Item: Portal for evil to access
# Description: The portal somehow seems to emit a dark form of light; only horrible things could be inside.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Portal for evil to access
# Description: The portal somehow seems to emit a dark form of light; only horrible things could be inside.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Portal for evil to access
# Description: The portal somehow seems to emit a dark form of light; only horrible things could be inside.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Portal for evil to access
# Description: The portal somehow seems to emit a dark form of light; only horrible things could be inside.
# Property: is_container
# Boolean: True
# ###
#
# Item: Portal for evil to access
# Description: The portal somehow seems to emit a dark form of light; only horrible things could be inside.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Portal for evil to access
# Description: The portal somehow seems to emit a dark form of light; only horrible things could be inside.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Portal for evil to access
# Description: The portal somehow seems to emit a dark form of light; only horrible things could be inside.
# Property: is_food
# Boolean: False
# ###
#
# Item: Jail cells
# Description: The cells are bare with rusty bars on the doors, a bucket for excrement and a pile of hay in the corner for sleeping.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Jail cells
# Description: The cells are bare with rusty bars on the doors, a bucket for excrement and a pile of hay in the corner for sleeping.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Jail cells
# Description: The cells are bare with rusty bars on the doors, a bucket for excrement and a pile of hay in the corner for sleeping.
# Property: is_surface
# Boolean: True
# ###
#
# Item: Jail cells
# Description: The cells are bare with rusty bars on the doors, a bucket for excrement and a pile of hay in the corner for sleeping.
# Property: is_container
# Boolean: True
# ###
#
# Item: Jail cells
# Description: The cells are bare with rusty bars on the doors, a bucket for excrement and a pile of hay in the corner for sleeping.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Jail cells
# Description: The cells are bare with rusty bars on the doors, a bucket for excrement and a pile of hay in the corner for sleeping.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Jail cells
# Description: The cells are bare with rusty bars on the doors, a bucket for excrement and a pile of hay in the corner for sleeping.
# Property: is_food
# Boolean: False
# ###
#
# Item: Secrets of evil
# Description: This secret was huge, it would cause evil throughout the entire kingdom if it was allowed.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Secrets of evil
# Description: This secret was huge, it would cause evil throughout the entire kingdom if it was allowed.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Secrets of evil
# Description: This secret was huge, it would cause evil throughout the entire kingdom if it was allowed.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Secrets of evil
# Description: This secret was huge, it would cause evil throughout the entire kingdom if it was allowed.
# Property: is_container
# Boolean: False
# ###
#
# Item: Secrets of evil
# Description: This secret was huge, it would cause evil throughout the entire kingdom if it was allowed.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Secrets of evil
# Description: This secret was huge, it would cause evil throughout the entire kingdom if it was allowed.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Secrets of evil
# Description: This secret was huge, it would cause evil throughout the entire kingdom if it was allowed.
# Property: is_food
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_container
# Boolean: True
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_food
# Boolean: False
# ###
#
# Item: Seats
# Description: The seat is embedded with expensive diamonds and made of the finest wood
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Seats
# Description: The seat is embedded with expensive diamonds and made of the finest wood
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Seats
# Description: The seat is embedded with expensive diamonds and made of the finest wood
# Property: is_surface
# Boolean: True
# ###
#
# Item: Seats
# Description: The seat is embedded with expensive diamonds and made of the finest wood
# Property: is_container
# Boolean: False
# ###
#
# Item: Seats
# Description: The seat is embedded with expensive diamonds and made of the finest wood
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Seats
# Description: The seat is embedded with expensive diamonds and made of the finest wood
# Property: is_drink
# Boolean: False
# ###
#
# Item: Seats
# Description: The seat is embedded with expensive diamonds and made of the finest wood
# Property: is_food
# Boolean: False
# ###
#
# Item: Boxes
# Description: The box is large and wide, and covered with mysterious markings that signify it as a true work of art.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Boxes
# Description: The box is large and wide, and covered with mysterious markings that signify it as a true work of art.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Boxes
# Description: The box is large and wide, and covered with mysterious markings that signify it as a true work of art.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Boxes
# Description: The box is large and wide, and covered with mysterious markings that signify it as a true work of art.
# Property: is_container
# Boolean: True
# ###
#
# Item: Boxes
# Description: The box is large and wide, and covered with mysterious markings that signify it as a true work of art.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Boxes
# Description: The box is large and wide, and covered with mysterious markings that signify it as a true work of art.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Boxes
# Description: The box is large and wide, and covered with mysterious markings that signify it as a true work of art.
# Property: is_food
# Boolean: False
# ###
#
# Item: Stage
# Description: The stage is dark and battered from years of foot traffic.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Stage
# Description: The stage is dark and battered from years of foot traffic.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Stage
# Description: The stage is dark and battered from years of foot traffic.
# Property: is_surface
# Boolean: True
# ###
#
# Item: Stage
# Description: The stage is dark and battered from years of foot traffic.
# Property: is_container
# Boolean: True
# ###
#
# Item: Stage
# Description: The stage is dark and battered from years of foot traffic.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Stage
# Description: The stage is dark and battered from years of foot traffic.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Stage
# Description: The stage is dark and battered from years of foot traffic.
# Property: is_food
# Boolean: False
# ###
#
# Item: Dome
# Description: The dome appears to be made of stone and large enough to hide a family underneath
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Dome
# Description: The dome appears to be made of stone and large enough to hide a family underneath
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Dome
# Description: The dome appears to be made of stone and large enough to hide a family underneath
# Property: is_surface
# Boolean: False
# ###
#
# Item: Dome
# Description: The dome appears to be made of stone and large enough to hide a family underneath
# Property: is_container
# Boolean: False
# ###
#
# Item: Dome
# Description: The dome appears to be made of stone and large enough to hide a family underneath
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Dome
# Description: The dome appears to be made of stone and large enough to hide a family underneath
# Property: is_drink
# Boolean: False
# ###
#
# Item: Dome
# Description: The dome appears to be made of stone and large enough to hide a family underneath
# Property: is_food
# Boolean: False
# ###
#
# Item: Ball
# Description: The ball is a little too large to fit comfortably in one hand. its black leather surface and stitching shows heavy wear.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Ball
# Description: The ball is a little too large to fit comfortably in one hand. its black leather surface and stitching shows heavy wear.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Ball
# Description: The ball is a little too large to fit comfortably in one hand. its black leather surface and stitching shows heavy wear.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Ball
# Description: The ball is a little too large to fit comfortably in one hand. its black leather surface and stitching shows heavy wear.
# Property: is_container
# Boolean: False
# ###
#
# Item: Ball
# Description: The ball is a little too large to fit comfortably in one hand. its black leather surface and stitching shows heavy wear.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Ball
# Description: The ball is a little too large to fit comfortably in one hand. its black leather surface and stitching shows heavy wear.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Ball
# Description: The ball is a little too large to fit comfortably in one hand. its black leather surface and stitching shows heavy wear.
# Property: is_food
# Boolean: False
# ###
#
# Item: Trees
# Description: The trees are old oaks with sprawling branches evenly spaced for climbing or hiding out in.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Trees
# Description: The trees are old oaks with sprawling branches evenly spaced for climbing or hiding out in.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Trees
# Description: The trees are old oaks with sprawling branches evenly spaced for climbing or hiding out in.
# Property: is_surface
# Boolean: True
# ###
#
# Item: Trees
# Description: The trees are old oaks with sprawling branches evenly spaced for climbing or hiding out in.
# Property: is_container
# Boolean: True
# ###
#
# Item: Trees
# Description: The trees are old oaks with sprawling branches evenly spaced for climbing or hiding out in.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Trees
# Description: The trees are old oaks with sprawling branches evenly spaced for climbing or hiding out in.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Trees
# Description: The trees are old oaks with sprawling branches evenly spaced for climbing or hiding out in.
# Property: is_food
# Boolean: False
# ###
#
# Item: Plants
# Description: I would imagine these plants would be something to be made into something else. it might be for food, or medicine.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Plants
# Description: I would imagine these plants would be something to be made into something else. it might be for food, or medicine.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Plants
# Description: I would imagine these plants would be something to be made into something else. it might be for food, or medicine.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Plants
# Description: I would imagine these plants would be something to be made into something else. it might be for food, or medicine.
# Property: is_container
# Boolean: False
# ###
#
# Item: Plants
# Description: I would imagine these plants would be something to be made into something else. it might be for food, or medicine.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Plants
# Description: I would imagine these plants would be something to be made into something else. it might be for food, or medicine.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Plants
# Description: I would imagine these plants would be something to be made into something else. it might be for food, or medicine.
# Property: is_food
# Boolean: True
# ###
#
# Item: Garden
# Description: The garden is lush and filled with foliage.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Garden
# Description: The garden is lush and filled with foliage.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Garden
# Description: The garden is lush and filled with foliage.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Garden
# Description: The garden is lush and filled with foliage.
# Property: is_container
# Boolean: True
# ###
#
# Item: Garden
# Description: The garden is lush and filled with foliage.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Garden
# Description: The garden is lush and filled with foliage.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Garden
# Description: The garden is lush and filled with foliage.
# Property: is_food
# Boolean: False
# ###
#
# Item: Branches
# Description: The branch is really sharp and could probably be used as a spear
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Branches
# Description: The branch is really sharp and could probably be used as a spear
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Branches
# Description: The branch is really sharp and could probably be used as a spear
# Property: is_surface
# Boolean: False
# ###
#
# Item: Branches
# Description: The branch is really sharp and could probably be used as a spear
# Property: is_container
# Boolean: False
# ###
#
# Item: Branches
# Description: The branch is really sharp and could probably be used as a spear
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Branches
# Description: The branch is really sharp and could probably be used as a spear
# Property: is_drink
# Boolean: False
# ###
#
# Item: Branches
# Description: The branch is really sharp and could probably be used as a spear
# Property: is_food
# Boolean: False
# ###
#
# Item: Fountain
# Description: The fountain is made of quartz, and water that flows from it glimmers in the sunlight.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Fountain
# Description: The fountain is made of quartz, and water that flows from it glimmers in the sunlight.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Fountain
# Description: The fountain is made of quartz, and water that flows from it glimmers in the sunlight.
# Property: is_surface
# Boolean: True
# ###
#
# Item: Fountain
# Description: The fountain is made of quartz, and water that flows from it glimmers in the sunlight.
# Property: is_container
# Boolean: True
# ###
#
# Item: Fountain
# Description: The fountain is made of quartz, and water that flows from it glimmers in the sunlight.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Fountain
# Description: The fountain is made of quartz, and water that flows from it glimmers in the sunlight.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Fountain
# Description: The fountain is made of quartz, and water that flows from it glimmers in the sunlight.
# Property: is_food
# Boolean: False
# ###
#
# Item: Marble
# Description: The marble was small and oddly heavy for its size.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Marble
# Description: The marble was small and oddly heavy for its size.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Marble
# Description: The marble was small and oddly heavy for its size.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Marble
# Description: The marble was small and oddly heavy for its size.
# Property: is_container
# Boolean: False
# ###
#
# Item: Marble
# Description: The marble was small and oddly heavy for its size.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Marble
# Description: The marble was small and oddly heavy for its size.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Marble
# Description: The marble was small and oddly heavy for its size.
# Property: is_food
# Boolean: False
# ###
#
# Item: Bench
# Description: The bench was simple but classy, strait sturdy peices of wood that looked like they would never budge, it included a small carving by the maker on the leg.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Bench
# Description: The bench was simple but classy, strait sturdy peices of wood that looked like they would never budge, it included a small carving by the maker on the leg.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Bench
# Description: The bench was simple but classy, strait sturdy peices of wood that looked like they would never budge, it included a small carving by the maker on the leg.
# Property: is_surface
# Boolean: True
# ###
#
# Item: Bench
# Description: The bench was simple but classy, strait sturdy peices of wood that looked like they would never budge, it included a small carving by the maker on the leg.
# Property: is_container
# Boolean: False
# ###
#
# Item: Bench
# Description: The bench was simple but classy, strait sturdy peices of wood that looked like they would never budge, it included a small carving by the maker on the leg.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Bench
# Description: The bench was simple but classy, strait sturdy peices of wood that looked like they would never budge, it included a small carving by the maker on the leg.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Bench
# Description: The bench was simple but classy, strait sturdy peices of wood that looked like they would never budge, it included a small carving by the maker on the leg.
# Property: is_food
# Boolean: False
# ###
#
# Item: Stone
# Description: The stone is appears to be really old and covered in moss
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Stone
# Description: The stone is appears to be really old and covered in moss
# Property: is_weapon
# Boolean: True
# ###
#
# Item: Stone
# Description: The stone is appears to be really old and covered in moss
# Property: is_surface
# Boolean: False
# ###
#
# Item: Stone
# Description: The stone is appears to be really old and covered in moss
# Property: is_container
# Boolean: False
# ###
#
# Item: Stone
# Description: The stone is appears to be really old and covered in moss
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Stone
# Description: The stone is appears to be really old and covered in moss
# Property: is_drink
# Boolean: False
# ###
#
# Item: Stone
# Description: The stone is appears to be really old and covered in moss
# Property: is_food
# Boolean: False
# ###
#
# Item: Straps
# Description: The straps have an extra hole added for tighter strappening.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Straps
# Description: The straps have an extra hole added for tighter strappening.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Straps
# Description: The straps have an extra hole added for tighter strappening.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Straps
# Description: The straps have an extra hole added for tighter strappening.
# Property: is_container
# Boolean: False
# ###
#
# Item: Straps
# Description: The straps have an extra hole added for tighter strappening.
# Property: is_wearable
# Boolean: True
# ###
#
# Item: Straps
# Description: The straps have an extra hole added for tighter strappening.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Straps
# Description: The straps have an extra hole added for tighter strappening.
# Property: is_food
# Boolean: False
# ###
#
# Item: Wooden door
# Description: This door is wooden, and maybe heavy.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Wooden door
# Description: This door is wooden, and maybe heavy.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Wooden door
# Description: This door is wooden, and maybe heavy.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Wooden door
# Description: This door is wooden, and maybe heavy.
# Property: is_container
# Boolean: False
# ###
#
# Item: Wooden door
# Description: This door is wooden, and maybe heavy.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Wooden door
# Description: This door is wooden, and maybe heavy.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Wooden door
# Description: This door is wooden, and maybe heavy.
# Property: is_food
# Boolean: False
# ###
#
# Item: Heavy lock
# Description: The lock is weighty and dull gray.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Heavy lock
# Description: The lock is weighty and dull gray.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Heavy lock
# Description: The lock is weighty and dull gray.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Heavy lock
# Description: The lock is weighty and dull gray.
# Property: is_container
# Boolean: False
# ###
#
# Item: Heavy lock
# Description: The lock is weighty and dull gray.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Heavy lock
# Description: The lock is weighty and dull gray.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Heavy lock
# Description: The lock is weighty and dull gray.
# Property: is_food
# Boolean: False
# ###
#
# Item: Hole
# Description: The hole appears to be very deep and may lead to some treasure
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Hole
# Description: The hole appears to be very deep and may lead to some treasure
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Hole
# Description: The hole appears to be very deep and may lead to some treasure
# Property: is_surface
# Boolean: True
# ###
#
# Item: Hole
# Description: The hole appears to be very deep and may lead to some treasure
# Property: is_container
# Boolean: False
# ###
#
# Item: Hole
# Description: The hole appears to be very deep and may lead to some treasure
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Hole
# Description: The hole appears to be very deep and may lead to some treasure
# Property: is_drink
# Boolean: False
# ###
#
# Item: Hole
# Description: The hole appears to be very deep and may lead to some treasure
# Property: is_food
# Boolean: False
# ###
#
# Item: Underground tunnels
# Description: The underground tunnel is dark and dank and smells of wet soil. the cobwebs certainly contribute to the eerie feeling it evokes.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Underground tunnels
# Description: The underground tunnel is dark and dank and smells of wet soil. the cobwebs certainly contribute to the eerie feeling it evokes.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Underground tunnels
# Description: The underground tunnel is dark and dank and smells of wet soil. the cobwebs certainly contribute to the eerie feeling it evokes.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Underground tunnels
# Description: The underground tunnel is dark and dank and smells of wet soil. the cobwebs certainly contribute to the eerie feeling it evokes.
# Property: is_container
# Boolean: False
# ###
#
# Item: Underground tunnels
# Description: The underground tunnel is dark and dank and smells of wet soil. the cobwebs certainly contribute to the eerie feeling it evokes.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Underground tunnels
# Description: The underground tunnel is dark and dank and smells of wet soil. the cobwebs certainly contribute to the eerie feeling it evokes.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Underground tunnels
# Description: The underground tunnel is dark and dank and smells of wet soil. the cobwebs certainly contribute to the eerie feeling it evokes.
# Property: is_food
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_surface
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_container
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_drink
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_food
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_container
# Boolean: True
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Room
# Description: It may not be much, but it's shelter! you can't ask for much more than four walls and a roof over your head.
# Property: is_food
# Boolean: False
# ###
#
# Item: Devices
# Description: The device is worn after years of use in the fields.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Devices
# Description: The device is worn after years of use in the fields.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Devices
# Description: The device is worn after years of use in the fields.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Devices
# Description: The device is worn after years of use in the fields.
# Property: is_container
# Boolean: True
# ###
#
# Item: Devices
# Description: The device is worn after years of use in the fields.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Devices
# Description: The device is worn after years of use in the fields.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Devices
# Description: The device is worn after years of use in the fields.
# Property: is_food
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_container
# Boolean: True
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_food
# Boolean: False
# ###
#
# Item: Skulls on stakes
# Description: The skull looks like it could fall apart if you were to pick it up due to its age.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Skulls on stakes
# Description: The skull looks like it could fall apart if you were to pick it up due to its age.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Skulls on stakes
# Description: The skull looks like it could fall apart if you were to pick it up due to its age.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Skulls on stakes
# Description: The skull looks like it could fall apart if you were to pick it up due to its age.
# Property: is_container
# Boolean: True
# ###
#
# Item: Skulls on stakes
# Description: The skull looks like it could fall apart if you were to pick it up due to its age.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Skulls on stakes
# Description: The skull looks like it could fall apart if you were to pick it up due to its age.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Skulls on stakes
# Description: The skull looks like it could fall apart if you were to pick it up due to its age.
# Property: is_food
# Boolean: False
# ###
#
# Item: Piles of bones
# Description: The archaeological department find a piles of bones in historical site
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Piles of bones
# Description: The archaeological department find a piles of bones in historical site
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Piles of bones
# Description: The archaeological department find a piles of bones in historical site
# Property: is_surface
# Boolean: False
# ###
#
# Item: Piles of bones
# Description: The archaeological department find a piles of bones in historical site
# Property: is_container
# Boolean: True
# ###
#
# Item: Piles of bones
# Description: The archaeological department find a piles of bones in historical site
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Piles of bones
# Description: The archaeological department find a piles of bones in historical site
# Property: is_drink
# Boolean: False
# ###
#
# Item: Piles of bones
# Description: The archaeological department find a piles of bones in historical site
# Property: is_food
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_surface
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_container
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_drink
# Boolean: False
# ###
#
# Item: Souls
# Description: The soul seems to be emitting a dark, evil aura
# Property: is_food
# Boolean: False
# ###
#
# Item: Torches
# Description: The torch seems to be made of the finest wood
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Torches
# Description: The torch seems to be made of the finest wood
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Torches
# Description: The torch seems to be made of the finest wood
# Property: is_surface
# Boolean: False
# ###
#
# Item: Torches
# Description: The torch seems to be made of the finest wood
# Property: is_container
# Boolean: False
# ###
#
# Item: Torches
# Description: The torch seems to be made of the finest wood
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Torches
# Description: The torch seems to be made of the finest wood
# Property: is_drink
# Boolean: False
# ###
#
# Item: Torches
# Description: The torch seems to be made of the finest wood
# Property: is_food
# Boolean: False
# ###
#
# Item: Manacles
# Description: On the alleged torture and abusive treatment is manacles
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Manacles
# Description: On the alleged torture and abusive treatment is manacles
# Property: is_weapon
# Boolean: True
# ###
#
# Item: Manacles
# Description: On the alleged torture and abusive treatment is manacles
# Property: is_surface
# Boolean: False
# ###
#
# Item: Manacles
# Description: On the alleged torture and abusive treatment is manacles
# Property: is_container
# Boolean: True
# ###
#
# Item: Manacles
# Description: On the alleged torture and abusive treatment is manacles
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Manacles
# Description: On the alleged torture and abusive treatment is manacles
# Property: is_drink
# Boolean: False
# ###
#
# Item: Manacles
# Description: On the alleged torture and abusive treatment is manacles
# Property: is_food
# Boolean: False
# ###
#
# Item: Cages
# Description: The cage is large and shiny with a silver appearance.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Cages
# Description: The cage is large and shiny with a silver appearance.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Cages
# Description: The cage is large and shiny with a silver appearance.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Cages
# Description: The cage is large and shiny with a silver appearance.
# Property: is_container
# Boolean: True
# ###
#
# Item: Cages
# Description: The cage is large and shiny with a silver appearance.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Cages
# Description: The cage is large and shiny with a silver appearance.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Cages
# Description: The cage is large and shiny with a silver appearance.
# Property: is_food
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_container
# Boolean: True
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Walls
# Description: The wall was painted blue. the wallpaper appears to have been painted over.
# Property: is_food
# Boolean: False
# ###
#
# Item: Table
# Description: The table was long wooden planks with scratches and nicks in the surface.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Table
# Description: The table was long wooden planks with scratches and nicks in the surface.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Table
# Description: The table was long wooden planks with scratches and nicks in the surface.
# Property: is_surface
# Boolean: True
# ###
#
# Item: Table
# Description: The table was long wooden planks with scratches and nicks in the surface.
# Property: is_container
# Boolean: False
# ###
#
# Item: Table
# Description: The table was long wooden planks with scratches and nicks in the surface.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Table
# Description: The table was long wooden planks with scratches and nicks in the surface.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Table
# Description: The table was long wooden planks with scratches and nicks in the surface.
# Property: is_food
# Boolean: False
# ###
#
# Item: Lever
# Description: A lever, made from iron. you know you want to pull it, but probably shouldn't.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Lever
# Description: A lever, made from iron. you know you want to pull it, but probably shouldn't.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Lever
# Description: A lever, made from iron. you know you want to pull it, but probably shouldn't.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Lever
# Description: A lever, made from iron. you know you want to pull it, but probably shouldn't.
# Property: is_container
# Boolean: False
# ###
#
# Item: Lever
# Description: A lever, made from iron. you know you want to pull it, but probably shouldn't.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Lever
# Description: A lever, made from iron. you know you want to pull it, but probably shouldn't.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Lever
# Description: A lever, made from iron. you know you want to pull it, but probably shouldn't.
# Property: is_food
# Boolean: False
# ###
#
# Item: Castle
# Description: A stalwart castle built to withstand the heaviest siege.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Castle
# Description: A stalwart castle built to withstand the heaviest siege.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Castle
# Description: A stalwart castle built to withstand the heaviest siege.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Castle
# Description: A stalwart castle built to withstand the heaviest siege.
# Property: is_container
# Boolean: True
# ###
#
# Item: Castle
# Description: A stalwart castle built to withstand the heaviest siege.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Castle
# Description: A stalwart castle built to withstand the heaviest siege.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Castle
# Description: A stalwart castle built to withstand the heaviest siege.
# Property: is_food
# Boolean: False
# ###
#
# Item: Flame
# Description: The flame glistens a vibrant red.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Flame
# Description: The flame glistens a vibrant red.
# Property: is_weapon
# Boolean: True
# ###
#
# Item: Flame
# Description: The flame glistens a vibrant red.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Flame
# Description: The flame glistens a vibrant red.
# Property: is_container
# Boolean: False
# ###
#
# Item: Flame
# Description: The flame glistens a vibrant red.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Flame
# Description: The flame glistens a vibrant red.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Flame
# Description: The flame glistens a vibrant red.
# Property: is_food
# Boolean: False
# ###
#
# Item: Structure
# Description: The large structure is grayed and worn from use by knights.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Structure
# Description: The large structure is grayed and worn from use by knights.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Structure
# Description: The large structure is grayed and worn from use by knights.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Structure
# Description: The large structure is grayed and worn from use by knights.
# Property: is_container
# Boolean: True
# ###
#
# Item: Structure
# Description: The large structure is grayed and worn from use by knights.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Structure
# Description: The large structure is grayed and worn from use by knights.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Structure
# Description: The large structure is grayed and worn from use by knights.
# Property: is_food
# Boolean: False
# ###
#
# Item: Ground
# Description: You notice the ground has absorbed a lot of fairy blood.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Ground
# Description: You notice the ground has absorbed a lot of fairy blood.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Ground
# Description: You notice the ground has absorbed a lot of fairy blood.
# Property: is_surface
# Boolean: True
# ###
#
# Item: Ground
# Description: You notice the ground has absorbed a lot of fairy blood.
# Property: is_container
# Boolean: False
# ###
#
# Item: Ground
# Description: You notice the ground has absorbed a lot of fairy blood.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Ground
# Description: You notice the ground has absorbed a lot of fairy blood.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Ground
# Description: You notice the ground has absorbed a lot of fairy blood.
# Property: is_food
# Boolean: False
# ###
#
# Item: Skeleton
# Description: The skeleton looked like it had been dead for 100's of years, the bones looked yellow and dirty and there were several of them broken especially in the ribs.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Skeleton
# Description: The skeleton looked like it had been dead for 100's of years, the bones looked yellow and dirty and there were several of them broken especially in the ribs.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Skeleton
# Description: The skeleton looked like it had been dead for 100's of years, the bones looked yellow and dirty and there were several of them broken especially in the ribs.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Skeleton
# Description: The skeleton looked like it had been dead for 100's of years, the bones looked yellow and dirty and there were several of them broken especially in the ribs.
# Property: is_container
# Boolean: False
# ###
#
# Item: Skeleton
# Description: The skeleton looked like it had been dead for 100's of years, the bones looked yellow and dirty and there were several of them broken especially in the ribs.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Skeleton
# Description: The skeleton looked like it had been dead for 100's of years, the bones looked yellow and dirty and there were several of them broken especially in the ribs.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Skeleton
# Description: The skeleton looked like it had been dead for 100's of years, the bones looked yellow and dirty and there were several of them broken especially in the ribs.
# Property: is_food
# Boolean: False
# ###
#
# Item: Zombies
# Description: Object is a death and life with rotting skin and deformed, twisted facial features.  object does not stand upright, but distorted. object moves with a haggard gait and groans rather than speaks.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Zombies
# Description: Object is a death and life with rotting skin and deformed, twisted facial features.  object does not stand upright, but distorted. object moves with a haggard gait and groans rather than speaks.
# Property: is_weapon
# Boolean: True
# ###
#
# Item: Zombies
# Description: Object is a death and life with rotting skin and deformed, twisted facial features.  object does not stand upright, but distorted. object moves with a haggard gait and groans rather than speaks.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Zombies
# Description: Object is a death and life with rotting skin and deformed, twisted facial features.  object does not stand upright, but distorted. object moves with a haggard gait and groans rather than speaks.
# Property: is_container
# Boolean: False
# ###
#
# Item: Zombies
# Description: Object is a death and life with rotting skin and deformed, twisted facial features.  object does not stand upright, but distorted. object moves with a haggard gait and groans rather than speaks.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Zombies
# Description: Object is a death and life with rotting skin and deformed, twisted facial features.  object does not stand upright, but distorted. object moves with a haggard gait and groans rather than speaks.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Zombies
# Description: Object is a death and life with rotting skin and deformed, twisted facial features.  object does not stand upright, but distorted. object moves with a haggard gait and groans rather than speaks.
# Property: is_food
# Boolean: False
# ###
#
# Item: Dead bodies
# ...
# Property: is_surface
# Boolean: False
# ###
#
# Item: Hoe
# Description: The hole has a splintered handle, and the head is caked with crumbling, drying mud.
# Property: is_container
# Boolean: False
# ###
#
# Item: Hoe
# Description: The hole has a splintered handle, and the head is caked with crumbling, drying mud.
# Property: is_wearable
# Boolean: True
# ###
#
# Item: Hoe
# Description: The hole has a splintered handle, and the head is caked with crumbling, drying mud.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Hoe
# Description: The hole has a splintered handle, and the head is caked with crumbling, drying mud.
# Property: is_food
# Boolean: False
# ###
#
# Item: Shovel
# Description: The shovel is dirt-encrusted and grimy.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Shovel
# Description: The shovel is dirt-encrusted and grimy.
# Property: is_weapon
# Boolean: True
# ###
#
# Item: Shovel
# Description: The shovel is dirt-encrusted and grimy.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Shovel
# Description: The shovel is dirt-encrusted and grimy.
# Property: is_container
# Boolean: False
# ###
#
# Item: Shovel
# Description: The shovel is dirt-encrusted and grimy.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Shovel
# Description: The shovel is dirt-encrusted and grimy.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Shovel
# Description: The shovel is dirt-encrusted and grimy.
# Property: is_food
# Boolean: False
# ###
#
# Item: Seaweed
# Description: The beach is destroyed from the storm, there is seaweed every where.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Seaweed
# Description: The beach is destroyed from the storm, there is seaweed every where.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Seaweed
# Description: The beach is destroyed from the storm, there is seaweed every where.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Seaweed
# Description: The beach is destroyed from the storm, there is seaweed every where.
# Property: is_container
# Boolean: False
# ###
#
# Item: Seaweed
# Description: The beach is destroyed from the storm, there is seaweed every where.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Seaweed
# Description: The beach is destroyed from the storm, there is seaweed every where.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Seaweed
# Description: The beach is destroyed from the storm, there is seaweed every where.
# Property: is_food
# Boolean: True
# ###
#
# Item: Shack
# Description: In the middle of this deserted forest a shack sits, with a mossy roof and stained glass windows.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Shack
# Description: In the middle of this deserted forest a shack sits, with a mossy roof and stained glass windows.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Shack
# Description: In the middle of this deserted forest a shack sits, with a mossy roof and stained glass windows.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Shack
# Description: In the middle of this deserted forest a shack sits, with a mossy roof and stained glass windows.
# Property: is_container
# Boolean: True
# ###
#
# Item: Shack
# Description: In the middle of this deserted forest a shack sits, with a mossy roof and stained glass windows.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Shack
# Description: In the middle of this deserted forest a shack sits, with a mossy roof and stained glass windows.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Shack
# Description: In the middle of this deserted forest a shack sits, with a mossy roof and stained glass windows.
# Property: is_food
# Boolean: False
# ###
#
# Item: Riches from the very infancy of the empire
# Description: The rich from the very infancy of the empire is golden and sparkles in the sun.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Riches from the very infancy of the empire
# Description: The rich from the very infancy of the empire is golden and sparkles in the sun.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Riches from the very infancy of the empire
# Description: The rich from the very infancy of the empire is golden and sparkles in the sun.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Riches from the very infancy of the empire
# Description: The rich from the very infancy of the empire is golden and sparkles in the sun.
# Property: is_container
# Boolean: False
# ###
#
# Item: Riches from the very infancy of the empire
# Description: The rich from the very infancy of the empire is golden and sparkles in the sun.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Riches from the very infancy of the empire
# Description: The rich from the very infancy of the empire is golden and sparkles in the sun.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Riches from the very infancy of the empire
# Description: The rich from the very infancy of the empire is golden and sparkles in the sun.
# Property: is_food
# Boolean: False
# ###
#
# Item: Painted walls as blue as the sea itself
# Description: The wall seems to be dirty and covered in graffiti
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Painted walls as blue as the sea itself
# Description: The wall seems to be dirty and covered in graffiti
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Painted walls as blue as the sea itself
# Description: The wall seems to be dirty and covered in graffiti
# Property: is_surface
# Boolean: False
# ###
#
# Item: Painted walls as blue as the sea itself
# Description: The wall seems to be dirty and covered in graffiti
# Property: is_container
# Boolean: False
# ###
#
# Item: Painted walls as blue as the sea itself
# Description: The wall seems to be dirty and covered in graffiti
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Painted walls as blue as the sea itself
# Description: The wall seems to be dirty and covered in graffiti
# Property: is_drink
# Boolean: False
# ###
#
# Item: Painted walls as blue as the sea itself
# Description: The wall seems to be dirty and covered in graffiti
# Property: is_food
# Boolean: False
# ###
#
# Item: Tables constructed of beautiful coral
# Description: The table has a history of it's own, full of color and scratches with each telling a tale
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Tables constructed of beautiful coral
# Description: The table has a history of it's own, full of color and scratches with each telling a tale
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Tables constructed of beautiful coral
# Description: The table has a history of it's own, full of color and scratches with each telling a tale
# Property: is_surface
# Boolean: True
# ###
#
# Item: Tables constructed of beautiful coral
# Description: The table has a history of it's own, full of color and scratches with each telling a tale
# Property: is_container
# Boolean: False
# ###
#
# Item: Tables constructed of beautiful coral
# Description: The table has a history of it's own, full of color and scratches with each telling a tale
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Tables constructed of beautiful coral
# Description: The table has a history of it's own, full of color and scratches with each telling a tale
# Property: is_drink
# Boolean: False
# ###
#
# Item: Tables constructed of beautiful coral
# Description: The table has a history of it's own, full of color and scratches with each telling a tale
# Property: is_food
# Boolean: False
# ###
#
# Item: Decorative shells
# Description: The shell looks clean and delicate.  it looks like it has been washed.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Decorative shells
# Description: The shell looks clean and delicate.  it looks like it has been washed.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Decorative shells
# Description: The shell looks clean and delicate.  it looks like it has been washed.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Decorative shells
# Description: The shell looks clean and delicate.  it looks like it has been washed.
# Property: is_container
# Boolean: False
# ###
#
# Item: Decorative shells
# Description: The shell looks clean and delicate.  it looks like it has been washed.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Decorative shells
# Description: The shell looks clean and delicate.  it looks like it has been washed.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Decorative shells
# Description: The shell looks clean and delicate.  it looks like it has been washed.
# Property: is_food
# Boolean: False
# ###
#
# Item: Ceiling
# Description: The ceiling is cracked, wet and stained.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Ceiling
# Description: The ceiling is cracked, wet and stained.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Ceiling
# Description: The ceiling is cracked, wet and stained.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Ceiling
# Description: The ceiling is cracked, wet and stained.
# Property: is_container
# Boolean: False
# ###
#
# Item: Ceiling
# Description: The ceiling is cracked, wet and stained.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Ceiling
# Description: The ceiling is cracked, wet and stained.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Ceiling
# Description: The ceiling is cracked, wet and stained.
# Property: is_food
# Boolean: False
# ###
#
# Item: Wares
# Description: The ware is old and cracked, but the inscriptions upon its' faces speak to the care taken during its' creation.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Wares
# Description: The ware is old and cracked, but the inscriptions upon its' faces speak to the care taken during its' creation.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Wares
# Description: The ware is old and cracked, but the inscriptions upon its' faces speak to the care taken during its' creation.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Wares
# Description: The ware is old and cracked, but the inscriptions upon its' faces speak to the care taken during its' creation.
# Property: is_container
# Boolean: False
# ###
#
# Item: Wares
# Description: The ware is old and cracked, but the inscriptions upon its' faces speak to the care taken during its' creation.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Wares
# Description: The ware is old and cracked, but the inscriptions upon its' faces speak to the care taken during its' creation.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Wares
# Description: The ware is old and cracked, but the inscriptions upon its' faces speak to the care taken during its' creation.
# Property: is_food
# Boolean: False
# ###
#
# Item: Stalls
# Description: He grabbed his horse from it's stall and proceeded to ride into the battle to reclaim his honor.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Stalls
# Description: He grabbed his horse from it's stall and proceeded to ride into the battle to reclaim his honor.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Stalls
# Description: He grabbed his horse from it's stall and proceeded to ride into the battle to reclaim his honor.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Stalls
# Description: He grabbed his horse from it's stall and proceeded to ride into the battle to reclaim his honor.
# Property: is_container
# Boolean: True
# ###
#
# Item: Stalls
# Description: He grabbed his horse from it's stall and proceeded to ride into the battle to reclaim his honor.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Stalls
# Description: He grabbed his horse from it's stall and proceeded to ride into the battle to reclaim his honor.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Stalls
# Description: He grabbed his horse from it's stall and proceeded to ride into the battle to reclaim his honor.
# Property: is_food
# Boolean: False
# ###
#
# Item: Colorful dyes
# Description: There are many leftover colorful dyes. these look like they would be good for coloring clothing.
# Property: is_gettable
# Boolean: True
# ###
#
# Item: Colorful dyes
# Description: There are many leftover colorful dyes. these look like they would be good for coloring clothing.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Colorful dyes
# Description: There are many leftover colorful dyes. these look like they would be good for coloring clothing.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Colorful dyes
# Description: There are many leftover colorful dyes. these look like they would be good for coloring clothing.
# Property: is_container
# Boolean: False
# ###
#
# Item: Colorful dyes
# Description: There are many leftover colorful dyes. these look like they would be good for coloring clothing.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Colorful dyes
# Description: There are many leftover colorful dyes. these look like they would be good for coloring clothing.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Colorful dyes
# Description: There are many leftover colorful dyes. these look like they would be good for coloring clothing.
# Property: is_food
# Boolean: False
# ###
#
# Item: Water
# Description: The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Water
# Description: The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Water
# Description: The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Water
# Description: The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven.
# Property: is_container
# Boolean: False
# ###
#
# Item: Water
# Description: The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Water
# Description: The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven.
# Property: is_drink
# Boolean: True
# ###
#
# Item: Water
# Description: The water was cool and clear, something was special about this water, water isn't usually this clean, and it tastes like heaven.
# Property: is_food
# Boolean: False
# ###
#
# Item: Pads
# Description: These pads are new, extra comfortable and easy to install in the leggings of armor
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Pads
# Description: These pads are new, extra comfortable and easy to install in the leggings of armor
# Property: is_weapon
# Boolean: True
# ###
#
# Item: Pads
# Description: These pads are new, extra comfortable and easy to install in the leggings of armor
# Property: is_surface
# Boolean: False
# ###
#
# Item: Pads
# Description: These pads are new, extra comfortable and easy to install in the leggings of armor
# Property: is_container
# Boolean: False
# ###
#
# Item: Pads
# Description: These pads are new, extra comfortable and easy to install in the leggings of armor
# Property: is_wearable
# Boolean: True
# ###
#
# Item: Pads
# Description: These pads are new, extra comfortable and easy to install in the leggings of armor
# Property: is_drink
# Boolean: False
# ###
#
# Item: Pads
# Description: These pads are new, extra comfortable and easy to install in the leggings of armor
# Property: is_food
# Boolean: False
# ###
#
# Item: Drainage pipe
# Description: A drainage pipe which may or may not be filled with unsanitary contents.
# Property: is_gettable
# Boolean: False
# ###
#
# Item: Drainage pipe
# Description: A drainage pipe which may or may not be filled with unsanitary contents.
# Property: is_weapon
# Boolean: False
# ###
#
# Item: Drainage pipe
# Description: A drainage pipe which may or may not be filled with unsanitary contents.
# Property: is_surface
# Boolean: False
# ###
#
# Item: Drainage pipe
# Description: A drainage pipe which may or may not be filled with unsanitary contents.
# Property: is_container
# Boolean: True
# ###
#
# Item: Drainage pipe
# Description: A drainage pipe which may or may not be filled with unsanitary contents.
# Property: is_wearable
# Boolean: False
# ###
#
# Item: Drainage pipe
# Description: A drainage pipe which may or may not be filled with unsanitary contents.
# Property: is_drink
# Boolean: False
# ###
#
# Item: Drainage pipe
# Description: A drainage pipe which may or may not be filled with unsanitary contents.
# Property: is_food
# Boolean: False
# ###

# %%
# !head fine_tuning_item_property.jsonl
# Out:
# {"prompt": "Item: River\nDescription: This river is strong, mighty, and full of fish that feed the nearby village. the river is wide and fast moving.\nProperty: is_gettable\n", "completion": "Boolean: False\n###\n"}
# {"prompt": "Item: River\nDescription: This river is strong, mighty, and full of fish that feed the nearby village. the river is wide and fast moving.\nProperty: is_weapon\n", "completion": "Boolean: False\n###\n"}
# {"prompt": "Item: River\nDescription: This river is strong, mighty, and full of fish that feed the nearby village. the river is wide and fast moving.\nProperty: is_surface\n", "completion": "Boolean: False\n###\n"}
# {"prompt": "Item: River\nDescription: This river is strong, mighty, and full of fish that feed the nearby village. the river is wide and fast moving.\nProperty: is_container\n", "completion": "Boolean: False\n###\n"}
# {"prompt": "Item: River\nDescription: This river is strong, mighty, and full of fish that feed the nearby village. the river is wide and fast moving.\nProperty: is_wearable\n", "completion": "Boolean: False\n###\n"}
# {"prompt": "Item: River\nDescription: This river is strong, mighty, and full of fish that feed the nearby village. the river is wide and fast moving.\nProperty: is_drink\n", "completion": "Boolean: True\n###\n"}
# {"prompt": "Item: River\nDescription: This river is strong, mighty, and full of fish that feed the nearby village. the river is wide and fast moving.\nProperty: is_food\n", "completion": "Boolean: False\n###\n"}
# {"prompt": "Item: Fish\nDescription: The fish is partially eaten, its thin bones poking out. it has been charred beyond recognition and smells a little bad. the fish is large\nProperty: is_gettable\n", "completion": "Boolean: True\n###\n"}
# {"prompt": "Item: Fish\nDescription: The fish is partially eaten, its thin bones poking out. it has been charred beyond recognition and smells a little bad. the fish is large\nProperty: is_weapon\n", "completion": "Boolean: True\n###\n"}
# {"prompt": "Item: Fish\nDescription: The fish is partially eaten, its thin bones poking out. it has been charred beyond recognition and smells a little bad. the fish is large\nProperty: is_surface\n", "completion": "Boolean: False\n###\n"}

# %%
# model name: babbage:ft-cis-700-48-2022-01-31-05-33-52
# model fine-tune: ft-TbxAayS2mnPrWoYI9sj0MpOd
# !openai api fine_tunes.create -t fine_tuning_item_property.jsonl -m babbage
# Out:
# [2022-01-31 05:08:23] Created fine-tune: ft-TbxAayS2mnPrWoYI9sj0MpOd
# [2022-01-31 05:08:33] Fine-tune costs $1.25
# [2022-01-31 05:08:34] Fine-tune enqueued. Queue number: 0
# [2022-01-31 05:08:36] Fine-tune started
# [2022-01-31 05:15:04] Completed epoch 1/4
# [2022-01-31 05:21:04] Completed epoch 2/4
# [2022-01-31 05:27:05] Completed epoch 3/4
# [2022-01-31 05:33:07] Completed epoch 4/4
# [2022-01-31 05:33:54] Uploaded model: babbage:ft-cis-700-48-2022-01-31-05-33-52
# [2022-01-31 05:33:57] Uploaded result file: file-Sx7SAlGFdZwD8gCmIvnMYhYT
# [2022-01-31 05:33:58] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m babbage:ft-cis-700-48-2022-01-31-05-33-52 -p <YOUR_PROMPT>

# %%
#@title Origianl code given by instructor (overcomplicated and thus abandoned)
def get_item_property(property_name, item_name, item_description, finetuned_model, property_description=""):
  if property_name == "is_gettable":
    return is_gettable(item_name, item_description, finetuned_model)
  elif property_name == "is_weapon":
    return is_weapon(item_name, item_description, finetuned_model)
  elif property_name == "is_surface":
    return is_surface(item_name, item_description, finetuned_model)
  elif property_name == "is_container":
    return is_container(item_name, item_description, finetuned_model)
  elif property_name == "is_wearable":
    return is_wearable(item_name, item_description, finetuned_model)
  elif property_name == "is_drink":
    return is_drink(item_name, item_description, finetuned_model)
  elif property_name == "is_food":
    return is_food(item_name, item_description, finetuned_model)
  else:
    pass

def is_gettable(item_name, item_description, finetuned_model, property_description="A player can pick this item up and add it to their inventory."):
    pass
#   response = openai.Completion.create(
#       model=finetuned_model,
#       prompt="Item: {item_name}\nDescription: {item_description}\nProperty: {property_description}\nBoolean:".format(
#           item_name=item_name.capitalize(),
#           item_description=item_description.capitalize(),
#           property_description=property_description.capitalize()
#       ),
#       temperature=0.7,
#       max_tokens=64,
#       top_p=1,
#       frequency_penalty=0,
#       presence_penalty=0,
#       stop=["###"]
#       )
#   return response['choices'][0]['text']

def is_weapon(item_name, item_description, finetuned_model, property_description="This item can be used as a weapon."):
  pass

def is_surface(item_name, item_description, finetuned_model, property_description="Another item can be placed on top of this item."):
  pass

def is_container(item_name, item_description, finetuned_model, property_description="Other items can be stored inside of this item."):
  pass

def is_wearable(item_name, item_description, finetuned_model, property_description="This item can be worn as an item of cloting."):
  pass

def is_drink(item_name, item_description, finetuned_model, property_description="This item is a liquid that can be drunk."):
  pass

def is_food(item_name, item_description, finetuned_model, property_description="This item can be eaten."):
  pass

# %%
def get_item_property(property_name, item_name, item_description, finetuned_model, temperature=0.7):
  response = openai.Completion.create(
      model=finetuned_model,
      prompt="Item: {item_name}\nDescroption: {item_description}\nProperty: {property_name}\nBoolean:".format(
          item_name=item_name.capitalize(),
          item_description=item_description.capitalize(),
          property_name=property_name
      ),
      temperature=temperature,
      max_tokens=64,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0,
      stop=["###"]
      )
  return response['choices'][0]['text']

finetuned_model = "babbage:ft-cis-700-48-2022-01-31-05-33-52"
property_name = "is_container"
item_name = "wooden bucket"
item_description = "The wooden bucket is well worn. It has been used to carry a variety of items and water over a period of many years."
# property_name = "is_gettable"
# item_name = "giant trees"
# item_description = "The giant tree is the center of the field and appears to be old enough to have seen the best years of the world's history."

property_boolean = get_item_property(property_name, item_name, item_description, finetuned_model)
print(property_boolean)
# Out:
#  True

# %% [markdown]
# # TODO: Generate A Game
#
# You now have all of the pieces that you need to generate a game!
#
# Build a game using your automatic methods, and then export it in the same JSON format as the LIGHT Environment Data.
#
# You'll upload your JSON file to Gradescope along with this notebook.
#
# If you'd like, you can build a game using the same theme and location names as the one that you did in HW1.

# %%
def get_reverse_direction(direction):
  prompt = "Given a direction, output the reverse of that direction: \nIn - Out\nUp - Down\nEast - West\nAscend - Descend\nGo in through the Gate - Exit the Gate\nClimb up the ladder - Descend the ladder\n"

  response = openai.Completion.create(
    engine="babbage",
    prompt=prompt + direction + " -",
    temperature=0,
    max_tokens=20,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0,
    stop=["\n"]
  )
  return response['choices'][0]['text']

get_reverse_direction("South")
# Out:
# ' North'

# %%
import random
from tqdm.notebook import tqdm

prompt = "Given a direction, output the reverse of that direction: \nIn - Out\nUp - Down\nEast - West\nAscend - Descend\nGo in through the Gate - Exit the Gate\nClimb up the ladder - Descend the ladder\n"

def get_reverse_direction(direction):
  response = openai.Completion.create(
    engine="babbage",
    prompt=prompt + direction + " -",
    temperature=0,
    max_tokens=20,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0,
    stop=["\n"]
  )
  return response['choices'][0]['text']

def build_game(category="Dark Forest", initial_location_names=[]):
  location_description_model = 'babbage:ft-cis-700-48-2022-01-29-03-34-26'
  items_at_location_model = 'babbage:ft-cis-700-48-2022-01-31-01-29-36'
  item_description_model = 'babbage:ft-cis-700-48-2022-01-31-02-09-12'
  connection_model = 'babbage:ft-cis-700-48-2022-01-31-05-56-21'
  item_preperties_model = 'babbage:ft-cis-700-48-2022-01-31-05-33-52'
  locations = {}
  items = {}
  location_id = 0
  item_id = 0
  print("generating items for locations ...")
  for location_name in tqdm(initial_location_names):
    location = {}
    location['setting'] = location_name.strip()
    location['description'] = get_location_description(category, location_name, location_description_model).strip()
    number_of_items = random.randint(0,20)
    item_names = get_items_at_location(category, location_name, location['description'], number_of_items, items_at_location_model)
    in_objects = []
    for item_name in item_names.split(", "):
      item = {}
      item['description'] = [get_item_description(category, item_name, item_description_model, location_name=location_name, location_description=location['description']).strip()]
      item['is_drink'] = 1.0 if get_item_property('is_drink', item_name, item['description'][0], item_preperties_model).strip() == 'True' else 0.0
      item['is_food'] = 1.0 if get_item_property('is_food', item_name, item['description'][0], item_preperties_model).strip() == 'True' else 0.0
      item['is_gettable'] = 1.0 if get_item_property('is_gettable', item_name, item['description'][0], item_preperties_model).strip() == 'True' else 0.0
      item['is_plural'] = 1.0 if get_item_property('is_plural', item_name, item['description'][0], item_preperties_model).strip() == 'True' else 0.0
      item['is_surface'] = 1.0 if get_item_property('is_surface', item_name, item['description'][0], item_preperties_model).strip() == 'True' else 0.0
      item['is_weapon'] = 1.0 if get_item_property('is_weapon', item_name, item['description'][0], item_preperties_model).strip() == 'True' else 0.0
      item['is_wearable'] = 1.0 if get_item_property('is_wearable', item_name, item['description'][0], item_preperties_model).strip() == 'True' else 0.0
      item['name'] = item_name.strip()
      in_objects.append(item)
    location['in_objects'] = in_objects
    location['neighbors'] = []
    locations[location_name.strip()] = location
  print("generating connections ...")
  for i in tqdm(range(len(initial_location_names) - 1)):
    location_name = initial_location_names[i]
    tuples = get_connections(category, location_name, locations[location_name]['description'], connection_model, initial_location_names[i+1:])
    tuples = [tuple(t.split(';')) for t in tuples.split('|')]
    for t in tuples:
      locations[location_name]['neighbors'].append({"direction": t[0].strip(), "destination": t[1].strip()})
      rev_direction = get_reverse_direction(t[0].strip()).strip()
      locations[t[1].strip()]['neighbors'].append({"direction": rev_direction, "destination": location_name})

  return {"categories": [category], "rooms": locations}
  # return game

def export_game_json(game, output_filename="my_gpt3_game.json"):
    idx = 0
    categories = {}
    for c in game['categories']:
        categories[idx] = c
        idx += 1
    rooms = {}
    objects = {}
    neighbors = {}
    for room_name in game['rooms']:
        object_ids = []
        for in_object in game['rooms'][room_name]['in_objects']:
            new_object = {}
            for attr in in_object:
                new_object[attr] = in_object[attr]
            new_object['object_id'] = idx
            objects[str(idx)] = new_object
            object_ids.append(idx)
            idx += 1
        neighbor_ids = []
        room_id = idx
        idx += 1
        for neighbor in game['rooms'][room_name]['neighbors']:
            new_neighbor = {}
            for attr in neighbor:
                new_neighbor[attr] = neighbor[attr]
            new_neighbor['room_id'] = room_id
            neighbors[str(idx)] = new_neighbor
            neighbor_ids.append(idx)
            idx += 1
        new_room = {}
        new_room['setting'] = game['rooms'][room_name]['setting']
        new_room['description'] = game['rooms'][room_name]['description']
        new_room['in_objects'] = object_ids
        new_room['neighbors'] = neighbor_ids
        new_room['room_id'] = room_id
        rooms[str(room_id)] = new_room

    data = {"categories": categories,
            "rooms": rooms,
            "neighbors": neighbors,
            "objects": objects}
    
    with open(output_filename, 'w') as output_file:
        json.dump(data, output_file)
        
    return data

# %%
game = build_game(category="magical realm", initial_location_names=['Cottage', 'Woods', 'Riverside', 'Dark Mountain', 'Rainbow Cloud', 'Time Machine'])
game
# Out:
# generating items for locations ...
#   0%|          | 0/6 [00:00<?, ?it/s]
# generating connections ...
#   0%|          | 0/5 [00:00<?, ?it/s]
# {'categories': ['magical realm'],
#  'rooms': {'Cottage': {'description': 'The magical realm is a cottage made of red brick. It is surrounded by a ring of magic that prevents evil from entering. A green candle lights its interior.',
#    'in_objects': [{'description': ['The brick has a bright red color and is very sturdy.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 1.0,
#      'is_wearable': 0.0,
#      'name': 'red brick'},
#     {'description': ['The candle is tall and white, and smells strongly of Cloves and Soy.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'green candle'},
#     {'description': ['The cottage is small and made of wood.  It looks like it could fit in a lot of people. The cottage is small and made of wood.  It looks like it could fit in a lot of space. The cottage is small and made of stone.  It looks like it could fit in a lot of'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'cottage'},
#     {'description': ['The ring of magic is covered in a fine layer of dust.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 1.0,
#      'name': 'ring of magic'}],
#    'neighbors': [{'destination': 'Dark Mountain', 'direction': 'east'}],
#    'setting': 'Cottage'},
#   'Dark Mountain': {'description': 'The dark mountain is covered in shadows. It is tall and thin, and it is dark. There are rocks on the surface, and darkness lies below.',
#    'in_objects': [{'description': ['You see the small rock has many sharp edges. The rock is plain and clearly had not been moved for some time, one side is covered in dirt while the other had a healthy coating of moss on it. The rocks are ready to catapult them and thus respond to the attack of the enemies that come to invade and plunder'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 1.0,
#      'is_wearable': 0.0,
#      'name': 'rocks'},
#     {'description': ['The shadow is dark and the shadow is long. The shadow is a decoy, put in place by those who would oppose you.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'shadows'},
#     {'description': ['You see the small rock has many sharp edges. The rock is plain and clearly had not been moved for some time, one side is covered in dirt while the other had a healthy coating of moss on it. The rocks are ready to catapult them and thus respond to the attack of the enemies that come to invade and plunder'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 1.0,
#      'is_surface': 0.0,
#      'is_weapon': 1.0,
#      'is_wearable': 0.0,
#      'name': 'rocks'},
#     {'description': ['The darkness is so dense that you can barely see the hand before yours. You would think that everyone would want to gaze into that darkness and never be seen again. The darkness is so thick that it is unable to be seen.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'darkness'},
#     {'description': ['The underground river is dark and murky.  Its waters must be dark as well, as they go undisturbed.'],
#      'is_drink': 1.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'underground river'}],
#    'neighbors': [{'destination': 'Cottage', 'direction': 'west'},
#     {'destination': 'Time Machine', 'direction': 'east'}],
#    'setting': 'Dark Mountain'},
#   'Rainbow Cloud': {'description': 'A cloud of pink and yellow rainbow smoke that sits in the sky.  It is the color of the rainbow that the landmass is covered in.  The landmass is covered in flowers and plants.',
#    'in_objects': [{'description': ["The smoke is thick and black, as if it hasn't seen light in ages."],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'rainbow smoke'},
#     {'description': ['The smoke is pink and yellow.  It smells like flowers and fruits.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'pink and yellow rainbow smoke'},
#     {'description': ['The landmass is large and surrounds the entire earth.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'landmass'},
#     {'description': ['These flowers grow tall behind the castle. They are medicinal and used in teas for the Kind and Queen. The flower smells like fresh lavender and has beautiful colors. The flower is majestic, a royal blue with a bright green stem. The flower is delicate and the petals are brightly colored. the flower is dry'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 1.0,
#      'name': 'flowers'},
#     {'description': ['The plant is wilted, trampled by marching soldiers. The plant is small and very green. It has tiny holes in the leaves. The plant has a green stalk , large yellow petals with a white center, and droops over under the flowers weight.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'plants'},
#     {'description': ['A dark and thick smoke that blocks out the light and reveals its secrets.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'smoke'}],
#    'neighbors': [{'destination': 'Time Machine', 'direction': 'past'}],
#    'setting': 'Rainbow Cloud'},
#   'Riverside': {'description': 'The river that runs through this area is clear and cold and crystal blue. The sun sparkles off the many gems that line the riverbanks.',
#    'in_objects': [{'description': ['This river is strong, mighty, and full of fish that feed the nearby village. The river is wide and fast moving.'],
#      'is_drink': 1.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'river'},
#     {'description': ['The gem is circular and gold with a silver center. The gem emits a white light.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 1.0,
#      'name': 'gems'},
#     {'description': ['The sun is a red giant and hotter than the fires of Sinai that burn for Months.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'sun'},
#     {'description': ['The riverbank is strong and mighty! The river is very clear and full of fish'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'riverbanks'},
#     {'description': ['The gem is delicate and clean.  It appears to be RUNAITE, the expensive type of steatite.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 1.0,
#      'name': 'many gems'},
#     {'description': ['This river is strong, mighty, and full of fish that feed the nearby village. The river is wide and fast moving.'],
#      'is_drink': 1.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'river'},
#     {'description': ['The cottage is small and cozy, with two rooms and a large fireplace.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'cottage'}],
#    'neighbors': [{'destination': 'Time Machine', 'direction': 'east'}],
#    'setting': 'Riverside'},
#   'Time Machine': {'description': 'The time machine is a fairly simple looking contraption. It is round and has a small opening near the top where you can put your hand. It has a small seat inside that you can place your body in. When you place your hand in the opening at the top of the time machine, you are transported back in',
#    'in_objects': [{'description': ['The opening is small in size and shape.  It may be used as a entrance for a small child.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'small opening'},
#     {'description': ['The seat is low and narrow, but it is sturdy.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 1.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'small seat'},
#     {'description': ['The time machine is gigantic, and seems to have only one trip setting. When you enter the time machine you feel as if you are leaving the past and going to a different time. The time machine is a simple wooden device.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'time machine'},
#     {'description': ['The seat is made of well worn leather and is slightly above the waist height of an ordinary adult.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 1.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'small seat'},
#     {'description': ["The door is heavy and creaks like the hinges can barely hold it's weight."],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'door'},
#     {'description': ["It may not be much, but it's shelter! You can't ask for much more than four walls and a roof over your head."],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'room'}],
#    'neighbors': [{'destination': 'Woods', 'direction': 'west'},
#     {'destination': 'Riverside', 'direction': 'west'},
#     {'destination': 'Dark Mountain', 'direction': 'west'},
#     {'destination': 'Rainbow Cloud', 'direction': 'future'}],
#    'setting': 'Time Machine'},
#   'Woods': {'description': 'The woods are a dark and mysterious place. The trees are so tall that they block the sunlight. The ground is covered in undergrowth that is too thick to penetrate. The birds are so quiet you can hear them laughing.',
#    'in_objects': [{'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ['The ground is fertile and well-watered. It is well-mown and in full shade.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 1.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'ground'},
#     {'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ['The ground is fertile and well-watered. It is populated by various plant life'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 1.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'ground'},
#     {'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ['The undergrowth is dense and hard to see through. There may be some wildlife living in it.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'undergrowth'},
#     {'description': ['The bird is cackling and c Heraldry: The bird is black and yellow, with red spots spreading across its chest.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'birds'}],
#    'neighbors': [{'destination': 'Time Machine', 'direction': 'east'}],
#    'setting': 'Woods'}}}

# %%
export_game_json(game, output_filename="my_gpt3_game.json")
# Out:
# {'categories': {0: 'magical realm'},
#  'neighbors': {'15': {'destination': 'Time Machine',
#    'direction': 'east',
#    'room_id': 14},
#   '24': {'destination': 'Time Machine', 'direction': 'east', 'room_id': 23},
#   '31': {'destination': 'Cottage', 'direction': 'west', 'room_id': 30},
#   '32': {'destination': 'Time Machine', 'direction': 'east', 'room_id': 30},
#   '40': {'destination': 'Time Machine', 'direction': 'past', 'room_id': 39},
#   '48': {'destination': 'Woods', 'direction': 'west', 'room_id': 47},
#   '49': {'destination': 'Riverside', 'direction': 'west', 'room_id': 47},
#   '50': {'destination': 'Dark Mountain', 'direction': 'west', 'room_id': 47},
#   '51': {'destination': 'Rainbow Cloud', 'direction': 'future', 'room_id': 47},
#   '6': {'destination': 'Dark Mountain', 'direction': 'east', 'room_id': 5}},
#  'objects': {'1': {'description': ['The brick has a bright red color and is very sturdy.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 1.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 1.0,
#    'is_wearable': 0.0,
#    'name': 'red brick',
#    'object_id': 1},
#   '10': {'description': ['The ground is fertile and well-watered. It is populated by various plant life'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 1.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'ground',
#    'object_id': 10},
#   '11': {'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'trees',
#    'object_id': 11},
#   '12': {'description': ['The undergrowth is dense and hard to see through. There may be some wildlife living in it.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'undergrowth',
#    'object_id': 12},
#   '13': {'description': ['The bird is cackling and c Heraldry: The bird is black and yellow, with red spots spreading across its chest.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'birds',
#    'object_id': 13},
#   '16': {'description': ['This river is strong, mighty, and full of fish that feed the nearby village. The river is wide and fast moving.'],
#    'is_drink': 1.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'river',
#    'object_id': 16},
#   '17': {'description': ['The gem is circular and gold with a silver center. The gem emits a white light.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 1.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 1.0,
#    'name': 'gems',
#    'object_id': 17},
#   '18': {'description': ['The sun is a red giant and hotter than the fires of Sinai that burn for Months.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'sun',
#    'object_id': 18},
#   '19': {'description': ['The riverbank is strong and mighty! The river is very clear and full of fish'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'riverbanks',
#    'object_id': 19},
#   '2': {'description': ['The candle is tall and white, and smells strongly of Cloves and Soy.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 1.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'green candle',
#    'object_id': 2},
#   '20': {'description': ['The gem is delicate and clean.  It appears to be RUNAITE, the expensive type of steatite.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 1.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 1.0,
#    'name': 'many gems',
#    'object_id': 20},
#   '21': {'description': ['This river is strong, mighty, and full of fish that feed the nearby village. The river is wide and fast moving.'],
#    'is_drink': 1.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'river',
#    'object_id': 21},
#   '22': {'description': ['The cottage is small and cozy, with two rooms and a large fireplace.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'cottage',
#    'object_id': 22},
#   '25': {'description': ['You see the small rock has many sharp edges. The rock is plain and clearly had not been moved for some time, one side is covered in dirt while the other had a healthy coating of moss on it. The rocks are ready to catapult them and thus respond to the attack of the enemies that come to invade and plunder'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 1.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 1.0,
#    'is_wearable': 0.0,
#    'name': 'rocks',
#    'object_id': 25},
#   '26': {'description': ['The shadow is dark and the shadow is long. The shadow is a decoy, put in place by those who would oppose you.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'shadows',
#    'object_id': 26},
#   '27': {'description': ['You see the small rock has many sharp edges. The rock is plain and clearly had not been moved for some time, one side is covered in dirt while the other had a healthy coating of moss on it. The rocks are ready to catapult them and thus respond to the attack of the enemies that come to invade and plunder'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 1.0,
#    'is_plural': 1.0,
#    'is_surface': 0.0,
#    'is_weapon': 1.0,
#    'is_wearable': 0.0,
#    'name': 'rocks',
#    'object_id': 27},
#   '28': {'description': ['The darkness is so dense that you can barely see the hand before yours. You would think that everyone would want to gaze into that darkness and never be seen again. The darkness is so thick that it is unable to be seen.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'darkness',
#    'object_id': 28},
#   '29': {'description': ['The underground river is dark and murky.  Its waters must be dark as well, as they go undisturbed.'],
#    'is_drink': 1.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'underground river',
#    'object_id': 29},
#   '3': {'description': ['The cottage is small and made of wood.  It looks like it could fit in a lot of people. The cottage is small and made of wood.  It looks like it could fit in a lot of space. The cottage is small and made of stone.  It looks like it could fit in a lot of'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'cottage',
#    'object_id': 3},
#   '33': {'description': ["The smoke is thick and black, as if it hasn't seen light in ages."],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'rainbow smoke',
#    'object_id': 33},
#   '34': {'description': ['The smoke is pink and yellow.  It smells like flowers and fruits.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'pink and yellow rainbow smoke',
#    'object_id': 34},
#   '35': {'description': ['The landmass is large and surrounds the entire earth.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'landmass',
#    'object_id': 35},
#   '36': {'description': ['These flowers grow tall behind the castle. They are medicinal and used in teas for the Kind and Queen. The flower smells like fresh lavender and has beautiful colors. The flower is majestic, a royal blue with a bright green stem. The flower is delicate and the petals are brightly colored. the flower is dry'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 1.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 1.0,
#    'name': 'flowers',
#    'object_id': 36},
#   '37': {'description': ['The plant is wilted, trampled by marching soldiers. The plant is small and very green. It has tiny holes in the leaves. The plant has a green stalk , large yellow petals with a white center, and droops over under the flowers weight.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 1.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'plants',
#    'object_id': 37},
#   '38': {'description': ['A dark and thick smoke that blocks out the light and reveals its secrets.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'smoke',
#    'object_id': 38},
#   '4': {'description': ['The ring of magic is covered in a fine layer of dust.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 1.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 1.0,
#    'name': 'ring of magic',
#    'object_id': 4},
#   '41': {'description': ['The opening is small in size and shape.  It may be used as a entrance for a small child.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'small opening',
#    'object_id': 41},
#   '42': {'description': ['The seat is low and narrow, but it is sturdy.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 1.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'small seat',
#    'object_id': 42},
#   '43': {'description': ['The time machine is gigantic, and seems to have only one trip setting. When you enter the time machine you feel as if you are leaving the past and going to a different time. The time machine is a simple wooden device.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'time machine',
#    'object_id': 43},
#   '44': {'description': ['The seat is made of well worn leather and is slightly above the waist height of an ordinary adult.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 1.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'small seat',
#    'object_id': 44},
#   '45': {'description': ["The door is heavy and creaks like the hinges can barely hold it's weight."],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'door',
#    'object_id': 45},
#   '46': {'description': ["It may not be much, but it's shelter! You can't ask for much more than four walls and a roof over your head."],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'room',
#    'object_id': 46},
#   '7': {'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'trees',
#    'object_id': 7},
#   '8': {'description': ['The ground is fertile and well-watered. It is well-mown and in full shade.'],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 1.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'ground',
#    'object_id': 8},
#   '9': {'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#    'is_drink': 0.0,
#    'is_food': 0.0,
#    'is_gettable': 0.0,
#    'is_plural': 0.0,
#    'is_surface': 0.0,
#    'is_weapon': 0.0,
#    'is_wearable': 0.0,
#    'name': 'trees',
#    'object_id': 9}},
#  'rooms': {'14': {'description': 'The woods are a dark and mysterious place. The trees are so tall that they block the sunlight. The ground is covered in undergrowth that is too thick to penetrate. The birds are so quiet you can hear them laughing.',
#    'in_objects': [7, 8, 9, 10, 11, 12, 13],
#    'neighbors': [15],
#    'room_id': 14,
#    'setting': 'Woods'},
#   '23': {'description': 'The river that runs through this area is clear and cold and crystal blue. The sun sparkles off the many gems that line the riverbanks.',
#    'in_objects': [16, 17, 18, 19, 20, 21, 22],
#    'neighbors': [24],
#    'room_id': 23,
#    'setting': 'Riverside'},
#   '30': {'description': 'The dark mountain is covered in shadows. It is tall and thin, and it is dark. There are rocks on the surface, and darkness lies below.',
#    'in_objects': [25, 26, 27, 28, 29],
#    'neighbors': [31, 32],
#    'room_id': 30,
#    'setting': 'Dark Mountain'},
#   '39': {'description': 'A cloud of pink and yellow rainbow smoke that sits in the sky.  It is the color of the rainbow that the landmass is covered in.  The landmass is covered in flowers and plants.',
#    'in_objects': [33, 34, 35, 36, 37, 38],
#    'neighbors': [40],
#    'room_id': 39,
#    'setting': 'Rainbow Cloud'},
#   '47': {'description': 'The time machine is a fairly simple looking contraption. It is round and has a small opening near the top where you can put your hand. It has a small seat inside that you can place your body in. When you place your hand in the opening at the top of the time machine, you are transported back in',
#    'in_objects': [41, 42, 43, 44, 45, 46],
#    'neighbors': [48, 49, 50, 51],
#    'room_id': 47,
#    'setting': 'Time Machine'},
#   '5': {'description': 'The magical realm is a cottage made of red brick. It is surrounded by a ring of magic that prevents evil from entering. A green candle lights its interior.',
#    'in_objects': [1, 2, 3, 4],
#    'neighbors': [6],
#    'room_id': 5,
#    'setting': 'Cottage'}}}

# %% [markdown]
# Another game of Dark Forest theme in comparison. This one is not the one saved.

# %%
game2 = build_game(category="Dark Forest", initial_location_names=['Cottage', 'Woods', 'Riverside', 'Dark Mountain', 'Rainbow Cloud', 'Time Machine'])
game2
# Out:
# generating items for locations ...
#   0%|          | 0/6 [00:00<?, ?it/s]
# generating connections ...
#   0%|          | 0/5 [00:00<?, ?it/s]
# {'categories': ['Dark Forest'],
#  'rooms': {'Cottage': {'description': 'The dark forest is a gloomy place. There are few lights and many shadows. The forest is very dense and hard to see because of the many trees.',
#    'in_objects': [{'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ['The light is a hexagon of glass panels with a metal top. It hangs from a blackened ceiling.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'lights'},
#     {'description': ['The shadow of a tree is cast on the ground by the sun. The shadow is growing shorter and shorter, showing that the tree is being cut down to make way for building project. The shadow is still reachable but getting smaller and smaller. It has a delicious smell of maple and a painful sight. The shadow is'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'shadows'},
#     {'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ['The house is large and yellow. The roof is red and sloped. The house is small and built of wood. The roof is that of an ox, and it is covered in carvings and crevices that reveal itself as you go up the stairs to the room on top. The house is small and'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'houses'},
#     {'description': ['The forest appears to contain tall trees and an underground lake.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'forest'},
#     {'description': ['The dense fog is obscuring the view.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'dense'},
#     {'description': ['The tree is too far away to see clearly.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'hardto see because of the many trees'}],
#    'neighbors': [{'destination': 'Time Machine', 'direction': 'North'}],
#    'setting': 'Cottage'},
#   'Dark Mountain': {'description': 'The dark forest is full of mysterious and dark things. The trees are thick and lush with moss. The ground is moist and dark.',
#    'in_objects': [{'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ['The moss is moist and feels soft. The moss covers everything, its green form is spongelike to the touch. The moss is vibrant green and very healthy.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'moss'},
#     {'description': ['The ground is littered with debris, including dirt, leaves, and rocks.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 1.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'ground'},
#     {'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ['The moss is moist and feels soft. The moss covers everything, its green form is spongelike to the touch. The moss is vibrant green and very healthy.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'moss'},
#     {'description': ['The ground is circular and cracked at the base.  It seems quite old, going back many years.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 1.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'ground'}],
#    'neighbors': [{'destination': 'Time Machine', 'direction': 'North'}],
#    'setting': 'Dark Mountain'},
#   'Rainbow Cloud': {'description': 'The forest is filled with beautiful colors of green and blue. There are many trees and plants that grow in the forest. The forest is full of animals that live in it. The forest is loud and full of life.',
#    'in_objects': [{'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ['The plant is wilted, trampled by marching soldiers. The plant is small and very green. It has tiny holes in the leaves. The plant has a green stalk , large yellow petals with a white center, and droops over under the flowers weight.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'plants'},
#     {'description': ['The animal is wild and must be kept in a shed at night. The animal is very large and is colored red, brown and yellow.'],
#      'is_drink': 0.0,
#      'is_food': 1.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'animals'}],
#    'neighbors': [{'destination': 'Time Machine', 'direction': 'Outside'}],
#    'setting': 'Rainbow Cloud'},
#   'Riverside': {'description': "The dark forest is a lit by only a few candle lit trees. The light shines in but doesn't reach the ground. There are some small animals that live here but don't like people to see them.",
#    'in_objects': [{'description': ['A wax object, with a wick, that can be set on fire, and used for light.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'candle'},
#     {'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ['Small and cuddly, the animal tiarra nuzzles its owner despite the rough bark.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'small animals'},
#     {'description': ['The tree is brightly lit up by the candle. The tree appears to be old and tall.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'candle lit trees'},
#     {'description': ['The animal is small and very observant.'],
#      'is_drink': 0.0,
#      'is_food': 1.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'some small animals'}],
#    'neighbors': [{'destination': 'Time Machine', 'direction': 'West'}],
#    'setting': 'Riverside'},
#   'Time Machine': {'description': 'The time machine is ajar, hanging from the ceiling by a chain. Inside, there is a large rotating dial that will take you back in time. There are chairs inside for people to sit in and watch the time pass on the dial.',
#    'in_objects': [{'description': ['The large rotating dial contains large, colored gems. The rotating action of the dial is what made it so special.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'large rotating dial'},
#     {'description': ['The chair is made out of sturdy wood. It is plain but well-built. The wooden chair is beginning to crack and come apart. The chair is worn with age, its seat and back rounded smooth from use.  It creaks as if it carries rheumatism in its glued points of contact. The'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'chairs'},
#     {'description': ["The time pass on the dial is getting closer to the 7 o'clock mark."],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'time pass on the dial'},
#     {'description': ['The chain is made of rusty metal. It is long and rusty.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 1.0,
#      'is_wearable': 0.0,
#      'name': 'chain'},
#     {'description': ['The dial is large and rotating it slowly gives you a good view of the time.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'large rotating dial'}],
#    'neighbors': [{'destination': 'Cottage', 'direction': 'South'},
#     {'destination': 'Woods', 'direction': 'South'},
#     {'destination': 'Riverside', 'direction': 'East'},
#     {'destination': 'Dark Mountain', 'direction': 'South'},
#     {'destination': 'Rainbow Cloud', 'direction': 'Inside'}],
#    'setting': 'Time Machine'},
#   'Woods': {'description': 'Dark and woody, the dark forest is filled with shadows and long dark lines that cut through the darkness. The trees loom over you, their thick branches blotting out the sun. The forest is creepy and dark, with the occasional scarecrow and spider web leading the way.',
#    'in_objects': [{'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ['The branch is torn and broken in several places.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 1.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'branches'},
#     {'description': ["The trees are monsterously large. The tree is old and extends far into the sky. It's far reaching branches cast a shadow to everything beneath it. The tree is split at the base and appears to be ready to fall. The tree is small and twisted.  It looks like it has been pummeled by"],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'trees'},
#     {'description': ["The branch is thick and twisted. You don't think it would support your weight."],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 1.0,
#      'is_wearable': 0.0,
#      'name': 'thick branches'},
#     {'description': ['The scarecrow is tall and has no face.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'scarecrow'},
#     {'description': ['The web is large and spooky.'],
#      'is_drink': 0.0,
#      'is_food': 0.0,
#      'is_gettable': 0.0,
#      'is_plural': 0.0,
#      'is_surface': 0.0,
#      'is_weapon': 0.0,
#      'is_wearable': 0.0,
#      'name': 'spider web'}],
#    'neighbors': [{'destination': 'Time Machine', 'direction': 'North'}],
#    'setting': 'Woods'}}}

# %% [markdown]
# # TODO: Evaluation
#
# An important part of NLP and machine learning is determining how good your models are.  It's very tricky to reliably evaluate generation output automatically.  For now, we'll evaluate the predictions of the model.
#
# For your model's attribute predictions, you should compute it's precision and recall for each attribute type on the LIGHT development data.

# %%
# !wget https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class-data/master/light_dialogue/light_environment_dev.json
# Out:
# --2022-01-31 03:01:27--  https://raw.githubusercontent.com/interactive-fiction-class/interactive-fiction-class-data/master/light_dialogue/light_environment_dev.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 485111 (474K) [text/plain]
# Saving to: ‘light_environment_dev.json’
#
# light_environment_d 100%[===================>] 473.74K  --.-KB/s    in 0.03s
#
# 2022-01-31 03:01:27 (17.5 MB/s) - ‘light_environment_dev.json’ saved [485111/485111]

# %%
f = open('light_environment_dev.json')
light_environment_dev = json.load(f)
# gold_standard_objects_by_property = sort_objects_by_property(light_environment_dev['objects'])
gold_standard_objects_by_property = sort_objects_by_property(light_environment_dev['objects'], thresh=0.5)

# %%
from tqdm.notebook import tqdm

def get_item_property_predictions(light_environment, finetuned_model, temperature):

  objects_by_property = defaultdict(set)
  all_objects = light_environment['objects']
  property_names = ["is_gettable", "is_weapon", "is_surface", "is_container", "is_wearable", "is_drink", "is_food"]

  for object_id, obj in tqdm(all_objects.items()):
    for property_name in property_names:
      item_name = obj['name']
      item_description = ' '.join(obj['descriptions'])
      property_boolean = get_item_property(property_name, item_name, item_description, finetuned_model, temperature)
      if property_boolean.strip() == 'True': 
        objects_by_property[property_name].add(str(object_id))    
  
  return objects_by_property


finetuned_model = "babbage:ft-cis-700-48-2022-01-31-05-33-52"
item_property_predictions_dev = get_item_property_predictions(light_environment_dev, finetuned_model, temperature=0.7)
item_property_predictions_dev_lower_temp = get_item_property_predictions(light_environment_dev, finetuned_model, temperature=0.1)
# Out:
#   0%|          | 0/251 [00:00<?, ?it/s]

# %%
from sklearn.metrics import precision_score, recall_score

# You can modify this function definition
def compute_precision_and_recall_for_each_properites(gold_standard_objects_by_property, predictions, property_names, light_environment):
  num = len(light_environment_dev['objects'].items())
  property_precisions, property_recalls = [], [] # the precision and recall w.r.t. each property, sorted as above
  for property_name in property_names:
    golds = [0 for _ in range(num)]
    preds = [0 for _ in range(num)]
    for i, (object_id, obj) in enumerate(light_environment_dev['objects'].items()):
      if object_id in gold_standard_objects_by_property[property_name]:
        golds[i] = 1
      if object_id in predictions[property_name]:
        preds[i] = 1 
    precision = precision_score(golds, preds)
    recall = recall_score(golds, preds)
    property_precisions.append(precision)
    property_recalls.append(recall)
  return property_precisions, property_recalls 

property_names = ["is_gettable", "is_weapon", "is_surface", "is_container", "is_wearable", "is_drink", "is_food"]
property_precisions, property_recalls  = compute_precision_and_recall_for_each_properites(gold_standard_objects_by_property, item_property_predictions_dev, property_names, light_environment_dev)
property_precisions_lower_temp, property_recalls_lower_temp  = compute_precision_and_recall_for_each_properites(gold_standard_objects_by_property, item_property_predictions_dev_lower_temp, property_names, light_environment_dev)

# %%
import numpy as np

# temperaute = 0.7
for property_name, p, r in zip(property_names, property_precisions, property_recalls):
  print(f'Property {property_name:<12}: precision={p:.2}, recall={r:.2}')
property_precisions_avg = np.array(property_precisions).mean()
property_recalls_avg = np.array(property_recalls).mean()
print(f'The mean of precision is {property_precisions_avg:.2}')
print(f'The mean of recall is {property_recalls_avg:.2}')
# Out:
# Property is_gettable : precision=0.89, recall=0.82
# Property is_weapon   : precision=0.85, recall=0.53
# Property is_surface  : precision=0.74, recall=0.48
# Property is_container: precision=0.69, recall=0.71
# Property is_wearable : precision=0.88, recall=0.64
# Property is_drink    : precision=0.67, recall=0.36
# Property is_food     : precision=0.75, recall=0.4
# The mean of precision is 0.78
# The mean of recall is 0.56

# %%
# lowe4 temperaute = 0.1
for property_name, p, r in zip(property_names, property_precisions_lower_temp, property_recalls_lower_temp):
  print(f'Property {property_name:<12}: precision={p:.2}, recall={r:.2}')
property_precisions_avg_lower_temp = np.array(property_precisions_lower_temp).mean()
property_recalls_avg_lower_temp = np.array(property_recalls_lower_temp).mean()
print(f'The mean of precision is {property_precisions_avg_lower_temp:.2}')
print(f'The mean of recall is {property_recalls_avg_lower_temp:.2}')
# Out:
# Property is_gettable : precision=0.89, recall=0.84
# Property is_weapon   : precision=0.85, recall=0.53
# Property is_surface  : precision=0.72, recall=0.5
# Property is_container: precision=0.68, recall=0.68
# Property is_wearable : precision=0.88, recall=0.68
# Property is_drink    : precision=0.67, recall=0.36
# Property is_food     : precision=0.8, recall=0.27
# The mean of precision is 0.78
# The mean of recall is 0.55

# %%
# latex
for property_name, p, r, pl, rl in zip(property_names, property_precisions, property_recalls, property_precisions_lower_temp, property_recalls_lower_temp):
  name = property_name.split('_')[1] 
  print(f'\\text{{is\\_{name}}} & {p:.2} & {pl:.2} & {round(pl-p,2):.2} & {r:.2} & {rl:.2} & {round(rl-r,2):.2} \\\\')
# Out:
# \text{is\_gettable} & 0.89 & 0.89 & 0.0 & 0.82 & 0.84 & 0.02 \\
# \text{is\_weapon} & 0.85 & 0.85 & 0.0 & 0.53 & 0.53 & 0.0 \\
# \text{is\_surface} & 0.74 & 0.72 & -0.01 & 0.48 & 0.5 & 0.02 \\
# \text{is\_container} & 0.69 & 0.68 & -0.01 & 0.71 & 0.68 & -0.03 \\
# \text{is\_wearable} & 0.88 & 0.88 & 0.01 & 0.64 & 0.68 & 0.05 \\
# \text{is\_drink} & 0.67 & 0.67 & 0.0 & 0.36 & 0.36 & 0.0 \\
# \text{is\_food} & 0.75 & 0.8 & 0.05 & 0.4 & 0.27 & -0.13 \\
